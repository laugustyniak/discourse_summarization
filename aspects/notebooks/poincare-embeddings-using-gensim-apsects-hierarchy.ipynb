# %% [markdown]
# # Imports and settings

# %%
# %load_ext autoreload
# %autoreload 2

import os
import logging
import numpy as np
import pandas as pd

from gensim.models.poincare import PoincareModel, PoincareKeyedVectors, PoincareRelations

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))

logging.basicConfig(level=logging.INFO)
# Out:
# <style>.container { width:90% !important; }</style>

# %%
from pathlib import Path

# %%
import spacy 
nlp = spacy.load('en')

# %%
from tqdm import tqdm  # for notebooks
tqdm.pandas()

# %% [markdown]
# # Load data and models

# %%
data_directory = Path('../results/reviews_Cell_Phones_and_Accessories/')
aspect_rules_file = os.path.join(data_directory, 'aspect-rules.csv')

# %%
aspect_df_min_10_times = pd.read_csv(data_directory / 'aspects_per_edu_filtered_min_10_freq.csv')
aspect_df_min_10_times.columns = ['aspect', 'count']

# %% [markdown]
# The model can be initialized using an iterable of relations, where a relation is simply a pair of nodes

# %%
aspect_df_min_10_times.shape
# Out:
# (946, 2)

# %%
aspect_df_min_10_times.head()
# Out:
#           aspect  count
# 0          price   6383
# 1       motorola   4246
# 2        battery   3925
# 3         amazon   2805
# 4  sound quality   2636

# %% [markdown]
# ## Unique aspects

# %%
len(aspect_df_min_10_times.aspect.unique())
# Out:
# 946

# %% [markdown]
# ## Get relations

# %%
aspect_rules_df = pd.read_csv(aspect_rules_file)
aspect_rules_df = aspect_rules_df[['id1', 'id2']]
aspect_rules_df.sample(2)
# Out:
#              id1      id2
# 2012  phone case  boxwave
# 2363      screen    nokia

# %%
aspect_rules_df.shape
# Out:
# (3651, 2)

# %% [markdown]
# ## Add aspects from ConceptNet

# %%
from aspects.enrichments import conceptnets

# %%
conceptnet = conceptnets.load_conceptnet_io()
# Out:
# INFO:aspects.enrichments.conceptnets:ConceptNet.io temp files will be load from: /home/laugustyniak/github/phd/sentiment-backend/aspects/data/conceptnet/conceptnet_io.pkl

# %% [markdown]
#  'car' -> 'HasPrerequisite' -> 'tire'

# %%
conceptnet['tire']
# Out:
# [{'end': 'active',
#   'end-lang': 'en',
#   'relation': 'Antonym',
#   'start': 'tire',
#   'start-lang': 'en',
#   'weight': 0.15},
#  {'end': 'bus_depot',
#   'end-lang': 'en',
#   'relation': 'AtLocation',
#   'start': 'tire',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'car',
#   'end-lang': 'en',
#   'relation': 'AtLocation',
#   'start': 'tire',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'car_show',
#   'end-lang': 'en',
#   'relation': 'AtLocation',
#   'start': 'tire',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'garage',
#   'end-lang': 'en',
#   'relation': 'AtLocation',
#   'start': 'tire',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'trunk',
#   'end-lang': 'en',
#   'relation': 'AtLocation',
#   'start': 'tire',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'get_leak',
#   'end-lang': 'en',
#   'relation': 'CapableOf',
#   'start': 'tire',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'need_attention_soon',
#   'end-lang': 'en',
#   'relation': 'CapableOf',
#   'start': 'tire',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'Causes',
#   'start': 'standing_up',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'Causes',
#   'start': 'tire',
#   'start-lang': 'en',
#   'weight': 2.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'Causes',
#   'start': 'tire',
#   'start-lang': 'en',
#   'weight': 2.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'DistinctFrom',
#   'start': 'energy',
#   'start-lang': 'en',
#   'weight': 0.173},
#  {'end': 'tear',
#   'end-lang': 'en',
#   'relation': 'EtymologicallyRelatedTo',
#   'start': 'tire',
#   'start-lang': 'en',
#   'weight': 0.25},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'FormOf',
#   'start': 'tired',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'FormOf',
#   'start': 'tires',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'FormOf',
#   'start': 'tires',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'FormOf',
#   'start': 'tirest',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'FormOf',
#   'start': 'tireth',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'FormOf',
#   'start': 'tiring',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'FormOf',
#   'start': 'tyre',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'north_america',
#   'end-lang': 'en',
#   'relation': 'HasContext',
#   'start': 'tire',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'HasPrerequisite',
#   'start': 'car',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'HasSubevent',
#   'start': 'competing_against',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'IsA',
#   'start': 'bicycle_tire',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'IsA',
#   'start': 'car_tire',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'IsA',
#   'start': 'car_tire',
#   'start-lang': 'en',
#   'weight': 2.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'IsA',
#   'start': 'exhaust',
#   'start-lang': 'en',
#   'weight': 2.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'IsA',
#   'start': 'overtire',
#   'start-lang': 'en',
#   'weight': 2.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'IsA',
#   'start': 'pirelli',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'IsA',
#   'start': 'pneumatic_tire',
#   'start-lang': 'en',
#   'weight': 2.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'IsA',
#   'start': 'poop_out',
#   'start-lang': 'en',
#   'weight': 2.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'IsA',
#   'start': 'retire',
#   'start-lang': 'en',
#   'weight': 2.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'IsA',
#   'start': 'snow_tire',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'wheel',
#   'end-lang': 'en',
#   'relation': 'IsA',
#   'start': 'tire',
#   'start-lang': 'en',
#   'weight': 2.0},
#  {'end': 'non_powered_device',
#   'end-lang': 'en',
#   'relation': 'IsA',
#   'start': 'tire',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'part_for_wheeled_vehicles',
#   'end-lang': 'en',
#   'relation': 'IsA',
#   'start': 'tire',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'hoop',
#   'end-lang': 'en',
#   'relation': 'IsA',
#   'start': 'tire',
#   'start-lang': 'en',
#   'weight': 2.0},
#  {'end': 'devolve',
#   'end-lang': 'en',
#   'relation': 'IsA',
#   'start': 'tire',
#   'start-lang': 'en',
#   'weight': 2.0},
#  {'end': 'indispose',
#   'end-lang': 'en',
#   'relation': 'IsA',
#   'start': 'tire',
#   'start-lang': 'en',
#   'weight': 2.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'IsA',
#   'start': 'wagon_tire',
#   'start-lang': 'en',
#   'weight': 2.0},
#  {'end': 'rubber',
#   'end-lang': 'en',
#   'relation': 'MadeOf',
#   'start': 'tire',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'rubber_and_latex',
#   'end-lang': 'en',
#   'relation': 'MadeOf',
#   'start': 'tire',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'automobile',
#   'end-lang': 'en',
#   'relation': 'PartOf',
#   'start': 'tire',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': "car's_wheel",
#   'end-lang': 'en',
#   'relation': 'PartOf',
#   'start': 'tire',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'car',
#   'end-lang': 'en',
#   'relation': 'PartOf',
#   'start': 'tire',
#   'start-lang': 'en',
#   'weight': 4.472},
#  {'end': 'filled_with_compressed_air',
#   'end-lang': 'en',
#   'relation': 'ReceivesAction',
#   'start': 'tire',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'found_on_car',
#   'end-lang': 'en',
#   'relation': 'ReceivesAction',
#   'start': 'tire',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'bead',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'bejade',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'bicycle_tire',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'blow_out',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'blowout',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'burn_out',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'burn_rubber',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'cake',
#   'start-lang': 'en',
#   'weight': 0.11},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'camelback',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'defatigable',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'dune_buggy',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'exhaust',
#   'start-lang': 'en',
#   'weight': 0.106},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'fag',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'fatigate',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'fatigue',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'fireplace',
#   'start-lang': 'en',
#   'weight': 0.115},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'flat',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'fortravel',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'hatter',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'high_wheeler',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'inflater',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'inner_tube',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'innertube',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'jade',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'knacker',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'lay_rubber',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'motor_vehicle',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'overtire',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'overweary',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'panic_rev',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'poop',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'pump',
#   'start-lang': 'en',
#   'weight': 0.224},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'rabbit',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'radial_tire',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'recap',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'resection',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'retread',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'rotation',
#   'start-lang': 'en',
#   'weight': 0.167},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'rubber',
#   'start-lang': 'en',
#   'weight': 0.448},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'rubber',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'shod',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'shoe',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'sidewall',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'sipe',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'slick',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'spare',
#   'start-lang': 'en',
#   'weight': 1.387},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'stagger',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'stinger',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'around',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'tire',
#   'start-lang': 'en',
#   'weight': 0.17},
#  {'end': 'around_wheel',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'tire',
#   'start-lang': 'en',
#   'weight': 0.17},
#  {'end': 'black',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'tire',
#   'start-lang': 'en',
#   'weight': 0.138},
#  {'end': 'car',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'tire',
#   'start-lang': 'en',
#   'weight': 0.319},
#  {'end': 'car_wheel',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'tire',
#   'start-lang': 'en',
#   'weight': 0.319},
#  {'end': 'donut',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'tire',
#   'start-lang': 'en',
#   'weight': 0.194},
#  {'end': 'doughnut',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'tire',
#   'start-lang': 'en',
#   'weight': 0.127},
#  {'end': 'exhausted',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'tire',
#   'start-lang': 'en',
#   'weight': 0.169},
#  {'end': 'inflatable',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'tire',
#   'start-lang': 'en',
#   'weight': 0.305},
#  {'end': 'inflatable_wheel',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'tire',
#   'start-lang': 'en',
#   'weight': 0.305},
#  {'end': 'on_wheel',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'tire',
#   'start-lang': 'en',
#   'weight': 0.227},
#  {'end': 'road',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'tire',
#   'start-lang': 'en',
#   'weight': 0.217},
#  {'end': 'round',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'tire',
#   'start-lang': 'en',
#   'weight': 0.285},
#  {'end': 'rubber',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'tire',
#   'start-lang': 'en',
#   'weight': 0.843},
#  {'end': 'rubber_round',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'tire',
#   'start-lang': 'en',
#   'weight': 0.135},
#  {'end': 'rubber_wheel',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'tire',
#   'start-lang': 'en',
#   'weight': 0.163},
#  {'end': 'tread',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'tire',
#   'start-lang': 'en',
#   'weight': 0.15},
#  {'end': 'weary',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'tire',
#   'start-lang': 'en',
#   'weight': 0.168},
#  {'end': 'wheel',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'tire',
#   'start-lang': 'en',
#   'weight': 1.569},
#  {'end': 'accessories',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'tire',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'accoutrements',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'tire',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'apron',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'tire',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'attire',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'tire',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'clothes',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'tire',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'dress',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'tire',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'locomotive',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'tire',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'pinafore',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'tire',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'railroad',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'tire',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'spare_tire',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'tire',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tier',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'tire',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire_yard',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'tire',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tyre',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'tire',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'rank',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'tire',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'row',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'tire',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tier',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'tire',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'bore',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'tire',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'bored',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'tire',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'impatient',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'tire',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'sleepy',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'tire',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tiresome',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'tire',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'weary',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'tire',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'adorn',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'tire',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'dress',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'tire',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tiring_house',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'tire',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'tire_pressure',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'tired',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'tired',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'tireless',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'tireless',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'tirelessly',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'tirelike',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'tiremaker',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'tires',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'tires',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'tiring',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'tiring',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'tiring',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'traction',
#   'start-lang': 'en',
#   'weight': 0.159},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'tread',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'treadwear',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'untiring',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'unwearying',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'upset',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'wear_up',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'wheel',
#   'start-lang': 'en',
#   'weight': 0.468},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'RelatedTo',
#   'start': 'whitewall',
#   'start-lang': 'en',
#   'weight': 1.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'Synonym',
#   'start': 'fag',
#   'start-lang': 'en',
#   'weight': 2.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'Synonym',
#   'start': 'fag_out',
#   'start-lang': 'en',
#   'weight': 2.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'Synonym',
#   'start': 'fatigue',
#   'start-lang': 'en',
#   'weight': 2.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'Synonym',
#   'start': 'jade',
#   'start-lang': 'en',
#   'weight': 2.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'Synonym',
#   'start': 'outwear',
#   'start-lang': 'en',
#   'weight': 2.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'Synonym',
#   'start': 'pall',
#   'start-lang': 'en',
#   'weight': 2.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'Synonym',
#   'start': 'tire',
#   'start-lang': 'en',
#   'weight': 0.5},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'Synonym',
#   'start': 'tire',
#   'start-lang': 'en',
#   'weight': 0.5},
#  {'end': 'bore',
#   'end-lang': 'en',
#   'relation': 'Synonym',
#   'start': 'tire',
#   'start-lang': 'en',
#   'weight': 2.0},
#  {'end': 'run_down',
#   'end-lang': 'en',
#   'relation': 'Synonym',
#   'start': 'tire',
#   'start-lang': 'en',
#   'weight': 2.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'Synonym',
#   'start': 'tire_out',
#   'start-lang': 'en',
#   'weight': 2.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'Synonym',
#   'start': 'tyre',
#   'start-lang': 'en',
#   'weight': 2.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'Synonym',
#   'start': 'wear',
#   'start-lang': 'en',
#   'weight': 2.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'Synonym',
#   'start': 'wear_down',
#   'start-lang': 'en',
#   'weight': 2.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'Synonym',
#   'start': 'wear_out',
#   'start-lang': 'en',
#   'weight': 2.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'Synonym',
#   'start': 'wear_upon',
#   'start-lang': 'en',
#   'weight': 2.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'Synonym',
#   'start': 'weary',
#   'start-lang': 'en',
#   'weight': 2.0},
#  {'end': 'tire',
#   'end-lang': 'en',
#   'relation': 'dbpedia',
#   'start': 'pirelli',
#   'start-lang': 'en',
#   'weight': 0.5}]

# %%
hierarchical_relations_parent_child = ['HasA', 'MadeOf', 'HasPrerequisite']
hierarchical_relations_child_parent = ['PartOf', 'IsA']

# %%
def get_neighbours_child_and_parents(conceptnet, concept, relation_types_get_child, relation_types_get_parent):
    neighbours_childs = set(
        (concept, concept_info['relation'], "---->", concept_info['end'])
        for concept_info
        in conceptnet[concept]
        if concept_info['relation'] in relation_types_get_child
    )
    neighbours_parents = set(
        (concept_info['start'], concept_info['relation'],  "<----", concept)
        
        for concept_info
        in conceptnet[concept]
        if concept_info['relation'] in relation_types_get_parent
    )

    return list(neighbours_childs.union(neighbours_parents))

# %%
get_neighbours_child_and_parents(conceptnet, 'tire', hierarchical_relations_child_parent, hierarchical_relations_parent_child)
# Out:
# [('tire', 'IsA', '---->', 'part_for_wheeled_vehicles'),
#  ('car', 'HasPrerequisite', '<----', 'tire'),
#  ('tire', 'IsA', '---->', 'hoop'),
#  ('tire', 'IsA', '---->', 'indispose'),
#  ('tire', 'IsA', '---->', 'non_powered_device'),
#  ('tire', 'PartOf', '---->', "car's_wheel"),
#  ('tire', 'IsA', '---->', 'tire'),
#  ('tire', 'IsA', '---->', 'wheel'),
#  ('tire', 'PartOf', '---->', 'car'),
#  ('tire', 'IsA', '---->', 'devolve'),
#  ('tire', 'MadeOf', '<----', 'tire'),
#  ('tire', 'PartOf', '---->', 'automobile')]

# %%
def get_concepts_based_on_hierarchy_relation(conceptnet, concept, relation_types_get_child, relation_types_get_parent):
    neighbours_childs = set(
        (concept_info['end'].replace('_', ' '), concept)
        for concept_info
        in conceptnet[concept]
        if concept_info['relation'] in relation_types_get_child
    )
    neighbours_parents = set(
        (concept_info['start'].replace('_', ' '), concept)
        for concept_info
        in conceptnet[concept]
        if concept_info['relation'] in relation_types_get_parent
    )

    return list(neighbours_childs.union(neighbours_parents))

# %%
get_concepts_based_on_hierarchy_relation(conceptnet, 'battery', hierarchical_relations_child_parent, hierarchical_relations_parent_child)
# Out:
# [('electrical component', 'battery'),
#  ('directed route', 'battery'),
#  ('using calculator', 'battery'),
#  ('battery', 'battery'),
#  ('voltage source', 'battery'),
#  ('source of current', 'battery'),
#  ('device stores energy chemically', 'battery'),
#  ('solar energy system', 'battery'),
#  ('collection', 'battery'),
#  ('electrical device', 'battery'),
#  ('artillery', 'battery'),
#  ('stamp mill', 'battery'),
#  ('team', 'battery'),
#  ('man made thing', 'battery'),
#  ('start car', 'battery'),
#  ('baseball team', 'battery'),
#  ('assault', 'battery'),
#  ('electrochemical cell', 'battery'),
#  ('power source', 'battery')]

# %% [markdown]
# ## Filter rules and aspects

# %%
aspect_rules_df = aspect_rules_df[aspect_rules_df.id1.isin(aspect_df_min_10_times.aspect.values) & aspect_rules_df.id2.isin(aspect_df_min_10_times.aspect.values)]

# %%
len(aspect_df_min_10_times.aspect.values)
# Out:
# 946

# %%
# aspect_rules_df.drop_duplicates(inplace=True)

# %%
relations = list(zip(aspect_rules_df.id2, aspect_rules_df.id1))

# %%
len(relations)
# Out:
# 2282

# %%
# relations

# %% [markdown]
# ### Add concepts from conceptnet

# %%
from more_itertools import flatten

# %%
conceptnet_relations = list(flatten([
    get_concepts_based_on_hierarchy_relation(conceptnet, aspect, hierarchical_relations_child_parent, hierarchical_relations_parent_child)
    for aspect
    in tqdm(aspect_df_min_10_times.aspect.values)
]))

# %%
len(conceptnet_relations)
# Out:
# 3099

# %%
all_relations = relations + conceptnet_relations

# %%
len(all_relations)
# Out:
# 4650

# %% [markdown]
# ## Filter aspects that are Named Entities [wrongly extracted during aspects extraction]

# %%
def is_named_entity(text):
    return True if nlp(text).ents else False

# %%
def is_named_entity(texts):
    return [
        text
        for text in texts
        if not nlp(text).ents   
    ]

# %%
nlp('amazon.com').ents
# Out:
# ()

# %%
is_named_entity((
    'amazon',
    'tire'
))
# Out:
# ['amazon', 'tire']

# %%
# aspect_rules_df = aspect_rules_df[~aspect_rules_df.progress_apply(lambda row: any([is_named_entity(row.id1), is_named_entity(row.id2)]), axis=1)]

# %%
# aspect_rules_df

# %% [markdown]
# ## Train or load pre-trained embedding

# %%
model = PoincareModel(train_data=all_relations, size=2, burn_in=0)
# Out:
# INFO:gensim.models.poincare:loading relations from train data..
# INFO:gensim.models.poincare:loaded 4650 relations from train data, 2707 nodes

# %%
model.train(epochs=100, print_every=500)
# Out:
# INFO:gensim.models.poincare:training model of size 2 with 1 workers on 4650 relations for 100 epochs and 0 burn-in epochs, using lr=0.10000 burn-in lr=0.01000 negative=10
# INFO:gensim.models.poincare:starting training (100 epochs)----------------------------------------
# INFO:gensim.models.poincare:training finished

# %%
# Saves the entire PoincareModel instance, the loaded model can be trained further
model.save('aspect_rules_model_with_conceptnet_relations')
# Out:
# INFO:gensim.utils:saving PoincareModel object under aspect_rules_model_with_conceptnet_relations, separately None
# INFO:gensim.utils:not storing attribute _node_probabilities
# INFO:gensim.utils:not storing attribute _node_counts_cumsum
# INFO:gensim.utils:saved aspect_rules_model_with_conceptnet_relations

# %%
model = PoincareModel.load('aspect_rules_model_with_conceptnet_relations')
# Out:
# INFO:gensim.utils:loading PoincareModel object from aspect_rules_model_with_conceptnet_relations
# INFO:gensim.utils:loading kv recursively from aspect_rules_model_with_conceptnet_relations.kv.* with mmap=None
# INFO:gensim.utils:setting ignored attribute _node_probabilities to None
# INFO:gensim.utils:setting ignored attribute _node_counts_cumsum to None
# INFO:gensim.utils:loaded aspect_rules_model_with_conceptnet_relations

# %% [markdown]
# # Experiment with embeddings distances and other attributes

# %%
model.kv.distance('battery life', 'battery')
# Out:
# 0.6535688230830381

# %%
model.kv.distance('case', 'battery')
# Out:
# 0.9756102605956604

# %%
model.kv.distance('phone', 'battery')
# Out:
# 0.7873491157117497

# %%
model.kv.distance('battery', 'phone')
# Out:
# 0.7873491157117497

# %%
model.kv.distance('battery', 'sound')
# Out:
# 0.9831219229245527

# %%
model.kv.most_similar('battery')
# Out:
# [('extended life battery', 0.03928540762000633),
#  ('durability', 0.06150953437530923),
#  ('bluetooth connection', 0.11546349192917825),
#  ('vonage', 0.12504089675208713),
#  ('car charger', 0.1310651807269191),
#  ('alltel', 0.13405388030240115),
#  ('krzr', 0.16060392675240817),
#  ('never', 0.16268109612134493),
#  ('voice dial', 0.19329367543601206),
#  ('at & t', 0.2023409538045585)]

# %%
model.kv.closest_child('battery')
# Out:
# 'extended life battery'

# %%
model.kv.closest_parent('battery')
# Out:
# 'durability'

# %%
model.kv.ancestors('phone')
# Out:
# ['touch screen',
#  'pictures',
#  'functions',
#  'ear speaker',
#  'interface',
#  'qwerty',
#  'features',
#  'wap',
#  'sync',
#  'ericson',
#  'samsung',
#  'camera quality',
#  'consume',
#  'electric blanket',
#  'cord',
#  'fashionable textile',
#  'volume unit',
#  'earbuds',
#  'adapter',
#  'earphone',
#  'protocol stack layer',
#  'mac']

# %%
model.kv.descendants('phone')
# Out:
# ['motorola droid', 'settings', 'color screen', 'cingular', 'sd']

# %%
# Saves only the vectors from the PoincareModel instance, in the commonly used word2vec format
# model.kv.save_word2vec_format('aspect_rules_vectors')
# PoincareKeyedVectors.load_word2vec_format('aspect_rules_vectors')

# %%
# Rank of distance of node 2 from node 1 in relation to distances of all nodes from node 1
model.kv.rank('phone', 'battery')
# Out:
# 133

# %%
# Closest child node
model.kv.closest_child('sound')
# Out:
# 'blackberry curve'

# %%
# Closest child node
model.kv.closest_parent('bluetooth')
# Out:
# 'screen quality'

# %%
# Difference in hierarchy between the first node and the second node
# Positive values indicate the first node is higher in the hierarchy
print(model.kv.difference_in_hierarchy('phone', 'battery'))
# Out:
# 0.0894106380464228

# %%
print(model.kv.difference_in_hierarchy('battery', 'battery life'))
# Out:
# -0.2588433525831279

# %%
model.kv.difference_in_hierarchy('bluetooth', 'headset')
# Out:
# 0.4335900804303457

# %%
model.kv.difference_in_hierarchy('charger', 'phone')
# Out:
# 0.14925883625996417

# %%
model.kv.difference_in_hierarchy('signal', 'phone')
# Out:
# -0.07389436421619844

# %%
# One possible descendant chain
model.kv.descendants('sound')
# Out:
# ['blackberry curve', 'priced', 'scosche', 'cardo scala', 'controls']

# %%
# One possible ancestor chain
model.kv.ancestors('sound')
# Out:
# ['body glove',
#  'sony',
#  'plug',
#  'droid',
#  'rma',
#  'dc',
#  'quantity',
#  'military company',
#  'blackberry 7100',
#  'scala',
#  'mac']

# %% [markdown]
# # Visualization

# %%
from gensim.viz.poincare import poincare_2d_visualization, poincare_distance_heatmap

# %%
all_relations = list(set(all_relations))

# %%
show_node_labels = ['battery', 'sound', 'bluetooth', 'headset', 'price', 'battery life', 'charging', 'charger', 'earphone']
filtered_set = set()
for relation in all_relations:
    if relation[0] in show_node_labels and relation[1] in show_node_labels:
        filtered_set.add(relation)

# %%
filtered_set
# Out:
# {('battery', 'battery'),
#  ('battery', 'battery life'),
#  ('battery', 'charger'),
#  ('battery', 'price'),
#  ('battery life', 'bluetooth'),
#  ('battery life', 'sound'),
#  ('bluetooth', 'battery life'),
#  ('bluetooth', 'price'),
#  ('bluetooth', 'sound'),
#  ('charger', 'price'),
#  ('charger', 'sound'),
#  ('headset', 'bluetooth'),
#  ('headset', 'headset'),
#  ('price', 'battery'),
#  ('price', 'battery life'),
#  ('price', 'bluetooth'),
#  ('price', 'charger'),
#  ('price', 'headset'),
#  ('price', 'price'),
#  ('price', 'sound'),
#  ('sound', 'battery life'),
#  ('sound', 'price'),
#  ('sound', 'sound')}

# %%
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# %%
init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
fig = poincare_2d_visualization(model, filtered_set, "Poincare Hierarchy", show_node_labels=show_node_labels)

# %%
iplot(fig)
# Out:
# <div id="c4671399-a98e-482b-930b-0d27543a059f" style="height: 800px; width: 800px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("c4671399-a98e-482b-930b-0d27543a059f", [{"type": "scatter", "x": [0.31501169535110396, 0.1263981461982086, null, 0.2292871073884045, 0.15905599006332935, null, 0.2292871073884045, 0.19614729462118619, null, 0.1263981461982086, -0.03285092641068917, null, 0.15905599006332935, 0.15905599006332935, null, 0.7076017062191675, 0.2292871073884045, null, 0.15905599006332935, 0.1263981461982086, null, 0.19614729462118619, -0.03285092641068917, null, 0.31501169535110396, 0.15905599006332935, null, 0.7076017062191675, 0.7076017062191675, null, 0.15905599006332935, 0.31501169535110396, null, -0.03285092641068917, 0.19614729462118619, null, 0.15905599006332935, 0.2292871073884045, null, 0.15905599006332935, -0.03285092641068917, null, -0.03285092641068917, 0.15905599006332935, null, 0.1263981461982086, 0.15905599006332935, null, 0.15905599006332935, 0.7076017062191675, null, 0.19614729462118619, 0.2292871073884045, null, 0.31501169535110396, 0.19614729462118619, null, 0.2292871073884045, -0.03285092641068917, null, 0.31501169535110396, 0.31501169535110396, null, -0.03285092641068917, -0.03285092641068917, null, 0.15905599006332935, 0.19614729462118619, null], "y": [0.4624262352845034, 0.2949118832645688, null, 0.19618327986598152, 0.2959104943902217, null, 0.19618327986598152, 0.2278965899423998, null, 0.2949118832645688, 0.2434994144914677, null, 0.2959104943902217, 0.2959104943902217, null, 0.20010716780897522, 0.19618327986598152, null, 0.2959104943902217, 0.2949118832645688, null, 0.2278965899423998, 0.2434994144914677, null, 0.4624262352845034, 0.2959104943902217, null, 0.20010716780897522, 0.20010716780897522, null, 0.2959104943902217, 0.4624262352845034, null, 0.2434994144914677, 0.2278965899423998, null, 0.2959104943902217, 0.19618327986598152, null, 0.2959104943902217, 0.2434994144914677, null, 0.2434994144914677, 0.2959104943902217, null, 0.2949118832645688, 0.2959104943902217, null, 0.2959104943902217, 0.20010716780897522, null, 0.2278965899423998, 0.19618327986598152, null, 0.4624262352845034, 0.2278965899423998, null, 0.19618327986598152, 0.2434994144914677, null, 0.4624262352845034, 0.4624262352845034, null, 0.2434994144914677, 0.2434994144914677, null, 0.2959104943902217, 0.2278965899423998, null], "mode": "line", "hoverinfo": false, "line": {"color": "rgb(50,50,50)", "width": 1}}, {"type": "scatter", "x": [-0.5785246499259131, -0.6018005868464905, -0.6822054492484009, 0.15428872936540422, 0.2292871073884045, -0.6720112358022803, -0.45672430895600813, 0.09376728529658762, -0.5022868272789021, 0.3769630220478835, 0.11247390350386081, -0.9729471753172991, 0.15905599006332935, 0.4536139590873027, 0.16814067877579086, 0.24198999080466083, 0.1481608628653006, 0.42991803163822573, 0.298522759613526, 0.31700113516969725, 0.31501169535110396, 0.4958233698211343, 0.03200996904988142, 0.15351419067488242, -0.03285092641068917, -0.23882212012156914, 0.19245721767251725, -0.5780940752670918, 0.1551394736194243, 0.6284713799406642, 0.29473669980289796, 0.40313393284633076, 0.05462598809514495, -0.033210227366020355, 0.07433417849124621, -0.10265519940720179, 0.20571977623734472, 0.18074525158365404, 0.027693143033007947, 0.03726548551716174, 0.0017684622896338624, -0.6791704761803736, -0.35706020617987794, 0.19650434225605778, 0.1750706662444499, -0.0193543294101232, -0.35186323441886685, 0.18159613593887158, 0.08196360936655021, -0.8274626613514621, 0.27837794940055927, 0.22433469016370342, 0.25017877095552454, 0.37527403907823126, 0.19614729462118619, 0.08934577323661022, 0.1263981461982086, 0.6575442039600773, 0.7472589954930366, 0.32452797495162855, 0.2067870089351646, 0.7546907036145405, -0.05463582590374535, 0.7582770696910152, 0.7669963180568499, -0.3 ...

# %%
iplot(fig, filename='poincare_viz_with_conceptnet_relations.png')
# Out:
# <div id="7262c25e-5975-4673-a0a7-f0bf5883f98d" style="height: 800px; width: 800px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("7262c25e-5975-4673-a0a7-f0bf5883f98d", [{"type": "scatter", "x": [0.15905599006332935, 0.31501169535110396, null, 0.15905599006332935, 0.7076017062191675, null, 0.31501169535110396, 0.42991803163822573, null, 0.15905599006332935, 0.2292871073884045, null, 0.15905599006332935, 0.15905599006332935, null, 0.2292871073884045, 0.15905599006332935, null, 0.42991803163822573, 0.42991803163822573, null, 0.15905599006332935, -0.03285092641068917, null, 0.2292871073884045, -0.03285092641068917, null, -0.03285092641068917, 0.15905599006332935, null, 0.7076017062191675, 0.2292871073884045, null, 0.31501169535110396, 0.31501169535110396, null, 0.42991803163822573, 0.31501169535110396, null, 0.15905599006332935, 0.42991803163822573, null, 0.42991803163822573, 0.2292871073884045, null, 0.42991803163822573, 0.15905599006332935, null, -0.03285092641068917, -0.03285092641068917, null, 0.31501169535110396, 0.15905599006332935, null, 0.7076017062191675, 0.7076017062191675, null], "y": [0.2959104943902217, 0.4624262352845034, null, 0.2959104943902217, 0.20010716780897522, null, 0.4624262352845034, 0.19020993397585273, null, 0.2959104943902217, 0.19618327986598152, null, 0.2959104943902217, 0.2959104943902217, null, 0.19618327986598152, 0.2959104943902217, null, 0.19020993397585273, 0.19020993397585273, null, 0.2959104943902217, 0.2434994144914677, null, 0.19618327986598152, 0.2434994144914677, null, 0.2434994144914677, 0.2959104943902217, null, 0.20010716780897522, 0.19618327986598152, null, 0.4624262352845034, 0.4624262352845034, null, 0.19020993397585273, 0.4624262352845034, null, 0.2959104943902217, 0.19020993397585273, null, 0.19020993397585273, 0.19618327986598152, null, 0.19020993397585273, 0.2959104943902217, null, 0.2434994144914677, 0.2434994144914677, null, 0.4624262352845034, 0.2959104943902217, null, 0.20010716780897522, 0.20010716780897522, null], "mode": "line", "hoverinfo": false, "line": {"color": "rgb(50,50,50)", "width": 1}}, {"type": "scatter", "x": [-0.5785246499259131, -0.6018005868464905, -0.6822054492484009, 0.15428872936540422, 0.2292871073884045, -0.6720112358022803, -0.45672430895600813, 0.09376728529658762, -0.5022868272789021, 0.3769630220478835, 0.11247390350386081, -0.9729471753172991, 0.15905599006332935, 0.4536139590873027, 0.16814067877579086, 0.24198999080466083, 0.1481608628653006, 0.42991803163822573, 0.298522759613526, 0.31700113516969725, 0.31501169535110396, 0.4958233698211343, 0.03200996904988142, 0.15351419067488242, -0.03285092641068917, -0.23882212012156914, 0.19245721767251725, -0.5780940752670918, 0.1551394736194243, 0.6284713799406642, 0.29473669980289796, 0.40313393284633076, 0.05462598809514495, -0.033210227366020355, 0.07433417849124621, -0.10265519940720179, 0.20571977623734472, 0.18074525158365404, 0.027693143033007947, 0.03726548551716174, 0.0017684622896338624, -0.6791704761803736, -0.35706020617987794, 0.19650434225605778, 0.1750706662444499, -0.0193543294101232, -0.35186323441886685, 0.18159613593887158, 0.08196360936655021, -0.8274626613514621, 0.27837794940055927, 0.22433469016370342, 0.25017877095552454, 0.37527403907823126, 0.19614729462118619, 0.08934577323661022, 0.1263981461982086, 0.6575442039600773, 0.7472589954930366, 0.32452797495162855, 0.2067870089351646, 0.7546907036145405, -0.05463582590374535, 0.7582770696910152, 0.7669963180568499, -0.3038708953380342, -0.23549844840542536, 0.11306441601531893, 0.12112980756968902, -0.3081484436213673, 0.3957254115455365, 0.14080962224282673, 0.3580682332173207, 0.3877022742982853, -0.20560670099081782, 0.5114653680899961, 0.23018190483833972, 0.32092123674799966, 0.10497348304166321, 0.002660537800500129, -0.13480488418969636, 0.4462248640583189, 0.14533452559681 ...

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
from plotly.graph_objs import  Bar, Layout, Figure
from plotly import __version__
from tqdm import tqdm_notebook
import numpy as np
import pandas as pd
from pathlib import Path
from typing import Iterable, Set
import sys
from IPython.core.display import display, HTML

display(HTML("<style>.container { width:100% !important; }</style>"))


# %matplotlib inline

sys.path.append('/home/laugustyniak/github/phd/sentiment-backend/')

from aspects.analysis import statistics_dataset
from aspects.analysis import nlp_architect

init_notebook_mode(connected=True)
# Out:
# <style>.container { width:100% !important; }</style>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# %%capture
from tqdm import tqdm_notebook as tqdm
tqdm().pandas()

# %% [markdown]
# # 2014

# %%
annotated_aspects = statistics_dataset.get_aspects()
# Out:
# Corpus iterator: 49475it [00:00, 437390.14it/s]
# Corpus iterator: 53781it [00:00, 863374.53it/s]
# Corpus iterator: 12470it [00:00, 749809.63it/s]
# Corpus iterator: 13257it [00:00, 736699.76it/s]

# %% [markdown]
# ## Unique aspects

# %%
pd.DataFrame([
    (k, len(set(v)))
    for k, v 
    in annotated_aspects.items()
], columns=['subset', 'unique_aspects'])
# Out:
#                     subset  unique_aspects
# 0  Restaurants_poria-train            1241
# 1      Laptops_poria-train             973
# 2       Laptops_poria-test             400
# 3   Restaurants_poria-test             530

# %% [markdown]
# ## Aspect intersection between train and test

# %%
annotated_aspects
# Out:
# {'Restaurants_poria-train': ['staff',
#   'food',
#   'food',
#   'kitchen',
#   'menu',
#   'food',
#   'perks',
#   'orrechiete with sausage and chicken',
#   'waiters',
#   'dish',
#   'meats',
#   'bagels',
#   'food',
#   'mayonnaise',
#   'toast',
#   'ingredients',
#   'cheese',
#   'omelet',
#   'bacon',
#   'plate',
#   'check',
#   'drinks',
#   'design',
#   'atmosphere',
#   'cuisine',
#   'pizza',
#   'thin crusted pizza',
#   'interior decoration',
#   'chefs',
#   'seats',
#   'seltzer with lime',
#   'pickles and',
#   'selection of meats and seafoods',
#   'eat family style',
#   'dishes',
#   'vibe',
#   'owner',
#   'service',
#   'delivery',
#   'food',
#   'atmosphere',
#   'service',
#   'food',
#   'prices',
#   'interior decor',
#   'prices',
#   'wine',
#   'price',
#   'service',
#   'quantity',
#   'sushi',
#   'sushi bar',
#   'fried rice',
#   'courses',
#   'mussels',
#   'puff pastry goat cheese',
#   'salad with a delicious dressing',
#   'a hanger steak au poivre',
#   'indian food',
#   'place',
#   'service',
#   'with',
#   'broth with noodles',
#   'meal',
#   'money',
#   'food',
#   'wine list',
#   'thai',
#   'thai food',
#   'glass of wine',
#   'specials',
#   'dine',
#   'lunch',
#   'dinner',
#   'atmosphere',
#   'service',
#   'desert',
#   'bar',
#   'table',
#   'dinner',
#   'service',
#   'food',
#   'atmosphere',
#   'environment',
#   'lasagnette appetizer',
#   'beer selection',
#   'food',
#   'menu',
#   'service',
#   'setting',
#   'dinner',
#   'dining',
#   'dosa',
#   'wine list selection',
#   'wine-by-the-glass',
#   'menu',
#   'menu',
#   'entrees',
#   'menu',
#   'dishes',
#   'sake martini',
#   'bagels',
#   'spreads',
#   'service',
#   'table',
#   'food',
#   'meal',
#   'ingredients',
#   'chopsticks',
#   'garden terrace',
#   'pizza',
#   'cuisine',
#   'atmosphere',
#   'crowded',
#   'service',
#   'dish',
#   'atmosphere',
#   'service',
#   'food',
#   'grilled branzino',
#   'wait staff',
#   'food',
#   'packed',
#   'vibe',
#   'french food',
#   'place',
#   'pizza',
#   'pre-theater menu',
#   'delivery',
#   'order',
#   'server',
#   'meal',
#   'scents',
#   'lobster sandwich',
#   'check',
#   'spider roll',
#   'shell crab',
#   'price',
#   'deep fried skewers',
#   'reservations',
#   'hostess',
#   'rice dishes',
#   'congee ( rice porridge )',
#   'tuna tartar appetizer',
#   'food',
#   'cuisine',
#   'fish dishes',
#   'soups',
#   'wine',
#   'cheese',
#   'french fare',
#   'indian food',
#   'baby pizzas',
#   'waiting',
#   'lava cake dessert',
#   'baby pizzas',
#   'service',
#   'food',
#   'managers',
#   'food',
#   'food',
#   'table',
#   'selection of wines',
#   'italian decor',
#   'food',
#   'dining experience',
#   'wine selection',
#   'reservation',
#   'service',
#   'reservation',
#   'maitre',
#   'panang duck',
#   'food',
#   'raw vegatables',
#   'service',
#   'indian',
#   'prices',
#   'ambiance',
#   'bbq salmon',
#   'sea bass',
#   'crispy duck',
#   'ingredients',
#   'ingredients',
#   'pizza',
#   'crust',
#   'dal bukhara',
#   'kababs',
#   'eating',
#   'taste',
#   'meal',
#   'price',
#   'glass of leaping lizard',
#   'glass of prosecco',
#   'mussels',
#   'food',
#   'creme brulee',
#   'sugar',
#   'food',
#   'served',
#   'pizza',
#   'pizza',
#   'garlic knots',
#   'delivery',
#   'chinese food',
#   'service',
#   'food',
#   'chef',
#   'service',
#   'teapot',
#   'pizza',
#   'fresh mozzarella',
#   'cheese',
#   'place',
#   'food',
#   'service',
#   'a',
#   'getting a table',
#   'atmosphere',
#   'bistro-type vibe',
#   'waitress',
#   'tables',
#   'food',
#   'prices',
#   'food',
#   'fish',
#   'variety of fish',
#   'of',
#   'meal',
#   'pesto pizza',
#   'house salad',
#   'bottle of wine',
#   'beverage manager',
#   'bartender',
#   'ambiance',
#   'music',
#   'food',
#   'drinks',
#   'service',
#   'food',
#   'refleshment',
#   'ambiance',
#   'service',
#   'sommlier',
#   'captain',
#   'back waiters',
#   'foods',
#   'tastes',
#   'waitress',
#   'tandoori salmon',
#   'atmosphere',
#   'space',
#   'service',
#   'atmorphere',
#   'service',
#   'menu items',
#   'three course meal',
#   'pizza',
#   'environment',
#   'food',
#   'service',
#   'crawfish boiled',
#   'reservation',
#   'table',
#   'pad thai',
#   'noodles',
#   'delivered',
#   'values for your money',
#   'lunch',
#   'hostess',
#   'food',
#   'wait building',
#   'corridor',
#   'space',
#   'counters',
#   'counter',
#   'entrees',
#   'food',
#   'steaks',
#   'salads',
#   'sides',
#   'lunch',
#   'pickels and slaw',
#   'wine',
#   'prices',
#   'delivered',
#   'the wine by the glass',
#   'price',
#   'dish',
#   'change mojito',
#   'service',
#   'food',
#   'service',
#   'food',
#   'soup for the udon',
#   'soy sauce',
#   'water',
#   'anti-pasta',
#   'calamari',
#   'filling pasta mains',
#   'waitress',
#   'glasses of wine',
#   'food',
#   'counter',
#   'food',
#   'sushi',
#   'ceviche mix ( special )',
#   'crab dumplings',
#   'assorted sashimi',
#   'sushi',
#   'rolls',
#   'sake',
#   'banana tempura',
#   'plain pizza',
#   'garlic',
#   'eggplant',
#   'servers',
#   'servers',
#   'getting a table',
#   'service',
#   'takeout menu',
#   'menu',
#   'italian dishes',
#   'thai food',
#   'hostess',
#   'pizza',
#   'bottles of wine',
#   'beers',
#   'food',
#   'dish',
#   'pumkin tortelini',
#   'dinner special',
#   'crabmeat lasagna',
#   'chocolate bread pudding',
#   'dessert',
#   'pasta dishes',
#   'tiramisu',
#   'service',
#   'prices',
#   'lunch',
#   'service',
#   'staff',
#   'menu',
#   'meal',
#   'bagel',
#   'food',
#   'servers',
#   'food',
#   'plate of dumplings',
#   'filet mignon',
#   'bar',
#   'sangria',
#   'bar',
#   'bartender',
#   'sake menu',
#   'drinks',
#   'beef cubes',
#   'service',
#   'wine selection',
#   'ambiance',
#   'reservations',
#   'service',
#   'service',
#   'waiters',
#   'food',
#   'portions',
#   'dessert',
#   'traffic noise',
#   'food',
#   'food',
#   'ambience',
#   'service',
#   'dinner meeting',
#   'atmosphere',
#   'food',
#   'cantonese',
#   'cooking',
#   'food',
#   'atmosphere',
#   'prix fixe menu',
#   'quantity',
#   'quality',
#   'lunch',
#   'eggs benedict',
#   'brunch',
#   'hollondaise sauce',
#   'oatmeal',
#   'food',
#   'menu',
#   'chilean sea bass',
#   'server',
#   'specials',
#   'food',
#   'onion soup',
#   'wine',
#   'staff',
#   'dinner',
#   'dim sum',
#   'roll',
#   'roll',
#   'roll',
#   'rice',
#   'gin and tonic',
#   'tonic',
#   'dim sum',
#   'little dishes',
#   'service',
#   'thai',
#   'reservation',
#   'grilled chicken special with edamame puree',
#   'roast duck',
#   'pork',
#   'chicken on rice with ginger',
#   'menu',
#   'staff',
#   'reservation',
#   'dinner',
#   'sake',
#   'portion',
#   'dishes',
#   'food',
#   'service',
#   'roti rolls',
#   'ingredients',
#   'meal',
#   'tip',
#   'food',
#   'service',
#   'meat',
#   'hot dogs',
#   'delivery',
#   'noise level',
#   'personal pans',
#   'spicy fried clam rolls',
#   'spider rolls',
#   'menu',
#   'atmosphere',
#   'place',
#   'food',
#   'lunch',
#   'food quality',
#   'man',
#   'table',
#   'table',
#   'cheesecake',
#   'food',
#   'manager',
#   'employees for',
#   'containers for condiments',
#   'containers',
#   'indian food',
#   'service',
#   'decor',
#   'food',
#   'wine list',
#   'food',
#   'salmon dish',
#   'price',
#   'flavor',
#   'tuna melt',
#   'cheese',
#   'tuna sandwich',
#   'chicken tikka',
#   'naan',
#   'dals',
#   'waiters',
#   'bill',
#   'lawns',
#   'staff',
#   'sangria',
#   'thai food',
#   'food',
#   'service',
#   'ravioli',
#   'menu',
#   'service',
#   'bill',
#   'lunch',
#   'drinks',
#   'sushi',
#   'food',
#   'service',
#   'price tag',
#   'thai food',
#   'appetizers',
#   'service',
#   'mozzarella',
#   'pie',
#   'fish',
#   'main dining room',
#   'ceiling',
#   'menu selections',
#   'service',
#   'music',
#   'establishment',
#   'dim sum',
#   'food',
#   'wait staff',
#   'dim sum',
#   'service',
#   'seafood dishes',
#   'appetizers',
#   'lunch',
#   'dinner',
#   'grapes',
#   'bottle of wine',
#   'prices',
#   'thai food',
#   'dish',
#   'staples',
#   'burger',
#   'pastas',
#   'food',
#   'dim sum',
#   'food',
#   'waitress',
#   'place',
#   'seating',
#   'bar',
#   'dinner',
#   'music',
#   'food',
#   'service',
#   'prices',
#   'wait',
#   'lobster sandwich',
#   'price',
#   'owner',
#   'sides',
#   'seafood',
#   'menu',
#   'salmon',
#   'place',
#   'beverages',
#   'dessert',
#   'hostess',
#   'waitress',
#   'asian appetizers',
#   'drinks',
#   'wait',
#   'view',
#   'meal',
#   'dinner',
#   'ambiance',
#   'food',
#   'service',
#   'prices',
#   'atmosphere',
#   'value',
#   'sushi',
#   'service',
#   'served',
#   'service',
#   'service',
#   'attitude',
#   'food',
#   'striped bass',
#   'music',
#   'corriander',
#   'black white shakes',
#   'meal',
#   'dinner',
#   'seating',
#   'chu chu curry',
#   'pad thai chicken',
#   'prix fixe',
#   'food',
#   'pastrami',
#   'soups',
#   'bagels',
#   'sushi',
#   'bagel with lox spread',
#   'bagles',
#   'food',
#   'quality of food',
#   'lobby area',
#   'seated',
#   'pizza',
#   'proprietor',
#   'lunch meetings',
#   'decor',
#   "food's presentation",
#   'prices',
#   'waitstaff',
#   'swordfish',
#   'meal',
#   'setting',
#   'management',
#   'service',
#   'seating',
#   'delivery',
#   'sushi',
#   'desserts',
#   'italian food',
#   'service',
#   'food',
#   'salmon dish',
#   'rolls',
#   'food',
#   'decor',
#   'prices',
#   'owner',
#   'lunch',
#   'dinner',
#   'moules',
#   'lobster ravioli',
#   'eat',
#   'dosa',
#   'atmosphere',
#   'waiters',
#   'seafood',
#   'wine list',
#   'menu',
#   'wine',
#   'indian',
#   'wine list',
#   'wines',
#   'pastrami or corned beef',
#   'rye bread',
#   'glasses of champagne',
#   'bottle of wine',
#   'after dinner drinks',
#   'seasoning',
#   'food',
#   'food',
#   'waitress',
#   'food',
#   'ambience',
#   'service',
#   'wine list',
#   'staff',
#   'owners',
#   'menu',
#   'people',
#   'menu',
#   'waiter',
#   'specials',
#   'main dishes',
#   'location',
#   'ambience',
#   'food',
#   'stuff',
#   'eats',
#   'dinner',
#   'gourmet food',
#   'bruschetta',
#   'dishes',
#   'menu',
#   'service',
#   'waitress',
#   'and',
#   'and',
#   'the fried mini buns with the condensed milk and the assorted fruits on beancurd',
#   'food',
#   'prices',
#   'food',
#   'sushi',
#   'portions',
#   'servers',
#   'starter',
#   'bagels',
#   'food',
#   'pizza',
#   'take-out pizza',
#   'server',
#   'green curry with vegetables',
#   'place',
#   'door',
#   'priced',
#   'food',
#   'portioins',
#   'reservation',
#   'pad thai',
#   'lunch specials',
#   'place',
#   'pizzas',
#   'food',
#   'pot-stickers',
#   'tempura dish',
#   'stuff',
#   'entree range',
#   'food',
#   'range',
#   'atmosphere',
#   'french food',
#   'deliveries',
#   'food',
#   'staff',
#   'portions',
#   'staff',
#   'smoked salmon and roe appetizer and',
#   'lunch',
#   'food',
#   'garlic shrimp',
#   'okra ( bindi )',
#   'lamb',
#   'waiter',
#   'menu',
#   'burger',
#   'steak',
#   'escargot',
#   'plate',
#   'food',
#   'casual dinner',
#   'food',
#   'price',
#   'wine list',
#   'prices',
#   'chicken tikka marsala',
#   'styles of pizza',
#   'look',
#   'food',
#   'portions',
#   'coconut rice',
#   'appetizer',
#   'food',
#   'food',
#   'beers on tap',
#   'priced wine list',
#   'music',
#   'bottle minimun',
#   'food',
#   'spot',
#   'staff',
#   'meal',
#   'table',
#   'quality of food',
#   'price',
#   'pork',
#   'fish',
#   'chicken',
#   'lamb',
#   'vegetables',
#   'place',
#   'seating',
#   'appetizing',
#   'price',
#   'bun',
#   'food',
#   'priced',
#   'fusion of french and indian cooking',
#   'turnip cake',
#   'roast pork buns',
#   'egg custards',
#   'bagels',
#   'the',
#   'seating in the garden',
#   'the seats',
#   'water',
#   'service',
#   'place',
#   'food',
#   'place',
#   'food options',
#   'cost',
#   'pre-theatre 3 - course dinner',
#   'wine flight',
#   'lunch',
#   'dinner',
#   'calzones',
#   'drink',
#   'place',
#   'bar scene',
#   'staff',
#   'spreads',
#   'beverage selections',
#   'bagels',
#   'waiter',
#   'served',
#   'specials',
#   'meal',
#   'tiramisu',
#   'secret back room',
#   'bar',
#   'food',
#   'service',
#   'gulab jamun',
#   'prices',
#   'atmosphere',
#   'service',
#   'wine list',
#   'diner',
#   'table',
#   'wait staff',
#   'meal',
#   'room',
#   'dinner',
#   'desserts',
#   'in',
#   'in',
#   'desserts with frog jelly in',
#   'pig feet ginger simmered in black vinegar',
#   'food',
#   'priced',
#   'thai cuisine',
#   'host',
#   'crew',
#   'round tables',
#   'taiwanese',
#   'portion',
#   'french fries',
#   'dinner',
#   'food',
#   'specials',
#   'regular menu-fare',
#   'dishes',
#   'prices',
#   'fresh tomato sauce',
#   'fresh mozz cheese',
#   'basil',
#   'dough',
#   'flour',
#   'food',
#   'indian food',
#   'paneer roll',
#   'food',
#   'plates',
#   'fresh mozzerella slices',
#   'plain cheese slice',
#   'food',
#   'food',
#   'food',
#   'filet mignon with garlic mash',
#   'pre-theater menu',
#   'roasted tomato soup with chevre',
#   'steak frites',
#   'creme brulee',
#   'waitstaff',
#   'bread',
#   'and',
#   'pizza',
#   'and',
#   "peter's favourite pizza with prosciutto and baby arugula",
#   'margarite pizza with cold prosciutto and baby arugula on top',
#   'salad',
#   'prices',
#   'bruschettas',
#   'paninis',
#   'tramezzinis',
#   'waiters',
#   'diners',
#   'chef',
#   'cuisine',
#   'dishes',
#   'indian',
#   'owner',
#   'food',
#   'meal',
#   'pre-theater prix-fixe',
#   'dining',
#   'food',
#   'wine',
#   'menu',
#   'fried chicken',
#   'pork chop',
#   'noodle dishes',
#   'indian food',
#   'place',
#   'corner booth table',
#   'privacy',
#   'open faced cheese sandwich',
#   'manager',
#   'breads',
#   'naan',
#   'half-price saturday night option',
#   'squid',
#   'pizza',
#   'homemade pasta',
#   'value ofr money',
#   'soup',
#   'mushrooms',
#   'service',
#   'waiting',
#   'beginning appetizers',
#   'scallops',
#   'chocolate souffle with rasberry mint sorbet',
#   'taste',
#   'japanese tapas',
#   'fish',
#   'rice',
#   'seaweed',
#   'dishes',
#   'lamb sausages',
#   'sardines with biscuits',
#   'large whole shrimp',
#   'pistachio ice cream',
#   'food',
#   'price',
#   'ambiance',
#   'atmosphere',
#   'food',
#   'service',
#   'server',
#   'served',
#   'food',
#   'drinks',
#   'food',
#   'sushi',
#   'thai food',
#   'chef',
#   'table',
#   'service',
#   'sauce on the pizza',
#   'garlic',
#   'fresh tomatoes',
#   'outdoor seating',
#   'mesclun',
#   'salmon',
#   'ice cream',
#   'courses',
#   'wait',
#   'food',
#   'place',
#   'staff',
#   'bistro fare',
#   'jazz brunch',
#   'live jazz',
#   'chilaquiles',
#   'prices',
#   'bill',
#   'measures of liquers',
#   'of',
#   'table service',
#   'service',
#   'thai food',
#   'food',
#   'pork belly',
#   'fat',
#   'food',
#   'tables',
#   'place',
#   'dinner',
#   'pizza',
#   'bar',
#   'service',
#   'lamb chop',
#   'salads',
#   'lemon',
#   'extra virgnin olive oil',
#   'sushi',
#   'meal',
#   'cost',
#   'dishes',
#   'pastrami sandwich',
#   'pickles',
#   'beer',
#   'plain pizza',
#   'wild mushroom ( third generation-fornini ) pizza',
#   'truffle oil',
#   '(',
#   ')',
#   'omelletes',
#   'tip',
#   'lunch',
#   'dinner',
#   'counter',
#   'sushi fix',
#   'fish',
#   'service',
#   'waitress',
#   'table',
#   'reservation sigh',
#   'food',
#   'place',
#   'menu',
#   'food art',
#   'outdoor atmosphere',
#   'toppings',
#   'pizza',
#   'service',
#   'food',
#   'price',
#   'thai food',
#   'bagels',
#   'bills',
#   'scallion pancakes',
#   'fried dumplings',
#   'appetizers',
#   'salads',
#   'steak',
#   'pasta',
#   'table',
#   'served dishes',
#   'table',
#   'served',
#   'bill',
#   'service',
#   'food',
#   'dumpling',
#   'fondue appetizer',
#   'spice',
#   'octopus salad',
#   'msg cooking',
#   'foods',
#   'tom kha soup',
#   'bombay beer',
#   'decor',
#   'semi-private boths',
#   'dining hall',
#   'service',
#   'service',
#   ...],
#  'Laptops_poria-train': ['cord',
#   'battery life',
#   'tech guy',
#   'service center',
#   '" sales " team',
#   'quality',
#   'gui',
#   'applications',
#   'use',
#   'start up',
#   'features',
#   'ichat',
#   'photobooth',
#   'garage band',
#   'features',
#   'gui',
#   'screen',
#   'power light',
#   'hard drive light',
#   'battery',
#   'rubber enclosure',
#   'edge',
#   'multi-touch gestures',
#   'tracking area',
#   'external mouse',
#   'gaming',
#   'suite of software',
#   'speed',
#   'windows 7',
#   'usb devices',
#   'keyboard',
#   'software',
#   'system',
#   'microsoft office for the mac',
#   'syncing',
#   '30 " hd monitor',
#   'screen',
#   'boot up',
#   'service',
#   'battery',
#   'operating system',
#   'preloaded software',
#   'price',
#   'features',
#   'clock in bios setup',
#   'warranty service',
#   'brand',
#   'warranty',
#   'features',
#   'fan',
#   'customer service number',
#   'warranty',
#   'talking to a technician',
#   'hard disc',
#   'windows',
#   'drivers',
#   'drivers',
#   'bios update',
#   'system',
#   'hp technical support',
#   'browser',
#   'keyboard',
#   'virus scan',
#   '9 punds',
#   'program',
#   'warrenty',
#   'toshiba',
#   'toshiba warranty',
#   'quality',
#   'webcam',
#   'value',
#   'internet',
#   'managing personal files',
#   'motherboard',
#   'system',
#   'charger',
#   'hardware',
#   'force quit',
#   'works',
#   'windows 7',
#   'vmware program',
#   'navigate',
#   'operating system',
#   'find files',
#   'runs',
#   'warrenty',
#   'extended warranty',
#   'memory',
#   'performace',
#   'speed',
#   'opening my documents folder',
#   'operating systems',
#   'charger',
#   'speed',
#   'glass touchpad',
#   'hard drive',
#   'mother board',
#   'external speaker',
#   'sound',
#   'battery life',
#   'hardware',
#   'shipping',
#   'use',
#   'mac software',
#   'microsoft software',
#   'editing',
#   'delete key',
#   'use',
#   'service',
#   'phone assistance',
#   'genius bar',
#   'battery life',
#   'web browsing',
#   'word editing',
#   'gaming',
#   'movie playing',
#   'battery life',
#   'recovery discs',
#   'office max\'s " max assurance "',
#   '"',
#   '"',
#   'imac backup disc',
#   'usb',
#   'battery life',
#   'battery timer',
#   'temperatures',
#   'core processing unit temperatures',
#   'service',
#   'virus protection for mac',
#   'bluetooth',
#   'lg notebook service center',
#   'hinge',
#   'games',
#   'responds',
#   'motherboard',
#   'motherboard',
#   'hardware',
#   'motherboard',
#   'use',
#   'representive at microsoft',
#   'system',
#   'xp',
#   'windows 7',
#   'vista',
#   'keyboard',
#   "dell's customer disservice",
#   'cooling system',
#   'use',
#   'quad core i7',
#   'sales associate',
#   'system',
#   'windows applications',
#   'virus program',
#   'weighed',
#   'seven pounds',
#   'battery',
#   'bag',
#   'color',
#   'keys',
#   'designed',
#   'style',
#   'speed',
#   'keyboard',
#   'mousepad',
#   'battery',
#   'sales',
#   'service',
#   'dell',
#   'dell support',
#   'hard drive',
#   'motherboard',
#   'cost',
#   'speed',
#   'construction quality',
#   'longevity',
#   'keyboard',
#   'keyboard',
#   'keys',
#   'configuration of " extra key "',
#   'touch pad',
#   'use',
#   'security',
#   'pricetag',
#   'use',
#   'work',
#   'preloaded software',
#   'webcam',
#   'vga port',
#   'screen',
#   'battery life',
#   'keys',
#   'software',
#   'volume',
#   'mouse',
#   'touchpad',
#   'boots up',
#   'hard drive',
#   'look and feel standpoint',
#   'safari',
#   'safari',
#   'mozzilla firfox',
#   'bluetooth',
#   'fingerprint reader driver',
#   'software',
#   'battery',
#   'speed',
#   'display',
#   'delivery',
#   'battery life',
#   'performance',
#   'memory',
#   'applications',
#   'microsoft office',
#   'resolution',
#   'appearance',
#   'cooling system',
#   'graphics card',
#   'built-in webcam',
#   'built-in mic',
#   'cam',
#   'mic',
#   'windows vista',
#   'board',
#   'connector',
#   'power supply',
#   'warrenty',
#   'power supply',
#   'works',
#   'ethernet',
#   'drag and drop feature',
#   'webcam',
#   'sales tax',
#   'software packages',
#   'iwork',
#   'garageband',
#   'imovie',
#   'screen',
#   'colors',
#   'resolution',
#   'monitor',
#   'itunes',
#   'size',
#   'external monitor',
#   'base installation',
#   'software',
#   'manuf',
#   'camera',
#   'display',
#   'amd turin processor',
#   'intel',
#   'warranty',
#   'start menu',
#   'navigate',
#   'bluray read / write drive',
#   'service tech',
#   'tech store',
#   'surface',
#   'screen',
#   'keyboard',
#   'ilife',
#   'snow leopard x',
#   'price tag',
#   'mac os',
#   'output',
#   'sound output quality',
#   'techie',
#   'use',
#   'toshiba online help',
#   'service life',
#   'ports',
#   'processor',
#   'price',
#   'look',
#   'keyboard',
#   'keys',
#   'screen',
#   'quality',
#   'stock screen',
#   'gray color',
#   'volume buttons',
#   'processor',
#   'computing',
#   'protector',
#   'key pad',
#   'magnetic plug-in power charging power cord',
#   'xp',
#   'vista',
#   'use',
#   'graphics',
#   'mac os',
#   'use',
#   'support',
#   'geek squad',
#   'graphics quality',
#   'appleworks',
#   'browser',
#   'paint',
#   'keyboard',
#   'service department',
#   'warrenty',
#   'warrentys',
#   'hard disk',
#   'running',
#   'cd drive',
#   'screen size',
#   'web browsing',
#   'software',
#   'loads',
#   'trackpad',
#   'external mouse',
#   'trackpad',
#   'games',
#   'games',
#   'features',
#   'human interface',
#   'software',
#   'inbuilt applications',
#   'body',
#   'i5',
#   'antivirus software',
#   'firewall',
#   'price',
#   'apple team',
#   'vista',
#   'vista',
#   'vista',
#   'operating system',
#   'video chat',
#   'quality',
#   'mouse',
#   'fan',
#   'cooling pad',
#   'feature',
#   'software',
#   'installation time',
#   'power',
#   'storage',
#   'abilitiy',
#   'feature',
#   'spotlight search',
#   'search',
#   'wireless system',
#   'windows 7',
#   'quality',
#   'battery life',
#   'speed',
#   'os',
#   'os',
#   'itunes',
#   'program',
#   'gaming',
#   'battery',
#   'apple support',
#   'techs',
#   'adding the bluetooth',
#   'graphic power',
#   'adobe creative apps',
#   'programs',
#   'use',
#   'materials',
#   'software',
#   'tech support',
#   'power supply',
#   'power supply',
#   'size',
#   'warranty',
#   'windows xp sp2',
#   'windows 7 ultimate',
#   'bluetooth',
#   'fingerprint reader',
#   'software',
#   'techs at hp',
#   'video card',
#   'graphics',
#   'security',
#   'audio',
#   'keyboard',
#   'runs',
#   'set up',
#   'screen',
#   'word processing',
#   'internet',
#   'trackpad',
#   'battery life',
#   'spec',
#   'dvd burner',
#   'hd',
#   'graphics chip',
#   'components',
#   'usb ports',
#   'software',
#   'system',
#   'ran',
#   'price',
#   'operation',
#   'brand',
#   'components',
#   'ground loop isolator',
#   'quality',
#   'price range',
#   'warranty',
#   'leading edge',
#   'bloatware',
#   'maximum sound',
#   'windows 7',
#   'bootcamp',
#   'price',
#   'works',
#   'action pack games',
#   'price',
#   'performance',
#   'twin packing',
#   'functions',
#   'look',
#   'after sales support',
#   'display screen',
#   'acer arcade',
#   'customer support',
#   'screen',
#   'cd drive',
#   'runs',
#   'design',
#   'size',
#   'games',
#   'games',
#   'life',
#   'warranty',
#   'pad',
#   'value',
#   'price',
#   'linux based os',
#   'system performance',
#   'use',
#   'batteries',
#   'shipping carton',
#   'use',
#   'program',
#   'virus protection',
#   'screen',
#   'processor',
#   'osx 16',
#   'graphics',
#   'hardware',
#   'software',
#   'intel core processors',
#   'hdmi port',
#   'internet explorer',
#   'staff',
#   'price premium',
#   'features',
#   'product and help aftermarket',
#   'microsoft word',
#   'usb ports',
#   'sd memory card reader',
#   'sd memory car expansion',
#   'lacie 2big external drive',
#   'firewire 800 interface',
#   'time machine',
#   'sound',
#   'extra features',
#   'windows 7 home premium',
#   'boot',
#   'acer screen',
#   'usb port',
#   'battery life',
#   'fires up',
#   'keyboard',
#   'software',
#   'online tutorial videos',
#   'image',
#   'soud',
#   'windows',
#   'boot up',
#   'shut down',
#   'windows',
#   'use',
#   'mac os',
#   'cost',
#   'windows 7 starter',
#   'windows 7 home premium',
#   'windows 7 professional',
#   'specifications',
#   'power cords',
#   'multi-touch features',
#   'screen',
#   'clicking buttons',
#   'battery life',
#   'windows',
#   'wired lan',
#   'hard reboot',
#   'hardware',
#   'hard drive',
#   'battery life',
#   'apple care',
#   'features',
#   'font',
#   'programs',
#   'run',
#   'plastic pieces',
#   '2gb ram stick',
#   'windows',
#   'microsoft word for mac',
#   'warranty company',
#   'cusromer service center',
#   'size',
#   'weight',
#   'battery',
#   'aluminum body',
#   'playing',
#   'watching movies',
#   'build quality',
#   'performance',
#   'dock',
#   'program',
#   'program',
#   'working',
#   'costing',
#   'i7',
#   'price',
#   'monitor',
#   'extended warranty',
#   'boots up',
#   'runs',
#   'screen',
#   'driver',
#   'tech support',
#   'work',
#   'hard drive',
#   'twin packing',
#   'functions',
#   'warranty',
#   'performance',
#   'price',
#   'bios',
#   'design',
#   'tech issues',
#   'size',
#   'space',
#   'service',
#   'priced',
#   'memory',
#   'speed',
#   'internet speed',
#   'programs',
#   'school or office use',
#   'pages',
#   'numbers',
#   'keynote',
#   'music',
#   'garageband',
#   'photo management',
#   'photo booth',
#   'iphoto',
#   'video-editing or movie-making',
#   'imovie',
#   'screen',
#   'colors',
#   'value',
#   'price',
#   'value',
#   "burn cd's",
#   'web cam',
#   '17 inch screen',
#   'support',
#   'bluetooth',
#   'launch manager',
#   'drivers / applications dvd',
#   'glass screen',
#   'switchable graphic card',
#   'gaming',
#   'service',
#   'battery life',
#   'technical support',
#   'boot mgr',
#   'recovery cd',
#   'price',
#   'features',
#   'skype',
#   'mouse buttons',
#   'hdd',
#   'rails',
#   'hard drive',
#   'quality',
#   'staff',
#   'games',
#   'garageband',
#   'warranty',
#   'hard drive',
#   'price',
#   'home use',
#   'business use',
#   'virus protection',
#   'updates',
#   'ms office apps',
#   'games',
#   'feature',
#   'windows',
#   'battery life',
#   'battery life',
#   'price',
#   'nortons virus scan',
#   'frame',
#   'features',
#   'use',
#   'loaded',
#   'windows',
#   'windows 7',
#   'vista',
#   'vista',
#   'windows xp',
#   'vista',
#   'key broad',
#   'warranty',
#   'repair " depot "',
#   'school use',
#   'design',
#   'battery life',
#   'programs',
#   'wireless',
#   'battery life',
#   'programs',
#   'trackpad',
#   'navigating',
#   'programs',
#   'speakers',
#   'subwoofer',
#   'built in camera',
#   'price',
#   'warranty',
#   'left mouse key',
#   'costed',
#   'speed',
#   'hard drive space',
#   'picture',
#   'extended warranty',
#   'extended warranties',
#   'battery',
#   'screen',
#   'battery life',
#   'appearance',
#   'technical service for dell',
#   'graphics',
#   'warranty',
#   'battery',
#   'case',
#   'performance',
#   'price',
#   'look',
#   'applications',
#   'speed',
#   'tech support',
#   'use',
#   'gaming',
#   'photoshop',
#   'system clock',
#   'ram',
#   'driver updates',
#   'windows',
#   'work',
#   'works',
#   'hd',
#   'graphics card',
#   'hd',
#   'built in camera',
#   'in',
#   'dvd burner',
#   'dvd burner',
#   'works',
#   '15 inch',
#   'product support',
#   'use',
#   'screen',
#   'casing of the power cord',
#   'of the',
#   'internet signals',
#   'price',
#   'right speaker',
#   'price tag',
#   'software',
#   'updates',
#   'multiple page viewer',
#   'page',
#   'shipped',
#   'keyboard',
#   'use',
#   'warranty',
#   'quality',
#   'features',
#   'recovery disk',
#   'features',
#   'programs',
#   'office',
#   'office programs',
#   'wifi',
#   'typing',
#   'screen',
#   'temp',
#   'windows operating system',
#   'os',
#   'processor speed',
#   'thunderbolt port',
#   'lcd screen',
#   'images',
#   'windows vista',
#   'windows xp',
#   'vista',
#   'adobe flash player',
#   'internet explore',
#   'windows update',
#   'update',
#   'switch',
#   'switch',
#   '4gb stick of ram',
#   'hardrive',
#   'touch control buttons',
#   'keyboard',
#   'performance',
#   'runs',
#   'ilife software',
#   'iphoto',
#   'imovie',
#   'iweb',
#   'itunes',
#   'garageband',
#   'system board',
#   'size',
#   'software',
#   'hardware',
#   'memory',
#   'hard drive',
#   'graphics',
#   'programs',
#   'navigation',
#   'hinge',
#   'lcd',
#   'dell customer service',
#   'rma service',
#   'rma',
#   'design',
#   'keyboard',
#   'battery life',
#   'screen / video resolution',
#   'resolution',
#   'dreamweaver',
#   'final cut pro 7',
#   'photoshop',
#   'safari',
#   'firefox',
#   'msn messenger',
#   'applications',
#   'warrenty',
#   'tech support',
#   'apple applications',
#   'gigs',
#   'memory',
#   '17 - inch screen',
#   'dvd',
#   'cd burners',
#   'web browsing',
#   'uploading photos',
#   'watching movies',
#   'creating presentations',
#   'quality display',
#   'weight',
#   '12 cell battery',
#   'case',
#   'power adapter plug',
#   'features',
#   'speakers',
#   'screen',
#   'tab',
#   'extended warrenty',
#   'tft panel',
#   'navigation',
#   'windows operating systems',
#   'screen',
#   'screen size',
#   'bulk',
#   'picture',
#   'video',
#   'music software',
#   'software',
#   'combined touch pad and clicker',
#   'unibody construction',
#   'value',
#   'windows',
#   'screen hinges',
#   'battery',
#   'storage life',
#   'service',
#   'storage',
#   'ram',
#   'nvidia chipset',
#   'extended warranty',
#   'programs',
#   'charge time',
#   'size',
#   'consistancy',
#   'key bindings',
#   'keyboard',
#   'size',
#   '10 - key',
#   'fan',
#   'fan',
#   'screen',
#   'operating system',
#   'processor',
#   '500gb hard drive',
#   'feature',
#   'tech support',
#   'usb output',
#   'wireless mouse',
#   'windows',
#   'linux',
#   'size',
#   'screen',
#   'windows disc',
#   'quality',
#   'touchpad',
#   'video card',
#   'touch pad',
#   'external mouse',
#   'set up',
#   'video',
#   'value',
#   'hard drive',
#   'runs',
#   'loads',
#   'warranty',
#   'program',
#   'spinning beachball',
#   'disk throughput',
#   'access wireless internet access',
#   'value',
#   'ran',
#   'battery',
#   'company',
#   'screen resolutions',
#   'carry',
#   'keyboard',
#   'edges',
#   'programs',
#   'ilife',
#   'iphotos',
#   'processor',
#   'fan',
#   'motherboard',
#   'built',
#   'performance',
#   'screen resolution',
#   'snow leopard',
#   'cpu',
#   'spinning wheel',
#   'office mac applications',
#   'word',
#   'excel',
#   'pad',
#   'keyboard',
#   'screen',
#   'windows 7',
#   'programs',
#   'ilife',
#   'iwork',
#   '18.4 " screen',
#   'battery life',
#   'runs',
#   'regular layout keyboard',
#   'programs',
#   'windows',
#   'recovery discs',
#   'windows 7 starter',
#   'support',
#   '3 year warranty',
#   'online chat service',
#   'iphoto',
#   'works',
#   'battery',
#   'quality',
#   'vhs',
#   'use',
#   'navigate',
#   'battery life',
#   'battery',
#   'usb ports',
#   'battery',
#   'design',
#   'quality',
#   'mac version of microsoft office',
#   'starting-up time',
#   'operates',
#   'touch pad',
#   'touch pad',
#   'pictures',
#   'transporting',
#   'gaming',
#   'wifi card',
#   'network capability',
#   'printer',
#   'use',
#   'os x',
#   'repair service',
#   'customer service agents',
#   'photoshop',
#   'aftereffects programs',
#   'runs',
#   'warrenty',
#   'look',
#   'dependability',
#   'company',
#   'warranty',
#   'features',
#   'mouse button',
#   'performance',
#   'touchpad',
#   'buttons',
#   'programs',
#   'space',
#   'keyboard',
#   'battery',
#   'keyboard',
#   'battery life',
#   'hard drive',
#   'windows 7',
#   'processor',
#   'load webpages',
#   'applications',
#   'battery',
#   'boot',
#   'windows',
#   'runs',
#   'openoffice',
#   'firefox',
#   'price',
#   'quality',
#   'performance',
#   'battery life',
#   'use',
#   'product key',
#   'specs',
#   'bluetooth',
#   'one touch keys',
#   'feature',
#   'battery life',
#   'keyboard',
#   'speed',
#   'specs',
#   'price',
#   'delivery',
#   'stability',
#   'mac software',
#   'operating system',
#   'sata controller',
#   'video editing',
#   'performance',
#   'mobile video editing',
#   'imovie program',
#   'processor',
#   'ram',
#   'battery',
#   'price',
#   'designed',
#   'warranty',
#   'bluetooth mouse',
#   'features',
#   'keyboard',
#   'control buttons',
#   'screen',
#   'motherboard',
#   'motherboard',
#   'processor',
#   'performance',
#   'motherboard',
#   'patches',
#   'speed',
#   'system memory',
#   'radeon 5850',
#   'ddr 5',
#   'ddr 3',
#   'programs',
#   'programs',
#   'speed',
#   'size',
#   'os ( vista )',
#   'software',
#   'battery life',
#   'battery life',
#   'extended warranty',
#   'use',
#   'use',
#   'features',
#   'programs',
#   'pop up windows',
#   'pop ups',
#   'web programming software',
#   'memory',
#   'web access',
#   '3g network',
#   'screen',
#   'design based programs',
#   'adobe creative suite',
#   ...],
#  'Laptops_poria-test': ['boot time',
#   'tech support',
#   'set up',
#   'windows 8',
#   'touchscreen functions',
#   'click pads',
#   'internal speakers',
#   'price tag',
#   'installation disk ( dvd )',
#   'use',
#   'works',
#   'apple os',
#   'features',
#   'log on',
#   'wifi connection',
#   'battery life',
#   'delete key',
#   'interneting',
#   'priced',
#   'works',
#   'track pad',
#   'graphics',
#   'mountain lion',
#   'build',
#   'durability',
#   'battery life',
#   'works',
#   'windows 8',
#   'baterry',
#   'size',
#   'weight',
#   'performance',
#   'usb ports',
#   'speed',
#   'screen',
#   'price',
#   'hardware performance',
#   'works',
#   'set up',
#   'keyboard',
#   'windows 8',
#   'setup',
#   'configure',
#   'windows 8',
#   'usb ports',
#   'features',
#   'screen',
#   'keyboard',
#   'performance',
#   'quality',
#   'performance',
#   'os',
#   'portability',
#   'portable computing',
#   'ms office 2011 for mac',
#   'performance',
#   'look',
#   'performance',
#   'lit up keys',
#   'screen display',
#   'mountain lion os',
#   'microsoft windows',
#   'osx',
#   'microsoft office',
#   'graphics',
#   'colors',
#   'built-in apps',
#   'screen resolution',
#   'speed',
#   'multi touch gestures',
#   'operating system',
#   'windows',
#   'size',
#   'squaretrade 3 - year computer accidental protection warranty',
#   'applecare',
#   'transport',
#   'windows 8 set-up',
#   'size',
#   'retina display',
#   'design',
#   'aluminum casing',
#   'aluminum body',
#   'integrate bluetooth devices',
#   'usb devices',
#   'intel 4000 graphic chip',
#   'dvd drive firewire port',
#   'adapter',
#   'sdxc slot',
#   'durability',
#   'designed',
#   'use',
#   'value',
#   'specs',
#   'product quality',
#   'aesthetics',
#   'craftmanship',
#   'customer service',
#   'size',
#   'windows 8',
#   'windows 8',
#   'startup times',
#   'colors',
#   'price',
#   'shipping',
#   'mouse',
#   'battery',
#   'windows 7',
#   'price',
#   'delivery',
#   'service',
#   'customer service',
#   'windows 8',
#   'price',
#   'set up',
#   'win 8',
#   'features',
#   'price',
#   'osx',
#   'support for games',
#   'mobility',
#   'price',
#   'set up',
#   'usb 3',
#   'sound',
#   'track pad',
#   'settings',
#   'openoffice',
#   'form factor',
#   'battery life',
#   'ux',
#   'keyboard',
#   'screen',
#   'touchpad',
#   'mavericks',
#   'i5',
#   'service',
#   'shipping',
#   'performance',
#   'built-in applications',
#   'iphoto',
#   'hard drive',
#   'samsung 830 ssd',
#   'starts up',
#   'aluminum',
#   'built in virus control',
#   'retina display',
#   'components',
#   'hardware',
#   'battery',
#   'snow lion',
#   'shipping',
#   'features',
#   'quality',
#   'keyboard',
#   'sound quality',
#   'navigate',
#   'battery life',
#   'performance',
#   'quality',
#   'windows xp',
#   'windows vista',
#   'windows 7',
#   'ssd drive',
#   'memory',
#   'start up',
#   'itune',
#   'os',
#   'restore disks',
#   'charging cables',
#   'material',
#   'cables',
#   'graphic design',
#   'external mics',
#   'os',
#   'screen',
#   'works',
#   'system',
#   'customize setting',
#   'create your own bookmarks',
#   'wireless keyboard / mouse',
#   'hdmi cable',
#   'features',
#   'price',
#   'working',
#   'gaming',
#   'operating system',
#   'set up',
#   'hard drive',
#   'boots up',
#   'scanning',
#   'price point',
#   'works',
#   'working',
#   'surfing',
#   'works',
#   'software',
#   'word processing',
#   'web browsing',
#   'gaming',
#   'programming',
#   'function',
#   'performance',
#   'apple " help "',
#   'work',
#   'harddrive',
#   'on / off switch',
#   'instructions',
#   'gaming',
#   'integrated intel 4000 graphics',
#   'features',
#   'content creation',
#   'audio',
#   'video',
#   'photo editing',
#   'screen',
#   'brightness',
#   'applications',
#   'use',
#   'use',
#   'i5 processor',
#   'built in features',
#   'screen',
#   'keyboard',
#   'delivery',
#   'ssd',
#   '16gb ram',
#   'memory',
#   'works',
#   'design',
#   'keyboard',
#   'ports',
#   'service',
#   'web browsing',
#   'safari browser',
#   'lighted screen',
#   'use',
#   'start up',
#   'operation',
#   'usb 3 peripherals',
#   'thunderbolt',
#   'media editing',
#   'battery',
#   'user experience',
#   'shipment',
#   'price',
#   'performance',
#   'usability',
#   'presentation',
#   'time response',
#   'size',
#   'mac os',
#   'programs',
#   'appleworks',
#   'filemaker pro',
#   'quicken',
#   'photoshop',
#   'operating system',
#   'form factor',
#   'loading the internet',
#   'looking',
#   'xp',
#   'support',
#   'os',
#   'overall build',
#   'keyboard',
#   'construction',
#   'system',
#   'unibody construction',
#   'runs',
#   'disk drive',
#   'hdmi receptacle',
#   'sd card slot',
#   'works',
#   'design app',
#   'trackpad',
#   'looks',
#   'feels',
#   'finish',
#   'price',
#   'price',
#   'system',
#   'power down',
#   'configuration',
#   'speakers',
#   'looks',
#   'use',
#   'trackpad',
#   'web surfuring',
#   'interface',
#   'portability',
#   'works',
#   'carry',
#   'handle',
#   'hardware ( keyboard )',
#   'performance',
#   'battery lifetime',
#   'runs',
#   'footprint',
#   'exterior',
#   'performance',
#   'design',
#   'intel 4000 graphics chipset',
#   'osx mountain lion',
#   'mavericks',
#   'usb ports',
#   'wakes',
#   'lid',
#   'size',
#   'speed',
#   'customer service',
#   'performed',
#   'battery cycle count',
#   'hardware',
#   'os',
#   'finger swipes',
#   'mouse',
#   'storage',
#   'screen',
#   'photoshop',
#   'mac os',
#   'speaker quality',
#   'shipped',
#   'thunderbolt port',
#   'performance',
#   'streaming video',
#   'entertainment uses',
#   'design',
#   'features',
#   'mac office',
#   'apple tech support',
#   'spec',
#   'works',
#   'use',
#   'looks',
#   'office',
#   'retina display',
#   'performance',
#   'ssd',
#   'magsafe accessories',
#   'magsafe 2 connection',
#   'touchpad',
#   'mouse',
#   'runs',
#   'fans',
#   'mac os',
#   'mac ecosystem',
#   'price',
#   'use',
#   'appearance',
#   'functionality',
#   'graphic design',
#   'slot',
#   'os',
#   'use',
#   'ssd',
#   'built-in camera',
#   'voice recording',
#   'start up',
#   'functionality',
#   'function',
#   'graphics',
#   'build quality',
#   'unibody construction',
#   'flexibility for connectivity',
#   'portability',
#   'mac tutorials',
#   'technical support',
#   'adapter',
#   'technical support',
#   'iphoto',
#   'garage band',
#   'logic board',
#   'sound',
#   'volume',
#   'osx lion',
#   'application',
#   'physical form',
#   'body',
#   'unibody construction',
#   '3d rendering',
#   'os x mountain lion',
#   'screen',
#   'apps',
#   'boot',
#   'ports',
#   'and',
#   'quad-core 2.5 ghz cpu',
#   'radeon hd 6750m 512mb graphic card',
#   'integrated intel 4000 card',
#   'and',
#   'wireless apple keyboard and mouse',
#   'and',
#   'package',
#   'cover',
#   'gestures',
#   'extender cable',
#   'cable',
#   '2.9 ghz dual-core i7 chip',
#   'starts up',
#   'noise',
#   'heat',
#   'windows 8',
#   'internal cd drive',
#   'hard drive',
#   'network lights',
#   'priced',
#   'storage',
#   'ports',
#   'audio volume',
#   'size',
#   'windows 8',
#   'capabilities',
#   'settings',
#   'runs',
#   'boot-up',
#   'windows updates',
#   'logic board',
#   'internet',
#   'word processing',
#   'graphic design',
#   'gaming',
#   'setup',
#   'install',
#   'tutorial',
#   'features',
#   'right mouse click menu',
#   'runs',
#   'ram memory',
#   'profile',
#   'wifi capability',
#   'disk drive',
#   'usb ports',
#   'sd card reader',
#   'the nail slot on the card',
#   'slot',
#   'touch',
#   'anodized aluminum',
#   'aluminium',
#   'glass',
#   'aluminum',
#   '16gb of ram',
#   'seagate momentus xt hybrid drives',
#   'owc upgrade kit',
#   'hard drive',
#   'number pad on the keyboard',
#   'on',
#   'regular hard drive',
#   'cd slot',
#   'hdmi port',
#   'install mountain lion',
#   'customization',
#   'hd',
#   'micron ssd',
#   'two finger clicking',
#   'right click button',
#   'superdrive',
#   'power plug',
#   'power adaptor',
#   'battery',
#   'battery',
#   'practicality',
#   'os',
#   'monitors',
#   'hdmi cables',
#   'price',
#   'ac adaptor',
#   'fan',
#   'playing a game',
#   'usb 2 ports',
#   'startup disk',
#   '" tools " menu',
#   'word program',
#   'cd / dvd drive',
#   'power switch',
#   'windows 7',
#   'windows 8',
#   'install',
#   'configure for adsl cable or wifi',
#   'speakers',
#   'packing',
#   'windows',
#   'idvd',
#   'windows 7',
#   'mac system',
#   'windows',
#   'works',
#   'software',
#   'os',
#   'works',
#   'runs',
#   'price',
#   'os',
#   'touch pad',
#   'reliability',
#   'sound',
#   'headphones',
#   'track pad',
#   'os',
#   'application',
#   'price',
#   'battery',
#   'speed',
#   'price',
#   'shipping',
#   'retina display display',
#   'compact computing',
#   'the',
#   'performance and feature set of the hardware',
#   'ports',
#   'firewire 800',
#   'gigabit ethernet',
#   'magsafe port',
#   'microphone jack',
#   'ventilation system',
#   'watching videos',
#   'playing steam games',
#   'acer support',
#   'operating system files',
#   'keys',
#   'os',
#   'lion',
#   'mac os',
#   'ram',
#   'hdd',
#   'cd / dvd player',
#   'ram memory',
#   'os . x',
#   'windows',
#   'windows .',
#   'softwares',
#   'os',
#   'mac os x 10.8 " mountain lion "',
#   'performance',
#   'external 24 " lcd screen',
#   'built in screen size',
#   'dvd slot',
#   'install software',
#   'word processing program',
#   'third-generation cpu ( " ivy bridge " )',
#   'fourth-generation haswell cpu',
#   'cd rom',
#   'features',
#   'volume',
#   'volume',
#   'case',
#   'price',
#   'log into the system',
#   'ssd',
#   '21 " led screen',
#   'set up',
#   'case',
#   'external power supply',
#   'size',
#   'wireless mouse',
#   'pad',
#   'works',
#   'key board',
#   'cost of ownership',
#   'price tag',
#   'features',
#   'vga port',
#   'hdmi',
#   'ethernet',
#   'usb ports',
#   'rubber pads',
#   'price',
#   'price',
#   'heat output',
#   'operation',
#   'upgrade the ram',
#   'price',
#   'mac',
#   'built-in mic',
#   'mac os 10.9',
#   'external microphones',
#   'features',
#   'shortcuts',
#   'ios system',
#   'resolution',
#   'fonts',
#   'working',
#   'features',
#   'brightness',
#   'adjustments',
#   'cd / dvd player',
#   'backlit keys',
#   '" home / end " type keys',
#   'microsoft word',
#   'memory',
#   'speed',
#   'flexibility',
#   'speed',
#   'simplicity',
#   'design',
#   'battery life',
#   'display',
#   'downloading apps',
#   'screen',
#   'software',
#   'operating system',
#   'slim plastic case',
#   'recovery usb stick',
#   'bass',
#   'sound',
#   'built quality',
#   'performance',
#   'mac',
#   'bluetooth interface',
#   'mac os',
#   'range',
#   'start',
#   'start menu',
#   'ram',
#   'touch screen',
#   'games',
#   'photoshop',
#   '" wlan " card',
#   'lan device drivers',
#   'built',
#   'battery life',
#   'os',
#   'apple customer support',
#   'firewire 800',
#   'usb 3',
#   'usb 3',
#   'mac os',
#   'windows 7',
#   'itunes',
#   'security',
#   'mini form factor',
#   'graphics stuff',
#   'the card reader',
#   'remove the card',
#   'spinning hard disk',
#   'ssd drive',
#   'hdmi',
#   'firmware patch',
#   'specs',
#   'packing',
#   'mother boards',
#   'mother board',
#   'graphics card',
#   '4g of ram',
#   '8g of ram',
#   'performs',
#   'virtual home schooling',
#   'cost',
#   'operating system',
#   'size',
#   'weight',
#   'mobility',
#   'durability of the battery',
#   'the functions provided by the trackpad',
#   'by',
#   'hardware',
#   'software',
#   'updates',
#   'disc drive',
#   'screen',
#   'res'],
#  'Restaurants_poria-test': ['bread',
#   'delivery times',
#   'food',
#   'coffee',
#   'sushi',
#   'place',
#   'people',
#   'japanese food',
#   'spicy tuna roll',
#   'asian salad',
#   'rose roll',
#   'menu',
#   'drinks',
#   'lychee martini',
#   'food',
#   'nicoise salad',
#   'menu',
#   'drinks',
#   'dessert pizza',
#   'food',
#   'live entertainment',
#   'waiter',
#   'menu',
#   'sushi',
#   'portions',
#   'price',
#   'food',
#   'service',
#   'portions of the food',
#   "waitress's",
#   'staff memebers',
#   'parking',
#   'desserts',
#   'desserts',
#   'tart of the day',
#   'food',
#   'wine',
#   'lasagna',
#   'array of sushi',
#   'cuisine',
#   'owners',
#   'staff',
#   'indian food',
#   'ambiance',
#   'food',
#   'service',
#   'garden',
#   'food',
#   'appetizers',
#   'entrees',
#   'food',
#   'decor',
#   'lunch',
#   'dinners',
#   'steaks',
#   'staff',
#   'meatball parm',
#   'latin food',
#   'taglierini with truffles',
#   'staff',
#   'gnocchi',
#   'staff',
#   'food',
#   'portion size',
#   'portobello / gorgonzola / sausage appetizer',
#   'lobster risotto',
#   'entrees',
#   'lasagna',
#   'fettuccine alfredo',
#   'chicken parmigiana',
#   'food',
#   'teriyaki',
#   'meal',
#   'peanut butter sorbet',
#   'pizza with soy cheese',
#   'food',
#   'price',
#   'food',
#   'service',
#   'atmosphere',
#   'food',
#   'waitstaff',
#   'atmosphere',
#   'beer',
#   'food',
#   'kimono shrimp special',
#   'atmosphere',
#   'menu',
#   'priced',
#   'food',
#   'ingredients',
#   'food',
#   'appetizer',
#   'meal',
#   'spicy mussels',
#   'onion rings',
#   'food',
#   'portions',
#   'service',
#   'prices',
#   'service',
#   'food',
#   'waiter',
#   'manager',
#   'food',
#   'milkshakes',
#   'mushroom barley soup',
#   'food',
#   'staff',
#   'duck',
#   'drinks',
#   'food',
#   'curried casseroles',
#   'food',
#   'taste',
#   'space',
#   'cuisine',
#   'seafood',
#   'orange donut',
#   'atmosphere',
#   'meats',
#   'management',
#   'ambience',
#   'teas',
#   'sweets',
#   'mojitos',
#   'service',
#   'sandwiches',
#   'burgers',
#   'salads',
#   'lemon-dressed cobb',
#   'design',
#   'food',
#   'staff',
#   'taste',
#   'fajita',
#   'mole sauce',
#   'roasted chickens',
#   'atmosphere',
#   'food',
#   'selection',
#   'prices',
#   'drinks',
#   'steak',
#   'food',
#   'waiters',
#   'priced',
#   'selection of food',
#   'atmosphere',
#   'dessert',
#   'taste',
#   'food',
#   'hot dog',
#   'bar',
#   'food',
#   'waiters',
#   'atmosphere',
#   'food',
#   'wraps',
#   'burgers',
#   'salads',
#   'mango margareta',
#   'prices',
#   'service',
#   'waiter',
#   'staff',
#   'folding chair',
#   'service',
#   'fettucino alfredo',
#   'food',
#   'vegan options',
#   'indian food',
#   'smoked trout',
#   'lamb chops',
#   'veal chops',
#   'rabbit',
#   'potato gratin',
#   'chef',
#   'food',
#   'service',
#   'eggs benedict',
#   'mussels',
#   'hamburger',
#   'waiters',
#   'falafal',
#   'chicken',
#   'grand marnier shrimp',
#   'food',
#   'food',
#   'service',
#   'desserts',
#   'flan',
#   'sopaipillas',
#   'portions',
#   'wait staff',
#   'food',
#   'service',
#   'sushi',
#   'service',
#   'soup',
#   'crepes',
#   'creme brulee',
#   'apple',
#   'shrimp creole',
#   'chicken dinner',
#   'chili signed food items',
#   'decor',
#   'food',
#   'ribs',
#   'beef',
#   'coconut rice',
#   'avocado salad',
#   'honey bbq rib tips',
#   'chinese food',
#   'service',
#   'atmosphere',
#   'staff',
#   'waiters',
#   'pasta',
#   'wine list',
#   'cocktail menu',
#   'crab cakes',
#   'bbq rib',
#   'food',
#   'service',
#   'sauce',
#   'service',
#   'desserts',
#   'atmosphere',
#   'drinks',
#   'appetizers',
#   'pizza',
#   'service',
#   'food',
#   'beer list',
#   'chinese food',
#   'waiter',
#   'scallops',
#   'asparagus',
#   'soft shell crab',
#   'cheese plate',
#   'service',
#   'hotdogs',
#   'staff',
#   'saag gosht',
#   'garlic knots',
#   'indian food',
#   'pizza',
#   'music',
#   'service',
#   'owner',
#   'staff',
#   'sushi',
#   'menu',
#   'food',
#   'sushi',
#   'cooked food',
#   'dinner specials',
#   'food',
#   'drinks',
#   'dining atmosphere',
#   'price',
#   'food',
#   'food portion',
#   'chairs',
#   'tacos pastor',
#   'tostada de tinga',
#   'bartenders',
#   'managers',
#   'decor',
#   'soup and sandwich meal',
#   'hot and sour soup',
#   'drinks',
#   'atmosphere',
#   'service',
#   'food',
#   'chick peas with shrimp ( appetizer )',
#   'service',
#   'lamb',
#   'soft shell crab sandwich with fries',
#   'hong kong-style food',
#   'food',
#   'wine',
#   'staff',
#   'kitchen food',
#   'sushi',
#   'service',
#   'waitresses',
#   'atmosphere',
#   'italian food',
#   'food',
#   'rolls',
#   'sushi / sashimi',
#   'sashimi',
#   'price',
#   'hot dogs',
#   'breakfast sandwiches',
#   'tator tots',
#   'english muffins',
#   'pork product',
#   'taylor ham',
#   'manager',
#   'bartender',
#   'waiting',
#   'drinks',
#   'service',
#   'atmosphere',
#   'dish',
#   'green chillis',
#   'service',
#   'food',
#   'meals',
#   'lunch',
#   'take-out',
#   'dine-in',
#   'food',
#   'fresh juice concoctions',
#   'food',
#   'prices',
#   'place',
#   'soul food',
#   'place',
#   'roast chicken',
#   'salad',
#   'chicken with avocado',
#   'tuna',
#   'meals',
#   'chicken',
#   'sauce',
#   'malted milk ball gelato',
#   'meal',
#   'service',
#   'bar service',
#   'dessert',
#   'service',
#   'black vinegar',
#   'shredded ginger',
#   'lighting',
#   'food',
#   'disco pop duo',
#   'escargot',
#   'place',
#   'service',
#   'owner',
#   'waiters',
#   'food',
#   'waiter',
#   'salads',
#   'vegetarian platters',
#   'meal',
#   'food',
#   'service',
#   'pizza',
#   'pizza',
#   'service',
#   'chicken',
#   'food',
#   'host ( owner )',
#   'servers',
#   'food',
#   'atmosphere',
#   'hostess',
#   'food',
#   'service',
#   'vietnamese beef noodle soup',
#   'dining experience',
#   'indian food',
#   'waiters',
#   'interior',
#   'service',
#   'food',
#   'decor',
#   'menu',
#   'selection',
#   'sauce',
#   'crust',
#   'sushi',
#   'selection',
#   'rolls with crab',
#   'host',
#   'bartender',
#   'servers',
#   'food',
#   'potato spinach gnocchi',
#   'lamb',
#   'lunch',
#   'sandwiches',
#   'portuguese cheese cart',
#   'port',
#   'burger',
#   'blueberry pancakes',
#   'food',
#   'bill',
#   'toppings',
#   'crust',
#   'service',
#   'food',
#   'waitstaff',
#   'food',
#   'lobster ravioli',
#   'meal',
#   'service',
#   'wait',
#   'price',
#   'food',
#   'coffee',
#   'cosi sandwiches',
#   'drink',
#   'prices',
#   'food',
#   'waiting',
#   'place',
#   'ambience',
#   'brunch',
#   'food',
#   'crust',
#   'food',
#   'cake',
#   'dinner',
#   'service',
#   'delmonico steak',
#   'menu',
#   'chicken',
#   'rice',
#   'beans',
#   'service',
#   'value',
#   'food',
#   'value',
#   'garlic soup',
#   'falafel',
#   'tabouleh',
#   'humus',
#   'mediterranean delights',
#   "pizza's",
#   'staff',
#   'chef',
#   'priced',
#   'sushi',
#   'for',
#   'seafood paella for two',
#   'apetizers',
#   'sangria',
#   'service',
#   'server',
#   'staff',
#   'food',
#   'service',
#   'host',
#   'hostess',
#   'wait staff',
#   'meal',
#   'salmon dishes',
#   'foie gras',
#   'menu',
#   'mac cheese',
#   'brunch menu',
#   'jazz singer',
#   'service',
#   'food',
#   'breakfast food',
#   'soups',
#   'salads',
#   'sandwiches',
#   'food',
#   'banana pudding',
#   'crabcakes',
#   'and',
#   'mac and cheese',
#   'staff',
#   'prices',
#   'service',
#   'food',
#   'downstairs bar scene',
#   'food',
#   'price',
#   'drinks',
#   'casual lunches',
#   'tequila',
#   'beer selection',
#   'beers',
#   'delivary',
#   'food',
#   'owner',
#   'homemade pastas',
#   'gnocchi',
#   'vegetable risotto',
#   'flavor',
#   'price',
#   'service',
#   'dinner',
#   'prices',
#   'sandwiches',
#   'soup',
#   'pizza',
#   'homemade sorbets',
#   'homemade guacamole',
#   'entree',
#   'deserts',
#   'sushi',
#   'priced',
#   'deserts',
#   'grill',
#   'churrasco',
#   'ribs',
#   'traditional italian items',
#   'served',
#   'setting',
#   'iced blended mocha',
#   'hot white mocha',
#   'late lunch',
#   'parmesan cheese',
#   'waitress',
#   'food',
#   'wine',
#   'service',
#   'portions',
#   'ambiance',
#   'salad',
#   'salad dressing',
#   'quesedilla',
#   "pizza's",
#   'service',
#   'food',
#   'cost',
#   'food',
#   'staff',
#   'bar',
#   'chef',
#   'indian food',
#   'service',
#   'odessa stew',
#   'rabbit stew',
#   'kompot',
#   'lunch',
#   'waitress',
#   'quality of the meat',
#   'smoothies',
#   'fresh juices',
#   'black roasted codfish',
#   'dish',
#   'manager',
#   'menu',
#   'waiter',
#   'chicken',
#   'taste',
#   'reservation',
#   'brunch',
#   'sushi',
#   'sushi',
#   'food',
#   'served',
#   'the erbazzone emiliana',
#   'the mostarda on the cheese plate',
#   'the dishes',
#   'food',
#   'bar',
#   'vibe',
#   'candlelight',
#   'music',
#   'food',
#   'dining experience',
#   'food',
#   'service',
#   'place',
#   'food',
#   'chicken teriyaki',
#   'garlic shrimp',
#   'japanese food',
#   'food',
#   'staff members',
#   'drink',
#   'atmosphere',
#   'sashimi portion',
#   'artifical lobster meat',
#   'wheat crusted pizza',
#   'ingredients',
#   'dinner',
#   'food',
#   'service',
#   'cake',
#   'slices',
#   'staff',
#   'wait',
#   'wine list',
#   'priced',
#   'salads',
#   'bathroom',
#   'delivers',
#   'food',
#   'prices',
#   'service',
#   'repast',
#   'waiters',
#   'italian meal',
#   'pizza',
#   'steak',
#   ', organic grilled burgers',
#   'dish ,',
#   'jerusalem market-style falafel wraps and mediterranean salads--layered with beets , goat cheese and',
#   'dining experience',
#   'waiter',
#   'texture',
#   'hint of cocoa',
#   'the round corner table next to the large window',
#   'twist on pizza',
#   'flavor',
#   'ac',
#   'service',
#   'sales people',
#   'location',
#   'the display and quality of the food',
#   'food',
#   'food',
#   'italian cuisine',
#   'atmoshere',
#   'booth by the windows',
#   'place',
#   'food',
#   'service',
#   'coffee',
#   'wine list',
#   'vintages',
#   'priced food',
#   'scenery',
#   'new hamburger with special sauce',
#   'big mac',
#   'pasta',
#   'sauce',
#   'portions',
#   'prices',
#   'food',
#   'service',
#   'staff',
#   'owners',
#   'owner',
#   'place',
#   'meal',
#   'place',
#   'service',
#   'staff',
#   'food',
#   'fortune cookies',
#   'cookie',
#   'sushi lunch',
#   'mojito',
#   'back patio',
#   'service',
#   'meal',
#   'braised lamb shank with mashed potatoes',
#   'waitress',
#   'soy sauce',
#   'lunch',
#   'bar',
#   'bartender',
#   'fried pork dumplings',
#   'orange chicken / beef',
#   'fried rice',
#   'menu',
#   'french fries - - with the kalmata dip',
#   'wait',
#   'manager',
#   'bartender',
#   'drinks',
#   'boutique selection of wines',
#   'assortment of wraps',
#   'traditional mediterranean fare',
#   'fresh veggies',
#   'middle eastern spreads',
#   'cheese',
#   'falafel',
#   'soup',
#   'fish',
#   'rice',
#   'root vegetables',
#   'rice medley',
#   'spinach thing',
#   'lamb kebabs',
#   'cheese baclava',
#   'fooood',
#   'saketini',
#   'bar menu',
#   'look',
#   'martinis',
#   'chairs',
#   'table',
#   'happy hour',
#   'service',
#   'atmosphere',
#   'waiting',
#   'waiter',
#   'kitchen',
#   'quaility',
#   'atmosphere',
#   'space',
#   'treats',
#   'prices',
#   'menu',
#   'seats',
#   'value',
#   'attitude',
#   'food',
#   'glass of wine',
#   'wine',
#   'flavors',
#   'place',
#   'service',
#   'food',
#   'price',
#   'burrito',
#   'tacos',
#   'margarita',
#   'dessert',
#   'space',
#   'reservations',
#   'food',
#   'interior',
#   'owners',
#   'dining',
#   'service',
#   'food',
#   'value',
#   'wait',
#   'hot cakes',
#   'egg mcmuffin sandwich',
#   'breakfast',
#   'service',
#   'food',
#   'music',
#   'bartender',
#   'drinks',
#   'rice dishes',
#   'noodle dishes',
#   'ice drink',
#   'cuisine',
#   'billed',
#   'asian fusion',
#   'bill',
#   'dishes',
#   'king crab salad with passion fruit vinaigrette',
#   'fettuccine with grilled seafood in a rosemary-orange sauce',
#   'bistro menu',
#   'dishes',
#   '" roy\'s classics "',
#   'menu',
#   'recipes',
#   'macadamia-crusted mahi mahi',
#   'sweet honey-mustard beef short ribs',
#   'cold sesame noodles',
#   'meal',
#   'food served',
#   'argentine chorizo appetizer',
#   'fennel flavored italian sausage',
#   'dinner',
#   'delivery',
#   'value',
#   'sandwiches',
#   'soy mayonaise',
#   'table',
#   'hostess',
#   'dinner',
#   'food',
#   'staff',
#   'food',
#   'wine',
#   'music',
#   'tapas',
#   'selection of wines ( primarily spanish )',
#   'clientele',
#   'food',
#   'dumplings',
#   'cold sesame noodles',
#   'chicken',
#   'shrimp dishs',
#   'food',
#   'food',
#   'waiting',
#   'entrees',
#   'place',
#   'duck confitte',
#   'wine list',
#   'tapas',
#   'atmosphere',
#   'food',
#   'food price',
#   'food',
#   'service',
#   'prices',
#   'food',
#   'meal',
#   'food',
#   'service',
#   'dinner menu',
#   'entrees',
#   'seafood',
#   'steaks',
#   'non-meat alternatives',
#   'menu',
#   'food',
#   'appetizers',
#   'service',
#   'food',
#   'price',
#   'waitress',
#   'entree',
#   'prices',
#   'gratuity',
#   'bill',
#   'halibut cheek appetizer',
#   'portion of foie gras',
#   'meal',
#   'food',
#   'empenadas',
#   'plaintains',
#   'afternoon snack',
#   'appetizer',
#   'pasta specials',
#   'big mac',
#   'chicken mcnuggets',
#   'filet-o-fish sandwich',
#   "mcdonald's famous french fries",
#   'entree-sized salads',
#   'noise',
#   'pizza',
#   'pizza',
#   'tables',
#   'lunch',
#   'scene',
#   'blue bar area',
#   'upstrairs dining area',
#   'veggie burger',
#   'chickpeas',
#   'carrots',
#   'vegetables',
#   'spices',
#   'tables',
#   'service',
#   'menus',
#   'sweet corn-foie gras brulee',
#   'carinthia cheese ravioli with wild mushrooms',
#   'caviar-topped sturgeon',
#   'with',
#   'green spinach-vodka sauce',
#   'burgers',
#   'patties',
#   'lunch',
#   'delivery service',
#   'quality',
#   'prices',
#   'staff person',
#   'fork',
#   'specials',
#   'salmon',
#   'pastas',
#   'atmosphere',
#   'decor',
#   'wait staff',
#   'food',
#   'dishes',
#   'place',
#   'desserts',
#   'food',
#   'staff',
#   'service',
#   'atmosphere',
#   'branzini',
#   'fish',
#   'food',
#   'service',
#   'price',
#   'menu',
#   'ambiance',
#   'service',
#   'food',
#   'food',
#   'wine',
#   'host',
#   'pizzas',
#   'appetizers',
#   'main courses',
#   'calamari',
#   'pasta',
#   'sliced steak entree',
#   'caeser salad',
#   'fried calamari',
#   'atmosphere',
#   'food',
#   'food',
#   'service',
#   'portions',
#   'service',
#   'chicken milanese',
#   'tapas',
#   'prices',
#   'service',
#   'chocolate raspberry cake',
#   'flavor',
#   'waiter',
#   'food',
#   'wine',
#   'meal',
#   'service',
#   'hot dogs',
#   'service',
#   'food',
#   'wine',
#   'desserts',
#   'dining experience',
#   'food',
#   'service',
#   'escargot',
#   'menu',
#   'deco',
#   'ambiance',
#   'french food',
#   'indian food',
#   'curry',
#   'poori',
#   'naan',
#   'paratha',
#   'homemade breads',
#   'sushi',
#   'korean dishes',
#   'prix fixe menu',
#   'waiter',
#   'place',
#   'service',
#   'food',
#   'burgers',
#   'grilled cheeses',
#   'french fries',
#   'yellowfin tuna',
#   "calf's liver",
#   'sushi',
#   'bill',
#   'sauce cart',
#   'table',
#   'choices of sauces',
#   'steak',
#   'sushi',
#   'entrees',
#   'duck',
#   'variety',
#   'utensils',
#   'pie',
#   'thin crust',
#   'slices',
#   'green beans',
#   'egg',
#   'anchovy dressing',
#   'nicoise olives',
#   'red onion',
#   'meal',
#   'side orders',
#   "amazin ' greens salads",
#   'buffalo chicken kickers',
#   'cinna stix',
#   'fries',
#   'meaty chili',
#   'stuffed baked potatoes',
#   'menu',
#   'chocolate frosty',
#   'waiter',
#   'menu',
#   'cake',
#   'cake',
#   'employees',
#   'cherry marscapone',
#   'roti canai appetizer',
#   'fried pancake served with pungent curry dipping sauce',
#   'mango chicken',
#   'outside',
#   'atmosphere',
#   'ground chickpea soup',
#   'starter',
#   'sushi',
#   'service',
#   'quality of food',
#   'bartenders',
#   'clientele',
#   'staff',
#   'meal',
#   'desserts',
#   'tables',
#   'rooftop bar',
#   'decoration',
#   'ambience',
#   'food',
#   'catfish',
#   'service',
#   'food',
#   'brisket',
#   'ribs',
#   'wings',
#   'cajun shrimp',
#   'atmosphere',
#   'counter',
#   'bottle of wine',
#   'menu',
#   'japanese dishes',
#   ...]}

# %%
annotated_aspects.keys()
# Out:
# dict_keys(['Restaurants_poria-train', 'Laptops_poria-train', 'Laptops_poria-test', 'Restaurants_poria-test'])

# %% [markdown]
# ### Laptops

# %%
len(set(annotated_aspects['Laptops_poria-test']) - set(annotated_aspects['Laptops_poria-train']))
# Out:
# 243

# %%
len(set(annotated_aspects['Laptops_poria-train']) - set(annotated_aspects['Laptops_poria-test']))
# Out:
# 816

# %% [markdown]
# ### Restaurants

# %%
len(set(annotated_aspects['Restaurants_poria-test']) - set(annotated_aspects['Restaurants_poria-train']))
# Out:
# 336

# %%
len(set(annotated_aspects['Restaurants_poria-train']) - set(annotated_aspects['Restaurants_poria-test']))
# Out:
# 1047

# %% [markdown]
# ## Aspect Distribution

# %%
for k, v in annotated_aspects.items():
    print(k)
    print(pd.DataFrame(v, columns=['aspect'])['aspect'].value_counts()[:20])
# Out:
# Restaurants_poria-train
# food          373
# service       236
# place          65
# prices         64
# staff          57
# menu           57
# dinner         56
# pizza          50
# atmosphere     49
# price          42
# table          41
# meal           39
# sushi          38
# drinks         35
# bar            32
# lunch          29
# dishes         28
# decor          27
# ambience       27
# portions       27
# Name: aspect, dtype: int64
# Laptops_poria-train
# screen          64
# price           57
# use             55
# battery life    55
# keyboard        53
# battery         48
# programs        37
# features        35
# software        34
# warranty        31
# hard drive      30
# windows         30
# quality         25
# size            24
# performance     23
# speed           21
# applications    18
# graphics        18
# memory          18
# runs            17
# Name: aspect, dtype: int64
# Laptops_poria-test
# price               19
# performance         15
# works               14
# os                  13
# features            12
# screen              10
# windows 8           10
# use                  9
# size                 9
# keyboard             7
# mac os               6
# battery              6
# runs                 6
# battery life         6
# speed                6
# set up               6
# design               5
# windows 7            5
# usb ports            5
# operating system     5
# Name: aspect, dtype: int64
# Restaurants_poria-test
# food          124
# service        76
# atmosphere     23
# staff          22
# menu           22
# place          20
# prices         18
# sushi          16
# meal           15
# drinks         13
# waiter         13
# price          10
# pizza           9
# wine            9
# waiters         8
# desserts        8
# lunch           8
# dinner          7
# chicken         6
# bartender       6
# Name: aspect, dtype: int64

# %% [markdown]
# # 2016

# %% [markdown]
# ## Load pre-processed datasets [all in one file]

# %%
from utilities.settings import SEMEVAL_DATASETS_2016

# %%
semeval_2016_df = pd.read_csv(SEMEVAL_DATASETS_2016 / 'all-entities-and-aspects.csv')

# %%
semeval_2016_df[~semeval_2016_df.target.isna()].groupby(['category', 'target']).count()[['aspect']]
# Out:
#                                              aspect
# category         target
# AMBIENCE#GENERAL Ambiance                         1
#                  Ambience                         2
#                  Atmosphere                       4
#                  Balcony                          2
#                  Cosette                          1
#                  DJ                               1
#                  Decor                            4
#                  Dining Garden                    1
#                  Downstairs lounge                1
#                  Egyptian restaurant              1
#                  Indoor                           1
#                  Indoor ambience                  2
#                  Jazz Bar                         1
#                  Leon                             1
#                  Place                            2
#                  Raga's                           1
#                  Restaurant                       1
#                  Rice Avenue                      1
#                  Snooze                           2
#                  Thalia                           1
#                  Toons                            1
#                  Traditional French decour        1
#                  Zenkichi                         1
#                  actors                           1
#                  ambiance                        12
#                  ambience                        17
#                  ambient                          1
#                  art on the walls                 2
#                  artwork                          2
#                  atmoshere                        1
# ...                                             ...
# SERVICE#GENERAL  manager                         19
#                  owner                            6
#                  owners                           4
#                  people                           6
#                  proprietor                       1
#                  restaurant staff                 2
#                  runner                           1
#                  seating                          1
#                  server                          12
#                  servers                          8
#                  servers behind the counter       2
#                  service                        202
#                  service button                   1
#                  sommelier                        2
#                  staff                           56
#                  staff members                    2
#                  survice                          1
#                  svc                              1
#                  takeout                          1
#                  wait                             7
#                  wait staff                       9
#                  wait-staff                       1
#                  waiter                          29
#                  waiters                         14
#                  waiting staff                    2
#                  waitress                        22
#                  waitresses                       1
#                  waitstaff                        7
#                  waitstaffs                       1
#                  young woman                      2
#
# [1118 rows x 1 columns]

# %%
from aspects.embeddings.bert import BertWrapper

# %%
bert_embedder = BertWrapper()

# %%
semeval_2016_df.head()
# Out:
#    Unnamed: 0          category    entity   aspect          target  polarity
# 0          41  AMBIENCE#GENERAL  AMBIENCE  GENERAL          tables  negative
# 1          38  AMBIENCE#GENERAL  AMBIENCE  GENERAL    candle-light  positive
# 2          43  AMBIENCE#GENERAL  AMBIENCE  GENERAL  interior decor  positive
# 3          56  AMBIENCE#GENERAL  AMBIENCE  GENERAL        interior  negative
# 4          57  AMBIENCE#GENERAL  AMBIENCE  GENERAL           space  negative

# %%
semeval_2016_df.target = semeval_2016_df.target.progress_apply(str)
# Out:
# HBox(children=(IntProgress(value=0, max=4291), HTML(value='')))

# %%
semeval_2016_df['embedding'] = semeval_2016_df.target.progress_apply(bert_embedder.get_averaged_vector)
# Out:
# HBox(children=(IntProgress(value=0, max=4291), HTML(value='')))

# %%
semeval_2016_df.head()
# Out:
#    Unnamed: 0          category    entity   aspect          target  polarity  \
# 0          41  AMBIENCE#GENERAL  AMBIENCE  GENERAL          tables  negative
# 1          38  AMBIENCE#GENERAL  AMBIENCE  GENERAL    candle-light  positive
# 2          43  AMBIENCE#GENERAL  AMBIENCE  GENERAL  interior decor  positive
# 3          56  AMBIENCE#GENERAL  AMBIENCE  GENERAL        interior  negative
# 4          57  AMBIENCE#GENERAL  AMBIENCE  GENERAL           space  negative
#
#                                            embedding  cluster
# 0  [-0.26636368, -0.9098466, -0.23358482, -0.0058...        9
# 1  [-0.46664533, -1.2059094, -0.12933376, -0.0101...        9
# 2  [-0.47207767, -1.2466235, -0.20648655, -0.3695...        9
# 3  [-0.1322847, -0.7842638, -0.5341981, -0.113490...        3
# 4  [-0.1815286, -1.1119602, 0.0013807006, 0.19098...        5

# %%
len(semeval_2016_df.category.unique())
# Out:
# 12

# %%
semeval_2016_df.to_pickle(SEMEVAL_DATASETS_2016 / 'all-entities-and-aspects-with-bert-embeddings.pkl')

# %%
semeval_2016_df.drop_duplicates(subset=['target'], inplace=True)

# %%
from sklearn.cluster import AgglomerativeClustering

# %%
hierarchical_cluster = AgglomerativeClustering(n_clusters=50).fit(semeval_2016_df.embedding.tolist())
semeval_2016_df['cluster'] = hierarchical_cluster.labels_

# %%
from aspects.analysis import draw_embeddings

# %%
semeval_2016_df.head(1)
# Out:
#    Unnamed: 0          category    entity   aspect  target  polarity  \
# 0          41  AMBIENCE#GENERAL  AMBIENCE  GENERAL  tables  negative
#
#                                            embedding  cluster  \
# 0  [-0.26636368, -0.9098466, -0.23358482, -0.0058...       18
#
#                      tooltip
# 0  AMBIENCE#GENERAL : tables

# %%
semeval_2016_df['tooltip'] = semeval_2016_df.category + ' : ' + semeval_2016_df.target

# %%
import qgrid

# %%
qgrid.show_grid(semeval_2016_df)
# Out:
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': True, 'defau…

# %%
semeval_2016_df
# Out:
#       Unnamed: 0              category    entity         aspect  \
# 0             41      AMBIENCE#GENERAL  AMBIENCE        GENERAL
# 1             38      AMBIENCE#GENERAL  AMBIENCE        GENERAL
# 2             43      AMBIENCE#GENERAL  AMBIENCE        GENERAL
# 3             56      AMBIENCE#GENERAL  AMBIENCE        GENERAL
# 4             57      AMBIENCE#GENERAL  AMBIENCE        GENERAL
# 5              9      AMBIENCE#GENERAL  AMBIENCE        GENERAL
# 6             22      AMBIENCE#GENERAL  AMBIENCE        GENERAL
# 7             30      AMBIENCE#GENERAL  AMBIENCE        GENERAL
# 8             18  DRINKS#STYLE_OPTIONS    DRINKS  STYLE_OPTIONS
# 9             60        DRINKS#QUALITY    DRINKS        QUALITY
# 10            25          FOOD#QUALITY      FOOD        QUALITY
# 11            26          FOOD#QUALITY      FOOD        QUALITY
# 12            27          FOOD#QUALITY      FOOD        QUALITY
# 13            28          FOOD#QUALITY      FOOD        QUALITY
# 14            45          FOOD#QUALITY      FOOD        QUALITY
# 15            64          FOOD#QUALITY      FOOD        QUALITY
# 16            33          FOOD#QUALITY      FOOD        QUALITY
# 17            34          FOOD#QUALITY      FOOD        QUALITY
# 18            35          FOOD#QUALITY      FOOD        QUALITY
# 19            36          FOOD#QUALITY      FOOD        QUALITY
# 20            37          FOOD#QUALITY      FOOD        QUALITY
# 22            46          FOOD#QUALITY      FOOD        QUALITY
# 23            50          FOOD#QUALITY      FOOD        QUALITY
# 25            52          FOOD#QUALITY      FOOD        QUALITY
# 26            62          FOOD#QUALITY      FOOD        QUALITY
# 29             4          FOOD#QUALITY      FOOD        QUALITY
# 30             5          FOOD#QUALITY      FOOD        QUALITY
# 31             6          FOOD#QUALITY      FOOD        QUALITY
# 32            51          FOOD#QUALITY      FOOD        QUALITY
# 33             7          FOOD#QUALITY      FOOD        QUALITY
# ...          ...                   ...       ...            ...
# 3079        1707       SERVICE#GENERAL   SERVICE        GENERAL
# 3081        1708       SERVICE#GENERAL   SERVICE        GENERAL
# 3085        1594       SERVICE#GENERAL   SERVICE        GENERAL
# 3096        1624       SERVICE#GENERAL   SERVICE        GENERAL
# 3100        1592       SERVICE#GENERAL   SERVICE        GENERAL
# 3102        2433       SERVICE#GENERAL   SERVICE        GENERAL
# 3107        2420       SERVICE#GENERAL   SERVICE        GENERAL
# 3109        2426       SERVICE#GENERAL   SERVICE        GENERAL
# 3114        2415       SERVICE#GENERAL   SERVICE        GENERAL
# 3116          98       SERVICE#GENERAL   SERVICE        GENERAL
# 3125        2431       SERVICE#GENERAL   SERVICE        GENERAL
# 3144         246       SERVICE#GENERAL   SERVICE        GENERAL
# 3162        2377       SERVICE#GENERAL   SERVICE        GENERAL
# 3199         891       SERVICE#GENERAL   SERVICE        GENERAL
# 3207        1893       SERVICE#GENERAL   SERVICE        GENERAL
# 3214        1189       SERVICE#GENERAL   SERVICE        GENERAL
# 3217         768       SERVICE#GENERAL   SERVICE        GENERAL
# 3227        2072       SERVICE#GENERAL   SERVICE        GENERAL
# 3228         786       SERVICE#GENERAL   SERVICE        GENERAL
# 3235         816       SERVICE#GENERAL   SERVICE        GENERAL
# 3251        1113       SERVICE#GENERAL   SERVICE        GENERAL
# 3259        1945       SERVICE#GENERAL   SERVICE        GENERAL
# 3261        1943       SERVICE#GENERAL   SERVICE        GENERAL
# 3269        1102       SERVICE#GENERAL   SERVICE        GENERAL
# 3271        1928       SERVICE#GENERAL   SERVICE        GENERAL
# 3279        1149       SERVICE#GENERAL   SERVICE        GENERAL
# 3341         438       SERVICE#GENERAL   SERVICE        GENERAL
# 3346         451       SERVICE#GENERAL   SERVICE        GENERAL
# 3377        1835       SERVICE#GENERAL   SERVICE        GENERAL
# 3386        1841       SERVICE#GENERAL   SERVICE        GENERAL
#
#                                  target  polarity  \
# 0                                tables  negative
# 1                          candle-light  positive
# 2                        interior decor  positive
# 3                              interior  negative
# 4                                 space  negative
# 5                                 Decor  positive
# 6                                 place  positive
# 7                             trattoria  positive
# 8                           Bombay beer  positive
# 9                                  sake  positive
# 10                                 food  positive
# 11           Guacamole+shrimp appetizer  positive
# 12                                filet  positive
# 13                               frites  negative
# 14                    pad se ew chicken  positive
# 15                                  nan  negative
# 16                               dishes  positive
# 17                             specials  positive
# 18                    regular menu-fare  positive
# 19            parmesean porcini souffle  positive
# 20    lamb glazed with balsamic vinegar  positive
# 22                             pad thai  negative
# 23                                 Food   neutral
# 25                         pork shu mai  negative
# 26                                pizza  negative
# 29                    lava cake dessert  positive
# 30                                Pizza  positive
# 31                               Salads  positive
# 32                             Chow fun  negative
# 33                             calamari  negative
# ...                                 ...       ...
# 3079                           Delivery  negative
# 3081                       Delivery guy  negative
# 3085                         management  negative
# 3096                      delivery guys  negative
# 3100                         wait-staff  negative
# 3102                           maitre-D  negative
# 3107                               girl  negative
# 3109                           Maitre-D  negative
# 3114               front of house staff  negative
# 3116                            kitchen  negative
# 3125                           frontman  negative
# 3144                          maitre d'  negative
# 3162                              STAFF  negative
# 3199                          gentleman  negative
# 3207                               Paul  positive
# 3214                             Winnie  positive
# 3217                         waitstaffs  positive
# 3227                            SERVICE  positive
# 3228                                svc  negative
# 3235                          Waitstaff  positive
# 3251                             clerks  negative
# 3259                             runner  positive
# 3261                               Greg  positive
# 3269                    counter service  negative
# 3271                     service button  positive
# 3279                         proprietor  positive
# 3341                            takeout  positive
# 3346                            Manager  positive
# 3377                            survice  positive
# 3386                            Raymond  positive
#
#                                               embedding  cluster  \
# 0     [-0.26636368, -0.9098466, -0.23358482, -0.0058...        9
# 1     [-0.46664533, -1.2059094, -0.12933376, -0.0101...        9
# 2     [-0.47207767, -1.2466235, -0.20648655, -0.3695...        9
# 3     [-0.1322847, -0.7842638, -0.5341981, -0.113490...        3
# 4     [-0.1815286, -1.1119602, 0.0013807006, 0.19098...        5
# 5     [-0.113958694, -0.471622, -0.07242559, -0.0668...        3
# 6     [-0.39081353, -0.9756247, -0.08489291, -0.0357...        9
# 7     [0.033496413, -0.48428226, -0.31615463, -0.096...        3
# 8     [-0.4347301, -0.95703965, -0.056810495, -0.064...        9
# 9     [-0.2192443, 0.9397465, -0.014916062, 0.225952...        1
# 10    [-0.47516322, -0.961555, -0.17731234, -0.18118...        9
# 11    [-0.06854145, -0.37323, -0.044314533, 0.399161...        6
# 12    [-0.34168184, -0.49487662, 0.020994738, -0.097...        3
# 13    [-0.2287631, -0.7582856, -0.066959545, -0.0762...        3
# 14    [0.33289182, 0.052185904, -0.8525591, 0.350275...        6
# 15    [-0.7499665, -0.37060708, 0.64345133, 0.009676...        3
# 16    [-0.39348292, -1.080029, -0.043364506, -0.1484...        9
# 17    [-0.38640606, -0.82962793, -0.17887753, 0.0566...        9
# 18    [-0.4667635, -1.0173167, -0.1570497, 0.0075294...        9
# 19    [-0.4600465, -0.23957683, -0.79985666, 0.37555...        6
# 20    [-0.31329608, -0.7108887, -0.24648908, 0.28970...        8
# 22    [-0.18351248, -1.0474803, -0.22552904, 0.15184...        9
# 23    [-0.5497083, -0.75514734, -0.4024931, -0.02658...        5
# 25    [-0.13671987, -0.728458, -0.6085098, 0.4404362...        4
# 26    [-0.3765545, -0.96896183, -0.19500884, 0.11035...        9
# 29    [-0.14140247, -0.20586991, -0.38675287, 0.9319...        2
# 30    [-0.028660849, -0.56653464, -0.97096735, -0.38...        1
# 31    [-0.4189093, 0.08567718, -0.09664092, 0.033759...        8
# 32    [-0.3071333, -1.0122243, -0.3104456, -0.168704...        9
# 33    [-0.2183414, -0.08195571, -0.13720761, -0.0469...        0
# ...                                                 ...      ...
# 3079  [-0.1891303, -0.75477743, 0.06273157, -0.30030...        0
# 3081  [-0.05948333, -0.6009672, -0.11128234, -0.3341...        0
# 3085  [-0.58013934, -0.9303903, -0.27164894, -0.0164...        9
# 3096  [-0.30193067, -1.0244681, -0.28621098, -0.0736...        5
# 3100  [-0.3892292, -0.9698842, -0.081255935, -0.0047...        9
# 3102  [-0.11633167, 0.0011260012, -0.43849578, 0.004...        6
# 3107  [-0.38725907, -0.9913441, -0.16050783, -0.1061...        9
# 3109  [-0.6742184, -0.36066398, -0.2828587, 0.056703...        3
# 3114  [-0.5779918, -0.9726927, -0.05904493, -0.12239...        9
# 3116  [-0.43662035, -1.0698681, -0.34155408, 0.06085...        9
# 3125  [-0.31056577, -0.7996651, -0.0052915327, -0.10...        9
# 3144  [-0.12034837, 0.14338435, -0.3662841, -0.03977...        6
# 3162  [-0.8636748, -0.66348904, 0.17155959, 0.374403...        0
# 3199  [-0.103954524, -0.9648916, -0.26258948, 0.0891...        5
# 3207  [-0.36746532, -1.0335523, -0.27401683, 0.20306...        5
# 3214  [-0.38095272, -0.72412527, -0.2001759, -0.3980...        3
# 3217  [-0.13027053, -0.47492895, -0.0094737895, -0.1...        3
# 3227  [-0.40085077, -0.14153846, -0.00077204965, 0.0...        0
# 3228  [-0.4349662, -0.050543595, 0.24507038, 0.29057...        0
# 3235  [-0.20195317, 0.07767895, 0.18735094, 0.037370...        0
# 3251  [-0.55185854, -0.2042745, -0.1983691, -0.18383...        8
# 3259  [-0.42970026, -0.9713752, -0.11947668, -0.0578...        9
# 3261  [-0.25819868, -0.4610199, -0.04703028, 0.14621...        5
# 3269  [-0.38693988, -1.042796, -0.2928939, -0.167844...        9
# 3271  [-0.39446962, -0.90368843, -0.18064892, -0.139...        9
# 3279  [-0.36698812, -0.96068233, -0.021795953, -0.03...        9
# 3341  [-0.21696025, -0.5804167, -0.12419776, 0.08549...        8
# 3346  [-0.588903, -0.8363049, -0.15674219, -0.023523...        9
# 3377  [-0.15937486, -0.58208954, 0.20200385, -0.0311...        8
# 3386  [0.1063706, -0.56191176, -0.5420378, 0.697368,...        2
#
#                                                tooltip
# 0                            AMBIENCE#GENERAL : tables
# 1                      AMBIENCE#GENERAL : candle-light
# 2                    AMBIENCE#GENERAL : interior decor
# 3                          AMBIENCE#GENERAL : interior
# 4                             AMBIENCE#GENERAL : space
# 5                             AMBIENCE#GENERAL : Decor
# 6                             AMBIENCE#GENERAL : place
# 7                         AMBIENCE#GENERAL : trattoria
# 8                   DRINKS#STYLE_OPTIONS : Bombay beer
# 9                                DRINKS#QUALITY : sake
# 10                                 FOOD#QUALITY : food
# 11           FOOD#QUALITY : Guacamole+shrimp appetizer
# 12                                FOOD#QUALITY : filet
# 13                               FOOD#QUALITY : frites
# 14                    FOOD#QUALITY : pad se ew chicken
# 15                                  FOOD#QUALITY : nan
# 16                               FOOD#QUALITY : dishes
# 17                             FOOD#QUALITY : specials
# 18                    FOOD#QUALITY : regular menu-fare
# 19            FOOD#QUALITY : parmesean porcini souffle
# 20    FOOD#QUALITY : lamb glazed with balsamic vinegar
# 22                             FOOD#QUALITY : pad thai
# 23                                 FOOD#QUALITY : Food
# 25                         FOOD#QUALITY : pork shu mai
# 26                                FOOD#QUALITY : pizza
# 29                    FOOD#QUALITY : lava cake dessert
# 30                                FOOD#QUALITY : Pizza
# 31                               FOOD#QUALITY : Salads
# 32                             FOOD#QUALITY : Chow fun
# 33                             FOOD#QUALITY : calamari
# ...                                                ...
# 3079                        SERVICE#GENERAL : Delivery
# 3081                    SERVICE#GENERAL : Delivery guy
# 3085                      SERVICE#GENERAL : management
# 3096                   SERVICE#GENERAL : delivery guys
# 3100                      SERVICE#GENERAL : wait-staff
# 3102                        SERVICE#GENERAL : maitre-D
# 3107                            SERVICE#GENERAL : girl
# 3109                        SERVICE#GENERAL : Maitre-D
# 3114            SERVICE#GENERAL : front of house staff
# 3116                         SERVICE#GENERAL : kitchen
# 3125                        SERVICE#GENERAL : frontman
# 3144                       SERVICE#GENERAL : maitre d'
# 3162                           SERVICE#GENERAL : STAFF
# 3199                       SERVICE#GENERAL : gentleman
# 3207                            SERVICE#GENERAL : Paul
# 3214                          SERVICE#GENERAL : Winnie
# 3217                      SERVICE#GENERAL : waitstaffs
# 3227                         SERVICE#GENERAL : SERVICE
# 3228                             SERVICE#GENERAL : svc
# 3235                       SERVICE#GENERAL : Waitstaff
# 3251                          SERVICE#GENERAL : clerks
# 3259                          SERVICE#GENERAL : runner
# 3261                            SERVICE#GENERAL : Greg
# 3269                 SERVICE#GENERAL : counter service
# 3271                  SERVICE#GENERAL : service button
# 3279                      SERVICE#GENERAL : proprietor
# 3341                         SERVICE#GENERAL : takeout
# 3346                         SERVICE#GENERAL : Manager
# 3377                         SERVICE#GENERAL : survice
# 3386                         SERVICE#GENERAL : Raymond
#
# [946 rows x 9 columns]

# %%
draw_embeddings.draw(draw_embeddings.get_tsne(semeval_2016_df, tooltip_col='tooltip'))
# Out:
# <div>
#
#
#             <div id="740e189d-2136-4c1e-a393-e8deade333c0" class="plotly-graph-div" style="height:1500px; width:1500px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("740e189d-2136-4c1e-a393-e8deade333c0")) {
#                     Plotly.newPlot(
#                         '740e189d-2136-4c1e-a393-e8deade333c0',
#                         [{"marker": {"color": "rgb(253,174,97)", "size": 15, "symbol": 0}, "mode": "markers", "name": "0", "text": ["FOOD#QUALITY : calamari", "AMBIENCE#GENERAL : ambiance", "AMBIENCE#GENERAL : ambience", "AMBIENCE#GENERAL : jukebox's", "AMBIENCE#GENERAL : Atmosphere", "DRINKS#QUALITY : margaritas", "DRINKS#QUALITY : Margaritas", "FOOD#QUALITY : appetizer of oysters, lobster, crab (small size)", "FOOD#QUALITY : Seabass on lobster risotto", "FOOD#QUALITY : brocollis", "FOOD#QUALITY : prawns", "FOOD#QUALITY : chinese food", "FOOD#QUALITY : caeser salad", "FOOD#QUALITY : ingrediants", "FOOD#QUALITY : enchiladas", "FOOD#QUALITY : Oysters", "FOOD#QUALITY : Scallop", "FOOD#QUALITY : Sardine", "FOOD#QUALITY : Lobster", "FOOD#QUALITY : Fluke", "FOOD#QUALITY : scallops", "FOOD#QUALITY : appetizer", "FOOD#QUALITY : filet mignon", "FOOD#QUALITY : creamed Washington russet potatoes", "FOOD#QUALITY : seafood dinners", "FOOD#QUALITY : eel with avodcao", "FOOD#QUALITY : omikase", "FOOD#QUALITY : B Fast burritos", "FOOD#QUALITY : brocolli", "FOOD#QUALITY : shellfish and shrimp appetizer", "FOOD#QUALITY : asparagus", "FOOD#QUALITY : Tuna", "FOOD#QUALITY : filet mignon on top of spinach and mashed potatoes", "FOOD#QUALITY : sashmi", "FOOD#QUALITY : chana masala (garbanzo beans)", "FOOD#QUALITY : Sake Ikura roll", "FOOD#QUALITY : bhartha", "FOOD#QUALITY : fajita salad", "FOOD#QUALITY : fajitas", "FOOD#QUALITY : taco salads", "FOOD#QUALITY : burritos", "FOOD#QUALITY : Hummus", "FOOD#QUALITY : korma", "FOOD#QUALITY : saag paneer", "FOOD#QUALITY : samosas", "FOOD#QUALITY : FOOD", "FOOD#QUALITY : Kafta plate", "FOOD#QUALITY : salsa", "FOOD#QUALITY : sashimi", "FOOD#QUALITY : kafta plate", "LOCATION#GENERAL : SOHO location", "RESTAURANT#GENERAL : Scooner or Later", "RESTAURANT#GENERAL : PLACE", "RESTAURANT#GENERAL : mexican spot", "RESTAURANT#GENERAL : OPEN SESAME", "RESTAURANT#GENERAL : BLUE RIBBON SUSHI", "SERVICE#GENERAL : PEOPLE", "AMBIENCE#GENERAL : atomosphere", "AMBIENCE#GENERAL : Zenkichi", "AMBIENCE#GENERAL : Thalia", "AMBIENCE#GENERAL : jukebox", "AMBIENCE#GENERAL : Downstairs lounge", "AMBIENCE#GENERAL : Ambience", "AMBIENCE#GENERAL : atmoshere", "AMBIENCE#GENERAL : resturant", "AMBIENCE#GENERAL : boths", "AMBIENCE#GENERAL : Cosette", "AMBIENCE#GENERAL : Ambiance", "AMBIENCE#GENERAL : unisex bathroom", "DRINKS#QUALITY : SEASONAL beer", "DRINKS#STYLE_OPTIONS : drink menu", "DRINKS#PRICES : Voss bottles of water", "DRINKS#PRICES : martini", "DRINKS#QUALITY : Gigondas", "DRINKS#PRICES : martinis", "FOOD#QUALITY : calzones", "FOOD#STYLE_OPTIONS : dosas", "FOOD#QUALITY : vegetarian dish", "FOOD#QUALITY : sushimi cucumber roll", "FOOD#QUALITY : Bagels", "FOOD#QUALITY : Gulab Jamun (dessert)", "FOOD#QUALITY : sardines with biscuits", "FOOD#QUALITY : pesto pizza", "FOOD#STYLE_OPTIONS : burgers", "FOOD#QUALITY : appetizers", "FOOD#QUALITY : caviar", "FOOD#QUALITY : mahi mahi (on saffron risotto", "FOOD#STYLE_OPTIONS : buffet", "FOOD#STYLE_OPTIONS : cheeseburgers", "FOOD#STYLE_OPTIONS : trimmings", "FOOD#QUALITY : Spreads", "FOOD#QUALITY : lobster", "FOOD#QUALITY : Unda (Egg) rolls", "FOOD#QUALITY : indo-chinese food", "FOOD#QUALITY : seabass", "FOOD#QUALITY : mussles", "FOOD#STYLE_OPTIONS : pasta penne", "FOOD#QUALITY : eggplant pizza", "FOOD#QUALITY : mussels", "FOOD#QUALITY : BBQ Salmon", "FOOD#QUALITY : Yakitori (bbq meats)", "FOOD#PRICES : japanese food", "FOOD#QUALITY : portobello and asparagus mole", "FOOD#QUALITY : baba ganoush", "FOOD#QUALITY : brioche and lollies", "FOOD#QUALITY : appetizer menu", "FOOD#QUALITY : Margheritta slice", "FOOD#QUALITY : gyros", "FOOD#QUALITY : gyro meat", "FOOD#QUALITY : sausages", "FOOD#QUALITY : gyro", "FOOD#QUALITY : noodles with shrimp and chicken and coconut juice", "FOOD#QUALITY : congee (rice porridge)", "FOOD#STYLE_OPTIONS : BBQ ribs", "FOOD#QUALITY : tiramisu", "FOOD#QUALITY : Appetizers", "FOOD#STYLE_OPTIONS : pasta mains", "FOOD#QUALITY : quesadilla", "FOOD#STYLE_OPTIONS : antipasti", ...

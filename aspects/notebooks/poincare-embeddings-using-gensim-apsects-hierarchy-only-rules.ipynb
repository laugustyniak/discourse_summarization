# %% [markdown]
# # Imports and settings

# %%
# %load_ext autoreload
# %autoreload 2

import os
import logging
import numpy as np
import pandas as pd

from gensim.models.poincare import PoincareModel, PoincareKeyedVectors, PoincareRelations

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))

logging.basicConfig(level=logging.INFO)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# <style>.container { width:90% !important; }</style>

# %%
from pathlib import Path

# %%
import spacy 
nlp = spacy.load('en')

# %%
from tqdm import tqdm  # for notebooks
tqdm.pandas()

# %% [markdown]
# # Load data and models

# %%
from aspects.pipelines.aspect_analysis import AspectAnalysis
from aspects.utilities import settings
from aspects.rst.edu_tree_rules_extractor import EDURelation

DATASET_PATH = settings.AMAZON_REVIEWS_CELL_PHONES_AND_ACCESSORIES_DATASET_JSON

# TODO: better parametrization for experiments
aspect_analysis_gerani = AspectAnalysis(
    input_path=DATASET_PATH.as_posix(),
    output_path=settings.DEFAULT_OUTPUT_PATH / DATASET_PATH.stem,
    experiment_name='gerani',
    jobs=2,
    batch_size=100,
    max_docs=50000
)

# %%
discourse_tree_df = pd.read_pickle(aspect_analysis_gerani.paths.discourse_trees_df)

# %%
from typing import List, NamedTuple

class AspectsRelation(NamedTuple):
    aspect_1: str
    aspect_2: str
    relation_type: str
    weight: float

# %%
from itertools import product

relations = []
cycles = []

for row_id, row in tqdm(discourse_tree_df.iterrows(), total=len(discourse_tree_df), desc='Generating aspect-aspect graph based on rules'):
    for edu_left, edu_right, relation, weight in row.rules:
        for aspect_left, aspect_right in product(row.aspects[edu_left], row.aspects[edu_right]):
            if aspect_left != aspect_right:
                relations.append((aspect_left, aspect_right))
            else:
                cycles.append((aspect_left, aspect_right))

# %%
len(relations)

# %%
relations[:10]

# %%
# from aspects.enrichments import conceptnets

# conceptnet = conceptnets.load_conceptnet_io()
# #  'car' -> 'HasPrerequisite' -> 'tire'

# hierarchical_relations_parent_child = ['HasA', 'MadeOf', 'HasPrerequisite']
# hierarchical_relations_child_parent = ['PartOf', 'IsA']

# def get_neighbours_child_and_parents(conceptnet, concept, relation_types_get_child, relation_types_get_parent):
#     neighbours_childs = set(
#         (concept, concept_info['relation'], "---->", concept_info['end'])
#         for concept_info
#         in conceptnet[concept]
#         if concept_info['relation'] in relation_types_get_child
#     )
#     neighbours_parents = set(
#         (concept_info['start'], concept_info['relation'],  "<----", concept)
        
#         for concept_info
#         in conceptnet[concept]
#         if concept_info['relation'] in relation_types_get_parent
#     )

#     return list(neighbours_childs.union(neighbours_parents))

# get_neighbours_child_and_parents(conceptnet, 'tire', hierarchical_relations_child_parent, hierarchical_relations_parent_child)

# %%
# def get_concepts_based_on_hierarchy_relation(conceptnet, concept, relation_types_get_child, relation_types_get_parent):
#     neighbours_childs = set(
#         (concept_info['end'].replace('_', ' '), concept)
#         for concept_info
#         in conceptnet[concept]
#         if concept_info['relation'] in relation_types_get_child
#     )
#     neighbours_parents = set(
#         (concept_info['start'].replace('_', ' '), concept)
#         for concept_info
#         in conceptnet[concept]
#         if concept_info['relation'] in relation_types_get_parent
#     )

#     return list(neighbours_childs.union(neighbours_parents))

# %%
# get_concepts_based_on_hierarchy_relation(conceptnet, 'battery', hierarchical_relations_child_parent, hierarchical_relations_parent_child)

# %% [markdown]
# ## Add concepts from conceptnet

# %%
# from more_itertools import flatten

# unique_aspects = set(flatten(relations))

# conceptnet_relations = list(flatten([
#     get_concepts_based_on_hierarchy_relation(conceptnet, aspect, hierarchical_relations_child_parent, hierarchical_relations_parent_child)
#     for aspect
#     in unique_aspects 
# ]))

# len(conceptnet_relations)

# conceptnet_relations[:10]

# all_relations = relations + conceptnet_relations

# len(all_relations)

# %% [markdown]
# ## Train or load pre-trained embedding

# %%
all_relations = relations

# %%
model = PoincareModel(train_data=all_relations, size=50, burn_in=0)
# Out:
# INFO:gensim.models.poincare:loading relations from train data..
# INFO:gensim.models.poincare:loaded 22436 relations from train data, 7210 nodes

# %%
model.train(epochs=100, print_every=500)
# Out:
# INFO:gensim.models.poincare:training model of size 50 with 1 workers on 22436 relations for 100 epochs and 0 burn-in epochs, using lr=0.10000 burn-in lr=0.01000 negative=10
# INFO:gensim.models.poincare:starting training (100 epochs)----------------------------------------
# INFO:gensim.models.poincare:training on epoch 1, examples #4990-#5000, loss: 24.05
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.64 s, 3045.27 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #9990-#10000, loss: 23.98
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.50 s, 3331.17 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #14990-#15000, loss: 23.90
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.50 s, 3322.34 examples / s
# INFO:gensim.models.poincare:training on epoch 1, examples #19990-#20000, loss: 23.83
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.56 s, 3204.97 examples / s
# INFO:gensim.models.poincare:training on epoch 2, examples #4990-#5000, loss: 23.40
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.48 s, 3373.10 examples / s
# INFO:gensim.models.poincare:training on epoch 2, examples #9990-#10000, loss: 23.32
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.56 s, 3203.54 examples / s
# INFO:gensim.models.poincare:training on epoch 2, examples #14990-#15000, loss: 23.19
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.67 s, 3002.97 examples / s
# INFO:gensim.models.poincare:training on epoch 2, examples #19990-#20000, loss: 23.13
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.68 s, 2982.36 examples / s
# INFO:gensim.models.poincare:training on epoch 3, examples #4990-#5000, loss: 22.53
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.67 s, 2987.75 examples / s
# INFO:gensim.models.poincare:training on epoch 3, examples #9990-#10000, loss: 22.47
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.59 s, 3141.83 examples / s
# INFO:gensim.models.poincare:training on epoch 3, examples #14990-#15000, loss: 22.38
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.58 s, 3167.22 examples / s
# INFO:gensim.models.poincare:training on epoch 3, examples #19990-#20000, loss: 22.26
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.57 s, 3192.23 examples / s
# INFO:gensim.models.poincare:training on epoch 4, examples #4990-#5000, loss: 21.74
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.59 s, 3152.50 examples / s
# INFO:gensim.models.poincare:training on epoch 4, examples #9990-#10000, loss: 21.67
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.58 s, 3156.51 examples / s
# INFO:gensim.models.poincare:training on epoch 4, examples #14990-#15000, loss: 21.53
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.54 s, 3256.73 examples / s
# INFO:gensim.models.poincare:training on epoch 4, examples #19990-#20000, loss: 21.51
# INFO:gensim.models.poincare:time taken for 5000 examples: 2.14 s, 2337.98 examples / s
# INFO:gensim.models.poincare:training on epoch 5, examples #4990-#5000, loss: 20.96
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.65 s, 3028.97 examples / s
# INFO:gensim.models.poincare:training on epoch 5, examples #9990-#10000, loss: 20.93
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.64 s, 3055.88 examples / s
# INFO:gensim.models.poincare:training on epoch 5, examples #14990-#15000, loss: 20.89
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.72 s, 2906.56 examples / s
# INFO:gensim.models.poincare:training on epoch 5, examples #19990-#20000, loss: 20.79
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.75 s, 2857.30 examples / s
# INFO:gensim.models.poincare:training on epoch 6, examples #4990-#5000, loss: 20.26
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.95 s, 2559.11 examples / s
# INFO:gensim.models.poincare:training on epoch 6, examples #9990-#10000, loss: 20.30
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.88 s, 2657.41 examples / s
# INFO:gensim.models.poincare:training on epoch 6, examples #14990-#15000, loss: 20.22
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.67 s, 2985.73 examples / s
# INFO:gensim.models.poincare:training on epoch 6, examples #19990-#20000, loss: 20.22
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.61 s, 3102.81 examples / s
# INFO:gensim.models.poincare:training on epoch 7, examples #4990-#5000, loss: 19.72
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.56 s, 3198.80 examples / s
# INFO:gensim.models.poincare:training on epoch 7, examples #9990-#10000, loss: 19.72
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.52 s, 3295.36 examples / s
# INFO:gensim.models.poincare:training on epoch 7, examples #14990-#15000, loss: 19.75
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.64 s, 3045.43 examples / s
# INFO:gensim.models.poincare:training on epoch 7, examples #19990-#20000, loss: 19.61
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.67 s, 2993.65 examples / s
# INFO:gensim.models.poincare:training on epoch 8, examples #4990-#5000, loss: 19.18
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.54 s, 3236.28 examples / s
# INFO:gensim.models.poincare:training on epoch 8, examples #9990-#10000, loss: 19.19
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.59 s, 3145.22 examples / s
# INFO:gensim.models.poincare:training on epoch 8, examples #14990-#15000, loss: 19.27
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.56 s, 3206.65 examples / s
# INFO:gensim.models.poincare:training on epoch 8, examples #19990-#20000, loss: 19.13
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.70 s, 2948.50 examples / s
# INFO:gensim.models.poincare:training on epoch 9, examples #4990-#5000, loss: 18.75
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.61 s, 3115.22 examples / s
# INFO:gensim.models.poincare:training on epoch 9, examples #9990-#10000, loss: 18.89
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.65 s, 3031.59 examples / s
# INFO:gensim.models.poincare:training on epoch 9, examples #14990-#15000, loss: 18.67
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.71 s, 2920.68 examples / s
# INFO:gensim.models.poincare:training on epoch 9, examples #19990-#20000, loss: 18.58
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.66 s, 3010.51 examples / s
# INFO:gensim.models.poincare:training on epoch 10, examples #4990-#5000, loss: 18.39
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.68 s, 2979.11 examples / s
# INFO:gensim.models.poincare:training on epoch 10, examples #9990-#10000, loss: 18.35
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.58 s, 3155.23 examples / s
# INFO:gensim.models.poincare:training on epoch 10, examples #14990-#15000, loss: 18.25
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.60 s, 3123.81 examples / s
# INFO:gensim.models.poincare:training on epoch 10, examples #19990-#20000, loss: 18.32
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.67 s, 2998.21 examples / s
# INFO:gensim.models.poincare:training on epoch 11, examples #4990-#5000, loss: 17.93
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.65 s, 3034.69 examples / s
# INFO:gensim.models.poincare:training on epoch 11, examples #9990-#10000, loss: 17.84
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.72 s, 2914.31 examples / s
# INFO:gensim.models.poincare:training on epoch 11, examples #14990-#15000, loss: 17.96
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.77 s, 2831.53 examples / s
# INFO:gensim.models.poincare:training on epoch 11, examples #19990-#20000, loss: 18.03
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.72 s, 2902.79 examples / s
# INFO:gensim.models.poincare:training on epoch 12, examples #4990-#5000, loss: 17.56
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.78 s, 2816.23 examples / s
# INFO:gensim.models.poincare:training on epoch 12, examples #9990-#10000, loss: 17.62
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.62 s, 3082.83 examples / s
# INFO:gensim.models.poincare:training on epoch 12, examples #14990-#15000, loss: 17.59
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.76 s, 2833.01 examples / s
# INFO:gensim.models.poincare:training on epoch 12, examples #19990-#20000, loss: 17.64
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.63 s, 3070.17 examples / s
# INFO:gensim.models.poincare:training on epoch 13, examples #4990-#5000, loss: 17.28
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.53 s, 3261.48 examples / s
# INFO:gensim.models.poincare:training on epoch 13, examples #9990-#10000, loss: 17.35
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.68 s, 2968.06 examples / s
# INFO:gensim.models.poincare:training on epoch 13, examples #14990-#15000, loss: 17.32
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.63 s, 3062.03 examples / s
# INFO:gensim.models.poincare:training on epoch 13, examples #19990-#20000, loss: 17.38
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.59 s, 3138.46 examples / s
# INFO:gensim.models.poincare:training on epoch 14, examples #4990-#5000, loss: 17.02
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.64 s, 3041.85 examples / s
# INFO:gensim.models.poincare:training on epoch 14, examples #9990-#10000, loss: 17.02
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.65 s, 3036.32 examples / s
# INFO:gensim.models.poincare:training on epoch 14, examples #14990-#15000, loss: 17.00
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.63 s, 3060.01 examples / s
# INFO:gensim.models.poincare:training on epoch 14, examples #19990-#20000, loss: 17.13
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.63 s, 3074.36 examples / s
# INFO:gensim.models.poincare:training on epoch 15, examples #4990-#5000, loss: 16.60
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.60 s, 3121.85 examples / s
# INFO:gensim.models.poincare:training on epoch 15, examples #9990-#10000, loss: 16.75
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.61 s, 3100.40 examples / s
# INFO:gensim.models.poincare:training on epoch 15, examples #14990-#15000, loss: 16.89
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.65 s, 3034.22 examples / s
# INFO:gensim.models.poincare:training on epoch 15, examples #19990-#20000, loss: 16.97
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.64 s, 3042.29 examples / s
# INFO:gensim.models.poincare:training on epoch 16, examples #4990-#5000, loss: 16.84
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.66 s, 3014.81 examples / s
# INFO:gensim.models.poincare:training on epoch 16, examples #9990-#10000, loss: 16.45
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.60 s, 3132.94 examples / s
# INFO:gensim.models.poincare:training on epoch 16, examples #14990-#15000, loss: 16.78
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.67 s, 2999.26 examples / s
# INFO:gensim.models.poincare:training on epoch 16, examples #19990-#20000, loss: 16.39
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.63 s, 3067.20 examples / s
# INFO:gensim.models.poincare:training on epoch 17, examples #4990-#5000, loss: 16.29
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.62 s, 3078.58 examples / s
# INFO:gensim.models.poincare:training on epoch 17, examples #9990-#10000, loss: 16.44
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.60 s, 3117.81 examples / s
# INFO:gensim.models.poincare:training on epoch 17, examples #14990-#15000, loss: 16.53
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.58 s, 3160.11 examples / s
# INFO:gensim.models.poincare:training on epoch 17, examples #19990-#20000, loss: 16.47
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.58 s, 3156.73 examples / s
# INFO:gensim.models.poincare:training on epoch 18, examples #4990-#5000, loss: 16.10
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.66 s, 3010.29 examples / s
# INFO:gensim.models.poincare:training on epoch 18, examples #9990-#10000, loss: 16.30
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.50 s, 3330.13 examples / s
# INFO:gensim.models.poincare:training on epoch 18, examples #14990-#15000, loss: 16.26
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.63 s, 3066.52 examples / s
# INFO:gensim.models.poincare:training on epoch 18, examples #19990-#20000, loss: 16.24
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.64 s, 3044.39 examples / s
# INFO:gensim.models.poincare:training on epoch 19, examples #4990-#5000, loss: 15.99
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.73 s, 2888.23 examples / s
# INFO:gensim.models.poincare:training on epoch 19, examples #9990-#10000, loss: 16.03
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.61 s, 3109.39 examples / s
# INFO:gensim.models.poincare:training on epoch 19, examples #14990-#15000, loss: 16.21
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.53 s, 3271.74 examples / s
# INFO:gensim.models.poincare:training on epoch 19, examples #19990-#20000, loss: 16.05
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.75 s, 2854.77 examples / s
# INFO:gensim.models.poincare:training on epoch 20, examples #4990-#5000, loss: 15.93
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.60 s, 3134.79 examples / s
# INFO:gensim.models.poincare:training on epoch 20, examples #9990-#10000, loss: 15.91
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.65 s, 3025.69 examples / s
# INFO:gensim.models.poincare:training on epoch 20, examples #14990-#15000, loss: 15.92
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.62 s, 3086.26 examples / s
# INFO:gensim.models.poincare:training on epoch 20, examples #19990-#20000, loss: 15.90
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.58 s, 3164.55 examples / s
# INFO:gensim.models.poincare:training on epoch 21, examples #4990-#5000, loss: 15.67
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.58 s, 3155.36 examples / s
# INFO:gensim.models.poincare:training on epoch 21, examples #9990-#10000, loss: 15.78
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.59 s, 3138.21 examples / s
# INFO:gensim.models.poincare:training on epoch 21, examples #14990-#15000, loss: 15.75
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.58 s, 3159.21 examples / s
# INFO:gensim.models.poincare:training on epoch 21, examples #19990-#20000, loss: 15.93
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.66 s, 3009.89 examples / s
# INFO:gensim.models.poincare:training on epoch 22, examples #4990-#5000, loss: 15.65
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.60 s, 3118.42 examples / s
# INFO:gensim.models.poincare:training on epoch 22, examples #9990-#10000, loss: 15.57
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.60 s, 3126.50 examples / s
# INFO:gensim.models.poincare:training on epoch 22, examples #14990-#15000, loss: 15.75
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.64 s, 3044.80 examples / s
# INFO:gensim.models.poincare:training on epoch 22, examples #19990-#20000, loss: 15.65
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.60 s, 3117.26 examples / s
# INFO:gensim.models.poincare:training on epoch 23, examples #4990-#5000, loss: 15.51
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.68 s, 2982.46 examples / s
# INFO:gensim.models.poincare:training on epoch 23, examples #9990-#10000, loss: 15.35
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.56 s, 3204.76 examples / s
# INFO:gensim.models.poincare:training on epoch 23, examples #14990-#15000, loss: 15.59
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.59 s, 3151.80 examples / s
# INFO:gensim.models.poincare:training on epoch 23, examples #19990-#20000, loss: 15.59
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.62 s, 3080.33 examples / s
# INFO:gensim.models.poincare:training on epoch 24, examples #4990-#5000, loss: 15.43
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.65 s, 3027.37 examples / s
# INFO:gensim.models.poincare:training on epoch 24, examples #9990-#10000, loss: 15.43
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.71 s, 2917.04 examples / s
# INFO:gensim.models.poincare:training on epoch 24, examples #14990-#15000, loss: 15.52
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.61 s, 3107.04 examples / s
# INFO:gensim.models.poincare:training on epoch 24, examples #19990-#20000, loss: 15.39
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.58 s, 3165.94 examples / s
# INFO:gensim.models.poincare:training on epoch 25, examples #4990-#5000, loss: 15.29
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.54 s, 3248.93 examples / s
# INFO:gensim.models.poincare:training on epoch 25, examples #9990-#10000, loss: 15.44
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.53 s, 3269.18 examples / s
# INFO:gensim.models.poincare:training on epoch 25, examples #14990-#15000, loss: 15.27
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.70 s, 2947.16 examples / s
# INFO:gensim.models.poincare:training on epoch 25, examples #19990-#20000, loss: 15.27
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.56 s, 3203.22 examples / s
# INFO:gensim.models.poincare:training on epoch 26, examples #4990-#5000, loss: 15.21
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.60 s, 3127.38 examples / s
# INFO:gensim.models.poincare:training on epoch 26, examples #9990-#10000, loss: 15.30
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.64 s, 3040.09 examples / s
# INFO:gensim.models.poincare:training on epoch 26, examples #14990-#15000, loss: 15.08
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.58 s, 3157.37 examples / s
# INFO:gensim.models.poincare:training on epoch 26, examples #19990-#20000, loss: 15.42
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.55 s, 3217.09 examples / s
# INFO:gensim.models.poincare:training on epoch 27, examples #4990-#5000, loss: 15.21
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.56 s, 3212.32 examples / s
# INFO:gensim.models.poincare:training on epoch 27, examples #9990-#10000, loss: 15.36
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.54 s, 3251.68 examples / s
# INFO:gensim.models.poincare:training on epoch 27, examples #14990-#15000, loss: 15.20
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.53 s, 3260.21 examples / s
# INFO:gensim.models.poincare:training on epoch 27, examples #19990-#20000, loss: 15.27
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.57 s, 3175.44 examples / s
# INFO:gensim.models.poincare:training on epoch 28, examples #4990-#5000, loss: 15.10
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.55 s, 3230.03 examples / s
# INFO:gensim.models.poincare:training on epoch 28, examples #9990-#10000, loss: 15.04
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.54 s, 3256.42 examples / s
# INFO:gensim.models.poincare:training on epoch 28, examples #14990-#15000, loss: 15.17
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.54 s, 3250.06 examples / s
# INFO:gensim.models.poincare:training on epoch 28, examples #19990-#20000, loss: 15.13
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.55 s, 3227.08 examples / s
# INFO:gensim.models.poincare:training on epoch 29, examples #4990-#5000, loss: 14.94
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.52 s, 3285.14 examples / s
# INFO:gensim.models.poincare:training on epoch 29, examples #9990-#10000, loss: 15.06
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.56 s, 3197.53 examples / s
# INFO:gensim.models.poincare:training on epoch 29, examples #14990-#15000, loss: 14.91
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.55 s, 3216.51 examples / s
# INFO:gensim.models.poincare:training on epoch 29, examples #19990-#20000, loss: 15.20
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.56 s, 3214.22 examples / s
# INFO:gensim.models.poincare:training on epoch 30, examples #4990-#5000, loss: 14.75
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.55 s, 3234.04 examples / s
# INFO:gensim.models.poincare:training on epoch 30, examples #9990-#10000, loss: 14.81
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.51 s, 3304.38 examples / s
# INFO:gensim.models.poincare:training on epoch 30, examples #14990-#15000, loss: 15.17
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.58 s, 3174.37 examples / s
# INFO:gensim.models.poincare:training on epoch 30, examples #19990-#20000, loss: 15.12
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.55 s, 3231.15 examples / s
# INFO:gensim.models.poincare:training on epoch 31, examples #4990-#5000, loss: 14.79
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.65 s, 3030.32 examples / s
# INFO:gensim.models.poincare:training on epoch 31, examples #9990-#10000, loss: 14.83
# INFO:gensim.models.poincare:time taken for 5000 examples: 2.01 s, 2488.99 examples / s
# INFO:gensim.models.poincare:training on epoch 31, examples #14990-#15000, loss: 14.93
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.71 s, 2930.53 examples / s
# INFO:gensim.models.poincare:training on epoch 31, examples #19990-#20000, loss: 15.10
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.77 s, 2831.27 examples / s
# INFO:gensim.models.poincare:training on epoch 32, examples #4990-#5000, loss: 14.74
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.84 s, 2720.24 examples / s
# INFO:gensim.models.poincare:training on epoch 32, examples #9990-#10000, loss: 14.82
# INFO:gensim.models.poincare:time taken for 5000 examples: 2.06 s, 2427.54 examples / s
# INFO:gensim.models.poincare:training on epoch 32, examples #14990-#15000, loss: 14.82
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.77 s, 2827.05 examples / s
# INFO:gensim.models.poincare:training on epoch 32, examples #19990-#20000, loss: 14.97
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.92 s, 2608.82 examples / s
# INFO:gensim.models.poincare:training on epoch 33, examples #4990-#5000, loss: 14.77
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.64 s, 3043.85 examples / s
# INFO:gensim.models.poincare:training on epoch 33, examples #9990-#10000, loss: 14.78
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.85 s, 2703.45 examples / s
# INFO:gensim.models.poincare:training on epoch 33, examples #14990-#15000, loss: 14.84
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.59 s, 3143.46 examples / s
# INFO:gensim.models.poincare:training on epoch 33, examples #19990-#20000, loss: 14.79
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.59 s, 3142.06 examples / s
# INFO:gensim.models.poincare:training on epoch 34, examples #4990-#5000, loss: 14.64
# INFO:gensim.models.poincare:time taken for 5000 examples: 2.05 s, 2437.16 examples / s
# INFO:gensim.models.poincare:training on epoch 34, examples #9990-#10000, loss: 14.78
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.81 s, 2767.57 examples / s
# INFO:gensim.models.poincare:training on epoch 34, examples #14990-#15000, loss: 14.79
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.75 s, 2855.71 examples / s
# INFO:gensim.models.poincare:training on epoch 34, examples #19990-#20000, loss: 14.74
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.78 s, 2802.14 examples / s
# INFO:gensim.models.poincare:training on epoch 35, examples #4990-#5000, loss: 14.59
# INFO:gensim.models.poincare:time taken for 5000 examples: 2.34 s, 2134.79 examples / s
# INFO:gensim.models.poincare:training on epoch 35, examples #9990-#10000, loss: 14.82
# INFO:gensim.models.poincare:time taken for 5000 examples: 2.20 s, 2273.74 examples / s
# INFO:gensim.models.poincare:training on epoch 35, examples #14990-#15000, loss: 14.70
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.86 s, 2683.46 examples / s
# INFO:gensim.models.poincare:training on epoch 35, examples #19990-#20000, loss: 14.63
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.66 s, 3003.42 examples / s
# INFO:gensim.models.poincare:training on epoch 36, examples #4990-#5000, loss: 14.59
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.65 s, 3031.30 examples / s
# INFO:gensim.models.poincare:training on epoch 36, examples #9990-#10000, loss: 14.54
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.60 s, 3126.75 examples / s
# INFO:gensim.models.poincare:training on epoch 36, examples #14990-#15000, loss: 14.67
# INFO:gensim.models.poincare:time taken for 5000 examples: 2.01 s, 2486.19 examples / s
# INFO:gensim.models.poincare:training on epoch 36, examples #19990-#20000, loss: 14.73
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.72 s, 2913.26 examples / s
# INFO:gensim.models.poincare:training on epoch 37, examples #4990-#5000, loss: 14.51
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.76 s, 2834.40 examples / s
# INFO:gensim.models.poincare:training on epoch 37, examples #9990-#10000, loss: 14.73
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.73 s, 2892.83 examples / s
# INFO:gensim.models.poincare:training on epoch 37, examples #14990-#15000, loss: 14.61
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.57 s, 3175.44 examples / s
# INFO:gensim.models.poincare:training on epoch 37, examples #19990-#20000, loss: 14.66
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.60 s, 3129.36 examples / s
# INFO:gensim.models.poincare:training on epoch 38, examples #4990-#5000, loss: 14.70
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.66 s, 3018.81 examples / s
# INFO:gensim.models.poincare:training on epoch 38, examples #9990-#10000, loss: 14.41
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.92 s, 2599.63 examples / s
# INFO:gensim.models.poincare:training on epoch 38, examples #14990-#15000, loss: 14.63
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.81 s, 2761.22 examples / s
# INFO:gensim.models.poincare:training on epoch 38, examples #19990-#20000, loss: 14.46
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.65 s, 3022.86 examples / s
# INFO:gensim.models.poincare:training on epoch 39, examples #4990-#5000, loss: 14.49
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.97 s, 2543.07 examples / s
# INFO:gensim.models.poincare:training on epoch 39, examples #9990-#10000, loss: 14.36
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.64 s, 3041.56 examples / s
# INFO:gensim.models.poincare:training on epoch 39, examples #14990-#15000, loss: 14.68
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.80 s, 2780.49 examples / s
# INFO:gensim.models.poincare:training on epoch 39, examples #19990-#20000, loss: 14.64
# INFO:gensim.models.poincare:time taken for 5000 examples: 2.21 s, 2261.63 examples / s
# INFO:gensim.models.poincare:training on epoch 40, examples #4990-#5000, loss: 14.47
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.75 s, 2854.53 examples / s
# INFO:gensim.models.poincare:training on epoch 40, examples #9990-#10000, loss: 14.53
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.67 s, 2999.57 examples / s
# INFO:gensim.models.poincare:training on epoch 40, examples #14990-#15000, loss: 14.51
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.86 s, 2691.04 examples / s
# INFO:gensim.models.poincare:training on epoch 40, examples #19990-#20000, loss: 14.42
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.71 s, 2932.34 examples / s
# INFO:gensim.models.poincare:training on epoch 41, examples #4990-#5000, loss: 14.32
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.58 s, 3163.83 examples / s
# INFO:gensim.models.poincare:training on epoch 41, examples #9990-#10000, loss: 14.54
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.58 s, 3166.37 examples / s
# INFO:gensim.models.poincare:training on epoch 41, examples #14990-#15000, loss: 14.41
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.55 s, 3218.87 examples / s
# INFO:gensim.models.poincare:training on epoch 41, examples #19990-#20000, loss: 14.40
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.58 s, 3171.70 examples / s
# INFO:gensim.models.poincare:training on epoch 42, examples #4990-#5000, loss: 14.36
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.57 s, 3184.21 examples / s
# INFO:gensim.models.poincare:training on epoch 42, examples #9990-#10000, loss: 14.25
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.56 s, 3207.69 examples / s
# INFO:gensim.models.poincare:training on epoch 42, examples #14990-#15000, loss: 14.45
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.59 s, 3135.21 examples / s
# INFO:gensim.models.poincare:training on epoch 42, examples #19990-#20000, loss: 14.44
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.58 s, 3170.34 examples / s
# INFO:gensim.models.poincare:training on epoch 43, examples #4990-#5000, loss: 14.24
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.62 s, 3087.32 examples / s
# INFO:gensim.models.poincare:training on epoch 43, examples #9990-#10000, loss: 14.35
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.71 s, 2923.54 examples / s
# INFO:gensim.models.poincare:training on epoch 43, examples #14990-#15000, loss: 14.33
# INFO:gensim.models.poincare:time taken for 5000 examples: 2.25 s, 2219.10 examples / s
# INFO:gensim.models.poincare:training on epoch 43, examples #19990-#20000, loss: 14.61
# INFO:gensim.models.poincare:time taken for 5000 examples: 2.06 s, 2432.90 examples / s
# INFO:gensim.models.poincare:training on epoch 44, examples #4990-#5000, loss: 14.30
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.91 s, 2618.25 examples / s
# INFO:gensim.models.poincare:training on epoch 44, examples #9990-#10000, loss: 14.34
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.81 s, 2765.01 examples / s
# INFO:gensim.models.poincare:training on epoch 44, examples #14990-#15000, loss: 14.28
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.70 s, 2941.22 examples / s
# INFO:gensim.models.poincare:training on epoch 44, examples #19990-#20000, loss: 14.46
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.70 s, 2948.59 examples / s
# INFO:gensim.models.poincare:training on epoch 45, examples #4990-#5000, loss: 14.25
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.67 s, 2996.46 examples / s
# INFO:gensim.models.poincare:training on epoch 45, examples #9990-#10000, loss: 14.31
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.63 s, 3073.89 examples / s
# INFO:gensim.models.poincare:training on epoch 45, examples #14990-#15000, loss: 14.38
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.70 s, 2948.63 examples / s
# INFO:gensim.models.poincare:training on epoch 45, examples #19990-#20000, loss: 14.29
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.66 s, 3020.68 examples / s
# INFO:gensim.models.poincare:training on epoch 46, examples #4990-#5000, loss: 14.40
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.75 s, 2864.60 examples / s
# INFO:gensim.models.poincare:training on epoch 46, examples #9990-#10000, loss: 14.27
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.64 s, 3041.11 examples / s
# INFO:gensim.models.poincare:training on epoch 46, examples #14990-#15000, loss: 14.10
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.66 s, 3010.03 examples / s
# INFO:gensim.models.poincare:training on epoch 46, examples #19990-#20000, loss: 14.19
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.67 s, 2991.35 examples / s
# INFO:gensim.models.poincare:training on epoch 47, examples #4990-#5000, loss: 14.20
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.64 s, 3049.93 examples / s
# INFO:gensim.models.poincare:training on epoch 47, examples #9990-#10000, loss: 14.37
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.67 s, 2986.43 examples / s
# INFO:gensim.models.poincare:training on epoch 47, examples #14990-#15000, loss: 14.07
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.69 s, 2950.27 examples / s
# INFO:gensim.models.poincare:training on epoch 47, examples #19990-#20000, loss: 14.30
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.80 s, 2776.16 examples / s
# INFO:gensim.models.poincare:training on epoch 48, examples #4990-#5000, loss: 14.19
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.70 s, 2948.45 examples / s
# INFO:gensim.models.poincare:training on epoch 48, examples #9990-#10000, loss: 14.07
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.70 s, 2945.33 examples / s
# INFO:gensim.models.poincare:training on epoch 48, examples #14990-#15000, loss: 14.14
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.72 s, 2910.31 examples / s
# INFO:gensim.models.poincare:training on epoch 48, examples #19990-#20000, loss: 14.34
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.63 s, 3062.19 examples / s
# INFO:gensim.models.poincare:training on epoch 49, examples #4990-#5000, loss: 13.98
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.66 s, 3018.85 examples / s
# INFO:gensim.models.poincare:training on epoch 49, examples #9990-#10000, loss: 14.24
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.65 s, 3023.15 examples / s
# INFO:gensim.models.poincare:training on epoch 49, examples #14990-#15000, loss: 14.38
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.75 s, 2859.34 examples / s
# INFO:gensim.models.poincare:training on epoch 49, examples #19990-#20000, loss: 14.26
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.71 s, 2922.33 examples / s
# INFO:gensim.models.poincare:training on epoch 50, examples #4990-#5000, loss: 13.97
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.71 s, 2920.43 examples / s
# INFO:gensim.models.poincare:training on epoch 50, examples #9990-#10000, loss: 13.95
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.66 s, 3017.05 examples / s
# INFO:gensim.models.poincare:training on epoch 50, examples #14990-#15000, loss: 14.35
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.66 s, 3015.66 examples / s
# INFO:gensim.models.poincare:training on epoch 50, examples #19990-#20000, loss: 14.38
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.65 s, 3022.66 examples / s
# INFO:gensim.models.poincare:training on epoch 51, examples #4990-#5000, loss: 13.94
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.92 s, 2610.65 examples / s
# INFO:gensim.models.poincare:training on epoch 51, examples #9990-#10000, loss: 14.30
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.89 s, 2641.16 examples / s
# INFO:gensim.models.poincare:training on epoch 51, examples #14990-#15000, loss: 14.24
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.75 s, 2854.59 examples / s
# INFO:gensim.models.poincare:training on epoch 51, examples #19990-#20000, loss: 14.17
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.55 s, 3221.43 examples / s
# INFO:gensim.models.poincare:training on epoch 52, examples #4990-#5000, loss: 13.99
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.63 s, 3074.20 examples / s
# INFO:gensim.models.poincare:training on epoch 52, examples #9990-#10000, loss: 14.25
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.55 s, 3226.99 examples / s
# INFO:gensim.models.poincare:training on epoch 52, examples #14990-#15000, loss: 14.14
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.65 s, 3034.54 examples / s
# INFO:gensim.models.poincare:training on epoch 52, examples #19990-#20000, loss: 14.09
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.56 s, 3213.74 examples / s
# INFO:gensim.models.poincare:training on epoch 53, examples #4990-#5000, loss: 14.09
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.87 s, 2678.21 examples / s
# INFO:gensim.models.poincare:training on epoch 53, examples #9990-#10000, loss: 14.18
# INFO:gensim.models.poincare:time taken for 5000 examples: 2.12 s, 2360.34 examples / s
# INFO:gensim.models.poincare:training on epoch 53, examples #14990-#15000, loss: 14.10
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.93 s, 2585.43 examples / s
# INFO:gensim.models.poincare:training on epoch 53, examples #19990-#20000, loss: 14.01
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.89 s, 2640.21 examples / s
# INFO:gensim.models.poincare:training on epoch 54, examples #4990-#5000, loss: 13.85
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.76 s, 2844.77 examples / s
# INFO:gensim.models.poincare:training on epoch 54, examples #9990-#10000, loss: 14.02
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.63 s, 3067.33 examples / s
# INFO:gensim.models.poincare:training on epoch 54, examples #14990-#15000, loss: 14.22
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.81 s, 2765.63 examples / s
# INFO:gensim.models.poincare:training on epoch 54, examples #19990-#20000, loss: 14.05
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.75 s, 2861.70 examples / s
# INFO:gensim.models.poincare:training on epoch 55, examples #4990-#5000, loss: 13.90
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.69 s, 2953.47 examples / s
# INFO:gensim.models.poincare:training on epoch 55, examples #9990-#10000, loss: 14.12
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.69 s, 2963.74 examples / s
# INFO:gensim.models.poincare:training on epoch 55, examples #14990-#15000, loss: 14.14
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.59 s, 3135.88 examples / s
# INFO:gensim.models.poincare:training on epoch 55, examples #19990-#20000, loss: 14.07
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.52 s, 3290.32 examples / s
# INFO:gensim.models.poincare:training on epoch 56, examples #4990-#5000, loss: 13.91
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.63 s, 3067.18 examples / s
# INFO:gensim.models.poincare:training on epoch 56, examples #9990-#10000, loss: 13.99
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.61 s, 3112.78 examples / s
# INFO:gensim.models.poincare:training on epoch 56, examples #14990-#15000, loss: 14.16
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.61 s, 3108.83 examples / s
# INFO:gensim.models.poincare:training on epoch 56, examples #19990-#20000, loss: 14.09
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.69 s, 2953.30 examples / s
# INFO:gensim.models.poincare:training on epoch 57, examples #4990-#5000, loss: 14.04
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.60 s, 3133.41 examples / s
# INFO:gensim.models.poincare:training on epoch 57, examples #9990-#10000, loss: 13.96
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.72 s, 2907.74 examples / s
# INFO:gensim.models.poincare:training on epoch 57, examples #14990-#15000, loss: 14.03
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.61 s, 3110.36 examples / s
# INFO:gensim.models.poincare:training on epoch 57, examples #19990-#20000, loss: 14.10
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.89 s, 2649.28 examples / s
# INFO:gensim.models.poincare:training on epoch 58, examples #4990-#5000, loss: 13.92
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.61 s, 3098.45 examples / s
# INFO:gensim.models.poincare:training on epoch 58, examples #9990-#10000, loss: 13.88
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.66 s, 3018.79 examples / s
# INFO:gensim.models.poincare:training on epoch 58, examples #14990-#15000, loss: 14.13
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.65 s, 3032.34 examples / s
# INFO:gensim.models.poincare:training on epoch 58, examples #19990-#20000, loss: 14.05
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.62 s, 3080.21 examples / s
# INFO:gensim.models.poincare:training on epoch 59, examples #4990-#5000, loss: 13.81
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.61 s, 3101.02 examples / s
# INFO:gensim.models.poincare:training on epoch 59, examples #9990-#10000, loss: 14.17
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.69 s, 2964.21 examples / s
# INFO:gensim.models.poincare:training on epoch 59, examples #14990-#15000, loss: 14.01
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.60 s, 3131.41 examples / s
# INFO:gensim.models.poincare:training on epoch 59, examples #19990-#20000, loss: 13.91
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.68 s, 2973.26 examples / s
# INFO:gensim.models.poincare:training on epoch 60, examples #4990-#5000, loss: 13.75
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.65 s, 3031.68 examples / s
# INFO:gensim.models.poincare:training on epoch 60, examples #9990-#10000, loss: 14.06
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.61 s, 3104.98 examples / s
# INFO:gensim.models.poincare:training on epoch 60, examples #14990-#15000, loss: 13.96
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.70 s, 2947.41 examples / s
# INFO:gensim.models.poincare:training on epoch 60, examples #19990-#20000, loss: 14.00
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.62 s, 3092.01 examples / s
# INFO:gensim.models.poincare:training on epoch 61, examples #4990-#5000, loss: 13.68
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.67 s, 2992.91 examples / s
# INFO:gensim.models.poincare:training on epoch 61, examples #9990-#10000, loss: 13.93
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.86 s, 2686.43 examples / s
# INFO:gensim.models.poincare:training on epoch 61, examples #14990-#15000, loss: 13.84
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.76 s, 2847.63 examples / s
# INFO:gensim.models.poincare:training on epoch 61, examples #19990-#20000, loss: 14.20
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.59 s, 3141.96 examples / s
# INFO:gensim.models.poincare:training on epoch 62, examples #4990-#5000, loss: 13.89
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.65 s, 3037.97 examples / s
# INFO:gensim.models.poincare:training on epoch 62, examples #9990-#10000, loss: 13.94
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.70 s, 2938.82 examples / s
# INFO:gensim.models.poincare:training on epoch 62, examples #14990-#15000, loss: 13.92
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.59 s, 3145.49 examples / s
# INFO:gensim.models.poincare:training on epoch 62, examples #19990-#20000, loss: 14.12
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.53 s, 3262.19 examples / s
# INFO:gensim.models.poincare:training on epoch 63, examples #4990-#5000, loss: 13.69
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.54 s, 3242.93 examples / s
# INFO:gensim.models.poincare:training on epoch 63, examples #9990-#10000, loss: 13.89
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.61 s, 3106.75 examples / s
# INFO:gensim.models.poincare:training on epoch 63, examples #14990-#15000, loss: 13.88
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.57 s, 3180.99 examples / s
# INFO:gensim.models.poincare:training on epoch 63, examples #19990-#20000, loss: 14.10
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.56 s, 3204.20 examples / s
# INFO:gensim.models.poincare:training on epoch 64, examples #4990-#5000, loss: 13.87
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.55 s, 3224.63 examples / s
# INFO:gensim.models.poincare:training on epoch 64, examples #9990-#10000, loss: 13.91
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.54 s, 3242.74 examples / s
# INFO:gensim.models.poincare:training on epoch 64, examples #14990-#15000, loss: 13.78
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.52 s, 3285.48 examples / s
# INFO:gensim.models.poincare:training on epoch 64, examples #19990-#20000, loss: 14.08
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.57 s, 3187.77 examples / s
# INFO:gensim.models.poincare:training on epoch 65, examples #4990-#5000, loss: 13.82
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.53 s, 3271.76 examples / s
# INFO:gensim.models.poincare:training on epoch 65, examples #9990-#10000, loss: 13.81
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.53 s, 3268.39 examples / s
# INFO:gensim.models.poincare:training on epoch 65, examples #14990-#15000, loss: 14.03
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.59 s, 3141.77 examples / s
# INFO:gensim.models.poincare:training on epoch 65, examples #19990-#20000, loss: 13.99
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.58 s, 3159.35 examples / s
# INFO:gensim.models.poincare:training on epoch 66, examples #4990-#5000, loss: 13.77
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.58 s, 3170.69 examples / s
# INFO:gensim.models.poincare:training on epoch 66, examples #9990-#10000, loss: 13.95
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.55 s, 3231.69 examples / s
# INFO:gensim.models.poincare:training on epoch 66, examples #14990-#15000, loss: 13.81
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.55 s, 3230.53 examples / s
# INFO:gensim.models.poincare:training on epoch 66, examples #19990-#20000, loss: 13.87
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.53 s, 3263.36 examples / s
# INFO:gensim.models.poincare:training on epoch 67, examples #4990-#5000, loss: 13.62
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.52 s, 3292.36 examples / s
# INFO:gensim.models.poincare:training on epoch 67, examples #9990-#10000, loss: 13.84
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.53 s, 3263.43 examples / s
# INFO:gensim.models.poincare:training on epoch 67, examples #14990-#15000, loss: 14.07
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.56 s, 3207.90 examples / s
# INFO:gensim.models.poincare:training on epoch 67, examples #19990-#20000, loss: 13.69
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.54 s, 3256.59 examples / s
# INFO:gensim.models.poincare:training on epoch 68, examples #4990-#5000, loss: 13.90
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.56 s, 3214.07 examples / s
# INFO:gensim.models.poincare:training on epoch 68, examples #9990-#10000, loss: 14.01
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.55 s, 3220.32 examples / s
# INFO:gensim.models.poincare:training on epoch 68, examples #14990-#15000, loss: 13.88
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.53 s, 3265.75 examples / s
# INFO:gensim.models.poincare:training on epoch 68, examples #19990-#20000, loss: 13.79
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.55 s, 3230.82 examples / s
# INFO:gensim.models.poincare:training on epoch 69, examples #4990-#5000, loss: 13.62
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.49 s, 3355.65 examples / s
# INFO:gensim.models.poincare:training on epoch 69, examples #9990-#10000, loss: 13.78
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.55 s, 3226.47 examples / s
# INFO:gensim.models.poincare:training on epoch 69, examples #14990-#15000, loss: 13.88
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.55 s, 3216.71 examples / s
# INFO:gensim.models.poincare:training on epoch 69, examples #19990-#20000, loss: 13.89
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.50 s, 3338.03 examples / s
# INFO:gensim.models.poincare:training on epoch 70, examples #4990-#5000, loss: 13.98
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.54 s, 3257.27 examples / s
# ...
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.55 s, 3231.62 examples / s
# INFO:gensim.models.poincare:training on epoch 78, examples #4990-#5000, loss: 13.64
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.56 s, 3204.23 examples / s
# INFO:gensim.models.poincare:training on epoch 78, examples #9990-#10000, loss: 13.61
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.56 s, 3210.60 examples / s
# INFO:gensim.models.poincare:training on epoch 78, examples #14990-#15000, loss: 13.82
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.52 s, 3287.27 examples / s
# INFO:gensim.models.poincare:training on epoch 78, examples #19990-#20000, loss: 13.90
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.57 s, 3193.83 examples / s
# INFO:gensim.models.poincare:training on epoch 79, examples #4990-#5000, loss: 13.83
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.59 s, 3136.21 examples / s
# INFO:gensim.models.poincare:training on epoch 79, examples #9990-#10000, loss: 13.63
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.53 s, 3269.02 examples / s
# INFO:gensim.models.poincare:training on epoch 79, examples #14990-#15000, loss: 13.72
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.52 s, 3290.67 examples / s
# INFO:gensim.models.poincare:training on epoch 79, examples #19990-#20000, loss: 13.87
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.52 s, 3285.36 examples / s
# INFO:gensim.models.poincare:training on epoch 80, examples #4990-#5000, loss: 13.73
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.56 s, 3207.07 examples / s
# INFO:gensim.models.poincare:training on epoch 80, examples #9990-#10000, loss: 13.80
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.53 s, 3270.89 examples / s
# INFO:gensim.models.poincare:training on epoch 80, examples #14990-#15000, loss: 13.76
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.53 s, 3259.22 examples / s
# INFO:gensim.models.poincare:training on epoch 80, examples #19990-#20000, loss: 13.58
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.53 s, 3264.85 examples / s
# INFO:gensim.models.poincare:training on epoch 81, examples #4990-#5000, loss: 13.49
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.59 s, 3146.25 examples / s
# INFO:gensim.models.poincare:training on epoch 81, examples #9990-#10000, loss: 13.72
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.49 s, 3359.53 examples / s
# INFO:gensim.models.poincare:training on epoch 81, examples #14990-#15000, loss: 13.76
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.55 s, 3221.45 examples / s
# INFO:gensim.models.poincare:training on epoch 81, examples #19990-#20000, loss: 13.72
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.57 s, 3182.13 examples / s
# INFO:gensim.models.poincare:training on epoch 82, examples #4990-#5000, loss: 13.48
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.54 s, 3248.28 examples / s
# INFO:gensim.models.poincare:training on epoch 82, examples #9990-#10000, loss: 13.75
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.54 s, 3253.61 examples / s
# INFO:gensim.models.poincare:training on epoch 82, examples #14990-#15000, loss: 13.76
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.56 s, 3195.45 examples / s
# INFO:gensim.models.poincare:training on epoch 82, examples #19990-#20000, loss: 13.80
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.55 s, 3223.14 examples / s
# INFO:gensim.models.poincare:training on epoch 83, examples #4990-#5000, loss: 13.63
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.56 s, 3212.58 examples / s
# INFO:gensim.models.poincare:training on epoch 83, examples #9990-#10000, loss: 13.71
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.57 s, 3191.63 examples / s
# INFO:gensim.models.poincare:training on epoch 83, examples #14990-#15000, loss: 13.71
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.50 s, 3335.43 examples / s
# INFO:gensim.models.poincare:training on epoch 83, examples #19990-#20000, loss: 13.64
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.54 s, 3244.53 examples / s
# INFO:gensim.models.poincare:training on epoch 84, examples #4990-#5000, loss: 13.57
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.55 s, 3226.83 examples / s
# INFO:gensim.models.poincare:training on epoch 84, examples #9990-#10000, loss: 13.79
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.58 s, 3168.53 examples / s
# INFO:gensim.models.poincare:training on epoch 84, examples #14990-#15000, loss: 13.69
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.55 s, 3225.00 examples / s
# INFO:gensim.models.poincare:training on epoch 84, examples #19990-#20000, loss: 13.77
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.53 s, 3260.14 examples / s
# INFO:gensim.models.poincare:training on epoch 85, examples #4990-#5000, loss: 13.71
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.53 s, 3263.97 examples / s
# INFO:gensim.models.poincare:training on epoch 85, examples #9990-#10000, loss: 13.64
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.53 s, 3267.85 examples / s
# INFO:gensim.models.poincare:training on epoch 85, examples #14990-#15000, loss: 13.74
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.59 s, 3144.51 examples / s
# INFO:gensim.models.poincare:training on epoch 85, examples #19990-#20000, loss: 13.64
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.53 s, 3270.36 examples / s
# INFO:gensim.models.poincare:training on epoch 86, examples #4990-#5000, loss: 13.51
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.60 s, 3117.75 examples / s
# INFO:gensim.models.poincare:training on epoch 86, examples #9990-#10000, loss: 13.66
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.54 s, 3249.44 examples / s
# INFO:gensim.models.poincare:training on epoch 86, examples #14990-#15000, loss: 13.80
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.60 s, 3126.91 examples / s
# INFO:gensim.models.poincare:training on epoch 86, examples #19990-#20000, loss: 13.81
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.52 s, 3293.66 examples / s
# INFO:gensim.models.poincare:training on epoch 87, examples #4990-#5000, loss: 13.80
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.56 s, 3212.94 examples / s
# INFO:gensim.models.poincare:training on epoch 87, examples #9990-#10000, loss: 13.55
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.58 s, 3164.84 examples / s
# INFO:gensim.models.poincare:training on epoch 87, examples #14990-#15000, loss: 13.57
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.62 s, 3094.13 examples / s
# INFO:gensim.models.poincare:training on epoch 87, examples #19990-#20000, loss: 13.73
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.55 s, 3225.35 examples / s
# INFO:gensim.models.poincare:training on epoch 88, examples #4990-#5000, loss: 13.51
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.52 s, 3293.51 examples / s
# INFO:gensim.models.poincare:training on epoch 88, examples #9990-#10000, loss: 13.81
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.57 s, 3190.43 examples / s
# INFO:gensim.models.poincare:training on epoch 88, examples #14990-#15000, loss: 13.70
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.54 s, 3247.72 examples / s
# INFO:gensim.models.poincare:training on epoch 88, examples #19990-#20000, loss: 13.54
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.50 s, 3324.61 examples / s
# INFO:gensim.models.poincare:training on epoch 89, examples #4990-#5000, loss: 13.47
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.53 s, 3269.44 examples / s
# INFO:gensim.models.poincare:training on epoch 89, examples #9990-#10000, loss: 13.71
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.55 s, 3216.14 examples / s
# INFO:gensim.models.poincare:training on epoch 89, examples #14990-#15000, loss: 13.65
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.57 s, 3186.51 examples / s
# INFO:gensim.models.poincare:training on epoch 89, examples #19990-#20000, loss: 13.59
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.51 s, 3320.55 examples / s
# INFO:gensim.models.poincare:training on epoch 90, examples #4990-#5000, loss: 13.77
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.55 s, 3229.42 examples / s
# INFO:gensim.models.poincare:training on epoch 90, examples #9990-#10000, loss: 13.43
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.55 s, 3232.12 examples / s
# INFO:gensim.models.poincare:training on epoch 90, examples #14990-#15000, loss: 13.75
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.57 s, 3185.07 examples / s
# INFO:gensim.models.poincare:training on epoch 90, examples #19990-#20000, loss: 13.73
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.55 s, 3226.00 examples / s
# INFO:gensim.models.poincare:training on epoch 91, examples #4990-#5000, loss: 13.62
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.55 s, 3221.29 examples / s
# INFO:gensim.models.poincare:training on epoch 91, examples #9990-#10000, loss: 13.85
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.54 s, 3238.22 examples / s
# INFO:gensim.models.poincare:training on epoch 91, examples #14990-#15000, loss: 13.64
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.54 s, 3252.73 examples / s
# INFO:gensim.models.poincare:training on epoch 91, examples #19990-#20000, loss: 13.56
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.52 s, 3286.68 examples / s
# INFO:gensim.models.poincare:training on epoch 92, examples #4990-#5000, loss: 13.47
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.54 s, 3249.53 examples / s
# INFO:gensim.models.poincare:training on epoch 92, examples #9990-#10000, loss: 13.51
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.52 s, 3283.50 examples / s
# INFO:gensim.models.poincare:training on epoch 92, examples #14990-#15000, loss: 13.74
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.58 s, 3160.84 examples / s
# INFO:gensim.models.poincare:training on epoch 92, examples #19990-#20000, loss: 13.75
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.55 s, 3219.95 examples / s
# INFO:gensim.models.poincare:training on epoch 93, examples #4990-#5000, loss: 13.46
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.57 s, 3190.32 examples / s
# INFO:gensim.models.poincare:training on epoch 93, examples #9990-#10000, loss: 13.68
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.54 s, 3236.88 examples / s
# INFO:gensim.models.poincare:training on epoch 93, examples #14990-#15000, loss: 13.72
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.56 s, 3202.77 examples / s
# INFO:gensim.models.poincare:training on epoch 93, examples #19990-#20000, loss: 13.70
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.52 s, 3295.13 examples / s
# INFO:gensim.models.poincare:training on epoch 94, examples #4990-#5000, loss: 13.27
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.52 s, 3294.20 examples / s
# INFO:gensim.models.poincare:training on epoch 94, examples #9990-#10000, loss: 13.74
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.55 s, 3235.47 examples / s
# INFO:gensim.models.poincare:training on epoch 94, examples #14990-#15000, loss: 13.56
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.52 s, 3281.55 examples / s
# INFO:gensim.models.poincare:training on epoch 94, examples #19990-#20000, loss: 13.68
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.58 s, 3169.09 examples / s
# INFO:gensim.models.poincare:training on epoch 95, examples #4990-#5000, loss: 13.55
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.55 s, 3221.52 examples / s
# INFO:gensim.models.poincare:training on epoch 95, examples #9990-#10000, loss: 13.37
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.55 s, 3219.97 examples / s
# INFO:gensim.models.poincare:training on epoch 95, examples #14990-#15000, loss: 13.75
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.54 s, 3255.14 examples / s
# INFO:gensim.models.poincare:training on epoch 95, examples #19990-#20000, loss: 13.72
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.56 s, 3207.76 examples / s
# INFO:gensim.models.poincare:training on epoch 96, examples #4990-#5000, loss: 13.70
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.65 s, 3031.41 examples / s
# INFO:gensim.models.poincare:training on epoch 96, examples #9990-#10000, loss: 13.46
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.54 s, 3256.37 examples / s
# INFO:gensim.models.poincare:training on epoch 96, examples #14990-#15000, loss: 13.45
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.55 s, 3226.46 examples / s
# INFO:gensim.models.poincare:training on epoch 96, examples #19990-#20000, loss: 13.65
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.55 s, 3235.31 examples / s
# INFO:gensim.models.poincare:training on epoch 97, examples #4990-#5000, loss: 13.41
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.53 s, 3276.46 examples / s
# INFO:gensim.models.poincare:training on epoch 97, examples #9990-#10000, loss: 13.40
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.56 s, 3212.76 examples / s
# INFO:gensim.models.poincare:training on epoch 97, examples #14990-#15000, loss: 13.77
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.55 s, 3222.84 examples / s
# INFO:gensim.models.poincare:training on epoch 97, examples #19990-#20000, loss: 13.87
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.56 s, 3198.90 examples / s
# INFO:gensim.models.poincare:training on epoch 98, examples #4990-#5000, loss: 13.47
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.52 s, 3296.72 examples / s
# INFO:gensim.models.poincare:training on epoch 98, examples #9990-#10000, loss: 13.39
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.65 s, 3023.03 examples / s
# INFO:gensim.models.poincare:training on epoch 98, examples #14990-#15000, loss: 13.88
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.92 s, 2602.67 examples / s
# INFO:gensim.models.poincare:training on epoch 98, examples #19990-#20000, loss: 13.57
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.58 s, 3170.46 examples / s
# INFO:gensim.models.poincare:training on epoch 99, examples #4990-#5000, loss: 13.39
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.82 s, 2744.23 examples / s
# INFO:gensim.models.poincare:training on epoch 99, examples #9990-#10000, loss: 13.70
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.74 s, 2877.24 examples / s
# INFO:gensim.models.poincare:training on epoch 99, examples #14990-#15000, loss: 13.59
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.56 s, 3210.92 examples / s
# INFO:gensim.models.poincare:training on epoch 99, examples #19990-#20000, loss: 13.65
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.55 s, 3231.19 examples / s
# INFO:gensim.models.poincare:training on epoch 100, examples #4990-#5000, loss: 13.39
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.58 s, 3174.21 examples / s
# INFO:gensim.models.poincare:training on epoch 100, examples #9990-#10000, loss: 13.68
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.58 s, 3169.67 examples / s
# INFO:gensim.models.poincare:training on epoch 100, examples #14990-#15000, loss: 13.63
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.51 s, 3303.27 examples / s
# INFO:gensim.models.poincare:training on epoch 100, examples #19990-#20000, loss: 13.63
# INFO:gensim.models.poincare:time taken for 5000 examples: 1.58 s, 3157.47 examples / s
# INFO:gensim.models.poincare:training finished

# %%
model_path = aspect_analysis_gerani.paths.aspects_poincare_embeddings.with_suffix('.without_cycles_size_50').as_posix()

# %%
# Saves the entire PoincareModel instance, the loaded model can be trained further
model.save(model_path)

# %%
model = PoincareModel.load(model_path)
# Out:
# INFO:gensim.utils:loading PoincareModel object from /home/laugustyniak/github/phd/sentiment-backend/aspects/results/reviews_Cell_Phones_and_Accessories-50000-docs/gerani/aspects_poincare_embeddings.without_cycles
# INFO:gensim.utils:loading kv recursively from /home/laugustyniak/github/phd/sentiment-backend/aspects/results/reviews_Cell_Phones_and_Accessories-50000-docs/gerani/aspects_poincare_embeddings.without_cycles.kv.* with mmap=None
# INFO:gensim.utils:setting ignored attribute _node_counts_cumsum to None
# INFO:gensim.utils:setting ignored attribute _node_probabilities to None
# INFO:gensim.utils:loaded /home/laugustyniak/github/phd/sentiment-backend/aspects/results/reviews_Cell_Phones_and_Accessories-50000-docs/gerani/aspects_poincare_embeddings.without_cycles

# %% [markdown]
# # Experiment with embeddings distances and other attributes

# %%
model.kv.distance('phone', 'battery')
# Out:
# 1.489919649694419

# %%
model.kv.distance('battery', 'phone')
# Out:
# 1.4899196496944187

# %%
model.kv.distance('battery', 'sound')
# Out:
# 1.9501985741689873

# %%
model.kv.most_similar('battery')
# Out:
# [('samsung galaxay s2', 0.20379016345395914),
#  ('ky', 0.20779270918596948),
#  ('batterys', 0.20908684712468184),
#  ('nokia 6085', 0.23167321185122372),
#  ('mouse / keyboard', 0.23376832314210613),
#  ('bluetooth wireless headphone', 0.2361699841695625),
#  ('the nokia battery', 0.2398347598502745),
#  ('v60s motorola', 0.24003675853699497),
#  ('sure performs', 0.24409806685430396),
#  ('thin battery', 0.24630286722724992)]

# %%
model.kv.closest_child('battery')
# Out:
# 'samsung galaxay s2'

# %%
model.kv.closest_parent('battery')
# Out:
# 'rocksteady xl'

# %%
model.kv.ancestors('phone')
# Out:
# ['br50', 'built - in games', 'nokia 6010', '700w']

# %%
model.kv.descendants('phone')
# Out:
# ['nokia 8260', '100', 'phone - sprint', 'negative 110', 't1/t3']

# %%
# Saves only the vectors from the PoincareModel instance, in the commonly used word2vec format
# model.kv.save_word2vec_format('aspect_rules_vectors')
# PoincareKeyedVectors.load_word2vec_format('aspect_rules_vectors')

# %%
# Rank of distance of node 2 from node 1 in relation to distances of all nodes from node 1
model.kv.rank('phone', 'battery')
# Out:
# 655

# %%
# Closest child node
model.kv.closest_child('sound')
# Out:
# 'cassette slot'

# %%
# Closest child node
model.kv.closest_parent('bluetooth')
# Out:
# 'the qwerty key650'

# %%
# # Position in hierarchy - lower values represent that the node is higher in the hierarchy
# print(model.kv.norm('virginia_deer.n.01'))
# print(model.kv.norm('sheep.n.01'))
# print(model.kv.norm('dog.n.01'))
# print(model.kv.norm('placental.n.01'))
# print(model.kv.norm('mammal.n.01'))

# %% [raw]
# Difference in hierarchy between the first node and the second node
# Positive values indicate the first node is higher in the hierarchy

# %%
print(model.kv.difference_in_hierarchy('phone', 'battery'))
# Out:
# 0.12124990535767222

# %%
print(model.kv.difference_in_hierarchy('battery', 'battery life'))
# Out:
# -0.13077939037375474

# %%
model.kv.difference_in_hierarchy('bluetooth', 'headset')
# Out:
# 0.07872856870200895

# %%
model.kv.difference_in_hierarchy('charger', 'phone')
# Out:
# -0.28987449609222293

# %%
model.kv.difference_in_hierarchy('signal', 'phone')
# Out:
# -0.31579033459654904

# %%
# One possible descendant chain
model.kv.descendants('sound')
# Out:
# ['cassette slot',
#  'motorola mini wall charger',
#  'central florida',
#  'buzzing',
#  'earbuds hook']

# %%
# One possible ancestor chain
model.kv.ancestors('sound')
# Out:
# ['motorola hs820 bluetooth',
#  'control',
#  'jabra 250v',
#  'boring startac',
#  'motrola',
#  'palm applications screen',
#  '700w']

# %%
def check_hierarchy(model, parent: str, child: str) -> bool:
    return model.kv.difference_in_hierarchy(parent, child) > 0

# %%
check_hierarchy(model, 'battery', 'battery life')
# Out:
# False

# %% [markdown]
# # Check manually create hierarchy

# %%
from aspects.analysis.unsupervised_aspect_hierarchies import amazon_cellphone_aspect_hierarchy_100000_reviews

# %%
hierarchy_check_df = pd.DataFrame([
    (rule.nucleus, rule.satellite, check_hierarchy(model, rule.nucleus, rule.satellite))
    for rule 
    in amazon_cellphone_aspect_hierarchy_100000_reviews
    if rule.nucleus in model.kv.vocab and rule.satellite in model.kv.vocab
], columns=['nucleus', 'satellite', 'is_correct_hierarchy'])

# %%
# with cycles
len(hierarchy_check_df[hierarchy_check_df.is_correct_hierarchy]) / len(hierarchy_check_df)
# Out:
# 0.68

# %%
hierarchy_check_df[~hierarchy_check_df.is_correct_hierarchy]
# Out:
#     nucleus     satellite  is_correct_hierarchy
# 4     phone         price                 False
# 10     case         price                 False
# 13    phone  battery life                 False
# 14  headset         sound                 False
# 16  headset     bluetooth                 False
# 20  headset         price                 False
# 22  headset       quality                 False
# 23    phone           use                 False
# 26     case        design                 False
# 27     case         color                 False
# 30  headset           use                 False
# 33     case       quality                 False
# 34     case          belt                 False
# 35     case        screen                 False
# 39  headset       battery                 False
# 40  headset  battery life                 False

# %% [markdown]
# # Visualization

# %%
from gensim.viz.poincare import poincare_2d_visualization, poincare_distance_heatmap

# %%
all_relations = list(set(relations))

# %%
show_node_labels = ['phone', 'battery', 'sound', 'bluetooth', 'headset', 'price', 'quality', 'case', 'use', 'volume', 'battery life']
filtered_set = set()
for relation in all_relations:
    if relation[0] in show_node_labels and relation[1] in show_node_labels:
        filtered_set.add(relation)

# %%
filtered_set
# Out:
# {('battery', 'battery life'),
#  ('battery', 'bluetooth'),
#  ('battery', 'case'),
#  ('battery', 'headset'),
#  ('battery', 'phone'),
#  ('battery', 'price'),
#  ('battery', 'quality'),
#  ('battery', 'sound'),
#  ('battery', 'use'),
#  ('battery', 'volume'),
#  ('battery life', 'battery'),
#  ('battery life', 'bluetooth'),
#  ('battery life', 'case'),
#  ('battery life', 'headset'),
#  ('battery life', 'phone'),
#  ('battery life', 'price'),
#  ('battery life', 'quality'),
#  ('battery life', 'sound'),
#  ('battery life', 'use'),
#  ('battery life', 'volume'),
#  ('bluetooth', 'battery'),
#  ('bluetooth', 'battery life'),
#  ('bluetooth', 'phone'),
#  ('bluetooth', 'price'),
#  ('bluetooth', 'quality'),
#  ('bluetooth', 'sound'),
#  ('bluetooth', 'use'),
#  ('bluetooth', 'volume'),
#  ('case', 'battery'),
#  ('case', 'battery life'),
#  ('case', 'phone'),
#  ('case', 'price'),
#  ('case', 'quality'),
#  ('case', 'sound'),
#  ('case', 'use'),
#  ('case', 'volume'),
#  ('headset', 'battery'),
#  ('headset', 'battery life'),
#  ('headset', 'case'),
#  ('headset', 'phone'),
#  ('headset', 'price'),
#  ('headset', 'sound'),
#  ('headset', 'use'),
#  ('headset', 'volume'),
#  ('phone', 'battery'),
#  ('phone', 'battery life'),
#  ('phone', 'bluetooth'),
#  ('phone', 'case'),
#  ('phone', 'headset'),
#  ('phone', 'price'),
#  ('phone', 'quality'),
#  ('phone', 'sound'),
#  ('phone', 'use'),
#  ('phone', 'volume'),
#  ('price', 'battery'),
#  ('price', 'battery life'),
#  ('price', 'bluetooth'),
#  ('price', 'case'),
#  ('price', 'headset'),
#  ('price', 'phone'),
#  ('price', 'quality'),
#  ('price', 'sound'),
#  ('price', 'use'),
#  ('price', 'volume'),
#  ('quality', 'battery'),
#  ('quality', 'battery life'),
#  ('quality', 'bluetooth'),
#  ('quality', 'case'),
#  ('quality', 'phone'),
#  ('quality', 'price'),
#  ('quality', 'sound'),
#  ('quality', 'use'),
#  ('quality', 'volume'),
#  ('sound', 'battery'),
#  ('sound', 'battery life'),
#  ('sound', 'bluetooth'),
#  ('sound', 'case'),
#  ('sound', 'headset'),
#  ('sound', 'phone'),
#  ('sound', 'price'),
#  ('sound', 'quality'),
#  ('sound', 'use'),
#  ('sound', 'volume'),
#  ('use', 'battery'),
#  ('use', 'battery life'),
#  ('use', 'bluetooth'),
#  ('use', 'case'),
#  ('use', 'headset'),
#  ('use', 'phone'),
#  ('use', 'price'),
#  ('use', 'quality'),
#  ('use', 'sound'),
#  ('use', 'volume'),
#  ('volume', 'battery'),
#  ('volume', 'battery life'),
#  ('volume', 'bluetooth'),
#  ('volume', 'case'),
#  ('volume', 'headset'),
#  ('volume', 'phone'),
#  ('volume', 'price'),
#  ('volume', 'quality'),
#  ('volume', 'sound'),
#  ('volume', 'use')}

# %%
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# %%
init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
fig = poincare_2d_visualization(model, filtered_set, "Poincare Hierarchy", show_node_labels=show_node_labels)

# %%
iplot(fig)
# Out:
# <div id="4737bd45-f34e-4071-9380-378aa42a1d36" style="height: 800px; width: 800px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("4737bd45-f34e-4071-9380-378aa42a1d36", [{"type": "scatter", "x": [0.021067273510827038, 0.09484552230302862, null, 0.09484552230302862, 0.3333063115579882, null, 0.021067273510827038, 0.056865655467800286, null, 0.021067273510827038, 0.1735768386056612, null, 0.1519021156469761, -0.11600134038393216, null, 0.3333063115579882, -0.11600134038393216, null, 0.09484552230302862, 0.5026525147987747, null, 0.10000437390133718, 0.17689198963391847, null, 0.3333063115579882, 0.17689198963391847, null, 0.3333063115579882, 0.021067273510827038, null, 0.5026525147987747, 0.3333063115579882, null, 0.035097621323167495, 0.10000437390133718, null, 0.056865655467800286, 0.035097621323167495, null, 0.035097621323167495, -0.11600134038393216, null, 0.5026525147987747, 0.1519021156469761, null, 0.3333063115579882, 0.10000437390133718, null, -0.11600134038393216, 0.09484552230302862, null, 0.035097621323167495, 0.1735768386056612, null, 0.10000437390133718, 0.09484552230302862, null, 0.09484552230302862, 0.1519021156469761, null, 0.3333063115579882, 0.056865655467800286, null, 0.10000437390133718, 0.056865655467800286, null, 0.3333063115579882, 0.1735768386056612, null, 0.17689198963391847, -0.11600134038393216, null, 0.5026525147987747, 0.035097621323167495, null, 0.1519021156469761, 0.1735768386056612, null, 0.021067273510827038, -0.11600134038393216, null, -0.11600134038393216, 0.3333063115579882, null, 0.021067273510827038, 0.1519021156469761, null, 0.021067273510827038, 0.17689198963391847, null, 0.056865655467800286, 0.021067273510827038, null, 0.10000437390133718, 0.035097621323167495, null, 0.09484552230302862, -0.11600134038393216, null, 0.17689198963391847, 0.021067273510827038, null, 0.09484552230302862, 0.021067273510827038, null, 0.1519021156469761, 0.5026525147987747, null, 0.3333063115579882, 0.5026525147987747, null, 0.056865655467800286, 0.10000437390133718, null, 0.10000437390133718, 0.021067273510827038, null, 0.5026525147987747, 0.09484552230302862, null, 0.1519021156469761, 0.035097621323167495, null, 0.5026525147987747, 0.17689198963391847, null, 0.035097621323167495, 0.5026525147987747, null, 0.035097621323167495, 0.021067273510827038, null, 0.056865655467800286, 0.1735768386056612, null, 0.1735768386056612, 0.1519021156469761, null, 0.10000437390133718, -0.11600134038393216, null, 0.17689198963391847, 0.056865655467800286, null, 0.09484552230302862, 0.056865655467800286, null, 0.3333063115579882, 0.1519021156469761, null, 0.10000437390133718, 0.1519021156469761, null, 0.035097621323167495, 0.3333063115579882, null, 0.5026525147987747, 0.10000437390133718, null, 0.021067273510827038, 0.10000437390133718, null, 0.021067273510827038, 0.035097621323167495, null, 0.10000437390133718, 0.3333063115579882, null, 0.035097621323167495, 0.056865655467800286, null, 0.035097621323167495, 0.17689198963391847, null, 0.1519021156469761, 0.021067273510827038, null, 0.056865655467800286, 0.3333063115579882, null, 0.1735768386056612, 0.10000437390133718, null, 0.1735768386056612, 0.035097621323167495, null, 0.1519021156469761, 0.10000437390133718, null, 0.1519021156469761, 0.17689198963391847, null, -0.11600134038393216, 0.10000437390133718, null, -0.11600134038393216, 0.17689198963391847, null, 0.09484552230302862, 0.035097621323167495, null, -0.11600134038393216, 0.035097621323167495, null, 0.056865655467800286, 0.1519021156469761, null, 0.1735768386056612, 0.056865655467800286, null, 0.1735768386056612, 0.17689198963391847, null, 0.17689198963391847, 0.1519021156469761, null, 0.1735768386056612, 0.09484552230302862, null, 0.1519021156469761, 0.056865655467800286, null, -0.11600134038393216, 0.056865655467800286, null, 0.17689198963391847, 0.5026525147987747,  ...

# %%
iplot(fig, filename='poincare_viz.png')

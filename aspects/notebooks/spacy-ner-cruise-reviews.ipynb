# %% [markdown]
# # Rhetorical and sentiment analysis

# %% [markdown]
# # Imports

# %%
import simplejson
import numpy as np
from glob import glob
from bs4 import BeautifulSoup
from datetime import datetime
from os.path import basename, join
from pprint import pprint
import re
import pickle 
import cPickle
import pandas as pd

from pprint import pprint
from datetime import datetime
from tqdm import tqdm
from tqdm import tnrange, tqdm_notebook
from time import sleep

from joblib import Parallel, delayed

import networkx as nx
from operator import itemgetter
import matplotlib.pyplot as plt

import sys
sys.path.append("/root/sa/edu_dependency_parser/src")
from trees.parse_tree import ParseTree

import requests
import simplejson
import operator

from wordcloud import WordCloud

# %matplotlib inline

# %%
import spacy
nlp = spacy.load('en')

# %% [markdown]
# # Aspect-based sentiment analysis flow - texual data summarization

# %% [markdown]
# <img src="Rhetorical analysis - Flow croped.png">

# %% [markdown]
# # Exemplary Discourse Tree

# %% [markdown]
# <img src="Rhetorical Analysis example.png">

# %% [markdown]
# # Load parsed data

# %%
# data_path = '/datasets/sentiment/aspects/results-brexit/results/brexit-news-all/'
data_path = '/datasets/sentiment/aspects/results/2015-2016_CRUISE-SERVICE/'

# %%
def load_serialized(f_path, f_name):
    with open(join(f_path, f_name)) as f:
        obj = cPickle.load(f)
    return obj

# %%
aspect_graph = load_serialized(data_path, 'aspects_graph')

# %% [markdown]
# ## Sentiment EDUs load

# %%
sent_edu = load_serialized(data_path, 'sentiment_filtered_edus')

# %%
len(sent_edu)
# Out:
# 6842

# %%
sent_edu.items()[:3]
# Out:
# [(0,
#   {'entities': [],
#    'raw_text': u'\\ will also be a new onboard concierge service',
#    'sentiment': array([1]),
#    'source_document_id': 0,
#    'tokens': [{'is_stop': False,
#      'lemma': u'\\',
#      'pos': u'PUNCT',
#      'text': u'\\'},
#     {'is_stop': True, 'lemma': u'will', 'pos': u'VERB', 'text': u'will'},
#     {'is_stop': True, 'lemma': u'also', 'pos': u'ADV', 'text': u'also'},
#     {'is_stop': True, 'lemma': u'be', 'pos': u'VERB', 'text': u'be'},
#     {'is_stop': True, 'lemma': u'a', 'pos': u'DET', 'text': u'a'},
#     {'is_stop': False, 'lemma': u'new', 'pos': u'ADJ', 'text': u'new'},
#     {'is_stop': False, 'lemma': u'onboard', 'pos': u'ADJ', 'text': u'onboard'},
#     {'is_stop': False,
#      'lemma': u'concierge',
#      'pos': u'NOUN',
#      'text': u'concierge'},
#     {'is_stop': False,
#      'lemma': u'service',
#      'pos': u'NOUN',
#      'text': u'service'}]}),
#  (1,
#   {'entities': [],
#    'raw_text': u'to help passengers personalize their trip',
#    'sentiment': array([1]),
#    'source_document_id': 0,
#    'tokens': [{'is_stop': True, 'lemma': u'to', 'pos': u'PART', 'text': u'to'},
#     {'is_stop': False, 'lemma': u'help', 'pos': u'VERB', 'text': u'help'},
#     {'is_stop': False,
#      'lemma': u'passenger',
#      'pos': u'NOUN',
#      'text': u'passengers'},
#     {'is_stop': False,
#      'lemma': u'personalize',
#      'pos': u'VERB',
#      'text': u'personalize'},
#     {'is_stop': True, 'lemma': u'their', 'pos': u'ADJ', 'text': u'their'},
#     {'is_stop': False, 'lemma': u'trip', 'pos': u'NOUN', 'text': u'trip'}]}),
#  (2,
#   {'entities': [],
#    'raw_text': u'Show',
#    'sentiment': array([1]),
#    'source_document_id': 0,
#    'tokens': [{'is_stop': True,
#      'lemma': u'show',
#      'pos': u'NOUN',
#      'text': u'Show'}]})]

# %% [markdown]
# ## Aspects load

# %%
aspect_edu = load_serialized(data_path, 'aspects_per_edu')

# %% [markdown]
# ### Summarize sentiment per aspect

# %%
def graph_stats(graph):
    n_n = len(graph.nodes())
    n_e = len(graph.edges())
    print '#Nodes: {}'.format(n_n)
    print '#Edges: {}'.format(n_e)
    print 'Connections coverage: {}%'.format(( float(n_e) / (n_n * n_n ) * 100))

    degree_sequence=sorted(nx.degree(graph).values(),reverse=True) # degree sequence
    dmax=max(degree_sequence)

    print '-'*30
    print 'Highest degree of nodes'
    nd=sorted(aspect_graph.degree_iter(), key=itemgetter(1), reverse=True)
    df_nd = pd.DataFrame(nd, columns=['aspect', 'degree'])
    #     pprint([x for x in nd if len(x[0]) > 1]) # filter out aspect consists of one letter

    print '-'*30
    print 'Page Rank'
    pg = nx.pagerank(aspect_graph)
    df_pg = pd.DataFrame(pg.items(), columns=['aspect', 'pagerank'])
    # pgs = [(node, pagerank) for node, pagerank in pg.items()]
    #     pprint(pgs[:top_n])
    print '-'*30
    pprint('Unique Values of Page Rank: {}, unique nodes: {}'.format(len(set([pagerank for node, pagerank in pg.items()])), n_n))
    doc_asp_sent = []
    for doc_id, aspects in aspect_edu.iteritems():
        for aspect in aspects:
            doc_asp_sent.append((aspect, sent_edu[doc_id]['sentiment'][0]))

    df = pd.DataFrame()
    df['aspect'] = [x[0] for x in doc_asp_sent]
    df['sentiment'] = [x[1] for x in doc_asp_sent]

    df_mean = df.groupby('aspect').mean().reset_index().sort_values('sentiment', ascending=False)
    df_mean.columns = ['aspect', 'mean_sent']
    df_sum = df.groupby('aspect').sum().reset_index().sort_values('sentiment', ascending=False)
    df_sum.columns = ['aspect', 'sum_sent']

    df = pd.merge(df_mean, df_sum, on='aspect')
    df = pd.merge(df, df_pg, on='aspect')
    df = pd.merge(df, df_nd, on='aspect')

    df = df[[u'aspect', u'mean_sent', u'sum_sent', 'pagerank', 'degree']]

    return doc_asp_sent, df

# %%
doc_asp_sent, df = graph_stats(aspect_graph)
# Out:
# #Nodes: 2250
# #Edges: 3796
# Connections coverage: 0.0749827160494%
# ------------------------------
# Highest degree of nodes
# ------------------------------
# Page Rank
# ------------------------------
# 'Unique Values of Page Rank: 718, unique nodes: 2250'

# %%
# doc_asp_sent, df = graph_stats(aspect_graph)

# %%
# df.sort_values(by='pagerank', ascending=False)

# %%
aspects_to_remove = [u'day', u'days', u'week', u'weeks', u'month', u'months', u'year', u'years', 
                     u'time', u'today', u'data', u'date',
                     u'monday', u'tuesday', u'wednesday', u'thursday', u'friday', u'saturday', u'sunday', 
                     u'january', u'february', u'march', u'april', u'may', u'june', u'july',
                     u'august', u'september', u'october', u'november', u'december',
                     u'end']

# %%
df_filtered = df[ ( df.aspect.str.len() > 1 ) & ( ~df.aspect.isin( aspects_to_remove )) ]

# %%
# df_filtered.sort_values(by='degree', ascending=False).to_excel('/datasets/sentiment/aspects/results/brexit-preprocessed-news-all.aspects.xls',
#                                                             encoding='utf8')

# %%
df_filtered.sort_values(by='degree', ascending=False).head(150)
# Out:
#                    aspect  mean_sent  sum_sent  pagerank  degree
# 1536              service   0.462457       542  0.048818     618
# 1435                 ship   0.727749       139  0.009774     141
# 1408                guest   0.920000        92  0.010960     115
# 1543         room service   0.426230        52  0.004182      73
# 1405            passenger   0.936508        59  0.006296      71
# 1612                 line   0.250000        12  0.003711      40
# 1638               cruise   0.111111         7  0.002356      34
# 1445       butler service   0.684211        26  0.001547      28
# 1437                board   0.727273        16  0.000965      28
# 1436           restaurant   0.727273        16  0.003328      27
# 1548        ferry service   0.380282        27  0.001088      27
# 1484                suite   0.583333        14  0.001316      26
# 1537             gratuity   0.428571        12  0.001176      25
# 1344                fleet   1.000000        17  0.000392      23
# 1581                 post   0.333333        10  0.004245      23
# 1414                staff   0.851852        23  0.005653      22
# 1423            stateroom   0.800000        16  0.000991      22
# 1750              company  -0.166667        -4  0.002792      22
# 1434            breakfast   0.733333        11  0.000613      21
# 1490               people   0.555556        10  0.001682      21
# 1497                  tip   0.520000        13  0.000913      21
# 1608             addition   0.294118         5  0.002039      20
# 1406                place   0.931034        27  0.000782      19
# 1410                  bar   0.888889        16  0.000912      19
# 1407              amenity   0.925926        25  0.001712      19
# 1550        guest service   0.351351        13  0.002274      19
# 1450              program   0.666667         8  0.001940      19
# 1522               dining   0.500000        10  0.001567      18
# 1630          cruise line   0.200000         4  0.001815      18
# 1542               family   0.428571         9  0.001576      18
# ...                   ...        ...       ...       ...     ...
# 705                repair   1.000000         6  0.000438       8
# 1411     personal service   0.875000        14  0.000258       8
# 1677            statement   0.000000         0  0.000661       8
# 1622                ferry   0.200000         3  0.000449       8
# 1254        entertainment   1.000000        18  0.000428       8
# 1633            president   0.142857         1  0.002145       8
# 1795                  man  -0.500000        -2  0.000498       8
# 536                viking   1.000000         3  0.000909       8
# 1424               coffee   0.777778         7  0.000551       8
# 1430            treatment   0.750000         6  0.001421       8
# 1416                  cut   0.846154        11  0.000830       8
# 1432          dining room   0.750000         6  0.000341       8
# 1558                 city   0.333333         2  0.000991       8
# 1604           preference   0.333333         1  0.000245       8
# 1709                 sale   0.000000         0  0.000920       8
# 1526                point   0.500000         2  0.001187       8
# 1576                movie   0.333333         1  0.000442       8
# 1502                child   0.500000         4  0.000846       8
# 859                 class   1.000000         7  0.000368       8
# 1481                array   0.600000         3  0.000251       8
# 1562                 site   0.333333         2  0.000415       8
# 1592               client   0.333333         3  0.001017       8
# 482                spirit   1.000000         2  0.000462       7
# 162   outstanding service   1.000000        11  0.000782       7
# 427            technology   1.000000         7  0.000220       7
# 857                church   1.000000         2  0.000669       7
# 1425                drink   0.777778         7  0.000283       7
# 1527           relaxation   0.500000         2  0.000654       7
# 1488                  spa   0.555556         5  0.000501       7
# 1559            champagne   0.333333         1  0.000370       7
#
# [150 rows x 5 columns]

# %% [markdown]
# ## Page Rank based aspect

# %%
def draw_wordcloud(counts):
    wordcloud = WordCloud(background_color="white").generate_from_frequencies(counts)
    plt.figure(figsize=(9, 12))
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.show()

# %%
df_filtered.sort_values('pagerank', ascending=False).head(50)
# Out:
#                                aspect  mean_sent  sum_sent  pagerank  degree
# 1536                          service   0.462457       542  0.048818     618
# 1408                            guest   0.920000        92  0.010960     115
# 1435                             ship   0.727749       139  0.009774     141
# 1405                        passenger   0.936508        59  0.006296      71
# 1414                            staff   0.851852        23  0.005653      22
# 1521                           cabana   0.500000         2  0.004383       7
# 1581                             post   0.333333        10  0.004245      23
# 1543                     room service   0.426230        52  0.004182      73
# 1612                             line   0.250000        12  0.003711      40
# 1436                       restaurant   0.727273        16  0.003328      27
# 551                          wowbands   1.000000         2  0.003113       3
# 1750                          company  -0.166667        -4  0.002792      22
# 2003                discussion thread  -1.000000        -8  0.002453      13
# 1638                           cruise   0.111111         7  0.002356      34
# 1550                    guest service   0.351351        13  0.002274      19
# 1540                           flight   0.428571         3  0.002189      15
# 1633                        president   0.142857         1  0.002145       8
# 1760                           report  -0.333333        -1  0.002099       6
# 717                         reference   1.000000         3  0.002051       7
# 1608                         addition   0.294118         5  0.002039      20
# 1450                          program   0.666667         8  0.001940      19
# 1637                            route   0.125000         2  0.001903      17
# 1412                        concierge   0.866667        13  0.001842      13
# 1068              15 percent gratuity   1.000000         1  0.001839       3
# 1630                      cruise line   0.200000         4  0.001815      18
# 1640                            order   0.066667         1  0.001722       9
# 1407                          amenity   0.925926        25  0.001712      19
# 1072                          17 year   1.000000         1  0.001708       3
# 1263                            enjoy   1.000000         2  0.001689       9
# 1490                           people   0.555556        10  0.001682      21
# 1775                          onboard  -0.333333        -1  0.001661       4
# 175                               one   1.000000         3  0.001629       7
# 1288                       fun people   1.000000         8  0.001600       9
# 1487                            photo   0.555556         5  0.001582      11
# 1542                           family   0.428571         9  0.001576      18
# 1427                             tour   0.750000         6  0.001567      11
# 1522                           dining   0.500000        10  0.001567      18
# 471                           steward   1.000000         3  0.001561      11
# 1443                            level   0.703704        19  0.001550      14
# 1445                   butler service   0.684211        26  0.001547      28
# 1609                             cost   0.272727         3  0.001512      14
# 3     new ship construction operation   1.000000         1  0.001473       6
# 995                      consultation   1.000000         1  0.001464       2
# 1477                             wine   0.600000         6  0.001463      17
# 2129                           custom  -1.000000        -2  0.001453       7
# 1639                       experience   0.066667         1  0.001450      17
# 1829           launch freight service  -1.000000        -1  0.001426       1
# 1430                        treatment   0.750000         6  0.001421       8
# 1752                         customer  -0.200000        -3  0.001415      17
# 1721                         religion   0.000000         0  0.001412       4

# %%
print 'Page Rank stats:'
print 'Mean:', df_filtered.pagerank.mean()
print 'Min: ', df_filtered.pagerank.min()
print 'Max: ', df_filtered.pagerank.max()
# Out:
# Page Rank stats:
# Mean: 0.000439413137576
# Min:  0.000220164982827
# Max:  0.0488177269824

# %%
def draw_top_aspects_by_col(df=df_filtered, col='pagerank', top_n=100, ascending=False, pagerank_min=0.00005, min_degree=None):
    counts = []
    if min_degree is not None:
        df = df[df.degree > min_degree]
    for _, row in df[df.pagerank > pagerank_min].sort_values(col, ascending=ascending).head(top_n)[['aspect', col]].iterrows():
        counts.append((row['aspect'], row[col]))
    draw_wordcloud(counts)
    print counts

# %% [markdown]
# ### TOP100 aspects based on pagerank

# %%
draw_top_aspects_by_col(col='pagerank', top_n=50)
# Out:
# [(u'service', 0.04881772698243313), (u'guest', 0.010960183738954028), (u'ship', 0.009773607095312078), (u'passenger', 0.006296395401663637), (u'staff', 0.005652964655708412), (u'cabana', 0.00438323583366419), (u'post', 0.0042453691598021235), (u'room service', 0.0041818577523747985), (u'line', 0.003711345165207185), (u'restaurant', 0.0033284290241268294), (u'wowbands', 0.003113240733489846), (u'company', 0.0027919401136553973), (u'discussion thread', 0.0024531601500009507), (u'cruise', 0.00235594939963235), (u'guest service', 0.002273609073637405), (u'flight', 0.0021891582486637633), (u'president', 0.0021451689146558695), (u'report', 0.002099269936427928), (u'reference', 0.0020508646586936304), (u'addition', 0.0020388003425806187), (u'program', 0.0019403399715468687), (u'route', 0.0019026702984942508), (u'concierge', 0.001841848099229727), (u'15 percent gratuity', 0.0018390429492155334), (u'cruise line', 0.0018148908540145561), (u'order', 0.0017224889557503553), (u'amenity', 0.001712213873921344), (u'17 year', 0.001708204096642962), (u'enjoy', 0.001688772105238063), (u'people', 0.0016817416346809535), (u'onboard', 0.0016608825940600648), (u'one', 0.001629224872755785), (u'fun people', 0.001600020807858868), (u'photo', 0.0015817101573597954), (u'family', 0.0015759735203824566), (u'tour', 0.0015668175735447027), (u'dining', 0.0015665853049262562), (u'steward', 0.0015612444238274294), (u'level', 0.0015502733144647106), (u'butler service', 0.0015472653036416456), (u'cost', 0.001511981594140575), (u'new ship construction operation', 0.0014733210657456443), (u'consultation', 0.0014642325806460766), (u'wine', 0.0014633865186498562), (u'custom', 0.0014534818110751948), (u'experience', 0.001450438524467516), (u'launch freight service', 0.0014256053706028834), (u'treatment', 0.0014211453953225258), (u'customer', 0.001415293226499607), (u'religion', 0.0014115748531110346)]

# %% [markdown]
# ## Sentiment of the aspects

# %%
def draw_top_aspects_by_sent(df=df_filtered, col='mean_sent', top_n=100, pagerank_min=0.00005, 
                             min_degree=None, sentiment='positive'):
    counts = []
    
    # only positive of negative sentiment
    if sentiment in ['positive']:
        df = df[df.mean_sent > 0]
    elif sentiment in ['negative']:
        df = df[df.mean_sent < 0]
        # the higher sentiemtn the bigger word, reverse sign 
        df.mean_sent = df.mean_sent.apply(lambda x: x * (-1))
    else:
        raise 'Wrong sentiment variable, should be positive or negative only'
    
#     df = df[df.degree > min_degree]
#     print df
    
    if min_degree is not None:
        df = df[df.degree > min_degree]
    
    for _, row in df[df.pagerank > pagerank_min].sort_values(['degree', col], ascending=False).head(top_n)[['aspect', col]].iterrows():
        counts.append((row['aspect'], row[col]))
    
    print counts
    draw_wordcloud(counts)

# %% [markdown]
# ### Positive

# %%
draw_top_aspects_by_sent(sentiment='positive')
# Out:
# [(u'service', 0.46245733788395904), (u'ship', 0.7277486910994765), (u'guest', 0.92), (u'room service', 0.4262295081967213), (u'passenger', 0.9365079365079365), (u'line', 0.25), (u'cruise', 0.1111111111111111), (u'board', 0.7272727272727273), (u'butler service', 0.6842105263157895), (u'restaurant', 0.7272727272727273), (u'ferry service', 0.38028169014084506), (u'suite', 0.5833333333333334), (u'gratuity', 0.42857142857142855), (u'fleet', 1.0), (u'post', 0.3333333333333333), (u'staff', 0.8518518518518519), (u'stateroom', 0.8), (u'breakfast', 0.7333333333333333), (u'people', 0.5555555555555556), (u'tip', 0.52), (u'addition', 0.29411764705882354), (u'place', 0.9310344827586207), (u'amenity', 0.9259259259259259), (u'bar', 0.8888888888888888), (u'program', 0.6666666666666666), (u'guest service', 0.35135135135135137), (u'charge', 0.7142857142857143), (u'cabin', 0.68), (u'dining', 0.5), (u'family', 0.42857142857142855), (u'cruise line', 0.2), (u'food', 0.6296296296296297), (u'wine', 0.6), (u'room service menu', 0.5789473684210527), (u'route', 0.125), (u'experience', 0.06666666666666667), (u'customer service', 0.043478260869565216), (u'itinerary', 1.0), (u'world', 0.5), (u'order room service', 0.5384615384615384), (u'crew', 0.5), (u'port', 0.42857142857142855), (u'flight', 0.42857142857142855), (u'level', 0.7037037037037037), (u'way', 0.6), (u'cost', 0.2727272727272727), (u'sea', 1.0), (u'concierge', 0.8666666666666667), (u'operation', 0.8666666666666667), (u'activity', 0.8), (u'option', 0.6363636363636364), (u'service charge', 0.3333333333333333), (u'airport', 0.3333333333333333), (u'meal', 0.2), (u'money', 0.06666666666666667), (u'author topic', 1.0), (u'pre', 0.14285714285714285), (u'menu', 1.0), (u'steward', 1.0), (u'chocolate', 1.0), (u'accommodation', 1.0), (u'evening', 1.0), (u'excellent service', 1.0), (u'fun', 1.0), (u'good service', 0.9), (u'product', 0.8181818181818182), (u'tour', 0.75), (u'photo', 0.5555555555555556), (u'discount', 0.4), (u'buffet', 0.25), (u'link', 0.2), (u'kid', 0.14285714285714285), (u'impeccable service', 1.0), (u'driver', 1.0), (u'quality', 0.8260869565217391), (u'new ship', 0.8), (u'spa service', 0.75), (u'night', 0.6923076923076923), (u'quality service', 0.5555555555555556), (u'country', 0.42857142857142855), (u'room', 0.36363636363636365), (u'vessel', 0.3333333333333333), (u'person', 0.3333333333333333), (u'event', 0.2), (u'price', 0.14285714285714285), (u'priority', 1.0), (u'tourist', 1.0), (u'resort', 1.0), (u'care', 1.0), (u'award', 1.0), (u'enjoy', 1.0), (u'fun people', 1.0), (u'24-hour room service', 0.8461538461538461), (u'trip', 0.8181818181818182), (u'hotel', 0.7647058823529411), (u'attention', 0.75), (u'casino', 0.6), (u'space', 0.5), (u'morning', 0.38461538461538464), (u'cruiser', 0.3333333333333333)]

# %% [markdown]
# ### Negative

# %%
draw_top_aspects_by_sent(sentiment='negative')
# Out:
# [(u'company', 0.16666666666666666), (u'customer', 0.2), (u'discussion thread', 1.0), (u'water', 0.14285714285714285), (u'shore excursion', 0.7142857142857143), (u'fee', 0.07692307692307693), (u'demand', 0.14285714285714285), (u'man', 0.5), (u'importance', 0.2), (u'thing', 0.1111111111111111), (u'custom', 1.0), (u'shame', 1.0), (u'tomorrow', 0.7142857142857143), (u'datum', 0.5), (u'industry', 0.42857142857142855), (u'main dining', 0.3333333333333333), (u'provence product', 1.0), (u'tonight', 1.0), (u'loading', 1.0), (u'stop', 1.0), (u'arrival', 0.75), (u'report', 0.3333333333333333), (u'owner', 0.3333333333333333), (u'dining choice', 0.3333333333333333), (u'security', 0.3333333333333333), (u'course', 0.1111111111111111), (u'consumer', 1.0), (u'23 maximum', 1.0), (u'blog', 1.0), (u'gourmet dining', 0.5), (u'result', 0.3333333333333333), (u'pay', 0.3333333333333333), (u'hope', 0.3333333333333333), (u'rate', 0.3333333333333333), (u'onboard account', 0.3333333333333333), (u'reception', 0.3333333333333333), (u'degree', 0.3333333333333333), (u'0 user', 0.14285714285714285), (u'harbor tour', 1.0), (u'nearly 40 percent', 1.0), (u'multiple restaurant', 1.0), (u'thickbluebug', 1.0), (u'credit', 1.0), (u'130,000 gross ton', 1.0), (u'carnival', 1.0), (u'letter', 1.0), (u'diploma', 1.0), (u'cover', 1.0), (u'sales/marketing/promotional budgeting fund', 1.0), (u'giftgrub', 1.0), (u'20knot', 1.0), (u'2013 period', 1.0), (u'respite', 1.0), (u'decline', 1.0), (u'royal caribbean veteran', 1.0), (u'day onboard', 1.0), (u'driver license', 1.0), (u'launch', 0.5), (u'introduction', 0.3333333333333333), (u'bus', 0.3333333333333333), (u'case', 0.3333333333333333), (u'fuel', 0.3333333333333333), (u'onboard', 0.3333333333333333), (u'story', 0.3333333333333333), (u'non alcoholic beverage', 1.0), (u'trans canal', 1.0), (u'30 % male', 1.0), (u'disgusting behavior', 1.0), (u'major component', 1.0), (u'dismay', 1.0), (u'nasty bedsheets', 1.0), (u'prop shaft damage', 1.0), (u'luxurious lie', 1.0), (u'series', 1.0), (u'complete refurbishment', 1.0), (u'88 time', 1.0), (u'841 time', 1.0), (u'myriad', 1.0), (u'70,000 gross ton', 1.0), (u'^ testing', 1.0), (u'honor company', 1.0), (u'cabin treat', 1.0), (u'country tipping', 1.0), (u'1409 time', 1.0), (u'global traveler', 1.0), (u'1 year', 1.0), (u'score', 1.0), (u'expensive suite', 1.0), (u'mess', 1.0), (u'legislation', 1.0), (u'dining room wine account', 1.0), (u'poor service', 1.0), (u'won', 1.0), (u'10 p.m.', 1.0), (u'scrap', 1.0), (u'new service charge', 1.0), (u'use instead', 1.0), (u'hacker', 1.0), (u'different company', 1.0), (u'184 time', 1.0)]
# /usr/local/lib/python2.7/dist-packages/pandas/core/generic.py:2701: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

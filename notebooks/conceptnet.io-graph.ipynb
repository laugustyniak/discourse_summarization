# %% [markdown]
# # # Imports

# %%
import requests

# %%
import networkx as nx
import matplotlib.pyplot as plt
import pylab

# %%
from networkx_viewer import Viewer

# %% [markdown]
# # # Example concept

# %%
obj = requests.get('http://api.conceptnet.io/c/en/camera').json()
obj.keys()
# Out:
# [u'@context', u'edges', u'@id', u'view']

# %%
obj['@id']
# Out:
# u'/c/en/camera'

# %%
obj['@context']
# Out:
# [u'http://api.conceptnet.io/ld/conceptnet5.5/context.ld.json',
#  u'http://api.conceptnet.io/ld/conceptnet5.5/pagination.ld.json']

# %%
obj['view']
# Out:
# {u'@id': u'/c/en/camera?offset=0&limit=20',
#  u'firstPage': u'/c/en/camera?offset=0&limit=20',
#  u'nextPage': u'/c/en/camera?offset=20&limit=20',
#  u'paginatedProperty': u'edges'}

# %%
len(obj['edges'])
# Out:
# 20

# %%
obj
# Out:
# {u'@context': [u'http://api.conceptnet.io/ld/conceptnet5.5/context.ld.json',
#   u'http://api.conceptnet.io/ld/conceptnet5.5/pagination.ld.json'],
#  u'@id': u'/c/en/camera',
#  u'edges': [{u'@id': u'/a/[/r/UsedFor/,/c/en/camera/,/c/en/take_pictures/]',
#    u'dataset': u'/d/conceptnet/4/en',
#    u'end': {u'@id': u'/c/en/take_pictures',
#     u'label': u'take pictures',
#     u'language': u'en',
#     u'term': u'/c/en/take_pictures'},
#    u'license': u'cc:by/4.0',
#    u'rel': {u'@id': u'/r/UsedFor', u'label': u'UsedFor'},
#    u'sources': [{u'@id': u'/and/[/s/activity/omcs/omcs1_possibly_free_text/,/s/contributor/omcs/ariadne/]',
#      u'activity': u'/s/activity/omcs/omcs1_possibly_free_text',
#      u'contributor': u'/s/contributor/omcs/ariadne'},
#     {u'@id': u'/and/[/s/activity/omcs/omcs1_possibly_free_text/,/s/contributor/omcs/porter/]',
#      u'activity': u'/s/activity/omcs/omcs1_possibly_free_text',
#      u'contributor': u'/s/contributor/omcs/porter'},
#     {u'@id': u'/and/[/s/activity/omcs/vote/,/s/contributor/omcs/anaitis/]',
#      u'activity': u'/s/activity/omcs/vote',
#      u'contributor': u'/s/contributor/omcs/anaitis'},
#     {u'@id': u'/and/[/s/activity/omcs/vote/,/s/contributor/omcs/ariadne/]',
#      u'activity': u'/s/activity/omcs/vote',
#      u'contributor': u'/s/contributor/omcs/ariadne'},
#     {u'@id': u'/and/[/s/activity/omcs/vote/,/s/contributor/omcs/browni/]',
#      u'activity': u'/s/activity/omcs/vote',
#      u'contributor': u'/s/contributor/omcs/browni'},
#     {u'@id': u'/and/[/s/activity/omcs/vote/,/s/contributor/omcs/chibong/]',
#      u'activity': u'/s/activity/omcs/vote',
#      u'contributor': u'/s/contributor/omcs/chibong'},
#     {u'@id': u'/and/[/s/activity/omcs/vote/,/s/contributor/omcs/czdurham/]',
#      u'activity': u'/s/activity/omcs/vote',
#      u'contributor': u'/s/contributor/omcs/czdurham'},
#     {u'@id': u'/and/[/s/activity/omcs/vote/,/s/contributor/omcs/davet/]',
#      u'activity': u'/s/activity/omcs/vote',
#      u'contributor': u'/s/contributor/omcs/davet'},
#     {u'@id': u'/and/[/s/activity/omcs/vote/,/s/contributor/omcs/dev24/]',
#      u'activity': u'/s/activity/omcs/vote',
#      u'contributor': u'/s/contributor/omcs/dev24'},
#     {u'@id': u'/and/[/s/activity/omcs/vote/,/s/contributor/omcs/jakenelson/]',
#      u'activity': u'/s/activity/omcs/vote',
#      u'contributor': u'/s/contributor/omcs/jakenelson'},
#     {u'@id': u'/and/[/s/activity/omcs/vote/,/s/contributor/omcs/jimh/]',
#      u'activity': u'/s/activity/omcs/vote',
#      u'contributor': u'/s/contributor/omcs/jimh'},
#     {u'@id': u'/and/[/s/activity/omcs/vote/,/s/contributor/omcs/jlquelch/]',
#      u'activity': u'/s/activity/omcs/vote',
#      u'contributor': u'/s/contributor/omcs/jlquelch'},
#     {u'@id': u'/and/[/s/activity/omcs/vote/,/s/contributor/omcs/mrycan/]',
#      u'activity': u'/s/activity/omcs/vote',
#      u'contributor': u'/s/contributor/omcs/mrycan'},
#     {u'@id': u'/and/[/s/activity/omcs/vote/,/s/contributor/omcs/polymatrix/]',
#      u'activity': u'/s/activity/omcs/vote',
#      u'contributor': u'/s/contributor/omcs/polymatrix'},
#     {u'@id': u'/and/[/s/activity/omcs/vote/,/s/contributor/omcs/sellis/]',
#      u'activity': u'/s/activity/omcs/vote',
#      u'contributor': u'/s/contributor/omcs/sellis'}],
#    u'start': {u'@id': u'/c/en/camera',
#     u'label': u'a camera',
#     u'language': u'en',
#     u'term': u'/c/en/camera'},
#    u'surfaceText': u'You can use [[a camera]] to [[take pictures]]',
#    u'weight': 7.483314773547882},
#   {u'@id': u'/a/[/r/AtLocation/,/c/en/lens/,/c/en/camera/]',
#    u'dataset': u'/d/conceptnet/4/en',
#    u'end': {u'@id': u'/c/en/camera',
#     u'label': u'the camera',
#     u'language': u'en',
#     u'term': u'/c/en/camera'},
#    u'license': u'cc:by/4.0',
#    u'rel': {u'@id': u'/r/AtLocation', u'label': u'AtLocation'},
#    u'sources': [{u'@id': u'/and/[/s/activity/omcs/omcs1_possibly_free_text/,/s/contributor/omcs/ali33/]',
#      u'activity': u'/s/activity/omcs/omcs1_possibly_free_text',
#      u'contributor': u'/s/contributor/omcs/ali33'},
#     {u'@id': u'/and/[/s/activity/omcs/omcs1_possibly_free_text/,/s/contributor/omcs/matches/]',
#      u'activity': u'/s/activity/omcs/omcs1_possibly_free_text',
#      u'contributor': u'/s/contributor/omcs/matches'},
#     {u'@id': u'/and/[/s/activity/omcs/vote/,/s/contributor/omcs/avaabbi/]',
#      u'activity': u'/s/activity/omcs/vote',
#      u'contributor': u'/s/contributor/omcs/avaabbi'},
#     {u'@id': u'/and/[/s/activity/omcs/vote/,/s/contributor/omcs/bobdhaliwal/]',
#      u'activity': u'/s/activity/omcs/vote',
#      u'contributor': u'/s/contributor/omcs/bobdhaliwal'},
#     {u'@id': u'/and/[/s/activity/omcs/vote/,/s/contributor/omcs/matches/]',
#      u'activity': u'/s/activity/omcs/vote',
#      u'contributor': u'/s/contributor/omcs/matches'},
#     {u'@id': u'/and/[/s/activity/omcs/vote/,/s/contributor/omcs/slux/]',
#      u'activity': u'/s/activity/omcs/vote',
#      u'contributor': u'/s/contributor/omcs/slux'}],
#    u'start': {u'@id': u'/c/en/lens',
#     u'label': u'a lens',
#     u'language': u'en',
#     u'term': u'/c/en/lens'},
#    u'surfaceText': u'You are likely to find [[a lens]] in [[the camera]]',
#    u'weight': 5.291502622129181},
#   {u'@id': u'/a/[/r/RelatedTo/,/c/en/picture/,/c/en/camera/]',
#    u'dataset': u'/d/verbosity',
#    u'end': {u'@id': u'/c/en/camera',
#     u'label': u'camera',
#     u'language': u'en',
#     u'term': u'/c/en/camera'},
#    u'license': u'cc:by/4.0',
#    u'rel': {u'@id': u'/r/RelatedTo', u'label': u'RelatedTo'},
#    u'sources': [{u'@id': u'/and/[/s/process/split_words/,/s/resource/verbosity/]',
#      u'contributor': u'/s/resource/verbosity',
#      u'process': u'/s/process/split_words'},
#     {u'@id': u'/s/resource/verbosity',
#      u'contributor': u'/s/resource/verbosity'}],
#    u'start': {u'@id': u'/c/en/picture',
#     u'label': u'picture',
#     u'language': u'en',
#     u'term': u'/c/en/picture'},
#    u'surfaceText': u'[[picture]] is related to [[camera]]',
#    u'weight': 4.024922359499621},
#   {u'@id': u'/a/[/r/RelatedTo/,/c/en/flash/,/c/en/camera/]',
#    u'dataset': u'/d/verbosity',
#    u'end': {u'@id': u'/c/en/camera',
#     u'label': u'camera',
#     u'language': u'en',
#     u'term': u'/c/en/camera'},
#    u'license': u'cc:by/4.0',
#    u'rel': {u'@id': u'/r/RelatedTo', u'label': u'RelatedTo'},
#    u'sources': [{u'@id': u'/and/[/s/process/split_words/,/s/resource/verbosity/]',
#      u'contributor': u'/s/resource/verbosity',
#      u'process': u'/s/process/split_words'},
#     {u'@id': u'/s/resource/verbosity',
#      u'contributor': u'/s/resource/verbosity'}],
#    u'start': {u'@id': u'/c/en/flash',
#     u'label': u'flash',
#     u'language': u'en',
#     u'term': u'/c/en/flash'},
#    u'surfaceText': u'[[flash]] is related to [[camera]]',
#    u'weight': 3.334066586017742},
#   {u'@id': u'/a/[/r/HasA/,/c/en/camera/,/c/en/flash/]',
#    u'dataset': u'/d/conceptnet/4/en',
#    u'end': {u'@id': u'/c/en/flash',
#     u'label': u'a flash',
#     u'language': u'en',
#     u'term': u'/c/en/flash'},
#    u'license': u'cc:by/4.0',
#    u'rel': {u'@id': u'/r/HasA', u'label': u'HasA'},
#    u'sources': [{u'@id': u'/and/[/s/activity/omcs/omcs1_possibly_free_text/,/s/contributor/omcs/alexwg/]',
#      u'activity': u'/s/activity/omcs/omcs1_possibly_free_text',
#      u'contributor': u'/s/contributor/omcs/alexwg'},
#     {u'@id': u'/and/[/s/activity/omcs/omcs1_possibly_free_text/,/s/contributor/omcs/dev/]',
#      u'activity': u'/s/activity/omcs/omcs1_possibly_free_text',
#      u'contributor': u'/s/contributor/omcs/dev'},
#     {u'@id': u'/and/[/s/activity/omcs/vote/,/s/contributor/omcs/dev/]',
#      u'activity': u'/s/activity/omcs/vote',
#      u'contributor': u'/s/contributor/omcs/dev'}],
#    u'start': {u'@id': u'/c/en/camera',
#     u'label': u'Camera',
#     u'language': u'en',
#     u'term': u'/c/en/camera'},
#    u'surfaceText': u'[[Camera]] has [[a flash]]',
#    u'weight': 2.82842712474619},
#   {u'@id': u'/a/[/r/AtLocation/,/c/en/camera/,/c/en/suitcase/]',
#    u'dataset': u'/d/conceptnet/4/en',
#    u'end': {u'@id': u'/c/en/suitcase',
#     u'label': u'a suitcase',
#     u'language': u'en',
#     u'term': u'/c/en/suitcase'},
#    u'license': u'cc:by/4.0',
#    u'rel': {u'@id': u'/r/AtLocation', u'label': u'AtLocation'},
#    u'sources': [{u'@id': u'/and/[/s/activity/omcs/omcs1_possibly_free_text/,/s/contributor/omcs/annedog/]',
#      u'activity': u'/s/activity/omcs/omcs1_possibly_free_text',
#      u'contributor': u'/s/contributor/omcs/annedog'},
#     {u'@id': u'/and/[/s/activity/omcs/vote/,/s/contributor/omcs/laserjoy/]',
#      u'activity': u'/s/activity/omcs/vote',
#      u'contributor': u'/s/contributor/omcs/laserjoy'}],
#    u'start': {u'@id': u'/c/en/camera',
#     u'label': u'a camera',
#     u'language': u'en',
#     u'term': u'/c/en/camera'},
#    u'surfaceText': u'*Something you find in [[a suitcase]] is [[a camera]]',
#    u'weight': 2.0},
#   {u'@id': u'/a/[/r/IsA/,/c/en/box_camera/n/,/c/en/camera/n/]',
#    u'dataset': u'/d/wordnet/3.1',
#    u'end': {u'@id': u'/c/en/camera/n',
#     u'label': u'camera',
#     u'language': u'en',
#     u'sense_label': u'n',
#     u'term': u'/c/en/camera'},
#    u'license': u'cc:by/4.0',
#    u'rel': {u'@id': u'/r/IsA', u'label': u'IsA'},
#    u'sources': [{u'@id': u'/s/resource/wordnet/rdf/3.1',
#      u'contributor': u'/s/resource/wordnet/rdf/3.1'}],
#    u'start': {u'@id': u'/c/en/box_camera/n',
#     u'label': u'box camera',
#     u'language': u'en',
#     u'sense_label': u'n',
#     u'term': u'/c/en/box_camera'},
#    u'surfaceText': u'[[box camera]] is a type of [[camera]]',
#    u'weight': 2.0},
#   {u'@id': u'/a/[/r/IsA/,/c/en/camera/,/c/en/tool_for_taking_pictures/]',
#    u'dataset': u'/d/conceptnet/4/en',
#    u'end': {u'@id': u'/c/en/tool_for_taking_pictures',
#     u'label': u'a tool for taking pictures',
#     u'language': u'en',
#     u'term': u'/c/en/tool_for_taking_pictures'},
#    u'license': u'cc:by/4.0',
#    u'rel': {u'@id': u'/r/IsA', u'label': u'IsA'},
#    u'sources': [{u'@id': u'/and/[/s/activity/omcs/is_a_cleanup/,/s/contributor/omcs/rosaleah/]',
#      u'activity': u'/s/activity/omcs/is_a_cleanup',
#      u'contributor': u'/s/contributor/omcs/rosaleah'},
#     {u'@id': u'/and/[/s/activity/omcs/vote/,/s/contributor/omcs/mrycan/]',
#      u'activity': u'/s/activity/omcs/vote',
#      u'contributor': u'/s/contributor/omcs/mrycan'}],
#    u'start': {u'@id': u'/c/en/camera',
#     u'label': u'A camera',
#     u'language': u'en',
#     u'term': u'/c/en/camera'},
#    u'surfaceText': u'[[A camera]] is [[a tool for taking pictures]]',
#    u'weight': 2.0},
#   {u'@id': u'/a/[/r/IsA/,/c/en/camera/n/,/c/en/photographic_equipment/n/]',
#    u'dataset': u'/d/wordnet/3.1',
#    u'end': {u'@id': u'/c/en/photographic_equipment/n',
#     u'label': u'photographic equipment',
#     u'language': u'en',
#     u'sense_label': u'n',
#     u'term': u'/c/en/photographic_equipment'},
#    u'license': u'cc:by/4.0',
#    u'rel': {u'@id': u'/r/IsA', u'label': u'IsA'},
#    u'sources': [{u'@id': u'/s/resource/wordnet/rdf/3.1',
#      u'contributor': u'/s/resource/wordnet/rdf/3.1'}],
#    u'start': {u'@id': u'/c/en/camera/n',
#     u'label': u'camera',
#     u'language': u'en',
#     u'sense_label': u'n',
#     u'term': u'/c/en/camera'},
#    u'surfaceText': u'[[camera]] is a type of [[photographic equipment]]',
#    u'weight': 2.0},
#   {u'@id': u'/a/[/r/IsA/,/c/en/candid_camera/n/,/c/en/camera/n/]',
#    u'dataset': u'/d/wordnet/3.1',
#    u'end': {u'@id': u'/c/en/camera/n',
#     u'label': u'camera',
#     u'language': u'en',
#     u'sense_label': u'n',
#     u'term': u'/c/en/camera'},
#    u'license': u'cc:by/4.0',
#    u'rel': {u'@id': u'/r/IsA', u'label': u'IsA'},
#    u'sources': [{u'@id': u'/s/resource/wordnet/rdf/3.1',
#      u'contributor': u'/s/resource/wordnet/rdf/3.1'}],
#    u'start': {u'@id': u'/c/en/candid_camera/n',
#     u'label': u'candid camera',
#     u'language': u'en',
#     u'sense_label': u'n',
#     u'term': u'/c/en/candid_camera'},
#    u'surfaceText': u'[[candid camera]] is a type of [[camera]]',
#    u'weight': 2.0},
#   {u'@id': u'/a/[/r/IsA/,/c/en/flash_camera/n/,/c/en/camera/n/]',
#    u'dataset': u'/d/wordnet/3.1',
#    u'end': {u'@id': u'/c/en/camera/n',
#     u'label': u'camera',
#     u'language': u'en',
#     u'sense_label': u'n',
#     u'term': u'/c/en/camera'},
#    u'license': u'cc:by/4.0',
#    u'rel': {u'@id': u'/r/IsA', u'label': u'IsA'},
#    u'sources': [{u'@id': u'/s/resource/wordnet/rdf/3.1',
#      u'contributor': u'/s/resource/wordnet/rdf/3.1'}],
#    u'start': {u'@id': u'/c/en/flash_camera/n',
#     u'label': u'flash camera',
#     u'language': u'en',
#     u'sense_label': u'n',
#     u'term': u'/c/en/flash_camera'},
#    u'surfaceText': u'[[flash camera]] is a type of [[camera]]',
#    u'weight': 2.0},
#   {u'@id': u'/a/[/r/IsA/,/c/en/motion_picture_camera/n/,/c/en/camera/n/]',
#    u'dataset': u'/d/wordnet/3.1',
#    u'end': {u'@id': u'/c/en/camera/n',
#     u'label': u'camera',
#     u'language': u'en',
#     u'sense_label': u'n',
#     u'term': u'/c/en/camera'},
#    u'license': u'cc:by/4.0',
#    u'rel': {u'@id': u'/r/IsA', u'label': u'IsA'},
#    u'sources': [{u'@id': u'/s/resource/wordnet/rdf/3.1',
#      u'contributor': u'/s/resource/wordnet/rdf/3.1'}],
#    u'start': {u'@id': u'/c/en/motion_picture_camera/n',
#     u'label': u'motion-picture camera',
#     u'language': u'en',
#     u'sense_label': u'n',
#     u'term': u'/c/en/motion_picture_camera'},
#    u'surfaceText': u'[[motion-picture camera]] is a type of [[camera]]',
#    u'weight': 2.0},
#   {u'@id': u'/a/[/r/IsA/,/c/en/point_and_shoot_camera/n/,/c/en/camera/n/]',
#    u'dataset': u'/d/wordnet/3.1',
#    u'end': {u'@id': u'/c/en/camera/n',
#     u'label': u'camera',
#     u'language': u'en',
#     u'sense_label': u'n',
#     u'term': u'/c/en/camera'},
#    u'license': u'cc:by/4.0',
#    u'rel': {u'@id': u'/r/IsA', u'label': u'IsA'},
#    u'sources': [{u'@id': u'/s/resource/wordnet/rdf/3.1',
#      u'contributor': u'/s/resource/wordnet/rdf/3.1'}],
#    u'start': {u'@id': u'/c/en/point_and_shoot_camera/n',
#     u'label': u'point-and-shoot camera',
#     u'language': u'en',
#     u'sense_label': u'n',
#     u'term': u'/c/en/point_and_shoot_camera'},
#    u'surfaceText': u'[[point-and-shoot camera]] is a type of [[camera]]',
#    u'weight': 2.0},
#   {u'@id': u'/a/[/r/IsA/,/c/en/portrait_camera/n/,/c/en/camera/n/]',
#    u'dataset': u'/d/wordnet/3.1',
#    u'end': {u'@id': u'/c/en/camera/n',
#     u'label': u'camera',
#     u'language': u'en',
#     u'sense_label': u'n',
#     u'term': u'/c/en/camera'},
#    u'license': u'cc:by/4.0',
#    u'rel': {u'@id': u'/r/IsA', u'label': u'IsA'},
#    u'sources': [{u'@id': u'/s/resource/wordnet/rdf/3.1',
#      u'contributor': u'/s/resource/wordnet/rdf/3.1'}],
#    u'start': {u'@id': u'/c/en/portrait_camera/n',
#     u'label': u'portrait camera',
#     u'language': u'en',
#     u'sense_label': u'n',
#     u'term': u'/c/en/portrait_camera'},
#    u'surfaceText': u'[[portrait camera]] is a type of [[camera]]',
#    u'weight': 2.0},
#   {u'@id': u'/a/[/r/IsA/,/c/en/reflex_camera/n/,/c/en/camera/n/]',
#    u'dataset': u'/d/wordnet/3.1',
#    u'end': {u'@id': u'/c/en/camera/n',
#     u'label': u'camera',
#     u'language': u'en',
#     u'sense_label': u'n',
#     u'term': u'/c/en/camera'},
#    u'license': u'cc:by/4.0',
#    u'rel': {u'@id': u'/r/IsA', u'label': u'IsA'},
#    u'sources': [{u'@id': u'/s/resource/wordnet/rdf/3.1',
#      u'contributor': u'/s/resource/wordnet/rdf/3.1'}],
#    u'start': {u'@id': u'/c/en/reflex_camera/n',
#     u'label': u'reflex camera',
#     u'language': u'en',
#     u'sense_label': u'n',
#     u'term': u'/c/en/reflex_camera'},
#    u'surfaceText': u'[[reflex camera]] is a type of [[camera]]',
#    u'weight': 2.0},
#   {u'@id': u'/a/[/r/PartOf/,/c/en/aperture/n/,/c/en/camera/n/]',
#    u'dataset': u'/d/wordnet/3.1',
#    u'end': {u'@id': u'/c/en/camera/n',
#     u'label': u'camera',
#     u'language': u'en',
#     u'sense_label': u'n',
#     u'term': u'/c/en/camera'},
#    u'license': u'cc:by/4.0',
#    u'rel': {u'@id': u'/r/PartOf', u'label': u'PartOf'},
#    u'sources': [{u'@id': u'/s/resource/wordnet/rdf/3.1',
#      u'contributor': u'/s/resource/wordnet/rdf/3.1'}],
#    u'start': {u'@id': u'/c/en/aperture/n',
#     u'label': u'aperture',
#     u'language': u'en',
#     u'sense_label': u'n',
#     u'term': u'/c/en/aperture'},
#    u'surfaceText': u'[[aperture]] is a part of [[camera]]',
#    u'weight': 2.0},
#   {u'@id': u'/a/[/r/PartOf/,/c/en/camera_lens/n/,/c/en/camera/n/]',
#    u'dataset': u'/d/wordnet/3.1',
#    u'end': {u'@id': u'/c/en/camera/n',
#     u'label': u'camera',
#     u'language': u'en',
#     u'sense_label': u'n',
#     u'term': u'/c/en/camera'},
#    u'license': u'cc:by/4.0',
#    u'rel': {u'@id': u'/r/PartOf', u'label': u'PartOf'},
#    u'sources': [{u'@id': u'/s/resource/wordnet/rdf/3.1',
#      u'contributor': u'/s/resource/wordnet/rdf/3.1'}],
#    u'start': {u'@id': u'/c/en/camera_lens/n',
#     u'label': u'camera lens',
#     u'language': u'en',
#     u'sense_label': u'n',
#     u'term': u'/c/en/camera_lens'},
#    u'surfaceText': u'[[camera lens]] is a part of [[camera]]',
#    u'weight': 2.0},
#   {u'@id': u'/a/[/r/PartOf/,/c/en/delayed_action/n/,/c/en/camera/n/]',
#    u'dataset': u'/d/wordnet/3.1',
#    u'end': {u'@id': u'/c/en/camera/n',
#     u'label': u'camera',
#     u'language': u'en',
#     u'sense_label': u'n',
#     u'term': u'/c/en/camera'},
#    u'license': u'cc:by/4.0',
#    u'rel': {u'@id': u'/r/PartOf', u'label': u'PartOf'},
#    u'sources': [{u'@id': u'/s/resource/wordnet/rdf/3.1',
#      u'contributor': u'/s/resource/wordnet/rdf/3.1'}],
#    u'start': {u'@id': u'/c/en/delayed_action/n',
#     u'label': u'delayed action',
#     u'language': u'en',
#     u'sense_label': u'n',
#     u'term': u'/c/en/delayed_action'},
#    u'surfaceText': u'[[delayed action]] is a part of [[camera]]',
#    u'weight': 2.0},
#   {u'@id': u'/a/[/r/PartOf/,/c/en/diaphragm/n/,/c/en/camera/n/]',
#    u'dataset': u'/d/wordnet/3.1',
#    u'end': {u'@id': u'/c/en/camera/n',
#     u'label': u'camera',
#     u'language': u'en',
#     u'sense_label': u'n',
#     u'term': u'/c/en/camera'},
#    u'license': u'cc:by/4.0',
#    u'rel': {u'@id': u'/r/PartOf', u'label': u'PartOf'},
#    u'sources': [{u'@id': u'/s/resource/wordnet/rdf/3.1',
#      u'contributor': u'/s/resource/wordnet/rdf/3.1'}],
#    u'start': {u'@id': u'/c/en/diaphragm/n',
#     u'label': u'diaphragm',
#     u'language': u'en',
#     u'sense_label': u'n',
#     u'term': u'/c/en/diaphragm'},
#    u'surfaceText': u'[[diaphragm]] is a part of [[camera]]',
#    u'weight': 2.0},
#   {u'@id': u'/a/[/r/PartOf/,/c/en/finder/n/,/c/en/camera/n/]',
#    u'dataset': u'/d/wordnet/3.1',
#    u'end': {u'@id': u'/c/en/camera/n',
#     u'label': u'camera',
#     u'language': u'en',
#     u'sense_label': u'n',
#     u'term': u'/c/en/camera'},
#    u'license': u'cc:by/4.0',
#    u'rel': {u'@id': u'/r/PartOf', u'label': u'PartOf'},
#    u'sources': [{u'@id': u'/s/resource/wordnet/rdf/3.1',
#      u'contributor': u'/s/resource/wordnet/rdf/3.1'}],
#    u'start': {u'@id': u'/c/en/finder/n',
#     u'label': u'finder',
#     u'language': u'en',
#     u'sense_label': u'n',
#     u'term': u'/c/en/finder'},
#    u'surfaceText': u'[[finder]] is a part of [[camera]]',
#    u'weight': 2.0}],
#  u'view': {u'@id': u'/c/en/camera?offset=0&limit=20',
#   u'firstPage': u'/c/en/camera?offset=0&limit=20',
#   u'nextPage': u'/c/en/camera?offset=20&limit=20',
#   u'paginatedProperty': u'edges'}}

# %% [markdown]
# # # Relations for aspect's hierarchy

# %%
relations_aspects = ['LocatedNear', 'HasA', 'PartOf', 'MadeOf', 'IsA', 'InheritsFrom']

# %% [markdown]
# # # Get relation types

# %%
for edge in obj['edges']:
#     print edge['@id']
    print edge['start']['label'], edge['rel']['label'], edge['end']['label']
# Out:
# a camera UsedFor take pictures
# a lens AtLocation the camera
# picture RelatedTo camera
# flash RelatedTo camera
# Camera HasA a flash
# a camera AtLocation a suitcase
# box camera IsA camera
# A camera IsA a tool for taking pictures
# camera IsA photographic equipment
# candid camera IsA camera
# flash camera IsA camera
# motion-picture camera IsA camera
# point-and-shoot camera IsA camera
# portrait camera IsA camera
# reflex camera IsA camera
# aperture PartOf camera
# camera lens PartOf camera
# delayed action PartOf camera
# diaphragm PartOf camera
# finder PartOf camera

# %% [markdown]
# # # Create graph based on relations

# %%
# chosen concepts to build a graph
concept_names = ['camera', 'screen', 'phone', 'signal', 'operator', 'computer screen']

# %%
# %%timeit -r 1

concepts = []
for concept_name in concept_names:
    concepts += requests.get('http://api.conceptnet.io/c/en/{}'.format(concept_name)).json()['edges']

# %%
len(concepts)
# Out:
# 100

# %%
aspects_graph = nx.DiGraph()

# %%
for edge in concepts:
    relation = edge['rel']['label']
    if relation in relations_aspects:
        aspects_graph.add_edge(edge['start']['label'], edge['end']['label'], relation=relation)

# %%
concept_aspects_ = {}
for edge in concepts:
    relation = edge['rel']['label']
    if relation in relations_aspects:
        print(edge['start']['label'], edge['end']['label'], relation)
# Out:
# (u'Camera', u'a flash', u'HasA')
# (u'box camera', u'camera', u'IsA')
# (u'A camera', u'a tool for taking pictures', u'IsA')
# (u'camera', u'photographic equipment', u'IsA')
# (u'candid camera', u'camera', u'IsA')
# (u'flash camera', u'camera', u'IsA')
# (u'motion-picture camera', u'camera', u'IsA')
# (u'point-and-shoot camera', u'camera', u'IsA')
# (u'portrait camera', u'camera', u'IsA')
# (u'reflex camera', u'camera', u'IsA')
# (u'aperture', u'camera', u'PartOf')
# (u'camera lens', u'camera', u'PartOf')
# (u'delayed action', u'camera', u'PartOf')
# (u'diaphragm', u'camera', u'PartOf')
# (u'finder', u'camera', u'PartOf')
# (u'altarpiece', u'screen', u'IsA')
# (u'background', u'screen', u'IsA')
# (u'blind', u'screen', u'IsA')
# (u'camouflage', u'screen', u'IsA')
# (u'computer screen', u'screen', u'IsA')
# (u'fire screen', u'screen', u'IsA')
# (u'mosquito net', u'screen', u'IsA')
# (u'purdah', u'screen', u'IsA')
# (u'rood screen', u'screen', u'IsA')
# (u'screen', u'covering', u'IsA')
# (u'screen', u'display', u'IsA')
# (u'screen', u'partition', u'IsA')
# (u'screen', u'protective covering', u'IsA')
# (u'screen', u'surface', u'IsA')
# (u'screen', u'analyze', u'IsA')
# (u'consonant', u'phone', u'IsA')
# (u'orinasal phone', u'phone', u'IsA')
# (u'all clear', u'signal', u'IsA')
# (u'animal communication', u'signal', u'IsA')
# (u'bugle call', u'signal', u'IsA')
# (u'curfew', u'signal', u'IsA')
# (u'distress signal', u'signal', u'IsA')
# (u'dog-ear', u'signal', u'IsA')
# (u'drumbeat', u'signal', u'IsA')
# (u'high sign', u'signal', u'IsA')
# (u'indicator', u'signal', u'IsA')
# (u'input signal', u'signal', u'IsA')
# (u'interrupt', u'signal', u'IsA')
# (u'output signal', u'signal', u'IsA')
# (u'phone number', u'signal', u'IsA')
# (u'radio beacon', u'signal', u'IsA')
# (u'radio beam', u'signal', u'IsA')
# (u'recording', u'signal', u'IsA')
# (u'retreat', u'signal', u'IsA')
# (u'signal', u'communication', u'IsA')
# (u'signal', u'electricity', u'IsA')
# (u'company operator', u'operator', u'IsA')
# (u'driver', u'operator', u'IsA')
# (u'elevator operator', u'operator', u'IsA')
# (u'engineer', u'operator', u'IsA')
# (u'hoister', u'operator', u'IsA')
# (u'identity', u'operator', u'IsA')
# (u'jockey', u'operator', u'IsA')
# (u'linear operator', u'operator', u'IsA')
# (u'motorman', u'operator', u'IsA')
# (u'operator', u'businessman', u'IsA')
# (u'operator', u'causal agent', u'IsA')
# (u'operator', u'mapping', u'IsA')
# (u'operator', u'speculator', u'IsA')
# (u'radio operator', u'operator', u'IsA')
# (u'supermarketer', u'operator', u'IsA')
# (u'switchman', u'operator', u'IsA')
# (u'telegrapher', u'operator', u'IsA')

# %%
# dict([((u,v,),d['relation']) for u,v,d in aspects_graph.edges(data=True)])

# %%
edge_labels = dict([((u,v,),d['relation']) for u,v,d in aspects_graph.edges(data=True)])
node_labels = {n:n for n in aspects_graph.nodes()}

# pos = nx.spring_layout(aspects_graph)
pos = nx.random_layout(aspects_graph)
nx.draw_networkx_edge_labels(aspects_graph, pos, edge_labels=edge_labels, font_size=6)
nx.draw_networkx_labels(aspects_graph, pos, labels=node_labels, font_size=6)
nx.draw(aspects_graph, pos, node_size=150, edge_cmap=plt.cm.Reds)
# plt.show()

# %%
plt.savefig('concepts-graph.png', dpi=300)

# %%
app = Viewer(aspects_graph)
app.mainloop()

# %%
nx.write_gexf(aspects_graph, 'concept-graph.gexf')

# %% [markdown]
# # Training the poincare embedding

# %%
# %load_ext autoreload
# %autoreload 2

import os
import logging
import numpy as np
import pandas as pd

from gensim.models.poincare import PoincareModel, PoincareKeyedVectors, PoincareRelations

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

logging.basicConfig(level=logging.INFO)
# Out:
# <style>.container { width:100% !important; }</style>

# %%
from pathlib import Path

# %%
data_directory = Path('../results/reviews_Cell_Phones_and_Accessories/')
wordnet_mammal_file = os.path.join(data_directory, 'aspect-rules.csv')

# %%
aspect_df_min_10_times = pd.read_csv(data_directory / 'aspects_per_edu_filtered_min_10_freq.csv')
aspect_df_min_10_times.columns = ['aspect', 'count']

# %% [markdown]
# The model can be initialized using an iterable of relations, where a relation is simply a pair of nodes

# %%
aspect_df_min_10_times.head()
# Out:
#           aspect  count
# 0          price   6383
# 1       motorola   4246
# 2        battery   3925
# 3         amazon   2805
# 4  sound quality   2636

# %%
aspect_rules_df = pd.read_csv(wordnet_mammal_file)
aspect_rules_df = aspect_rules_df[['id1', 'id2']]
aspect_rules_df.sample(2)
# Out:
#           id1       id2
# 1578   belkin        hp
# 815   quality  features

# %%
aspect_rules_df = aspect_rules_df[aspect_rules_df.id1.isin(aspect_df_min_10_times.aspect.values) & aspect_rules_df.id2.isin(aspect_df_min_10_times.aspect.values)]

# %%
aspect_rules_df
# Out:
#                 id1                id2
# 0              mike             accord
# 2           outlook        sidekick ii
# 3         bluetooth        sidekick ii
# 4      web browsing        sidekick ii
# 5              java        sidekick ii
# 7            amazon        sidekick ii
# 8           forever        sidekick ii
# 9            amazon        sidekick ii
# 13           volume           motorola
# 15            price                 tl
# 16           amazon                 tl
# 18           amazon                 tl
# 19            works             seller
# 20       power cord             seller
# 21             cord             seller
# 22          verizon              phone
# 24        bluetooth              phone
# 25          verizon              phone
# 26         keyboard              phone
# 27          battery              works
# 29           sprint              works
# 30            price      headset works
# 31            sound      sound quality
# 32            sound          bluetooth
# 33            sound           horrible
# 35    shipping cost            battery
# 36    sound quality          bluetooth
# 37         shipping              china
# 38          quality          caller id
# 39          battery              nokia
# ...             ...                ...
# 3609         amazon           warranty
# 3610         amazon  extended warranty
# 3611         amazon              apple
# 3612         amazon           warranty
# 3613         amazon  extended warranty
# 3614         amazon              apple
# 3615       warranty  extended warranty
# 3616       warranty              apple
# 3617       features              phone
# 3618            pda              phone
# 3619         volume              phone
# 3620         camera              phone
# 3621     resolution              phone
# 3624             aa       battery life
# 3625       shipping       battery life
# 3626          built              works
# 3630  sound quality           motorola
# 3632         switch           motorola
# 3634        operate           motorola
# 3636    plantronics           motorola
# 3639          phone               case
# 3640         weight             stylus
# 3643           case            samsung
# 3644           case            samsung
# 3645          price               case
# 3646          price            samsung
# 3647          price            samsung
# 3648          price               case
# 3649          price            samsung
# 3650          price            samsung
#
# [2282 rows x 2 columns]

# %%
relations = list(zip(aspect_rules_df.id1, aspect_rules_df.id2))

# %%
model = PoincareModel(train_data=relations, size=2, burn_in=0)
# Out:
# INFO:gensim.models.poincare:loading relations from train data..
# INFO:gensim.models.poincare:loaded 2282 relations from train data, 481 nodes

# %%
model.train(epochs=100, print_every=500)
# Out:
# INFO:gensim.models.poincare:training model of size 2 with 1 workers on 2282 relations for 100 epochs and 0 burn-in epochs, using lr=0.10000 burn-in lr=0.01000 negative=10
# INFO:gensim.models.poincare:starting training (100 epochs)----------------------------------------

# %% [markdown]
# The model can be saved and loaded using two different methods -

# %%
# Saves the entire PoincareModel instance, the loaded model can be trained further
model.save('aspect_rules_model')
PoincareModel.load('aspect_rules_model')

# %%
model.kv.distance('phone', 'battery')

# %%
model.kv.distance('battery', 'sound')

# %%
model.kv.most_similar('battery')

# %%
model.kv.closest_child('battery')

# %%
model.kv.closest_parent('battery')

# %%
model.kv.ancestors('phone')

# %%
model.kv.descendants('phone')

# %%
# Saves only the vectors from the PoincareModel instance, in the commonly used word2vec format
# model.kv.save_word2vec_format('aspect_rules_vectors')
# PoincareKeyedVectors.load_word2vec_format('aspect_rules_vectors')

# %%
# Rank of distance of node 2 from node 1 in relation to distances of all nodes from node 1
model.kv.rank('phone', 'battery')

# %%
# Closest child node
model.kv.closest_child('sound')

# %%
# Closest child node
model.kv.closest_parent('bluetooth')

# %%
# # Position in hierarchy - lower values represent that the node is higher in the hierarchy
# print(model.kv.norm('virginia_deer.n.01'))
# print(model.kv.norm('sheep.n.01'))
# print(model.kv.norm('dog.n.01'))
# print(model.kv.norm('placental.n.01'))
# print(model.kv.norm('mammal.n.01'))

# %%
# Difference in hierarchy between the first node and the second node
# Positive values indicate the first node is higher in the hierarchy
print(model.kv.difference_in_hierarchy('phone', 'battery'))

# %%
model.kv.difference_in_hierarchy('bluetooth', 'headset')

# %%
# One possible descendant chain
model.kv.descendants('sound')

# %%
# One possible ancestor chain
model.kv.ancestors('sound')

# %% [markdown]
# # Visualization

# %%
from gensim.viz.poincare import poincare_2d_visualization, poincare_distance_heatmap

# %%
all_relations = list(set(relations))

# %%
show_node_labels = ['phone', 'battery', 'sound', 'bluetooth', 'headset', 'price', 'disc']
filtered_set = set()
for relation in all_relations:
    if relation[0] in show_node_labels and relation[1] in show_node_labels:
        filtered_set.add(relation)

# %%
filtered_set

# %%
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
fig = poincare_2d_visualization(model, filtered_set, "Poincare Hierarchy", show_node_labels=show_node_labels,)

# %%
iplot(fig)
# Out:
# <div>
#
#
#             <div id="94869218-1c7d-4f97-824e-2a3f363d7b54" class="plotly-graph-div" style="height:800px; width:800px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("94869218-1c7d-4f97-824e-2a3f363d7b54")) {
#                     Plotly.newPlot(
#                         '94869218-1c7d-4f97-824e-2a3f363d7b54',
#                         [{"hoverinfo": "none", "line": {"color": "rgb(50,50,50)", "width": 1}, "mode": "lines", "type": "scatter", "uid": "7f6e3c53-24cc-4026-b74b-7a55e681454c", "x": [0.17501814201289115, -0.025510427945234, null, -0.025510427945234, 0.22332203893661942, null, -0.10547897797904181, -0.025510427945234, null, 0.5004570015831855, 0.22332203893661942, null, 0.22332203893661942, -0.025510427945234, null, 0.5004570015831855, -0.025510427945234, null, -0.10547897797904181, 0.17501814201289115, null, 0.22332203893661942, 0.09556542350025546, null, -0.025510427945234, 0.17501814201289115, null, 0.22332203893661942, 0.17501814201289115, null, -0.025510427945234, -0.10547897797904181, null, 0.17501814201289115, -0.10547897797904181, null, -0.025510427945234, 0.5004570015831855, null, 0.09556542350025546, -0.025510427945234, null], "y": [0.2556838561533409, -0.1023120669826916, null, -0.1023120669826916, -0.19879197512285746, null, -0.3461244860910741, -0.1023120669826916, null, -0.6112090120645867, -0.19879197512285746, null, -0.19879197512285746, -0.1023120669826916, null, -0.6112090120645867, -0.1023120669826916, null, -0.3461244860910741, 0.2556838561533409, null, -0.19879197512285746, -0.3252358054980903, null, -0.1023120669826916, 0.2556838561533409, null, -0.19879197512285746, 0.2556838561533409, null, -0.1023120669826916, -0.3461244860910741, null, 0.2556838561533409, -0.3461244860910741, null, -0.1023120669826916, -0.6112090120645867, null, -0.3252358054980903, -0.1023120669826916, null]}, {"marker": {"color": "rgb(30, 100, 200)"}, "mode": "markers", "text": ["mike", "accord", "wilson", "nm", "outlook", "sidekick ii", "bluetooth", "web browsing", "java", "major", "amazon", "forever", "z50a", "sony ericsson k750", "ac chargervery", "jabra ear boom", "motorola", "volume", "microphone performs", "sound volume", "price", "tl", "shipping costs", "works", "seller", "power cord", "cord", "verizon", "phone", "useless", "keyboard", "battery", "cover fits", "sprint", "headset works", "sound", "sound quality", "horrible", "screen guard", "cleartouch anti-glare screen protector", "shipping cost", "shipping", "china", "quality", "caller id", "nokia", "garmin", "oem motorola", "v3 & my w490.can", "case", "usb", "keyboard case", "customer service", "boxwave", "return process", "nokia nseries", "n73", "use", "features", "te samsung", "240x320 screen", "quality video", "mb", "xilisoft 3gp converter", "the", "camera", "memory", "screen", "leather case", "samsung", "gp", "quality case", "quality leather", "sony", "ear", "size", "motorola v3", "nokia 6600", "sony ericsson k 750i", "key pad", "speaker phone", "camera quality", "video capture", "ear pieces", "terriffic", "highly", "junk", "razr v3", "motorola bluetooth headset", "function controls", "jabra", "jabra bt620", "samsung blast", "interface", "amoi", "menu options", "battery life", "performance", "charger", "windows rolled up", "picture quality", "headphone design", "bluetooth connection", "ear side", "lg", "operation", "bluetooth headset", "functionality", "system", "range", "palm", "at&t", "8525", "tilt", "factory cord", "retractable feature", "exchange", "software", "pictures", "video", "video camera", "mmc", "bluetooth keyboard", "htc", "aluminum", "mobile charging cord", "charging cord", "plantronics", "ac", "dc", "the doubletalk ac/dc chargers", "blackberry", "escort", "escort solo 2", "incipio", "power", "volume buttons", "power buttons", "nexus 7", "lenovo", "design", "great service", "electronic shipping info received walnut ca", "quality sound", "small design", "bluetooth enabled", "priced", "items", "iphone & ipad", "great &", "audio quality", "sena", "leather", "vzw", "uk", "europe", "hard travel case", "travel case", "the neatco mobile scanner!previously", "glimmer", "price ca", "volume control", "chrystal", "navigation", "ebay", "bionic", "lesson learned : most smartphones", "micro", "body", "voyager 510", "headset", "krusell", "the naztech voyage", "treo", "ch ...

# %%
iplot(fig, filename='poincare_viz.png')
# Out:
# <div>
#
#
#             <div id="4b927e49-1627-4dfa-ae2a-b46f367df943" class="plotly-graph-div" style="height:800px; width:800px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("4b927e49-1627-4dfa-ae2a-b46f367df943")) {
#                     Plotly.newPlot(
#                         '4b927e49-1627-4dfa-ae2a-b46f367df943',
#                         [{"hoverinfo": "none", "line": {"color": "rgb(50,50,50)", "width": 1}, "mode": "lines", "type": "scatter", "uid": "4800af9b-f740-4f98-a9ba-f0b523d31a25", "x": [-0.10547897797904181, 0.17501814201289115, null, 0.17501814201289115, -0.10547897797904181, null], "y": [-0.3461244860910741, 0.2556838561533409, null, 0.2556838561533409, -0.3461244860910741, null]}, {"marker": {"color": "rgb(30, 100, 200)"}, "mode": "markers", "text": ["mike", "accord", "wilson", "nm", "outlook", "sidekick ii", "bluetooth", "web browsing", "java", "major", "amazon", "forever", "z50a", "sony ericsson k750", "ac chargervery", "jabra ear boom", "motorola", "volume", "microphone performs", "sound volume", "price", "tl", "shipping costs", "works", "seller", "power cord", "cord", "verizon", "phone", "useless", "keyboard", "battery", "cover fits", "sprint", "headset works", "sound", "sound quality", "horrible", "screen guard", "cleartouch anti-glare screen protector", "shipping cost", "shipping", "china", "quality", "caller id", "nokia", "garmin", "oem motorola", "v3 & my w490.can", "case", "usb", "keyboard case", "customer service", "boxwave", "return process", "nokia nseries", "n73", "use", "features", "te samsung", "240x320 screen", "quality video", "mb", "xilisoft 3gp converter", "the", "camera", "memory", "screen", "leather case", "samsung", "gp", "quality case", "quality leather", "sony", "ear", "size", "motorola v3", "nokia 6600", "sony ericsson k 750i", "key pad", "speaker phone", "camera quality", "video capture", "ear pieces", "terriffic", "highly", "junk", "razr v3", "motorola bluetooth headset", "function controls", "jabra", "jabra bt620", "samsung blast", "interface", "amoi", "menu options", "battery life", "performance", "charger", "windows rolled up", "picture quality", "headphone design", "bluetooth connection", "ear side", "lg", "operation", "bluetooth headset", "functionality", "system", "range", "palm", "at&t", "8525", "tilt", "factory cord", "retractable feature", "exchange", "software", "pictures", "video", "video camera", "mmc", "bluetooth keyboard", "htc", "aluminum", "mobile charging cord", "charging cord", "plantronics", "ac", "dc", "the doubletalk ac/dc chargers", "blackberry", "escort", "escort solo 2", "incipio", "power", "volume buttons", "power buttons", "nexus 7", "lenovo", "design", "great service", "electronic shipping info received walnut ca", "quality sound", "small design", "bluetooth enabled", "priced", "items", "iphone & ipad", "great &", "audio quality", "sena", "leather", "vzw", "uk", "europe", "hard travel case", "travel case", "the neatco mobile scanner!previously", "glimmer", "price ca", "volume control", "chrystal", "navigation", "ebay", "bionic", "lesson learned : most smartphones", "micro", "body", "voyager 510", "headset", "krusell", "the naztech voyage", "treo", "charging port", "blackberry curve 8330", "kindle", "the m800 instinct", "key", "case works", "microphone", "us", "gsm", "usa", "slvr", "software steps", "camera phone", "resolution", "la", "datavision", "ever", "doesn", "cable", "the motorola bluetooth", "reception", "contour plus", "keys", "quality small keyboard", "weight", "q. worked", "palm centro", "music", "the palm centro", "microsoft", "bluesoilel", "phone quality", "sansa", "motostart", "the jarbra a125s", "k850i", "charger works", "plug", "adapter plug", "att", "display", "li", "overall quality", "look", "motorola v600", "sony ericsson", "anyone", "blueant", "t2 works", "usb hubs", "cyberpower", "buttons", "speaker volume", "moto", "dont buy", "ear piece", "service", "received quickly", "motorola bluetooth", "motorola hs850 bluetooth headset", "motorolas", "bestbuy", "price point", "pda/smartphone", "keyboard2", "lcd screen", "funcionality", "palmone zire", "big mistake", "worst", "ear loop", "fit", "quality packaging", "pda", "exterior noise", "palm tx", "hard case", "krussell", "sd", "cased phone", "pearl", "650", "& pda", "skype", "a kindle fire", "battery performs" ...

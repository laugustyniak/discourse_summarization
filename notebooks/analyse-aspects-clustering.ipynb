# %%
# %load_ext autoreload
# %autoreload 2

# %%
import json

from pathlib import Path

import pandas as pd
import plotly
from more_itertools import flatten
from sklearn.cluster import AgglomerativeClustering
plotly.offline.init_notebook_mode(connected=True)

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

from gensim.models import fasttext

# %matplotlib inline
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <style>.container { width:100% !important; }</style>

# %%
from aspects.analysis import draw_embeddings

# %%
import spacy
nlp = spacy.load('en_vectors_web_lg')
# nlp = spacy.load('en')

# %% [markdown]
# # Load prodigy manually created aspect lexicons

# %%
PRODIGY_PATH = Path('/home/laugustyniak/github/nlp/prodigy-trainings/')

# %%
aspect_jsonls = list(PRODIGY_PATH.glob('*.jsonl'))

# %%
aspect_jsonls
# Out:
# [PosixPath('/home/laugustyniak/github/nlp/prodigy-trainings/connection-aspects-patterns.jsonl'),
#  PosixPath('/home/laugustyniak/github/nlp/prodigy-trainings/screen-aspects-patterns.jsonl'),
#  PosixPath('/home/laugustyniak/github/nlp/prodigy-trainings/cpu-aspects-patterns.jsonl'),
#  PosixPath('/home/laugustyniak/github/nlp/prodigy-trainings/sound-aspects-patterns.jsonl'),
#  PosixPath('/home/laugustyniak/github/nlp/prodigy-trainings/memory-aspects-patterns.jsonl'),
#  PosixPath('/home/laugustyniak/github/nlp/prodigy-trainings/battery-aspects-patterns.jsonl'),
#  PosixPath('/home/laugustyniak/github/nlp/prodigy-trainings/price-aspects-patterns.jsonl'),
#  PosixPath('/home/laugustyniak/github/nlp/prodigy-trainings/technical-support-aspects-patterns.jsonl')]

# %%
aspects_prodigy = []
for j in aspect_jsonls:
    print(j)
    with open(j.as_posix(), 'r') as lines:
        for line in lines:
            aspects_prodigy.append(json.loads(line))
# Out:
# /home/laugustyniak/github/nlp/prodigy-trainings/connection-aspects-patterns.jsonl
# /home/laugustyniak/github/nlp/prodigy-trainings/screen-aspects-patterns.jsonl
# /home/laugustyniak/github/nlp/prodigy-trainings/cpu-aspects-patterns.jsonl
# /home/laugustyniak/github/nlp/prodigy-trainings/sound-aspects-patterns.jsonl
# /home/laugustyniak/github/nlp/prodigy-trainings/memory-aspects-patterns.jsonl
# /home/laugustyniak/github/nlp/prodigy-trainings/battery-aspects-patterns.jsonl
# /home/laugustyniak/github/nlp/prodigy-trainings/price-aspects-patterns.jsonl
# /home/laugustyniak/github/nlp/prodigy-trainings/technical-support-aspects-patterns.jsonl

# %%
prodigy_aspects_df = pd.DataFrame([
    {
        'label': label_pattern['label'],
        'term': label_pattern['pattern'][0]['lower']
    } 
    for label_pattern 
    in aspects_prodigy
])

# %%
prodigy_aspects_df
# Out:
#                  label                     term
# 0           CONNECTION                bluetooth
# 1           CONNECTION                 ethernet
# 2           CONNECTION                     wlan
# 3           CONNECTION               connection
# 4           CONNECTION                   signal
# 5           CONNECTION             signal range
# 6           CONNECTION                  network
# 7           CONNECTION                     wifi
# 8           CONNECTION                      usb
# 9           CONNECTION                 wireless
# 10          CONNECTION                    modem
# 11          CONNECTION                   router
# 12          CONNECTION                  linksys
# 13          CONNECTION             connectivity
# 14          CONNECTION                  connect
# 15          CONNECTION                   modems
# 16          CONNECTION                     hdmi
# 17          CONNECTION                      vpn
# 18          CONNECTION                broadband
# 19          CONNECTION                 firewire
# 20          CONNECTION                  routers
# 21          CONNECTION                   pcmcia
# 22          CONNECTION                  wirless
# 23          CONNECTION                      dsl
# 24          CONNECTION               wirelessly
# 25          CONNECTION                 internet
# 26          CONNECTION               networking
# 27          CONNECTION                   switch
# 28          CONNECTION                  hotspot
# 29          CONNECTION               connecting
# ..                 ...                      ...
# 312              PRICE                    penny
# 313              PRICE                    pricy
# 314              PRICE                     pays
# 315              PRICE                    funds
# 316              PRICE                  rebates
# 317  TECHNICAL_SUPPORT        technical support
# 318  TECHNICAL_SUPPORT                  support
# 319  TECHNICAL_SUPPORT            documentation
# 320  TECHNICAL_SUPPORT                   update
# 321  TECHNICAL_SUPPORT  technical documentation
# 322  TECHNICAL_SUPPORT                  updates
# 323  TECHNICAL_SUPPORT                 updating
# 324  TECHNICAL_SUPPORT                supported
# 325  TECHNICAL_SUPPORT                 supports
# 326  TECHNICAL_SUPPORT                   issues
# 327  TECHNICAL_SUPPORT                  upgrade
# 328  TECHNICAL_SUPPORT                  updated
# 329  TECHNICAL_SUPPORT                  install
# 330  TECHNICAL_SUPPORT            compatibility
# 331  TECHNICAL_SUPPORT                   report
# 332  TECHNICAL_SUPPORT             instructions
# 333  TECHNICAL_SUPPORT                configure
# 334  TECHNICAL_SUPPORT                upgrading
# 335  TECHNICAL_SUPPORT                   update
# 336  TECHNICAL_SUPPORT                  support
# 337  TECHNICAL_SUPPORT            documentation
# 338  TECHNICAL_SUPPORT        technical support
# 339  TECHNICAL_SUPPORT  technical documentation
# 340  TECHNICAL_SUPPORT               supporting
# 341  TECHNICAL_SUPPORT               assistance
#
# [342 rows x 2 columns]

# %%
prodigy_aspects_df['embedding'] = prodigy_aspects_df.term.apply(lambda text: nlp(text).vector)

# %%
prodigy_aspects_df['tooltip'] = prodigy_aspects_df.label + ' : ' +  prodigy_aspects_df.term

# %%
prodigy_aspects_df['cluster'] = AgglomerativeClustering(n_clusters=len(prodigy_aspects_df.label.unique())).fit(prodigy_aspects_df.embedding.tolist()).labels_

# %%
draw_embeddings.draw(draw_embeddings.get_tsne(prodigy_aspects_df, text='term', tooltip_col='tooltip'))
# Out:
# <div>
#
#
#             <div id="bf8a5d46-a2b2-4e3e-a03f-b82946a9cd51" class="plotly-graph-div" style="height:1500px; width:1500px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("bf8a5d46-a2b2-4e3e-a03f-b82946a9cd51")) {
#                     Plotly.newPlot(
#                         'bf8a5d46-a2b2-4e3e-a03f-b82946a9cd51',
#                         [{"marker": {"color": "rgb(253,174,97)", "size": 15, "symbol": 0}, "mode": "markers", "name": "0", "text": ["SOUND : sound", "SOUND : voices", "SOUND : ringtones", "SOUND : voice", "SOUND : melody", "SOUND : tune", "SOUND : melodies", "SOUND : polyphonic", "SOUND : mute", "SOUND : soundtracks", "SOUND : inaudible", "SOUND : bells", "MEMORY : xp", "MEMORY : linux", "MEMORY : encrypt", "MEMORY : nfs", "TECHNICAL_SUPPORT : technical support", "TECHNICAL_SUPPORT : support", "TECHNICAL_SUPPORT : documentation", "TECHNICAL_SUPPORT : update", "TECHNICAL_SUPPORT : technical documentation", "TECHNICAL_SUPPORT : updates", "TECHNICAL_SUPPORT : updating", "TECHNICAL_SUPPORT : supported", "TECHNICAL_SUPPORT : supports", "TECHNICAL_SUPPORT : issues", "TECHNICAL_SUPPORT : upgrade", "TECHNICAL_SUPPORT : updated", "TECHNICAL_SUPPORT : install", "TECHNICAL_SUPPORT : compatibility", "TECHNICAL_SUPPORT : report", "TECHNICAL_SUPPORT : instructions", "TECHNICAL_SUPPORT : configure", "TECHNICAL_SUPPORT : upgrading", "TECHNICAL_SUPPORT : update", "TECHNICAL_SUPPORT : support", "TECHNICAL_SUPPORT : documentation", "TECHNICAL_SUPPORT : technical support", "TECHNICAL_SUPPORT : technical documentation", "TECHNICAL_SUPPORT : supporting", "TECHNICAL_SUPPORT : assistance"], "type": "scatter", "uid": "4b2472bf-1c88-4ab4-bd26-255b81dbd487", "x": [-14.601243019104004, -15.405718803405762, -20.86245346069336, -15.133359909057617, -17.373332977294922, -16.160001754760742, -17.53998565673828, -20.803438186645508, -13.049284934997559, -15.33601188659668, -14.536728858947754, -17.46810531616211, 10.25600814819336, 9.497116088867188, -7.881159782409668, 8.273059844970703, -9.510991096496582, -8.139643669128418, -11.71187973022461, -10.799720764160156, -11.024049758911133, -11.431055068969727, -10.069971084594727, -7.7083659172058105, -7.092260837554932, -11.007575035095215, -8.110115051269531, -11.781774520874023, -7.014062881469727, -7.674206733703613, -12.96329402923584, -13.161831855773926, -5.95641565322876, -8.446590423583984, -10.79983901977539, -8.341296195983887, -11.429800033569336, -9.652729034423828, -11.361618995666504, -8.605347633361816, -9.439873695373535], "y": [1.4338123798370361, 2.6880929470062256, -0.6495024561882019, 2.6456973552703857, 0.737960934638977, 1.0045344829559326, 0.5022304058074951, -0.6359440088272095, 3.157336473464966, -0.6289442181587219, 4.141955852508545, 2.8698372840881348, -14.77991008758545, -14.980185508728027, -7.479485511779785, -13.98747444152832, 13.305489540100098, 12.905927658081055, 15.494422912597656, 19.192888259887695, 14.512246131896973, 18.395488739013672, 18.24920082092285, 11.660360336303711, 12.479493141174316, 12.356640815734863, 18.427894592285156, 19.8327693939209, 18.733346939086914, 15.271984100341797, 13.231353759765625, 15.543394088745117, 18.27081871032715, 18.264904022216797, 19.193391799926758, 12.623052597045898, 15.6419677734375, 13.122024536132812, 14.32316780090332, 11.625887870788574, 14.541306495666504]}, {"marker": {"color": "rgb(215,48,39)", "size": 15, "symbol": 0}, "mode": "markers", "name": "1", "text": ["CPU : processor", "CPU : ghz", "CPU : cpu", "CPU : pentium", "CPU : intel", "CPU : overclock", "CPU : mhz", "CPU : athlon", "CPU : gpu", "CPU : amd", "CPU : celeron", "CPU : cpus", "CPU : chipset", "CPU : overclocking", "CPU : xeon", "CPU : processer", "CPU : gigahertz", "CPU : microprocessor", "CPU : mainboard", "CPU : hyperthreading", "CPU : procesor", "CPU : opteron", "CPU : sempron", "CPU : clocked", "CPU : microprocessors", "CPU : underclocked", "CPU : proccessor", "CPU : overclocks", "CPU : proccesor", "CPU : multicore", "CPU : multiprocessor", "CPU : clockspeed", "CPU : microcontroller", "CPU : processing", "CPU : vcore", "CPU : multiprocessing", "CPU : downclocked", "CPU : processers", "CPU : microarchitecture", "CPU : virtualization", "CPU : overclocker", "MEMORY : motherboard", "MEMORY : cpu"], "type": "scatter", "uid": "23695605-ac0d-4f24-b367-fc3de2991 ...

# %% [markdown]
# # Load SemEval dataset with aspects and categories

# %%
from utilities.settings import SEMEVAL_DATASETS_2016

# %%
semeval_df = pd.read_csv(SEMEVAL_DATASETS_2016 / 'all-entities-and-aspects.csv')

# %%
semeval_df.target = semeval_df.target.apply(lambda t: t.lower() if isinstance(t, str) else t)

# %%
semeval_df.dropna(how='all', inplace=True)

# %%
semeval_df.groupby(['category', 'target']).count().to_excel('restaurant-aspect-categories-and-targets.xlsx')

# %%
with open('../results/reviews_Cell_Phones_and_Accessories/aspects_per_edu.json') as f:
    aspects = json.load(f)

# %%
from bert_embedding import BertEmbedding

# %%
# model = fasttext.load_facebook_model('/home/laugustyniak/data/embeddings/cc.en.300.bin')

# %%
aspects['0']
# Out:
# ['phone case']

# %%
bert_embedding = BertEmbedding(model='bert_24_1024_16', dataset_name='book_corpus_wiki_en_cased')

# %%
bert_embedding(['battery life'])[0][1][0].shape
# Out:
# (1024,)

# %%
len(aspects)
# Out:
# 114536

# %%
aspects_flatten = list(flatten(aspects.values()))

# %%
aspects_df = pd.DataFrame(aspects_flatten, columns=['aspect'])

# %%
aspects_unique_df = pd.DataFrame.from_dict(aspects_df.aspect.value_counts())

# %%
aspects_unique_filtered_df = aspects_unique_df[aspects_unique_df.aspect >= 10]

# %%
aspects_unique_filtered_df = aspects_unique_filtered_df.applymap(lambda x: x.encode('unicode_escape').decode('utf-8') if isinstance(x, str) else x)

# %%
aspects_unique_filtered_df.to_csv('../results/reviews_Cell_Phones_and_Accessories/aspects_per_edu_filtered_min_10_freq.csv')

# %%
aspects_unique_filtered_df = aspects_unique_filtered_df.reset_index()
aspects_unique_filtered_df.columns = ['aspect', 'count']
aspects_unique_filtered_df.head(10)
# Out:
#           aspect  count
# 0          price   6383
# 1       motorola   4246
# 2        battery   3925
# 3         amazon   2805
# 4  sound quality   2636
# 5        charger   2605
# 6         screen   2506
# 7        quality   2350
# 8          sound   2317
# 9            use   2169

# %%
import numpy as np

# %%
# def get_vectors(text):
#     return nlp(text).vector

# def get_vectors(text):
#     return np.mean([model.wv[token.text] for token in nlp(text)], axis=0)

def get_vectors(text):
    return np.mean([bert_embedding([text])[0][1][0] for token in nlp(text)], axis=0)

# %%
get_vectors('test and there')
# Out:
# array([-0.6021834 , -0.90436697, -0.05011599, ..., -0.5272503 ,
#         0.2523726 , -0.39430416], dtype=float32)

# %%
aspects_unique_filtered_df['embedding'] = aspects_unique_filtered_df.aspect.apply(get_vectors)

# %%
hierarchical_cluster = AgglomerativeClustering(n_clusters=10).fit(aspects_unique_filtered_df.embedding.tolist())
aspects_unique_filtered_df['cluster'] = hierarchical_cluster.labels_

# %%
aspects_unique_filtered_df
# Out:
#                     aspect  count  \
# 0                    price   6383
# 1                 motorola   4246
# 2                  battery   3925
# 3                   amazon   2805
# 4            sound quality   2636
# 5                  charger   2605
# 6                   screen   2506
# 7                  quality   2350
# 8                    sound   2317
# 9                      use   2169
# 10                   phone   2129
# 11                   nokia   2075
# 12                    case   2051
# 13                features   1939
# 14               bluetooth   1670
# 15            battery life   1624
# 16                     usb   1620
# 17                 samsung   1529
# 18                  volume   1519
# 19                   works   1516
# 20                 verizon   1392
# 21                    size   1282
# 22                shipping   1277
# 23                keyboard   1187
# 24                    treo   1056
# 25                cingular    961
# 26                 service    835
# 27                   jabra    765
# 28                  camera    744
# 29                    sony    701
# ..                     ...    ...
# 916                   imei     10
# 917                   v60i     10
# 918                 boston     10
# 919                  light     10
# 920        qwerty keyboard     10
# 921               warrenty     10
# 922                  handy     10
# 923                  smell     10
# 924                 supply     10
# 925                     ge     10
# 926            the dry pak     10
# 927               tungsten     10
# 928  plantronics bluetooth     10
# 929               duracell     10
# 930                  motoq     10
# 931             nokia 3650     10
# 932            blackberrys     10
# 933                forever     10
# 934               capacity     10
# 935             audio jack     10
# 936                   rizr     10
# 937                     qa     10
# 938      resolution screen     10
# 939      camera resolution     10
# 940                eargels     10
# 941              powerbook     10
# 942                  k790a     10
# 943                  prius     10
# 944                 caller     10
# 945                 worked     10
#
#                                              embedding  cluster
# 0    [-0.4442973, -1.0091343, 0.060599357, -0.11182...        1
# 1    [-0.25731423, -0.4119842, -0.2841267, -0.03631...        5
# 2    [-0.31355655, -1.0403382, -0.00390834, -0.0332...        1
# 3    [-0.807282, -0.48361394, -0.04476956, 0.025126...        2
# 4    [-0.14678049, -0.3433536, -0.41184878, -0.7414...        0
# 5    [-0.5523349, -0.75383353, -0.061513424, 0.1178...        5
# 6    [-0.28711498, -0.83723056, -0.012677126, -0.13...        1
# 7    [-0.08396894, -0.008126093, 0.057925284, -0.07...        0
# 8    [-0.44968295, -0.9441416, 0.007318586, -0.0798...        1
# 9    [-0.21992154, -0.71526617, 0.03515914, 0.17506...        1
# 10   [-0.32975435, -0.8482823, -0.057655513, 0.0805...        1
# 11   [-0.2457469, -0.2821914, -0.31190756, 0.336148...        2
# 12   [-0.30369556, -0.9252489, -0.13929752, -0.1767...        1
# 13   [-0.56449294, -0.79403806, 0.0017733164, 0.014...        1
# 14   [-0.16809523, -0.7057056, -0.333708, 0.3379219...        5
# 15   [-0.39226562, -1.1734354, -0.14348644, -0.0806...        1
# 16   [-0.170908, -0.42800593, -0.08665458, 0.007679...        7
# 17   [-0.21254389, -0.13182761, 0.10385365, 0.10091...        2
# 18   [-0.19387594, -0.8368945, -0.17062083, -0.0102...        1
# 19   [0.24366294, 0.33870983, 0.42637244, 0.9533523...        8
# 20   [-0.49497437, -0.5117232, 0.29987887, 0.003761...        2
# 21   [-0.35917526, -0.9751861, 0.038271703, -0.1297...        1
# 22   [-0.35053283, -1.0761474, -0.123859994, -0.097...        1
# 23   [-0.38452786, -1.0178944, -0.122521795, 0.0480...        1
# 24   [-0.2670369, -0.16166656, 0.018742561, 0.00139...        2
# 25   [-0.23921828, -0.29222474, 0.2966567, -0.00344...        2
# 26   [-0.34487927, -0.8390368, -0.12677845, -0.1566...        1
# 27   [-0.16244851, -0.40341547, 0.08102321, -0.1925...        2
# 28   [-0.43756706, -1.0380778, 0.023654751, -0.1745...        1
# 29   [-0.4628775, -0.6049416, 0.01258171, -0.069262...        6
# ..                                                 ...      ...
# 916  [-0.21912526, -0.78673977, -0.284301, 0.328568...        5
# 917  [-0.2671487, -0.6421557, -0.15139788, -0.04733...        6
# 918  [0.09279352, 0.23517533, 0.1080527, -0.1978159...        2
# 919  [0.3536604, -1.075134, -0.64256203, -0.1246262...        4
# 920  [-0.6372649, 0.18807922, -0.26950926, 0.109945...        3
# 921  [-0.7806568, -0.45926395, -0.0936301, -0.15230...        2
# 922  [-0.384467, -0.7296128, -0.09301141, -0.067864...        1
# 923  [-0.43348408, -0.9056766, -0.105355345, -0.175...        1
# 924  [-0.23823762, -0.5287157, -0.21502528, 0.43964...        4
# 925  [-0.18051833, -0.12256193, 0.05293332, 0.11013...        6
# 926  [-0.39767155, -0.82152873, -0.07993868, -0.260...        4
# 927  [-0.08537177, -0.556953, -0.10907062, 0.295936...        2
# 928  [0.20186745, 0.18760677, -0.10088599, 0.049265...        3
# 929  [-0.46594843, -0.3455923, 0.12831824, 0.318238...        2
# 930  [-0.41711807, 0.23537694, 0.419755, 0.29395077...        7
# 931  [-0.12617289, 0.0563747, -0.2751254, 0.4622498...        3
# 932  [-0.57428616, -0.34662545, -0.15696435, 0.0796...        5
# 933  [-0.4135133, -0.8634334, 0.17812005, 0.2549082...        1
# 934  [-0.40343994, -1.0814366, -0.04036667, -0.1127...        1
# 935  [0.16443409, -0.6963113, -0.7976084, 0.0998908...        0
# 936  [-0.62713146, 0.094388686, 0.07073548, 0.02813...        7
# 937  [-0.30974197, -0.6928258, -0.023439985, -0.082...        6
# 938  [-0.20040742, -1.009044, -0.22455671, -0.06480...        1
# 939  [-0.36682415, -0.9974448, -0.21558416, -0.2325...        1
# 940  [-0.13374703, -0.111745745, 0.14935824, -0.161...        2
# 941  [-0.48530653, -0.3734243, 0.040306993, -0.2177...        5
# 942  [-0.24097826, -0.24391374, -0.09927368, 0.0509...        9
# 943  [-0.21679571, -0.5780887, 0.32710636, -0.56092...        5
# 944  [-0.38906312, -0.9032964, 0.13385785, 0.039391...        1
# 945  [-0.3877266, -0.6061729, -0.113527626, -0.0762...        1
#
# [946 rows x 4 columns]

# %%
manual_clusters = {
    1001: ['screen', 'monitor', 'lcd'],
    1002: ['phone', 'telephone', 'mobile phone'],
    1003: ['value', 'price', 'cost', 'expensive', 'cheap', 'money'],
    1004: ['volume', 'sound', 'voice', 
#            'echo' za daleko od innych
          ],
    1005: [],
    1006: ['bluetooth', 'usb', 'port', 'connection', 'wifi', 'network', 'signal range', 'signal'],
    1007: ['cpu', 'processor'],
    1008: ['memory', 'hard drive', 'hard disk', 'floppy disc', 'ssd drive', 'ram', 'rom', 'sd card', 'memory card', 'usb stick', 'pendrive'],
    1009: ['battery', 'charger', 'power', 'charging', 'power plug', 'power bank'],
    1010: ['technical documentation', 'support' ,'update']
}

# %%
manual_clusters_tuples = [
    (aspect, cluster_id)
    for cluster_id, aspects
    in manual_clusters.items()
    for aspect in aspects 
]

# %%
manual_clusters_df = pd.DataFrame(manual_clusters_tuples, columns=['aspect', 'cluster'])

# %%
manual_clusters_df['count'] = 1

# %%
manual_clusters_df['embedding'] = manual_clusters_df.aspect.apply(get_vectors)

# %%
aspects_with_manual = pd.concat([aspects_unique_filtered_df, manual_clusters_df], sort=False).reset_index(drop=True)

# %%
aspects_with_manual.sample(5)
# Out:
#           aspect  count                                          embedding  \
# 964   connection      1  [-0.39574474, -0.80263203, -0.010777239, 0.079...
# 176      dialing     62  [-0.36496538, -0.3415268, 0.49024117, 0.025630...
# 803  application     11  [-0.20704626, -0.80060315, -0.03289241, -0.013...
# 375      florida     27  [0.11800394, 0.13024826, 0.2570347, -0.3787836...
# 428          rca     23  [-0.45669454, -0.52944344, -0.026075576, -0.12...
#
#      cluster
# 964     1006
# 176        5
# 803        1
# 375        2
# 428        6

# %%
aspects_unique_filtered_df_tsne = draw_embeddings.get_tsne(aspects_with_manual)
aspects_unique_filtered_df_tsne.sample(5)
# Out:
#              x          y               text            tooltip  cluster  \
# 939 -24.436518 -35.785076  camera resolution  camera resolution        1
# 943  10.802140  18.798992              prius              prius        5
# 695  11.590446  25.670683      accessory one      accessory one        5
# 161   1.444517 -39.949253           graphics           graphics        1
# 830  -4.969251  12.305506               700w               700w        5
#
#                                              embedding
# 939  [-0.36682415, -0.9974448, -0.21558416, -0.2325...
# 943  [-0.21679571, -0.5780887, 0.32710636, -0.56092...
# 695  [-0.50451463, -0.4835921, -0.23530266, -0.1732...
# 161  [-0.33875427, -1.0402431, -0.046462692, -0.106...
# 830  [-0.57894605, -1.1176313, -0.052225683, -0.296...

# %%
draw_embeddings.draw(aspects_unique_filtered_df_tsne)
# Out:
# <div>
#
#
#             <div id="7bc6e5fb-0ee4-4846-85fb-2e56304ef4f1" class="plotly-graph-div" style="height:1500px; width:1500px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("7bc6e5fb-0ee4-4846-85fb-2e56304ef4f1")) {
#                     Plotly.newPlot(
#                         '7bc6e5fb-0ee4-4846-85fb-2e56304ef4f1',
#                         [{"marker": {"color": "rgb(253,174,97)", "size": 15, "symbol": 0}, "mode": "markers", "name": "0", "text": ["sound quality", "quality", "apple", "customer support", "picture quality", "operation", "manual", "problem", "speaker phone", "documentation", "worst", "quality pictures", "text messaging", "sound system", "audio jack"], "type": "scatter", "uid": "17ac3d34-11ee-4547-898f-dd963845f616", "x": [15.117974281311035, -20.415071487426758, 2.159609794616699, -2.5817556381225586, 6.571087837219238, 2.2936830520629883, 2.760713577270508, -17.433944702148438, -1.307269811630249, 2.926922082901001, 0.23546557128429413, -20.412492752075195, -3.1543495655059814, 15.050558090209961, 15.316497802734375], "y": [46.610530853271484, 57.92853927612305, 39.68061065673828, 72.75948333740234, -4.841177463531494, 42.22773361206055, 43.33613204956055, 30.284509658813477, 38.64952850341797, 49.29015350341797, 52.63502883911133, 57.93317413330078, 70.54515838623047, 46.86526870727539, 45.869972229003906]}, {"marker": {"color": "rgb(215,48,39)", "size": 15, "symbol": 0}, "mode": "markers", "name": "1", "text": ["price", "battery", "screen", "sound", "use", "phone", "case", "features", "battery life", "volume", "size", "shipping", "keyboard", "service", "camera", "software", "keys", "at&t", "cord", "buttons", "display", "sprint", "range", "design", "power", "plug", "palm", "us", "performance", "support", "interface", "signal", "memory", "color", "outlook", "priced", "power button", "weight", "volume control", "applications", "controls", "install", "set up", "ear piece", "pictures", "audio", "volume buttons", "video", "call quality", "menu", "tech support", "mac", "extended battery", "program", "ear", "windows", "microphone", "buy", "speaker", "hp", "car charger", "edges", "operate", "speakers", "hardware", "built", "ear pieces", "construction", "programs", "never", "key", "ports", "resolution", "radio shack", "drive", "power supply", "browser", "setup", "value", "installation", "color screen", "cell", "phone case", "system", "windows mobile", "build quality", "graphics", "volume controls", "belt clip", "don", "leather case", "ear hook", "price range", "jack", "time", "user interface", "virgin mobile", "quality sound", "aim", "calls", "button", "case fits", "uk", "web browser", "u.s.", "lot", "bass", "pearl", "games", "seller", "connectivity", "power cord", "junk", "voice", "mouse", "hard case", "processor", "signal strength", "product works", "battery charger", "leather", "charging port", "operating system", "razor", "functions", "cell phone", "cover", "virgin", "connection", "pad", "layout", "led", "voice dial", "battery power", "price tag", "battery works", "power adapter", "speed", "voice dialing", "rim", "easy", "stand", "video camera", "memory card", "runs", "fit", "highly", "touch screen", "switch", "body glove", "big", "pieces", "new", "carry", "screen protector", "blue", "port", "external display", "key pad", "multi", "quality case", "connect", "650", "hard drive", "background noise", "performs", "feature", "way", "picture", "camera quality", "instructions", "the", "phone charger", "charging cord", "galaxy", "stereo", "canon", "color display", "call", "gaming", "horrible", "music", "volume button", "blue tooth", "wear", "reliability", "shipped", "clip", "delivery", "ear design", "palm tx", "target", "extremely", "windows xp", "look", "external screen", "volume adjustment", "voice command", "sound volume", "only", "functionality", "web", "need", "flash", "case works", "calendar", "battery runs", "clarity", "ever", "bad", "blue ant", "curve", "phone quality", "build", "im", "palm centro", "micro usb", "i drive", "outside screen", "screen resolution", "small size", "extended life battery", "case looks", "batteries", "windows 7", "storage", "discovery", "kinda", "power buttons", "mobile", "external antenna", "pouch", "shipping cost", "ca", "menu system", "can", "screen size", "windows vista", "mm", "function", "web brows ...

# %%
import qgrid
qgrid_widget = qgrid.show_grid(aspects_unique_filtered_df_tsne, show_toolbar=True)

# %%
qgrid_widget
# Out:
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': True, 'defau…

# %%
aspects_unique_filtered_df_tsne.to_excel('../results/reviews_Cell_Phones_and_Accessories/aspects_per_edu_filtered_min_10_freq_clustered_spacy_en.xlsx')
# Out:
# -------------------------------------------------
# IllegalCharacterErrorTraceback (most recent call last)
# <ipython-input-79-b7293e5309b0> in <module>
# ----> 1 aspects_unique_filtered_df_tsne.to_excel('../results/reviews_Cell_Phones_and_Accessories/aspects_per_edu_filtered_min_10_freq_clustered_spacy_en.xlsx')
#
# ~/anaconda3/envs/aspect/lib/python3.6/site-packages/pandas/core/generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes)
#    2125         formatter.write(excel_writer, sheet_name=sheet_name, startrow=startrow,
#    2126                         startcol=startcol, freeze_panes=freeze_panes,
# -> 2127                         engine=engine)
#    2128
#    2129     def to_json(self, path_or_buf=None, orient=None, date_format=None,
#
# ~/anaconda3/envs/aspect/lib/python3.6/site-packages/pandas/io/formats/excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine)
#     660         writer.write_cells(formatted_cells, sheet_name,
#     661                            startrow=startrow, startcol=startcol,
# --> 662                            freeze_panes=freeze_panes)
#     663         if need_save:
#     664             writer.save()
#
# ~/anaconda3/envs/aspect/lib/python3.6/site-packages/pandas/io/excel.py in write_cells(self, cells, sheet_name, startrow, startcol, freeze_panes)
#    1603                 column=startcol + cell.col + 1
#    1604             )
# -> 1605             xcell.value, fmt = self._value_with_fmt(cell.val)
#    1606             if fmt:
#    1607                 xcell.number_format = fmt
#
# ~/anaconda3/envs/aspect/lib/python3.6/site-packages/openpyxl/cell/cell.py in value(self, value)
#     250     def value(self, value):
#     251         """Set the value and infer type and display options."""
# --> 252         self._bind_value(value)
#     253
#     254     @property
#
# ~/anaconda3/envs/aspect/lib/python3.6/site-packages/openpyxl/cell/cell.py in _bind_value(self, value)
#     203
#     204         elif t in STRING_TYPES:
# --> 205             value = self.check_string(value)
#     206             self.data_type = 's'
#     207             if len(value) > 1 and value.startswith("="):
#
# ~/anaconda3/envs/aspect/lib/python3.6/site-packages/openpyxl/cell/cell.py in check_string(self, value)
#     167         value = value[:32767]
#     168         if next(ILLEGAL_CHARACTERS_RE.finditer(value), None):
# --> 169             raise IllegalCharacterError
#     170         return value
#     171
#
# IllegalCharacterError:

# %% [markdown]
# ## Get id of the biggest cluster

# %%
biggest_cluster_id = aspects_unique_filtered_df_tsne.cluster.value_counts().keys()[0]

# %%
aspects_biggest_cluster = aspects_unique_filtered_df_tsne[aspects_unique_filtered_df_tsne.cluster == biggest_cluster_id]

# %% [markdown]
# # Second pass of clustering inside terms already marked as aspects :D

# %%
hierarchical_cluster_inner = AgglomerativeClustering(n_clusters=10).fit(aspects_biggest_cluster.embedding.tolist())
aspects_biggest_cluster['cluster'] = hierarchical_cluster_inner.labels_
# Out:
# /home/laugustyniak/anaconda3/envs/aspect/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
aspects_biggest_cluster.head()
# Out:
#            x          y           text        tooltip  cluster  \
# 0  20.684923  36.338680          price          price        4
# 2 -11.804303   7.810336        battery        battery        4
# 3 -18.295507  -1.036430         amazon         amazon        4
# 4  10.001678  24.498201  sound quality  sound quality        0
# 5 -14.308353   6.374245        charger        charger        4
#
#                                            embedding
# 0  [0.0025718957, 0.071242034, -0.08696756, 0.011...
# 2  [-0.03261149, -0.0027218256, 0.03191225, 0.098...
# 3  [-0.08989111, 0.045746423, -0.04043641, 0.0190...
# 4  [0.057565868, -0.0043674195, 0.062438954, 0.06...
# 5  [-0.002593959, -0.003030438, 0.0010705708, 0.0...

# %%
aspects_biggest_cluster_tsne = draw_embeddings.get_tsne(aspects_biggest_cluster, text='intent', tooltip_col='tooltip')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/aspect/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'intent'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-75db1e877921> in <module>
# ----> 1 aspects_biggest_cluster_tsne = draw_embeddings.get_tsne(aspects_biggest_cluster, text='intent', tooltip_col='tooltip')
#
# ~/github/phd/sentiment-backend/aspects/analysis/draw_embeddings.py in get_tsne(df, text, tooltip_col, tsne)
#      34         x=tsne_coords[:, 0],
#      35         y=tsne_coords[:, 1],
# ---> 36         text=df[text],
#      37         tooltip=df[tooltip_col],
#      38         cluster=df.cluster,
#
# ~/anaconda3/envs/aspect/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# ~/anaconda3/envs/aspect/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'intent'

# %%
draw_embeddings.draw(aspects_biggest_cluster_tsne)

# %%
qgrid_widget_inner = qgrid.show_grid(aspects_biggest_cluster_tsne, show_toolbar=True)

# %%
qgrid_widget_inner
# Out:
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': True, 'defau…

# %% [markdown]
# # Get aspects from SemEval - annotated

# %%
from aspects.analysis import statistics_dataset

# %%
aspects = statistics_dataset.get_aspects()
# Out:
# Corpus iterator: 49475it [00:00, 356789.73it/s]
# Corpus iterator: 53781it [00:00, 229197.01it/s]
# Corpus iterator: 12470it [00:00, 543995.29it/s]
# Corpus iterator: 13257it [00:00, 403704.88it/s]

# %%
# aspects
# Out:
# {'Restaurants_poria-train': ['staff',
#   'food',
#   'food',
#   'kitchen',
#   'menu',
#   'food',
#   'perks',
#   'orrechiete with sausage and chicken',
#   'waiters',
#   'dish',
#   'meats',
#   'bagels',
#   'food',
#   'mayonnaise',
#   'toast',
#   'ingredients',
#   'cheese',
#   'omelet',
#   'bacon',
#   'plate',
#   'check',
#   'drinks',
#   'design',
#   'atmosphere',
#   'cuisine',
#   'pizza',
#   'thin crusted pizza',
#   'interior decoration',
#   'chefs',
#   'seats',
#   'seltzer with lime',
#   'pickles and',
#   'selection of meats and seafoods',
#   'eat family style',
#   'dishes',
#   'vibe',
#   'owner',
#   'service',
#   'delivery',
#   'food',
#   'atmosphere',
#   'service',
#   'food',
#   'prices',
#   'interior decor',
#   'prices',
#   'wine',
#   'price',
#   'service',
#   'quantity',
#   'sushi',
#   'sushi bar',
#   'fried rice',
#   'courses',
#   'mussels',
#   'puff pastry goat cheese',
#   'salad with a delicious dressing',
#   'a hanger steak au poivre',
#   'indian food',
#   'place',
#   'service',
#   'with',
#   'broth with noodles',
#   'meal',
#   'money',
#   'food',
#   'wine list',
#   'thai',
#   'thai food',
#   'glass of wine',
#   'specials',
#   'dine',
#   'lunch',
#   'dinner',
#   'atmosphere',
#   'service',
#   'desert',
#   'bar',
#   'table',
#   'dinner',
#   'service',
#   'food',
#   'atmosphere',
#   'environment',
#   'lasagnette appetizer',
#   'beer selection',
#   'food',
#   'menu',
#   'service',
#   'setting',
#   'dinner',
#   'dining',
#   'dosa',
#   'wine list selection',
#   'wine-by-the-glass',
#   'menu',
#   'menu',
#   'entrees',
#   'menu',
#   'dishes',
#   'sake martini',
#   'bagels',
#   'spreads',
#   'service',
#   'table',
#   'food',
#   'meal',
#   'ingredients',
#   'chopsticks',
#   'garden terrace',
#   'pizza',
#   'cuisine',
#   'atmosphere',
#   'crowded',
#   'service',
#   'dish',
#   'atmosphere',
#   'service',
#   'food',
#   'grilled branzino',
#   'wait staff',
#   'food',
#   'packed',
#   'vibe',
#   'french food',
#   'place',
#   'pizza',
#   'pre-theater menu',
#   'delivery',
#   'order',
#   'server',
#   'meal',
#   'scents',
#   'lobster sandwich',
#   'check',
#   'spider roll',
#   'shell crab',
#   'price',
#   'deep fried skewers',
#   'reservations',
#   'hostess',
#   'rice dishes',
#   'congee ( rice porridge )',
#   'tuna tartar appetizer',
#   'food',
#   'cuisine',
#   'fish dishes',
#   'soups',
#   'wine',
#   'cheese',
#   'french fare',
#   'indian food',
#   'baby pizzas',
#   'waiting',
#   'lava cake dessert',
#   'baby pizzas',
#   'service',
#   'food',
#   'managers',
#   'food',
#   'food',
#   'table',
#   'selection of wines',
#   'italian decor',
#   'food',
#   'dining experience',
#   'wine selection',
#   'reservation',
#   'service',
#   'reservation',
#   'maitre',
#   'panang duck',
#   'food',
#   'raw vegatables',
#   'service',
#   'indian',
#   'prices',
#   'ambiance',
#   'bbq salmon',
#   'sea bass',
#   'crispy duck',
#   'ingredients',
#   'ingredients',
#   'pizza',
#   'crust',
#   'dal bukhara',
#   'kababs',
#   'eating',
#   'taste',
#   'meal',
#   'price',
#   'glass of leaping lizard',
#   'glass of prosecco',
#   'mussels',
#   'food',
#   'creme brulee',
#   'sugar',
#   'food',
#   'served',
#   'pizza',
#   'pizza',
#   'garlic knots',
#   'delivery',
#   'chinese food',
#   'service',
#   'food',
#   'chef',
#   'service',
#   'teapot',
#   'pizza',
#   'fresh mozzarella',
#   'cheese',
#   'place',
#   'food',
#   'service',
#   'a',
#   'getting a table',
#   'atmosphere',
#   'bistro-type vibe',
#   'waitress',
#   'tables',
#   'food',
#   'prices',
#   'food',
#   'fish',
#   'variety of fish',
#   'of',
#   'meal',
#   'pesto pizza',
#   'house salad',
#   'bottle of wine',
#   'beverage manager',
#   'bartender',
#   'ambiance',
#   'music',
#   'food',
#   'drinks',
#   'service',
#   'food',
#   'refleshment',
#   'ambiance',
#   'service',
#   'sommlier',
#   'captain',
#   'back waiters',
#   'foods',
#   'tastes',
#   'waitress',
#   'tandoori salmon',
#   'atmosphere',
#   'space',
#   'service',
#   'atmorphere',
#   'service',
#   'menu items',
#   'three course meal',
#   'pizza',
#   'environment',
#   'food',
#   'service',
#   'crawfish boiled',
#   'reservation',
#   'table',
#   'pad thai',
#   'noodles',
#   'delivered',
#   'values for your money',
#   'lunch',
#   'hostess',
#   'food',
#   'wait building',
#   'corridor',
#   'space',
#   'counters',
#   'counter',
#   'entrees',
#   'food',
#   'steaks',
#   'salads',
#   'sides',
#   'lunch',
#   'pickels and slaw',
#   'wine',
#   'prices',
#   'delivered',
#   'the wine by the glass',
#   'price',
#   'dish',
#   'change mojito',
#   'service',
#   'food',
#   'service',
#   'food',
#   'soup for the udon',
#   'soy sauce',
#   'water',
#   'anti-pasta',
#   'calamari',
#   'filling pasta mains',
#   'waitress',
#   'glasses of wine',
#   'food',
#   'counter',
#   'food',
#   'sushi',
#   'ceviche mix ( special )',
#   'crab dumplings',
#   'assorted sashimi',
#   'sushi',
#   'rolls',
#   'sake',
#   'banana tempura',
#   'plain pizza',
#   'garlic',
#   'eggplant',
#   'servers',
#   'servers',
#   'getting a table',
#   'service',
#   'takeout menu',
#   'menu',
#   'italian dishes',
#   'thai food',
#   'hostess',
#   'pizza',
#   'bottles of wine',
#   'beers',
#   'food',
#   'dish',
#   'pumkin tortelini',
#   'dinner special',
#   'crabmeat lasagna',
#   'chocolate bread pudding',
#   'dessert',
#   'pasta dishes',
#   'tiramisu',
#   'service',
#   'prices',
#   'lunch',
#   'service',
#   'staff',
#   'menu',
#   'meal',
#   'bagel',
#   'food',
#   'servers',
#   'food',
#   'plate of dumplings',
#   'filet mignon',
#   'bar',
#   'sangria',
#   'bar',
#   'bartender',
#   'sake menu',
#   'drinks',
#   'beef cubes',
#   'service',
#   'wine selection',
#   'ambiance',
#   'reservations',
#   'service',
#   'service',
#   'waiters',
#   'food',
#   'portions',
#   'dessert',
#   'traffic noise',
#   'food',
#   'food',
#   'ambience',
#   'service',
#   'dinner meeting',
#   'atmosphere',
#   'food',
#   'cantonese',
#   'cooking',
#   'food',
#   'atmosphere',
#   'prix fixe menu',
#   'quantity',
#   'quality',
#   'lunch',
#   'eggs benedict',
#   'brunch',
#   'hollondaise sauce',
#   'oatmeal',
#   'food',
#   'menu',
#   'chilean sea bass',
#   'server',
#   'specials',
#   'food',
#   'onion soup',
#   'wine',
#   'staff',
#   'dinner',
#   'dim sum',
#   'roll',
#   'roll',
#   'roll',
#   'rice',
#   'gin and tonic',
#   'tonic',
#   'dim sum',
#   'little dishes',
#   'service',
#   'thai',
#   'reservation',
#   'grilled chicken special with edamame puree',
#   'roast duck',
#   'pork',
#   'chicken on rice with ginger',
#   'menu',
#   'staff',
#   'reservation',
#   'dinner',
#   'sake',
#   'portion',
#   'dishes',
#   'food',
#   'service',
#   'roti rolls',
#   'ingredients',
#   'meal',
#   'tip',
#   'food',
#   'service',
#   'meat',
#   'hot dogs',
#   'delivery',
#   'noise level',
#   'personal pans',
#   'spicy fried clam rolls',
#   'spider rolls',
#   'menu',
#   'atmosphere',
#   'place',
#   'food',
#   'lunch',
#   'food quality',
#   'man',
#   'table',
#   'table',
#   'cheesecake',
#   'food',
#   'manager',
#   'employees for',
#   'containers for condiments',
#   'containers',
#   'indian food',
#   'service',
#   'decor',
#   'food',
#   'wine list',
#   'food',
#   'salmon dish',
#   'price',
#   'flavor',
#   'tuna melt',
#   'cheese',
#   'tuna sandwich',
#   'chicken tikka',
#   'naan',
#   'dals',
#   'waiters',
#   'bill',
#   'lawns',
#   'staff',
#   'sangria',
#   'thai food',
#   'food',
#   'service',
#   'ravioli',
#   'menu',
#   'service',
#   'bill',
#   'lunch',
#   'drinks',
#   'sushi',
#   'food',
#   'service',
#   'price tag',
#   'thai food',
#   'appetizers',
#   'service',
#   'mozzarella',
#   'pie',
#   'fish',
#   'main dining room',
#   'ceiling',
#   'menu selections',
#   'service',
#   'music',
#   'establishment',
#   'dim sum',
#   'food',
#   'wait staff',
#   'dim sum',
#   'service',
#   'seafood dishes',
#   'appetizers',
#   'lunch',
#   'dinner',
#   'grapes',
#   'bottle of wine',
#   'prices',
#   'thai food',
#   'dish',
#   'staples',
#   'burger',
#   'pastas',
#   'food',
#   'dim sum',
#   'food',
#   'waitress',
#   'place',
#   'seating',
#   'bar',
#   'dinner',
#   'music',
#   'food',
#   'service',
#   'prices',
#   'wait',
#   'lobster sandwich',
#   'price',
#   'owner',
#   'sides',
#   'seafood',
#   'menu',
#   'salmon',
#   'place',
#   'beverages',
#   'dessert',
#   'hostess',
#   'waitress',
#   'asian appetizers',
#   'drinks',
#   'wait',
#   'view',
#   'meal',
#   'dinner',
#   'ambiance',
#   'food',
#   'service',
#   'prices',
#   'atmosphere',
#   'value',
#   'sushi',
#   'service',
#   'served',
#   'service',
#   'service',
#   'attitude',
#   'food',
#   'striped bass',
#   'music',
#   'corriander',
#   'black white shakes',
#   'meal',
#   'dinner',
#   'seating',
#   'chu chu curry',
#   'pad thai chicken',
#   'prix fixe',
#   'food',
#   'pastrami',
#   'soups',
#   'bagels',
#   'sushi',
#   'bagel with lox spread',
#   'bagles',
#   'food',
#   'quality of food',
#   'lobby area',
#   'seated',
#   'pizza',
#   'proprietor',
#   'lunch meetings',
#   'decor',
#   "food's presentation",
#   'prices',
#   'waitstaff',
#   'swordfish',
#   'meal',
#   'setting',
#   'management',
#   'service',
#   'seating',
#   'delivery',
#   'sushi',
#   'desserts',
#   'italian food',
#   'service',
#   'food',
#   'salmon dish',
#   'rolls',
#   'food',
#   'decor',
#   'prices',
#   'owner',
#   'lunch',
#   'dinner',
#   'moules',
#   'lobster ravioli',
#   'eat',
#   'dosa',
#   'atmosphere',
#   'waiters',
#   'seafood',
#   'wine list',
#   'menu',
#   'wine',
#   'indian',
#   'wine list',
#   'wines',
#   'pastrami or corned beef',
#   'rye bread',
#   'glasses of champagne',
#   'bottle of wine',
#   'after dinner drinks',
#   'seasoning',
#   'food',
#   'food',
#   'waitress',
#   'food',
#   'ambience',
#   'service',
#   'wine list',
#   'staff',
#   'owners',
#   'menu',
#   'people',
#   'menu',
#   'waiter',
#   'specials',
#   'main dishes',
#   'location',
#   'ambience',
#   'food',
#   'stuff',
#   'eats',
#   'dinner',
#   'gourmet food',
#   'bruschetta',
#   'dishes',
#   'menu',
#   'service',
#   'waitress',
#   'and',
#   'and',
#   'the fried mini buns with the condensed milk and the assorted fruits on beancurd',
#   'food',
#   'prices',
#   'food',
#   'sushi',
#   'portions',
#   'servers',
#   'starter',
#   'bagels',
#   'food',
#   'pizza',
#   'take-out pizza',
#   'server',
#   'green curry with vegetables',
#   'place',
#   'door',
#   'priced',
#   'food',
#   'portioins',
#   'reservation',
#   'pad thai',
#   'lunch specials',
#   'place',
#   'pizzas',
#   'food',
#   'pot-stickers',
#   'tempura dish',
#   'stuff',
#   'entree range',
#   'food',
#   'range',
#   'atmosphere',
#   'french food',
#   'deliveries',
#   'food',
#   'staff',
#   'portions',
#   'staff',
#   'smoked salmon and roe appetizer and',
#   'lunch',
#   'food',
#   'garlic shrimp',
#   'okra ( bindi )',
#   'lamb',
#   'waiter',
#   'menu',
#   'burger',
#   'steak',
#   'escargot',
#   'plate',
#   'food',
#   'casual dinner',
#   'food',
#   'price',
#   'wine list',
#   'prices',
#   'chicken tikka marsala',
#   'styles of pizza',
#   'look',
#   'food',
#   'portions',
#   'coconut rice',
#   'appetizer',
#   'food',
#   'food',
#   'beers on tap',
#   'priced wine list',
#   'music',
#   'bottle minimun',
#   'food',
#   'spot',
#   'staff',
#   'meal',
#   'table',
#   'quality of food',
#   'price',
#   'pork',
#   'fish',
#   'chicken',
#   'lamb',
#   'vegetables',
#   'place',
#   'seating',
#   'appetizing',
#   'price',
#   'bun',
#   'food',
#   'priced',
#   'fusion of french and indian cooking',
#   'turnip cake',
#   'roast pork buns',
#   'egg custards',
#   'bagels',
#   'the',
#   'seating in the garden',
#   'the seats',
#   'water',
#   'service',
#   'place',
#   'food',
#   'place',
#   'food options',
#   'cost',
#   'pre-theatre 3 - course dinner',
#   'wine flight',
#   'lunch',
#   'dinner',
#   'calzones',
#   'drink',
#   'place',
#   'bar scene',
#   'staff',
#   'spreads',
#   'beverage selections',
#   'bagels',
#   'waiter',
#   'served',
#   'specials',
#   'meal',
#   'tiramisu',
#   'secret back room',
#   'bar',
#   'food',
#   'service',
#   'gulab jamun',
#   'prices',
#   'atmosphere',
#   'service',
#   'wine list',
#   'diner',
#   'table',
#   'wait staff',
#   'meal',
#   'room',
#   'dinner',
#   'desserts',
#   'in',
#   'in',
#   'desserts with frog jelly in',
#   'pig feet ginger simmered in black vinegar',
#   'food',
#   'priced',
#   'thai cuisine',
#   'host',
#   'crew',
#   'round tables',
#   'taiwanese',
#   'portion',
#   'french fries',
#   'dinner',
#   'food',
#   'specials',
#   'regular menu-fare',
#   'dishes',
#   'prices',
#   'fresh tomato sauce',
#   'fresh mozz cheese',
#   'basil',
#   'dough',
#   'flour',
#   'food',
#   'indian food',
#   'paneer roll',
#   'food',
#   'plates',
#   'fresh mozzerella slices',
#   'plain cheese slice',
#   'food',
#   'food',
#   'food',
#   'filet mignon with garlic mash',
#   'pre-theater menu',
#   'roasted tomato soup with chevre',
#   'steak frites',
#   'creme brulee',
#   'waitstaff',
#   'bread',
#   'and',
#   'pizza',
#   'and',
#   "peter's favourite pizza with prosciutto and baby arugula",
#   'margarite pizza with cold prosciutto and baby arugula on top',
#   'salad',
#   'prices',
#   'bruschettas',
#   'paninis',
#   'tramezzinis',
#   'waiters',
#   'diners',
#   'chef',
#   'cuisine',
#   'dishes',
#   'indian',
#   'owner',
#   'food',
#   'meal',
#   'pre-theater prix-fixe',
#   'dining',
#   'food',
#   'wine',
#   'menu',
#   'fried chicken',
#   'pork chop',
#   'noodle dishes',
#   'indian food',
#   'place',
#   'corner booth table',
#   'privacy',
#   'open faced cheese sandwich',
#   'manager',
#   'breads',
#   'naan',
#   'half-price saturday night option',
#   'squid',
#   'pizza',
#   'homemade pasta',
#   'value ofr money',
#   'soup',
#   'mushrooms',
#   'service',
#   'waiting',
#   'beginning appetizers',
#   'scallops',
#   'chocolate souffle with rasberry mint sorbet',
#   'taste',
#   'japanese tapas',
#   'fish',
#   'rice',
#   'seaweed',
#   'dishes',
#   'lamb sausages',
#   'sardines with biscuits',
#   'large whole shrimp',
#   'pistachio ice cream',
#   'food',
#   'price',
#   'ambiance',
#   'atmosphere',
#   'food',
#   'service',
#   'server',
#   'served',
#   'food',
#   'drinks',
#   'food',
#   'sushi',
#   'thai food',
#   'chef',
#   'table',
#   'service',
#   'sauce on the pizza',
#   'garlic',
#   'fresh tomatoes',
#   'outdoor seating',
#   'mesclun',
#   'salmon',
#   'ice cream',
#   'courses',
#   'wait',
#   'food',
#   'place',
#   'staff',
#   'bistro fare',
#   'jazz brunch',
#   'live jazz',
#   'chilaquiles',
#   'prices',
#   'bill',
#   'measures of liquers',
#   'of',
#   'table service',
#   'service',
#   'thai food',
#   'food',
#   'pork belly',
#   'fat',
#   'food',
#   'tables',
#   'place',
#   'dinner',
#   'pizza',
#   'bar',
#   'service',
#   'lamb chop',
#   'salads',
#   'lemon',
#   'extra virgnin olive oil',
#   'sushi',
#   'meal',
#   'cost',
#   'dishes',
#   'pastrami sandwich',
#   'pickles',
#   'beer',
#   'plain pizza',
#   'wild mushroom ( third generation-fornini ) pizza',
#   'truffle oil',
#   '(',
#   ')',
#   'omelletes',
#   'tip',
#   'lunch',
#   'dinner',
#   'counter',
#   'sushi fix',
#   'fish',
#   'service',
#   'waitress',
#   'table',
#   'reservation sigh',
#   'food',
#   'place',
#   'menu',
#   'food art',
#   'outdoor atmosphere',
#   'toppings',
#   'pizza',
#   'service',
#   'food',
#   'price',
#   'thai food',
#   'bagels',
#   'bills',
#   'scallion pancakes',
#   'fried dumplings',
#   'appetizers',
#   'salads',
#   'steak',
#   'pasta',
#   'table',
#   'served dishes',
#   'table',
#   'served',
#   'bill',
#   'service',
#   'food',
#   'dumpling',
#   'fondue appetizer',
#   'spice',
#   'octopus salad',
#   'msg cooking',
#   'foods',
#   'tom kha soup',
#   'bombay beer',
#   'decor',
#   'semi-private boths',
#   'dining hall',
#   'service',
#   'service',
#   ...],
#  'Laptops_poria-train': ['cord',
#   'battery life',
#   'tech guy',
#   'service center',
#   '" sales " team',
#   'quality',
#   'gui',
#   'applications',
#   'use',
#   'start up',
#   'features',
#   'ichat',
#   'photobooth',
#   'garage band',
#   'features',
#   'gui',
#   'screen',
#   'power light',
#   'hard drive light',
#   'battery',
#   'rubber enclosure',
#   'edge',
#   'multi-touch gestures',
#   'tracking area',
#   'external mouse',
#   'gaming',
#   'suite of software',
#   'speed',
#   'windows 7',
#   'usb devices',
#   'keyboard',
#   'software',
#   'system',
#   'microsoft office for the mac',
#   'syncing',
#   '30 " hd monitor',
#   'screen',
#   'boot up',
#   'service',
#   'battery',
#   'operating system',
#   'preloaded software',
#   'price',
#   'features',
#   'clock in bios setup',
#   'warranty service',
#   'brand',
#   'warranty',
#   'features',
#   'fan',
#   'customer service number',
#   'warranty',
#   'talking to a technician',
#   'hard disc',
#   'windows',
#   'drivers',
#   'drivers',
#   'bios update',
#   'system',
#   'hp technical support',
#   'browser',
#   'keyboard',
#   'virus scan',
#   '9 punds',
#   'program',
#   'warrenty',
#   'toshiba',
#   'toshiba warranty',
#   'quality',
#   'webcam',
#   'value',
#   'internet',
#   'managing personal files',
#   'motherboard',
#   'system',
#   'charger',
#   'hardware',
#   'force quit',
#   'works',
#   'windows 7',
#   'vmware program',
#   'navigate',
#   'operating system',
#   'find files',
#   'runs',
#   'warrenty',
#   'extended warranty',
#   'memory',
#   'performace',
#   'speed',
#   'opening my documents folder',
#   'operating systems',
#   'charger',
#   'speed',
#   'glass touchpad',
#   'hard drive',
#   'mother board',
#   'external speaker',
#   'sound',
#   'battery life',
#   'hardware',
#   'shipping',
#   'use',
#   'mac software',
#   'microsoft software',
#   'editing',
#   'delete key',
#   'use',
#   'service',
#   'phone assistance',
#   'genius bar',
#   'battery life',
#   'web browsing',
#   'word editing',
#   'gaming',
#   'movie playing',
#   'battery life',
#   'recovery discs',
#   'office max\'s " max assurance "',
#   '"',
#   '"',
#   'imac backup disc',
#   'usb',
#   'battery life',
#   'battery timer',
#   'temperatures',
#   'core processing unit temperatures',
#   'service',
#   'virus protection for mac',
#   'bluetooth',
#   'lg notebook service center',
#   'hinge',
#   'games',
#   'responds',
#   'motherboard',
#   'motherboard',
#   'hardware',
#   'motherboard',
#   'use',
#   'representive at microsoft',
#   'system',
#   'xp',
#   'windows 7',
#   'vista',
#   'keyboard',
#   "dell's customer disservice",
#   'cooling system',
#   'use',
#   'quad core i7',
#   'sales associate',
#   'system',
#   'windows applications',
#   'virus program',
#   'weighed',
#   'seven pounds',
#   'battery',
#   'bag',
#   'color',
#   'keys',
#   'designed',
#   'style',
#   'speed',
#   'keyboard',
#   'mousepad',
#   'battery',
#   'sales',
#   'service',
#   'dell',
#   'dell support',
#   'hard drive',
#   'motherboard',
#   'cost',
#   'speed',
#   'construction quality',
#   'longevity',
#   'keyboard',
#   'keyboard',
#   'keys',
#   'configuration of " extra key "',
#   'touch pad',
#   'use',
#   'security',
#   'pricetag',
#   'use',
#   'work',
#   'preloaded software',
#   'webcam',
#   'vga port',
#   'screen',
#   'battery life',
#   'keys',
#   'software',
#   'volume',
#   'mouse',
#   'touchpad',
#   'boots up',
#   'hard drive',
#   'look and feel standpoint',
#   'safari',
#   'safari',
#   'mozzilla firfox',
#   'bluetooth',
#   'fingerprint reader driver',
#   'software',
#   'battery',
#   'speed',
#   'display',
#   'delivery',
#   'battery life',
#   'performance',
#   'memory',
#   'applications',
#   'microsoft office',
#   'resolution',
#   'appearance',
#   'cooling system',
#   'graphics card',
#   'built-in webcam',
#   'built-in mic',
#   'cam',
#   'mic',
#   'windows vista',
#   'board',
#   'connector',
#   'power supply',
#   'warrenty',
#   'power supply',
#   'works',
#   'ethernet',
#   'drag and drop feature',
#   'webcam',
#   'sales tax',
#   'software packages',
#   'iwork',
#   'garageband',
#   'imovie',
#   'screen',
#   'colors',
#   'resolution',
#   'monitor',
#   'itunes',
#   'size',
#   'external monitor',
#   'base installation',
#   'software',
#   'manuf',
#   'camera',
#   'display',
#   'amd turin processor',
#   'intel',
#   'warranty',
#   'start menu',
#   'navigate',
#   'bluray read / write drive',
#   'service tech',
#   'tech store',
#   'surface',
#   'screen',
#   'keyboard',
#   'ilife',
#   'snow leopard x',
#   'price tag',
#   'mac os',
#   'output',
#   'sound output quality',
#   'techie',
#   'use',
#   'toshiba online help',
#   'service life',
#   'ports',
#   'processor',
#   'price',
#   'look',
#   'keyboard',
#   'keys',
#   'screen',
#   'quality',
#   'stock screen',
#   'gray color',
#   'volume buttons',
#   'processor',
#   'computing',
#   'protector',
#   'key pad',
#   'magnetic plug-in power charging power cord',
#   'xp',
#   'vista',
#   'use',
#   'graphics',
#   'mac os',
#   'use',
#   'support',
#   'geek squad',
#   'graphics quality',
#   'appleworks',
#   'browser',
#   'paint',
#   'keyboard',
#   'service department',
#   'warrenty',
#   'warrentys',
#   'hard disk',
#   'running',
#   'cd drive',
#   'screen size',
#   'web browsing',
#   'software',
#   'loads',
#   'trackpad',
#   'external mouse',
#   'trackpad',
#   'games',
#   'games',
#   'features',
#   'human interface',
#   'software',
#   'inbuilt applications',
#   'body',
#   'i5',
#   'antivirus software',
#   'firewall',
#   'price',
#   'apple team',
#   'vista',
#   'vista',
#   'vista',
#   'operating system',
#   'video chat',
#   'quality',
#   'mouse',
#   'fan',
#   'cooling pad',
#   'feature',
#   'software',
#   'installation time',
#   'power',
#   'storage',
#   'abilitiy',
#   'feature',
#   'spotlight search',
#   'search',
#   'wireless system',
#   'windows 7',
#   'quality',
#   'battery life',
#   'speed',
#   'os',
#   'os',
#   'itunes',
#   'program',
#   'gaming',
#   'battery',
#   'apple support',
#   'techs',
#   'adding the bluetooth',
#   'graphic power',
#   'adobe creative apps',
#   'programs',
#   'use',
#   'materials',
#   'software',
#   'tech support',
#   'power supply',
#   'power supply',
#   'size',
#   'warranty',
#   'windows xp sp2',
#   'windows 7 ultimate',
#   'bluetooth',
#   'fingerprint reader',
#   'software',
#   'techs at hp',
#   'video card',
#   'graphics',
#   'security',
#   'audio',
#   'keyboard',
#   'runs',
#   'set up',
#   'screen',
#   'word processing',
#   'internet',
#   'trackpad',
#   'battery life',
#   'spec',
#   'dvd burner',
#   'hd',
#   'graphics chip',
#   'components',
#   'usb ports',
#   'software',
#   'system',
#   'ran',
#   'price',
#   'operation',
#   'brand',
#   'components',
#   'ground loop isolator',
#   'quality',
#   'price range',
#   'warranty',
#   'leading edge',
#   'bloatware',
#   'maximum sound',
#   'windows 7',
#   'bootcamp',
#   'price',
#   'works',
#   'action pack games',
#   'price',
#   'performance',
#   'twin packing',
#   'functions',
#   'look',
#   'after sales support',
#   'display screen',
#   'acer arcade',
#   'customer support',
#   'screen',
#   'cd drive',
#   'runs',
#   'design',
#   'size',
#   'games',
#   'games',
#   'life',
#   'warranty',
#   'pad',
#   'value',
#   'price',
#   'linux based os',
#   'system performance',
#   'use',
#   'batteries',
#   'shipping carton',
#   'use',
#   'program',
#   'virus protection',
#   'screen',
#   'processor',
#   'osx 16',
#   'graphics',
#   'hardware',
#   'software',
#   'intel core processors',
#   'hdmi port',
#   'internet explorer',
#   'staff',
#   'price premium',
#   'features',
#   'product and help aftermarket',
#   'microsoft word',
#   'usb ports',
#   'sd memory card reader',
#   'sd memory car expansion',
#   'lacie 2big external drive',
#   'firewire 800 interface',
#   'time machine',
#   'sound',
#   'extra features',
#   'windows 7 home premium',
#   'boot',
#   'acer screen',
#   'usb port',
#   'battery life',
#   'fires up',
#   'keyboard',
#   'software',
#   'online tutorial videos',
#   'image',
#   'soud',
#   'windows',
#   'boot up',
#   'shut down',
#   'windows',
#   'use',
#   'mac os',
#   'cost',
#   'windows 7 starter',
#   'windows 7 home premium',
#   'windows 7 professional',
#   'specifications',
#   'power cords',
#   'multi-touch features',
#   'screen',
#   'clicking buttons',
#   'battery life',
#   'windows',
#   'wired lan',
#   'hard reboot',
#   'hardware',
#   'hard drive',
#   'battery life',
#   'apple care',
#   'features',
#   'font',
#   'programs',
#   'run',
#   'plastic pieces',
#   '2gb ram stick',
#   'windows',
#   'microsoft word for mac',
#   'warranty company',
#   'cusromer service center',
#   'size',
#   'weight',
#   'battery',
#   'aluminum body',
#   'playing',
#   'watching movies',
#   'build quality',
#   'performance',
#   'dock',
#   'program',
#   'program',
#   'working',
#   'costing',
#   'i7',
#   'price',
#   'monitor',
#   'extended warranty',
#   'boots up',
#   'runs',
#   'screen',
#   'driver',
#   'tech support',
#   'work',
#   'hard drive',
#   'twin packing',
#   'functions',
#   'warranty',
#   'performance',
#   'price',
#   'bios',
#   'design',
#   'tech issues',
#   'size',
#   'space',
#   'service',
#   'priced',
#   'memory',
#   'speed',
#   'internet speed',
#   'programs',
#   'school or office use',
#   'pages',
#   'numbers',
#   'keynote',
#   'music',
#   'garageband',
#   'photo management',
#   'photo booth',
#   'iphoto',
#   'video-editing or movie-making',
#   'imovie',
#   'screen',
#   'colors',
#   'value',
#   'price',
#   'value',
#   "burn cd's",
#   'web cam',
#   '17 inch screen',
#   'support',
#   'bluetooth',
#   'launch manager',
#   'drivers / applications dvd',
#   'glass screen',
#   'switchable graphic card',
#   'gaming',
#   'service',
#   'battery life',
#   'technical support',
#   'boot mgr',
#   'recovery cd',
#   'price',
#   'features',
#   'skype',
#   'mouse buttons',
#   'hdd',
#   'rails',
#   'hard drive',
#   'quality',
#   'staff',
#   'games',
#   'garageband',
#   'warranty',
#   'hard drive',
#   'price',
#   'home use',
#   'business use',
#   'virus protection',
#   'updates',
#   'ms office apps',
#   'games',
#   'feature',
#   'windows',
#   'battery life',
#   'battery life',
#   'price',
#   'nortons virus scan',
#   'frame',
#   'features',
#   'use',
#   'loaded',
#   'windows',
#   'windows 7',
#   'vista',
#   'vista',
#   'windows xp',
#   'vista',
#   'key broad',
#   'warranty',
#   'repair " depot "',
#   'school use',
#   'design',
#   'battery life',
#   'programs',
#   'wireless',
#   'battery life',
#   'programs',
#   'trackpad',
#   'navigating',
#   'programs',
#   'speakers',
#   'subwoofer',
#   'built in camera',
#   'price',
#   'warranty',
#   'left mouse key',
#   'costed',
#   'speed',
#   'hard drive space',
#   'picture',
#   'extended warranty',
#   'extended warranties',
#   'battery',
#   'screen',
#   'battery life',
#   'appearance',
#   'technical service for dell',
#   'graphics',
#   'warranty',
#   'battery',
#   'case',
#   'performance',
#   'price',
#   'look',
#   'applications',
#   'speed',
#   'tech support',
#   'use',
#   'gaming',
#   'photoshop',
#   'system clock',
#   'ram',
#   'driver updates',
#   'windows',
#   'work',
#   'works',
#   'hd',
#   'graphics card',
#   'hd',
#   'built in camera',
#   'in',
#   'dvd burner',
#   'dvd burner',
#   'works',
#   '15 inch',
#   'product support',
#   'use',
#   'screen',
#   'casing of the power cord',
#   'of the',
#   'internet signals',
#   'price',
#   'right speaker',
#   'price tag',
#   'software',
#   'updates',
#   'multiple page viewer',
#   'page',
#   'shipped',
#   'keyboard',
#   'use',
#   'warranty',
#   'quality',
#   'features',
#   'recovery disk',
#   'features',
#   'programs',
#   'office',
#   'office programs',
#   'wifi',
#   'typing',
#   'screen',
#   'temp',
#   'windows operating system',
#   'os',
#   'processor speed',
#   'thunderbolt port',
#   'lcd screen',
#   'images',
#   'windows vista',
#   'windows xp',
#   'vista',
#   'adobe flash player',
#   'internet explore',
#   'windows update',
#   'update',
#   'switch',
#   'switch',
#   '4gb stick of ram',
#   'hardrive',
#   'touch control buttons',
#   'keyboard',
#   'performance',
#   'runs',
#   'ilife software',
#   'iphoto',
#   'imovie',
#   'iweb',
#   'itunes',
#   'garageband',
#   'system board',
#   'size',
#   'software',
#   'hardware',
#   'memory',
#   'hard drive',
#   'graphics',
#   'programs',
#   'navigation',
#   'hinge',
#   'lcd',
#   'dell customer service',
#   'rma service',
#   'rma',
#   'design',
#   'keyboard',
#   'battery life',
#   'screen / video resolution',
#   'resolution',
#   'dreamweaver',
#   'final cut pro 7',
#   'photoshop',
#   'safari',
#   'firefox',
#   'msn messenger',
#   'applications',
#   'warrenty',
#   'tech support',
#   'apple applications',
#   'gigs',
#   'memory',
#   '17 - inch screen',
#   'dvd',
#   'cd burners',
#   'web browsing',
#   'uploading photos',
#   'watching movies',
#   'creating presentations',
#   'quality display',
#   'weight',
#   '12 cell battery',
#   'case',
#   'power adapter plug',
#   'features',
#   'speakers',
#   'screen',
#   'tab',
#   'extended warrenty',
#   'tft panel',
#   'navigation',
#   'windows operating systems',
#   'screen',
#   'screen size',
#   'bulk',
#   'picture',
#   'video',
#   'music software',
#   'software',
#   'combined touch pad and clicker',
#   'unibody construction',
#   'value',
#   'windows',
#   'screen hinges',
#   'battery',
#   'storage life',
#   'service',
#   'storage',
#   'ram',
#   'nvidia chipset',
#   'extended warranty',
#   'programs',
#   'charge time',
#   'size',
#   'consistancy',
#   'key bindings',
#   'keyboard',
#   'size',
#   '10 - key',
#   'fan',
#   'fan',
#   'screen',
#   'operating system',
#   'processor',
#   '500gb hard drive',
#   'feature',
#   'tech support',
#   'usb output',
#   'wireless mouse',
#   'windows',
#   'linux',
#   'size',
#   'screen',
#   'windows disc',
#   'quality',
#   'touchpad',
#   'video card',
#   'touch pad',
#   'external mouse',
#   'set up',
#   'video',
#   'value',
#   'hard drive',
#   'runs',
#   'loads',
#   'warranty',
#   'program',
#   'spinning beachball',
#   'disk throughput',
#   'access wireless internet access',
#   'value',
#   'ran',
#   'battery',
#   'company',
#   'screen resolutions',
#   'carry',
#   'keyboard',
#   'edges',
#   'programs',
#   'ilife',
#   'iphotos',
#   'processor',
#   'fan',
#   'motherboard',
#   'built',
#   'performance',
#   'screen resolution',
#   'snow leopard',
#   'cpu',
#   'spinning wheel',
#   'office mac applications',
#   'word',
#   'excel',
#   'pad',
#   'keyboard',
#   'screen',
#   'windows 7',
#   'programs',
#   'ilife',
#   'iwork',
#   '18.4 " screen',
#   'battery life',
#   'runs',
#   'regular layout keyboard',
#   'programs',
#   'windows',
#   'recovery discs',
#   'windows 7 starter',
#   'support',
#   '3 year warranty',
#   'online chat service',
#   'iphoto',
#   'works',
#   'battery',
#   'quality',
#   'vhs',
#   'use',
#   'navigate',
#   'battery life',
#   'battery',
#   'usb ports',
#   'battery',
#   'design',
#   'quality',
#   'mac version of microsoft office',
#   'starting-up time',
#   'operates',
#   'touch pad',
#   'touch pad',
#   'pictures',
#   'transporting',
#   'gaming',
#   'wifi card',
#   'network capability',
#   'printer',
#   'use',
#   'os x',
#   'repair service',
#   'customer service agents',
#   'photoshop',
#   'aftereffects programs',
#   'runs',
#   'warrenty',
#   'look',
#   'dependability',
#   'company',
#   'warranty',
#   'features',
#   'mouse button',
#   'performance',
#   'touchpad',
#   'buttons',
#   'programs',
#   'space',
#   'keyboard',
#   'battery',
#   'keyboard',
#   'battery life',
#   'hard drive',
#   'windows 7',
#   'processor',
#   'load webpages',
#   'applications',
#   'battery',
#   'boot',
#   'windows',
#   'runs',
#   'openoffice',
#   'firefox',
#   'price',
#   'quality',
#   'performance',
#   'battery life',
#   'use',
#   'product key',
#   'specs',
#   'bluetooth',
#   'one touch keys',
#   'feature',
#   'battery life',
#   'keyboard',
#   'speed',
#   'specs',
#   'price',
#   'delivery',
#   'stability',
#   'mac software',
#   'operating system',
#   'sata controller',
#   'video editing',
#   'performance',
#   'mobile video editing',
#   'imovie program',
#   'processor',
#   'ram',
#   'battery',
#   'price',
#   'designed',
#   'warranty',
#   'bluetooth mouse',
#   'features',
#   'keyboard',
#   'control buttons',
#   'screen',
#   'motherboard',
#   'motherboard',
#   'processor',
#   'performance',
#   'motherboard',
#   'patches',
#   'speed',
#   'system memory',
#   'radeon 5850',
#   'ddr 5',
#   'ddr 3',
#   'programs',
#   'programs',
#   'speed',
#   'size',
#   'os ( vista )',
#   'software',
#   'battery life',
#   'battery life',
#   'extended warranty',
#   'use',
#   'use',
#   'features',
#   'programs',
#   'pop up windows',
#   'pop ups',
#   'web programming software',
#   'memory',
#   'web access',
#   '3g network',
#   'screen',
#   'design based programs',
#   'adobe creative suite',
#   ...],
#  'Laptops_poria-test': ['boot time',
#   'tech support',
#   'set up',
#   'windows 8',
#   'touchscreen functions',
#   'click pads',
#   'internal speakers',
#   'price tag',
#   'installation disk ( dvd )',
#   'use',
#   'works',
#   'apple os',
#   'features',
#   'log on',
#   'wifi connection',
#   'battery life',
#   'delete key',
#   'interneting',
#   'priced',
#   'works',
#   'track pad',
#   'graphics',
#   'mountain lion',
#   'build',
#   'durability',
#   'battery life',
#   'works',
#   'windows 8',
#   'baterry',
#   'size',
#   'weight',
#   'performance',
#   'usb ports',
#   'speed',
#   'screen',
#   'price',
#   'hardware performance',
#   'works',
#   'set up',
#   'keyboard',
#   'windows 8',
#   'setup',
#   'configure',
#   'windows 8',
#   'usb ports',
#   'features',
#   'screen',
#   'keyboard',
#   'performance',
#   'quality',
#   'performance',
#   'os',
#   'portability',
#   'portable computing',
#   'ms office 2011 for mac',
#   'performance',
#   'look',
#   'performance',
#   'lit up keys',
#   'screen display',
#   'mountain lion os',
#   'microsoft windows',
#   'osx',
#   'microsoft office',
#   'graphics',
#   'colors',
#   'built-in apps',
#   'screen resolution',
#   'speed',
#   'multi touch gestures',
#   'operating system',
#   'windows',
#   'size',
#   'squaretrade 3 - year computer accidental protection warranty',
#   'applecare',
#   'transport',
#   'windows 8 set-up',
#   'size',
#   'retina display',
#   'design',
#   'aluminum casing',
#   'aluminum body',
#   'integrate bluetooth devices',
#   'usb devices',
#   'intel 4000 graphic chip',
#   'dvd drive firewire port',
#   'adapter',
#   'sdxc slot',
#   'durability',
#   'designed',
#   'use',
#   'value',
#   'specs',
#   'product quality',
#   'aesthetics',
#   'craftmanship',
#   'customer service',
#   'size',
#   'windows 8',
#   'windows 8',
#   'startup times',
#   'colors',
#   'price',
#   'shipping',
#   'mouse',
#   'battery',
#   'windows 7',
#   'price',
#   'delivery',
#   'service',
#   'customer service',
#   'windows 8',
#   'price',
#   'set up',
#   'win 8',
#   'features',
#   'price',
#   'osx',
#   'support for games',
#   'mobility',
#   'price',
#   'set up',
#   'usb 3',
#   'sound',
#   'track pad',
#   'settings',
#   'openoffice',
#   'form factor',
#   'battery life',
#   'ux',
#   'keyboard',
#   'screen',
#   'touchpad',
#   'mavericks',
#   'i5',
#   'service',
#   'shipping',
#   'performance',
#   'built-in applications',
#   'iphoto',
#   'hard drive',
#   'samsung 830 ssd',
#   'starts up',
#   'aluminum',
#   'built in virus control',
#   'retina display',
#   'components',
#   'hardware',
#   'battery',
#   'snow lion',
#   'shipping',
#   'features',
#   'quality',
#   'keyboard',
#   'sound quality',
#   'navigate',
#   'battery life',
#   'performance',
#   'quality',
#   'windows xp',
#   'windows vista',
#   'windows 7',
#   'ssd drive',
#   'memory',
#   'start up',
#   'itune',
#   'os',
#   'restore disks',
#   'charging cables',
#   'material',
#   'cables',
#   'graphic design',
#   'external mics',
#   'os',
#   'screen',
#   'works',
#   'system',
#   'customize setting',
#   'create your own bookmarks',
#   'wireless keyboard / mouse',
#   'hdmi cable',
#   'features',
#   'price',
#   'working',
#   'gaming',
#   'operating system',
#   'set up',
#   'hard drive',
#   'boots up',
#   'scanning',
#   'price point',
#   'works',
#   'working',
#   'surfing',
#   'works',
#   'software',
#   'word processing',
#   'web browsing',
#   'gaming',
#   'programming',
#   'function',
#   'performance',
#   'apple " help "',
#   'work',
#   'harddrive',
#   'on / off switch',
#   'instructions',
#   'gaming',
#   'integrated intel 4000 graphics',
#   'features',
#   'content creation',
#   'audio',
#   'video',
#   'photo editing',
#   'screen',
#   'brightness',
#   'applications',
#   'use',
#   'use',
#   'i5 processor',
#   'built in features',
#   'screen',
#   'keyboard',
#   'delivery',
#   'ssd',
#   '16gb ram',
#   'memory',
#   'works',
#   'design',
#   'keyboard',
#   'ports',
#   'service',
#   'web browsing',
#   'safari browser',
#   'lighted screen',
#   'use',
#   'start up',
#   'operation',
#   'usb 3 peripherals',
#   'thunderbolt',
#   'media editing',
#   'battery',
#   'user experience',
#   'shipment',
#   'price',
#   'performance',
#   'usability',
#   'presentation',
#   'time response',
#   'size',
#   'mac os',
#   'programs',
#   'appleworks',
#   'filemaker pro',
#   'quicken',
#   'photoshop',
#   'operating system',
#   'form factor',
#   'loading the internet',
#   'looking',
#   'xp',
#   'support',
#   'os',
#   'overall build',
#   'keyboard',
#   'construction',
#   'system',
#   'unibody construction',
#   'runs',
#   'disk drive',
#   'hdmi receptacle',
#   'sd card slot',
#   'works',
#   'design app',
#   'trackpad',
#   'looks',
#   'feels',
#   'finish',
#   'price',
#   'price',
#   'system',
#   'power down',
#   'configuration',
#   'speakers',
#   'looks',
#   'use',
#   'trackpad',
#   'web surfuring',
#   'interface',
#   'portability',
#   'works',
#   'carry',
#   'handle',
#   'hardware ( keyboard )',
#   'performance',
#   'battery lifetime',
#   'runs',
#   'footprint',
#   'exterior',
#   'performance',
#   'design',
#   'intel 4000 graphics chipset',
#   'osx mountain lion',
#   'mavericks',
#   'usb ports',
#   'wakes',
#   'lid',
#   'size',
#   'speed',
#   'customer service',
#   'performed',
#   'battery cycle count',
#   'hardware',
#   'os',
#   'finger swipes',
#   'mouse',
#   'storage',
#   'screen',
#   'photoshop',
#   'mac os',
#   'speaker quality',
#   'shipped',
#   'thunderbolt port',
#   'performance',
#   'streaming video',
#   'entertainment uses',
#   'design',
#   'features',
#   'mac office',
#   'apple tech support',
#   'spec',
#   'works',
#   'use',
#   'looks',
#   'office',
#   'retina display',
#   'performance',
#   'ssd',
#   'magsafe accessories',
#   'magsafe 2 connection',
#   'touchpad',
#   'mouse',
#   'runs',
#   'fans',
#   'mac os',
#   'mac ecosystem',
#   'price',
#   'use',
#   'appearance',
#   'functionality',
#   'graphic design',
#   'slot',
#   'os',
#   'use',
#   'ssd',
#   'built-in camera',
#   'voice recording',
#   'start up',
#   'functionality',
#   'function',
#   'graphics',
#   'build quality',
#   'unibody construction',
#   'flexibility for connectivity',
#   'portability',
#   'mac tutorials',
#   'technical support',
#   'adapter',
#   'technical support',
#   'iphoto',
#   'garage band',
#   'logic board',
#   'sound',
#   'volume',
#   'osx lion',
#   'application',
#   'physical form',
#   'body',
#   'unibody construction',
#   '3d rendering',
#   'os x mountain lion',
#   'screen',
#   'apps',
#   'boot',
#   'ports',
#   'and',
#   'quad-core 2.5 ghz cpu',
#   'radeon hd 6750m 512mb graphic card',
#   'integrated intel 4000 card',
#   'and',
#   'wireless apple keyboard and mouse',
#   'and',
#   'package',
#   'cover',
#   'gestures',
#   'extender cable',
#   'cable',
#   '2.9 ghz dual-core i7 chip',
#   'starts up',
#   'noise',
#   'heat',
#   'windows 8',
#   'internal cd drive',
#   'hard drive',
#   'network lights',
#   'priced',
#   'storage',
#   'ports',
#   'audio volume',
#   'size',
#   'windows 8',
#   'capabilities',
#   'settings',
#   'runs',
#   'boot-up',
#   'windows updates',
#   'logic board',
#   'internet',
#   'word processing',
#   'graphic design',
#   'gaming',
#   'setup',
#   'install',
#   'tutorial',
#   'features',
#   'right mouse click menu',
#   'runs',
#   'ram memory',
#   'profile',
#   'wifi capability',
#   'disk drive',
#   'usb ports',
#   'sd card reader',
#   'the nail slot on the card',
#   'slot',
#   'touch',
#   'anodized aluminum',
#   'aluminium',
#   'glass',
#   'aluminum',
#   '16gb of ram',
#   'seagate momentus xt hybrid drives',
#   'owc upgrade kit',
#   'hard drive',
#   'number pad on the keyboard',
#   'on',
#   'regular hard drive',
#   'cd slot',
#   'hdmi port',
#   'install mountain lion',
#   'customization',
#   'hd',
#   'micron ssd',
#   'two finger clicking',
#   'right click button',
#   'superdrive',
#   'power plug',
#   'power adaptor',
#   'battery',
#   'battery',
#   'practicality',
#   'os',
#   'monitors',
#   'hdmi cables',
#   'price',
#   'ac adaptor',
#   'fan',
#   'playing a game',
#   'usb 2 ports',
#   'startup disk',
#   '" tools " menu',
#   'word program',
#   'cd / dvd drive',
#   'power switch',
#   'windows 7',
#   'windows 8',
#   'install',
#   'configure for adsl cable or wifi',
#   'speakers',
#   'packing',
#   'windows',
#   'idvd',
#   'windows 7',
#   'mac system',
#   'windows',
#   'works',
#   'software',
#   'os',
#   'works',
#   'runs',
#   'price',
#   'os',
#   'touch pad',
#   'reliability',
#   'sound',
#   'headphones',
#   'track pad',
#   'os',
#   'application',
#   'price',
#   'battery',
#   'speed',
#   'price',
#   'shipping',
#   'retina display display',
#   'compact computing',
#   'the',
#   'performance and feature set of the hardware',
#   'ports',
#   'firewire 800',
#   'gigabit ethernet',
#   'magsafe port',
#   'microphone jack',
#   'ventilation system',
#   'watching videos',
#   'playing steam games',
#   'acer support',
#   'operating system files',
#   'keys',
#   'os',
#   'lion',
#   'mac os',
#   'ram',
#   'hdd',
#   'cd / dvd player',
#   'ram memory',
#   'os . x',
#   'windows',
#   'windows .',
#   'softwares',
#   'os',
#   'mac os x 10.8 " mountain lion "',
#   'performance',
#   'external 24 " lcd screen',
#   'built in screen size',
#   'dvd slot',
#   'install software',
#   'word processing program',
#   'third-generation cpu ( " ivy bridge " )',
#   'fourth-generation haswell cpu',
#   'cd rom',
#   'features',
#   'volume',
#   'volume',
#   'case',
#   'price',
#   'log into the system',
#   'ssd',
#   '21 " led screen',
#   'set up',
#   'case',
#   'external power supply',
#   'size',
#   'wireless mouse',
#   'pad',
#   'works',
#   'key board',
#   'cost of ownership',
#   'price tag',
#   'features',
#   'vga port',
#   'hdmi',
#   'ethernet',
#   'usb ports',
#   'rubber pads',
#   'price',
#   'price',
#   'heat output',
#   'operation',
#   'upgrade the ram',
#   'price',
#   'mac',
#   'built-in mic',
#   'mac os 10.9',
#   'external microphones',
#   'features',
#   'shortcuts',
#   'ios system',
#   'resolution',
#   'fonts',
#   'working',
#   'features',
#   'brightness',
#   'adjustments',
#   'cd / dvd player',
#   'backlit keys',
#   '" home / end " type keys',
#   'microsoft word',
#   'memory',
#   'speed',
#   'flexibility',
#   'speed',
#   'simplicity',
#   'design',
#   'battery life',
#   'display',
#   'downloading apps',
#   'screen',
#   'software',
#   'operating system',
#   'slim plastic case',
#   'recovery usb stick',
#   'bass',
#   'sound',
#   'built quality',
#   'performance',
#   'mac',
#   'bluetooth interface',
#   'mac os',
#   'range',
#   'start',
#   'start menu',
#   'ram',
#   'touch screen',
#   'games',
#   'photoshop',
#   '" wlan " card',
#   'lan device drivers',
#   'built',
#   'battery life',
#   'os',
#   'apple customer support',
#   'firewire 800',
#   'usb 3',
#   'usb 3',
#   'mac os',
#   'windows 7',
#   'itunes',
#   'security',
#   'mini form factor',
#   'graphics stuff',
#   'the card reader',
#   'remove the card',
#   'spinning hard disk',
#   'ssd drive',
#   'hdmi',
#   'firmware patch',
#   'specs',
#   'packing',
#   'mother boards',
#   'mother board',
#   'graphics card',
#   '4g of ram',
#   '8g of ram',
#   'performs',
#   'virtual home schooling',
#   'cost',
#   'operating system',
#   'size',
#   'weight',
#   'mobility',
#   'durability of the battery',
#   'the functions provided by the trackpad',
#   'by',
#   'hardware',
#   'software',
#   'updates',
#   'disc drive',
#   'screen',
#   'res'],
#  'Restaurants_poria-test': ['bread',
#   'delivery times',
#   'food',
#   'coffee',
#   'sushi',
#   'place',
#   'people',
#   'japanese food',
#   'spicy tuna roll',
#   'asian salad',
#   'rose roll',
#   'menu',
#   'drinks',
#   'lychee martini',
#   'food',
#   'nicoise salad',
#   'menu',
#   'drinks',
#   'dessert pizza',
#   'food',
#   'live entertainment',
#   'waiter',
#   'menu',
#   'sushi',
#   'portions',
#   'price',
#   'food',
#   'service',
#   'portions of the food',
#   "waitress's",
#   'staff memebers',
#   'parking',
#   'desserts',
#   'desserts',
#   'tart of the day',
#   'food',
#   'wine',
#   'lasagna',
#   'array of sushi',
#   'cuisine',
#   'owners',
#   'staff',
#   'indian food',
#   'ambiance',
#   'food',
#   'service',
#   'garden',
#   'food',
#   'appetizers',
#   'entrees',
#   'food',
#   'decor',
#   'lunch',
#   'dinners',
#   'steaks',
#   'staff',
#   'meatball parm',
#   'latin food',
#   'taglierini with truffles',
#   'staff',
#   'gnocchi',
#   'staff',
#   'food',
#   'portion size',
#   'portobello / gorgonzola / sausage appetizer',
#   'lobster risotto',
#   'entrees',
#   'lasagna',
#   'fettuccine alfredo',
#   'chicken parmigiana',
#   'food',
#   'teriyaki',
#   'meal',
#   'peanut butter sorbet',
#   'pizza with soy cheese',
#   'food',
#   'price',
#   'food',
#   'service',
#   'atmosphere',
#   'food',
#   'waitstaff',
#   'atmosphere',
#   'beer',
#   'food',
#   'kimono shrimp special',
#   'atmosphere',
#   'menu',
#   'priced',
#   'food',
#   'ingredients',
#   'food',
#   'appetizer',
#   'meal',
#   'spicy mussels',
#   'onion rings',
#   'food',
#   'portions',
#   'service',
#   'prices',
#   'service',
#   'food',
#   'waiter',
#   'manager',
#   'food',
#   'milkshakes',
#   'mushroom barley soup',
#   'food',
#   'staff',
#   'duck',
#   'drinks',
#   'food',
#   'curried casseroles',
#   'food',
#   'taste',
#   'space',
#   'cuisine',
#   'seafood',
#   'orange donut',
#   'atmosphere',
#   'meats',
#   'management',
#   'ambience',
#   'teas',
#   'sweets',
#   'mojitos',
#   'service',
#   'sandwiches',
#   'burgers',
#   'salads',
#   'lemon-dressed cobb',
#   'design',
#   'food',
#   'staff',
#   'taste',
#   'fajita',
#   'mole sauce',
#   'roasted chickens',
#   'atmosphere',
#   'food',
#   'selection',
#   'prices',
#   'drinks',
#   'steak',
#   'food',
#   'waiters',
#   'priced',
#   'selection of food',
#   'atmosphere',
#   'dessert',
#   'taste',
#   'food',
#   'hot dog',
#   'bar',
#   'food',
#   'waiters',
#   'atmosphere',
#   'food',
#   'wraps',
#   'burgers',
#   'salads',
#   'mango margareta',
#   'prices',
#   'service',
#   'waiter',
#   'staff',
#   'folding chair',
#   'service',
#   'fettucino alfredo',
#   'food',
#   'vegan options',
#   'indian food',
#   'smoked trout',
#   'lamb chops',
#   'veal chops',
#   'rabbit',
#   'potato gratin',
#   'chef',
#   'food',
#   'service',
#   'eggs benedict',
#   'mussels',
#   'hamburger',
#   'waiters',
#   'falafal',
#   'chicken',
#   'grand marnier shrimp',
#   'food',
#   'food',
#   'service',
#   'desserts',
#   'flan',
#   'sopaipillas',
#   'portions',
#   'wait staff',
#   'food',
#   'service',
#   'sushi',
#   'service',
#   'soup',
#   'crepes',
#   'creme brulee',
#   'apple',
#   'shrimp creole',
#   'chicken dinner',
#   'chili signed food items',
#   'decor',
#   'food',
#   'ribs',
#   'beef',
#   'coconut rice',
#   'avocado salad',
#   'honey bbq rib tips',
#   'chinese food',
#   'service',
#   'atmosphere',
#   'staff',
#   'waiters',
#   'pasta',
#   'wine list',
#   'cocktail menu',
#   'crab cakes',
#   'bbq rib',
#   'food',
#   'service',
#   'sauce',
#   'service',
#   'desserts',
#   'atmosphere',
#   'drinks',
#   'appetizers',
#   'pizza',
#   'service',
#   'food',
#   'beer list',
#   'chinese food',
#   'waiter',
#   'scallops',
#   'asparagus',
#   'soft shell crab',
#   'cheese plate',
#   'service',
#   'hotdogs',
#   'staff',
#   'saag gosht',
#   'garlic knots',
#   'indian food',
#   'pizza',
#   'music',
#   'service',
#   'owner',
#   'staff',
#   'sushi',
#   'menu',
#   'food',
#   'sushi',
#   'cooked food',
#   'dinner specials',
#   'food',
#   'drinks',
#   'dining atmosphere',
#   'price',
#   'food',
#   'food portion',
#   'chairs',
#   'tacos pastor',
#   'tostada de tinga',
#   'bartenders',
#   'managers',
#   'decor',
#   'soup and sandwich meal',
#   'hot and sour soup',
#   'drinks',
#   'atmosphere',
#   'service',
#   'food',
#   'chick peas with shrimp ( appetizer )',
#   'service',
#   'lamb',
#   'soft shell crab sandwich with fries',
#   'hong kong-style food',
#   'food',
#   'wine',
#   'staff',
#   'kitchen food',
#   'sushi',
#   'service',
#   'waitresses',
#   'atmosphere',
#   'italian food',
#   'food',
#   'rolls',
#   'sushi / sashimi',
#   'sashimi',
#   'price',
#   'hot dogs',
#   'breakfast sandwiches',
#   'tator tots',
#   'english muffins',
#   'pork product',
#   'taylor ham',
#   'manager',
#   'bartender',
#   'waiting',
#   'drinks',
#   'service',
#   'atmosphere',
#   'dish',
#   'green chillis',
#   'service',
#   'food',
#   'meals',
#   'lunch',
#   'take-out',
#   'dine-in',
#   'food',
#   'fresh juice concoctions',
#   'food',
#   'prices',
#   'place',
#   'soul food',
#   'place',
#   'roast chicken',
#   'salad',
#   'chicken with avocado',
#   'tuna',
#   'meals',
#   'chicken',
#   'sauce',
#   'malted milk ball gelato',
#   'meal',
#   'service',
#   'bar service',
#   'dessert',
#   'service',
#   'black vinegar',
#   'shredded ginger',
#   'lighting',
#   'food',
#   'disco pop duo',
#   'escargot',
#   'place',
#   'service',
#   'owner',
#   'waiters',
#   'food',
#   'waiter',
#   'salads',
#   'vegetarian platters',
#   'meal',
#   'food',
#   'service',
#   'pizza',
#   'pizza',
#   'service',
#   'chicken',
#   'food',
#   'host ( owner )',
#   'servers',
#   'food',
#   'atmosphere',
#   'hostess',
#   'food',
#   'service',
#   'vietnamese beef noodle soup',
#   'dining experience',
#   'indian food',
#   'waiters',
#   'interior',
#   'service',
#   'food',
#   'decor',
#   'menu',
#   'selection',
#   'sauce',
#   'crust',
#   'sushi',
#   'selection',
#   'rolls with crab',
#   'host',
#   'bartender',
#   'servers',
#   'food',
#   'potato spinach gnocchi',
#   'lamb',
#   'lunch',
#   'sandwiches',
#   'portuguese cheese cart',
#   'port',
#   'burger',
#   'blueberry pancakes',
#   'food',
#   'bill',
#   'toppings',
#   'crust',
#   'service',
#   'food',
#   'waitstaff',
#   'food',
#   'lobster ravioli',
#   'meal',
#   'service',
#   'wait',
#   'price',
#   'food',
#   'coffee',
#   'cosi sandwiches',
#   'drink',
#   'prices',
#   'food',
#   'waiting',
#   'place',
#   'ambience',
#   'brunch',
#   'food',
#   'crust',
#   'food',
#   'cake',
#   'dinner',
#   'service',
#   'delmonico steak',
#   'menu',
#   'chicken',
#   'rice',
#   'beans',
#   'service',
#   'value',
#   'food',
#   'value',
#   'garlic soup',
#   'falafel',
#   'tabouleh',
#   'humus',
#   'mediterranean delights',
#   "pizza's",
#   'staff',
#   'chef',
#   'priced',
#   'sushi',
#   'for',
#   'seafood paella for two',
#   'apetizers',
#   'sangria',
#   'service',
#   'server',
#   'staff',
#   'food',
#   'service',
#   'host',
#   'hostess',
#   'wait staff',
#   'meal',
#   'salmon dishes',
#   'foie gras',
#   'menu',
#   'mac cheese',
#   'brunch menu',
#   'jazz singer',
#   'service',
#   'food',
#   'breakfast food',
#   'soups',
#   'salads',
#   'sandwiches',
#   'food',
#   'banana pudding',
#   'crabcakes',
#   'and',
#   'mac and cheese',
#   'staff',
#   'prices',
#   'service',
#   'food',
#   'downstairs bar scene',
#   'food',
#   'price',
#   'drinks',
#   'casual lunches',
#   'tequila',
#   'beer selection',
#   'beers',
#   'delivary',
#   'food',
#   'owner',
#   'homemade pastas',
#   'gnocchi',
#   'vegetable risotto',
#   'flavor',
#   'price',
#   'service',
#   'dinner',
#   'prices',
#   'sandwiches',
#   'soup',
#   'pizza',
#   'homemade sorbets',
#   'homemade guacamole',
#   'entree',
#   'deserts',
#   'sushi',
#   'priced',
#   'deserts',
#   'grill',
#   'churrasco',
#   'ribs',
#   'traditional italian items',
#   'served',
#   'setting',
#   'iced blended mocha',
#   'hot white mocha',
#   'late lunch',
#   'parmesan cheese',
#   'waitress',
#   'food',
#   'wine',
#   'service',
#   'portions',
#   'ambiance',
#   'salad',
#   'salad dressing',
#   'quesedilla',
#   "pizza's",
#   'service',
#   'food',
#   'cost',
#   'food',
#   'staff',
#   'bar',
#   'chef',
#   'indian food',
#   'service',
#   'odessa stew',
#   'rabbit stew',
#   'kompot',
#   'lunch',
#   'waitress',
#   'quality of the meat',
#   'smoothies',
#   'fresh juices',
#   'black roasted codfish',
#   'dish',
#   'manager',
#   'menu',
#   'waiter',
#   'chicken',
#   'taste',
#   'reservation',
#   'brunch',
#   'sushi',
#   'sushi',
#   'food',
#   'served',
#   'the erbazzone emiliana',
#   'the mostarda on the cheese plate',
#   'the dishes',
#   'food',
#   'bar',
#   'vibe',
#   'candlelight',
#   'music',
#   'food',
#   'dining experience',
#   'food',
#   'service',
#   'place',
#   'food',
#   'chicken teriyaki',
#   'garlic shrimp',
#   'japanese food',
#   'food',
#   'staff members',
#   'drink',
#   'atmosphere',
#   'sashimi portion',
#   'artifical lobster meat',
#   'wheat crusted pizza',
#   'ingredients',
#   'dinner',
#   'food',
#   'service',
#   'cake',
#   'slices',
#   'staff',
#   'wait',
#   'wine list',
#   'priced',
#   'salads',
#   'bathroom',
#   'delivers',
#   'food',
#   'prices',
#   'service',
#   'repast',
#   'waiters',
#   'italian meal',
#   'pizza',
#   'steak',
#   ', organic grilled burgers',
#   'dish ,',
#   'jerusalem market-style falafel wraps and mediterranean salads--layered with beets , goat cheese and',
#   'dining experience',
#   'waiter',
#   'texture',
#   'hint of cocoa',
#   'the round corner table next to the large window',
#   'twist on pizza',
#   'flavor',
#   'ac',
#   'service',
#   'sales people',
#   'location',
#   'the display and quality of the food',
#   'food',
#   'food',
#   'italian cuisine',
#   'atmoshere',
#   'booth by the windows',
#   'place',
#   'food',
#   'service',
#   'coffee',
#   'wine list',
#   'vintages',
#   'priced food',
#   'scenery',
#   'new hamburger with special sauce',
#   'big mac',
#   'pasta',
#   'sauce',
#   'portions',
#   'prices',
#   'food',
#   'service',
#   'staff',
#   'owners',
#   'owner',
#   'place',
#   'meal',
#   'place',
#   'service',
#   'staff',
#   'food',
#   'fortune cookies',
#   'cookie',
#   'sushi lunch',
#   'mojito',
#   'back patio',
#   'service',
#   'meal',
#   'braised lamb shank with mashed potatoes',
#   'waitress',
#   'soy sauce',
#   'lunch',
#   'bar',
#   'bartender',
#   'fried pork dumplings',
#   'orange chicken / beef',
#   'fried rice',
#   'menu',
#   'french fries - - with the kalmata dip',
#   'wait',
#   'manager',
#   'bartender',
#   'drinks',
#   'boutique selection of wines',
#   'assortment of wraps',
#   'traditional mediterranean fare',
#   'fresh veggies',
#   'middle eastern spreads',
#   'cheese',
#   'falafel',
#   'soup',
#   'fish',
#   'rice',
#   'root vegetables',
#   'rice medley',
#   'spinach thing',
#   'lamb kebabs',
#   'cheese baclava',
#   'fooood',
#   'saketini',
#   'bar menu',
#   'look',
#   'martinis',
#   'chairs',
#   'table',
#   'happy hour',
#   'service',
#   'atmosphere',
#   'waiting',
#   'waiter',
#   'kitchen',
#   'quaility',
#   'atmosphere',
#   'space',
#   'treats',
#   'prices',
#   'menu',
#   'seats',
#   'value',
#   'attitude',
#   'food',
#   'glass of wine',
#   'wine',
#   'flavors',
#   'place',
#   'service',
#   'food',
#   'price',
#   'burrito',
#   'tacos',
#   'margarita',
#   'dessert',
#   'space',
#   'reservations',
#   'food',
#   'interior',
#   'owners',
#   'dining',
#   'service',
#   'food',
#   'value',
#   'wait',
#   'hot cakes',
#   'egg mcmuffin sandwich',
#   'breakfast',
#   'service',
#   'food',
#   'music',
#   'bartender',
#   'drinks',
#   'rice dishes',
#   'noodle dishes',
#   'ice drink',
#   'cuisine',
#   'billed',
#   'asian fusion',
#   'bill',
#   'dishes',
#   'king crab salad with passion fruit vinaigrette',
#   'fettuccine with grilled seafood in a rosemary-orange sauce',
#   'bistro menu',
#   'dishes',
#   '" roy\'s classics "',
#   'menu',
#   'recipes',
#   'macadamia-crusted mahi mahi',
#   'sweet honey-mustard beef short ribs',
#   'cold sesame noodles',
#   'meal',
#   'food served',
#   'argentine chorizo appetizer',
#   'fennel flavored italian sausage',
#   'dinner',
#   'delivery',
#   'value',
#   'sandwiches',
#   'soy mayonaise',
#   'table',
#   'hostess',
#   'dinner',
#   'food',
#   'staff',
#   'food',
#   'wine',
#   'music',
#   'tapas',
#   'selection of wines ( primarily spanish )',
#   'clientele',
#   'food',
#   'dumplings',
#   'cold sesame noodles',
#   'chicken',
#   'shrimp dishs',
#   'food',
#   'food',
#   'waiting',
#   'entrees',
#   'place',
#   'duck confitte',
#   'wine list',
#   'tapas',
#   'atmosphere',
#   'food',
#   'food price',
#   'food',
#   'service',
#   'prices',
#   'food',
#   'meal',
#   'food',
#   'service',
#   'dinner menu',
#   'entrees',
#   'seafood',
#   'steaks',
#   'non-meat alternatives',
#   'menu',
#   'food',
#   'appetizers',
#   'service',
#   'food',
#   'price',
#   'waitress',
#   'entree',
#   'prices',
#   'gratuity',
#   'bill',
#   'halibut cheek appetizer',
#   'portion of foie gras',
#   'meal',
#   'food',
#   'empenadas',
#   'plaintains',
#   'afternoon snack',
#   'appetizer',
#   'pasta specials',
#   'big mac',
#   'chicken mcnuggets',
#   'filet-o-fish sandwich',
#   "mcdonald's famous french fries",
#   'entree-sized salads',
#   'noise',
#   'pizza',
#   'pizza',
#   'tables',
#   'lunch',
#   'scene',
#   'blue bar area',
#   'upstrairs dining area',
#   'veggie burger',
#   'chickpeas',
#   'carrots',
#   'vegetables',
#   'spices',
#   'tables',
#   'service',
#   'menus',
#   'sweet corn-foie gras brulee',
#   'carinthia cheese ravioli with wild mushrooms',
#   'caviar-topped sturgeon',
#   'with',
#   'green spinach-vodka sauce',
#   'burgers',
#   'patties',
#   'lunch',
#   'delivery service',
#   'quality',
#   'prices',
#   'staff person',
#   'fork',
#   'specials',
#   'salmon',
#   'pastas',
#   'atmosphere',
#   'decor',
#   'wait staff',
#   'food',
#   'dishes',
#   'place',
#   'desserts',
#   'food',
#   'staff',
#   'service',
#   'atmosphere',
#   'branzini',
#   'fish',
#   'food',
#   'service',
#   'price',
#   'menu',
#   'ambiance',
#   'service',
#   'food',
#   'food',
#   'wine',
#   'host',
#   'pizzas',
#   'appetizers',
#   'main courses',
#   'calamari',
#   'pasta',
#   'sliced steak entree',
#   'caeser salad',
#   'fried calamari',
#   'atmosphere',
#   'food',
#   'food',
#   'service',
#   'portions',
#   'service',
#   'chicken milanese',
#   'tapas',
#   'prices',
#   'service',
#   'chocolate raspberry cake',
#   'flavor',
#   'waiter',
#   'food',
#   'wine',
#   'meal',
#   'service',
#   'hot dogs',
#   'service',
#   'food',
#   'wine',
#   'desserts',
#   'dining experience',
#   'food',
#   'service',
#   'escargot',
#   'menu',
#   'deco',
#   'ambiance',
#   'french food',
#   'indian food',
#   'curry',
#   'poori',
#   'naan',
#   'paratha',
#   'homemade breads',
#   'sushi',
#   'korean dishes',
#   'prix fixe menu',
#   'waiter',
#   'place',
#   'service',
#   'food',
#   'burgers',
#   'grilled cheeses',
#   'french fries',
#   'yellowfin tuna',
#   "calf's liver",
#   'sushi',
#   'bill',
#   'sauce cart',
#   'table',
#   'choices of sauces',
#   'steak',
#   'sushi',
#   'entrees',
#   'duck',
#   'variety',
#   'utensils',
#   'pie',
#   'thin crust',
#   'slices',
#   'green beans',
#   'egg',
#   'anchovy dressing',
#   'nicoise olives',
#   'red onion',
#   'meal',
#   'side orders',
#   "amazin ' greens salads",
#   'buffalo chicken kickers',
#   'cinna stix',
#   'fries',
#   'meaty chili',
#   'stuffed baked potatoes',
#   'menu',
#   'chocolate frosty',
#   'waiter',
#   'menu',
#   'cake',
#   'cake',
#   'employees',
#   'cherry marscapone',
#   'roti canai appetizer',
#   'fried pancake served with pungent curry dipping sauce',
#   'mango chicken',
#   'outside',
#   'atmosphere',
#   'ground chickpea soup',
#   'starter',
#   'sushi',
#   'service',
#   'quality of food',
#   'bartenders',
#   'clientele',
#   'staff',
#   'meal',
#   'desserts',
#   'tables',
#   'rooftop bar',
#   'decoration',
#   'ambience',
#   'food',
#   'catfish',
#   'service',
#   'food',
#   'brisket',
#   'ribs',
#   'wings',
#   'cajun shrimp',
#   'atmosphere',
#   'counter',
#   'bottle of wine',
#   'menu',
#   'japanese dishes',
#   ...]}

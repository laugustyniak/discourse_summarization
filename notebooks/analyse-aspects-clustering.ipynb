# %%
# %load_ext autoreload
# %autoreload 2

# %%
import json

import pandas as pd
import plotly
from more_itertools import flatten
from sklearn.cluster import AgglomerativeClustering
plotly.offline.init_notebook_mode(connected=True)

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

from gensim.models import fasttext

# %matplotlib inline
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <style>.container { width:100% !important; }</style>
# /home/laugustyniak/anaconda3/envs/aspect/lib/python3.6/site-packages/smart_open/ssh.py:34: UserWarning:
#
# paramiko missing, opening SSH/SCP/SFTP paths will be disabled.  `pip install paramiko` to suppress

# %%
from aspects.analysis import draw_embeddings

# %%
# import spacy
# nlp = spacy.load('en_vectors_web_lg')

# %%
with open('../results/reviews_Cell_Phones_and_Accessories/aspects_per_edu.json') as f:
    aspects = json.load(f)

# %%
model = fasttext.load_facebook_model('/home/laugustyniak/data/embeddings/cc.en.300.bin')

# %%
aspects['0']
# Out:
# ['phone case']

# %%
len(aspects)
# Out:
# 114536

# %%
aspects_flatten = list(flatten(aspects.values()))

# %%
aspects_df = pd.DataFrame(aspects_flatten, columns=['aspect'])

# %%
aspects_unique_df = pd.DataFrame.from_dict(aspects_df.aspect.value_counts())

# %%
aspects_unique_filtered_df = aspects_unique_df[aspects_unique_df.aspect >= 10]

# %%
aspects_unique_filtered_df = aspects_unique_filtered_df.applymap(lambda x: x.encode('unicode_escape').decode('utf-8') if isinstance(x, str) else x)

# %%
aspects_unique_filtered_df.to_csv('../results/reviews_Cell_Phones_and_Accessories/aspects_per_edu_filtered_min_10_freq.csv')

# %%
aspects_unique_filtered_df = aspects_unique_filtered_df.reset_index()
aspects_unique_filtered_df.columns = ['aspect', 'count']
aspects_unique_filtered_df.head(10)
# Out:
#           aspect  count
# 0          price   6383
# 1       motorola   4246
# 2        battery   3925
# 3         amazon   2805
# 4  sound quality   2636
# 5        charger   2605
# 6         screen   2506
# 7        quality   2350
# 8          sound   2317
# 9            use   2169

# %%
# def get_vectors(text):
#     return nlp(text).vector

def get_vectors(text):
    return model.wv[text]

# %%
aspects_unique_filtered_df['embedding'] = aspects_unique_filtered_df.aspect.apply(get_vectors)

# %%
hierarchical_cluster = AgglomerativeClustering(n_clusters=50).fit(aspects_unique_filtered_df.embedding.tolist())
aspects_unique_filtered_df['cluster'] = hierarchical_cluster.labels_

# %%
aspects_unique_filtered_df
# Out:
#                     aspect  count  \
# 0                    price   6383
# 1                 motorola   4246
# 2                  battery   3925
# 3                   amazon   2805
# 4            sound quality   2636
# 5                  charger   2605
# 6                   screen   2506
# 7                  quality   2350
# 8                    sound   2317
# 9                      use   2169
# 10                   phone   2129
# 11                   nokia   2075
# 12                    case   2051
# 13                features   1939
# 14               bluetooth   1670
# 15            battery life   1624
# 16                     usb   1620
# 17                 samsung   1529
# 18                  volume   1519
# 19                   works   1516
# 20                 verizon   1392
# 21                    size   1282
# 22                shipping   1277
# 23                keyboard   1187
# 24                    treo   1056
# 25                cingular    961
# 26                 service    835
# 27                   jabra    765
# 28                  camera    744
# 29                    sony    701
# ..                     ...    ...
# 916               ear clip     10
# 917           sound system     10
# 918                  handy     10
# 919                 always     10
# 920             audio jack     10
# 921          new york city     10
# 922                   v60i     10
# 923                standby     10
# 924                     ge     10
# 925                  prius     10
# 926                   ymmv     10
# 927                 worked     10
# 928      extended warranty     10
# 929            video games     10
# 930              messenger     10
# 931                forever     10
# 932               ear buds     10
# 933         sounds quality     10
# 934        qwerty keyboard     10
# 935              energizer     10
# 936  plantronics bluetooth     10
# 937            jabra jx-10     10
# 938         phone features     10
# 939                  light     10
# 940                    car     10
# 941            alarm clock     10
# 942                    wav     10
# 943                  smell     10
# 944      resolution screen     10
# 945               tungsten     10
#
#                                              embedding  cluster
# 0    [0.0025718957, 0.071242034, -0.08696756, 0.011...       17
# 1    [0.035119545, -0.017936235, -0.038057335, 0.00...       20
# 2    [-0.03261149, -0.0027218256, 0.03191225, 0.098...       17
# 3    [-0.08989111, 0.045746423, -0.04043641, 0.0190...       17
# 4    [0.013252061, 0.018266795, -0.010041953, 0.034...       19
# 5    [-0.002593959, -0.003030438, 0.0010705708, 0.0...       17
# 6    [0.05261301, 0.053623445, 0.028286066, 0.06863...       17
# 7    [0.041569266, 0.017836045, 0.0021298677, 0.019...       17
# 8    [0.07356247, -0.026570885, 0.12274804, 0.11256...       17
# 9    [-0.0271657, 0.06062786, -0.06484954, 0.040234...       42
# 10   [0.07102983, 0.09355253, 0.100892246, 0.056122...       17
# 11   [0.06567579, -0.010771435, -0.08261301, -0.111...       20
# 12   [-0.059265822, 0.028125873, 0.13133758, 0.0921...       42
# 13   [0.025140334, -0.0055917692, -0.012356021, 0.0...       17
# 14   [0.041269727, 0.021860193, 0.03288254, 0.04725...       17
# 15   [-0.019641237, -0.00089959725, -0.011080701, 0...       19
# 16   [0.037043445, 0.104951024, 0.16893354, 0.13650...       11
# 17   [-0.02436286, -0.06004606, 0.0045943866, -0.02...       20
# 18   [0.013073435, 0.08596334, 0.022631407, 0.05755...       17
# 19   [-0.020681161, 0.043454114, 0.061430413, 0.038...       42
# 20   [-0.005708197, -0.034684714, -0.045131292, -0....       20
# 21   [0.07772068, 0.04544719, -0.050824, 0.05927849...       17
# 22   [-0.024753615, -0.0010057682, -0.031445257, 0....       17
# 23   [0.05128644, 0.0045179697, 0.03315417, 0.06846...       17
# 24   [0.09005844, -0.13140467, -0.12111449, 0.00811...        5
# 25   [0.09674171, -0.08432565, -0.01760591, 0.06410...       20
# 26   [-0.030742258, 0.031656675, -0.010755129, 0.03...       17
# 27   [-0.0007241769, -0.017589182, -0.0322842, 0.01...       20
# 28   [0.10729106, 0.034428485, 0.0974046, 0.0954753...       17
# 29   [-0.12022847, -0.14198287, -0.0025326286, 0.01...       20
# ..                                                 ...      ...
# 916  [0.030429168, 0.004865701, -0.0012406936, 0.12...       19
# 917  [0.010395834, 0.021464292, -0.009225022, 0.036...       19
# 918  [0.053747393, -0.019603472, -0.05178736, 0.082...       42
# 919  [0.038699646, 0.0014436899, 0.010590323, 0.115...       42
# 920  [-0.0014758105, 0.02152656, 0.0094296485, 0.09...       19
# 921  [-0.018754123, -0.021738777, 0.017073842, 0.03...       19
# 922  [0.07295813, -0.03936355, -0.027981665, -0.069...       19
# 923  [-0.057084456, 0.02241222, 0.02214296, 0.07119...       17
# 924  [0.09299887, -0.3412332, -0.24311717, -0.04689...       10
# 925  [-0.084240735, -0.11038187, 0.0008293241, 0.04...        7
# 926  [0.010380063, 0.069947146, -0.10398758, -0.080...       42
# 927  [0.013690911, 0.020517219, 0.04969846, 0.04750...       42
# 928  [-0.023590036, 0.012183009, -0.03076181, 0.010...       19
# 929  [0.0050588804, 0.0043719118, -0.019049801, 0.0...       19
# 930  [0.09802309, 0.06304766, 0.034883633, 0.029171...       17
# 931  [0.028768757, 0.023884952, 0.0018523255, 0.046...       42
# 932  [0.017416399, -0.02352195, 0.0031975135, 0.114...       19
# 933  [0.0037467007, -0.012291922, -0.01048139, 0.02...       19
# 934  [-0.03912683, 0.0049626185, 0.01266321, 0.0607...       19
# 935  [0.01309561, -0.03002376, -0.015779043, 0.0532...       17
# 936  [-0.011280573, 0.006898325, 0.009564103, 0.053...       19
# 937  [-0.009819637, 0.00034986975, -0.00297024, 0.0...       19
# 938  [0.00616716, -0.016424036, 0.009799941, 0.0187...       19
# 939  [-0.116084486, -0.016968077, 0.03961698, 0.089...       17
# 940  [0.13749835, 0.17365289, 0.015517365, 0.237601...        7
# 941  [0.0041586836, 0.015123393, 0.022693023, 0.052...       19
# 942  [0.45048952, -0.1348583, 0.15337768, 0.0657800...       46
# 943  [0.023477782, -0.016103238, 0.0962702, 0.05615...       17
# 944  [-0.0083194105, -0.0098570585, 0.00025114318, ...       19
# 945  [0.036188252, 1.8275741e-05, -0.052067455, 0.0...       17
#
# [946 rows x 4 columns]

# %%
manual_clusters = {
    1001: ['screen', 'monitor', 'lcd'],
    1002: ['phone', 'telephone', 'mobile phone'],
    1003: ['value', 'price', 'cost', 'expensive', 'cheap', 'money'],
    1004: ['volume', 'sound', 'voice', 
#            'echo' za daleko od innych
          ],
    1005: [],
    1006: ['bluetooth', 'usb', 'port', 'connection', 'wifi', 'network', 'signal range', 'signal'],
    1007: ['cpu', 'processor', 'processing power'],
    1008: ['memory', 'hard drive', 'hard disk', 'floppy disc', 'ssd drive', 'ram', 'rom', 'sd card', 'memory card', 'usb stick', 'pendrive'],
    1009: ['battery', 'charger', 'power', 'charging', 'power plug', 'power bank'],
    1010: ['technical documentation', 'support' ,'update']
}

# %%
manual_clusters_tuples = [
    (aspect, cluster_id)
    for cluster_id, aspects
    in manual_clusters.items()
    for aspect in aspects 
]

# %%
manual_clusters_df = pd.DataFrame(manual_clusters_tuples, columns=['aspect', 'cluster'])

# %%
manual_clusters_df['count'] = 1

# %%
manual_clusters_df['embedding'] = manual_clusters_df.aspect.apply(get_vectors)

# %%
aspects_with_manual = pd.concat([aspects_unique_filtered_df, manual_clusters_df], sort=False).reset_index(drop=True)

# %%
aspects_with_manual.sample(5)
# Out:
#             aspect  count                                          embedding  \
# 202          hinge     53  [-0.090258524, 0.03709165, 0.12392286, 0.11929...
# 189  virgin mobile     58  [-0.021190563, 0.019408423, -0.001742857, 0.05...
# 74              sd    186  [0.34264448, 0.07104431, 0.14408736, -0.105851...
# 197            usa     55  [0.14131713, -0.070365265, -0.068361, -0.07894...
# 217   connectivity     49  [-0.013129184, -0.008202838, 0.011541892, -0.0...
#
#      cluster
# 202       17
# 189       19
# 74        39
# 197        2
# 217       17

# %%
aspects_unique_filtered_df_tsne = draw_embeddings.get_tsne(aspects_with_manual)
aspects_unique_filtered_df_tsne.sample(5)
# Out:
#              x          y     intent    tooltip  cluster
# 641   7.516838  -7.501706    webtreo    webtreo       19
# 376  18.368053  24.937998    florida    florida        2
# 970  -5.018254   7.659589  processor  processor     1007
# 874 -11.643503 -38.819744    eargels    eargels       19
# 809  11.448671  27.094051     elliot     elliot        2

# %%
draw_embeddings.draw(aspects_unique_filtered_df_tsne)
# Out:
# <div>
#
#
#             <div id="4d97dacd-7bf6-4ea0-84a6-799e934aaa5b" class="plotly-graph-div" style="height:1500px; width:1500px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("4d97dacd-7bf6-4ea0-84a6-799e934aaa5b")) {
#                     Plotly.newPlot(
#                         '4d97dacd-7bf6-4ea0-84a6-799e934aaa5b',
#                         [{"marker": {"color": "rgb(253,174,97)", "size": 15, "symbol": 0}, "mode": "markers", "name": "0", "text": ["aaa", "mda", "dsp", "dlo", "ibm", "mmc", "pim", "rma", "pdf", "mhz"], "type": "scatter", "uid": "435b1581-3c81-4cb8-a7cb-bb362ed2f1fc", "x": [15.944655418395996, 3.5318641662597656, -17.261962890625, 9.911052703857422, 4.3225626945495605, 1.7797785997390747, 1.6166555881500244, -0.4928116202354431, 19.40635871887207, -5.7093119621276855], "y": [30.259212493896484, 38.888389587402344, 25.500732421875, 31.917688369750977, 29.354869842529297, 26.866073608398438, 36.1220817565918, 24.469646453857422, 17.57323455810547, 40.382530212402344]}, {"marker": {"color": "rgb(215,48,39)", "size": 15, "symbol": 0}, "mode": "markers", "name": "1", "text": ["us", "go", "on", "of"], "type": "scatter", "uid": "43e34968-bb21-4b12-8833-d1a0db5090a0", "x": [21.43687629699707, 25.872039794921875, -29.396032333374023, -28.0546817779541], "y": [2.109591484069824, -13.629578590393066, -14.341808319091797, -14.01921272277832]}, {"marker": {"color": "rgb(166,217,106)", "size": 15, "symbol": 0}, "mode": "markers", "name": "2", "text": ["china", "europe", "ebay", "buy", "california", "usa", "u.s.", "india", "japan", "asia", "wilson", "texas", "wal-mart", "florida", "walmart", "italy", "nyc", "chicago", "usps", "canada", "france", "mexico", "costco", "bestbuy", "kensington", "manhattan", "john", "london", "phillips", "korea", "england", "australia", "seattle", "cox", "borg", "philips", "centro", "joe", "germany", "j.d.", "turk", "america", "brazil", "hawaii", "spain", "ireland", "houston", "xmas", "atlanta", "asap", "jimi", "africa", "elliot", "mike", "compusa", "boston"], "type": "scatter", "uid": "67717da0-1cb3-4b14-b682-4a7ec683a8b1", "x": [18.27332305908203, 21.979816436767578, -25.934358596801758, 19.3692684173584, 18.26080894470215, 23.0617618560791, 21.287986755371094, 19.83832550048828, 23.04645347595215, 22.43960189819336, 10.82589340209961, 18.76555061340332, -2.2929255962371826, 18.368053436279297, -2.290191173553467, 23.36208152770996, 18.612598419189453, 16.910545349121094, -2.1290829181671143, 19.35843276977539, 21.739837646484375, 20.245588302612305, -2.526402473449707, -1.4971466064453125, 15.17741584777832, 15.711891174316406, 12.457894325256348, 16.518774032592773, 9.968117713928223, 23.174667358398438, 20.25450325012207, 18.85280990600586, 16.75642204284668, 11.504877090454102, 5.672179222106934, 9.508906364440918, -9.419567108154297, 13.131872177124023, 22.194618225097656, 11.77122688293457, 15.120758056640625, 20.72305679321289, 21.3659610748291, 17.75078010559082, 22.485572814941406, 19.77541732788086, 17.61502456665039, -0.8341819643974304, 17.330202102661133, 24.79889678955078, 10.001900672912598, 20.896198272705078, 11.448671340942383, 12.124552726745605, -1.3078862428665161, 15.983241081237793], "y": [21.738887786865234, 23.364778518676758, 21.393085479736328, -9.8595609664917, 24.183704376220703, 26.69375228881836, 25.918987274169922, 21.607797622680664, 22.266080856323242, 20.72201156616211, 25.447772979736328, 26.632474899291992, 21.446651458740234, 24.937997817993164, 21.049232482910156, 24.258249282836914, 28.66032600402832, 26.29949378967285, 18.819900512695312, 22.73406982421875, 24.008888244628906, 25.004230499267578, 20.510208129882812, 23.74399757385254, 23.968467712402344, 24.35710334777832, 25.507648468017578, 23.153064727783203, 27.24700927734375, 21.694992065429688, 23.534908294677734, 23.196439743041992, 25.59050178527832, 24.458602905273438, 19.870132446289062, 27.5683650970459, -14.60509967803955, 26.068523406982422, 23.296611785888672, 28.681978225708008, 27.61176872253418, 23.176496505737305, 22.30851936340332, 24.10361099243164, 24.75969696044922, 23.577350616455078, 26.59043312072754, 20.93811798095703, 26.729143142700195, -17.404172897338867, 25.958330154418945, 21.205242156982422, 27.094051361083984, 26.38496208190918, 23.872119903564453, 26.971052169799805]}, {"marker": {"color ...

# %%
import qgrid
qgrid_widget = qgrid.show_grid(aspects_unique_filtered_df_tsne, show_toolbar=True)

# %%
qgrid_widget
# Out:
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': True, 'defau…

# %%
2 -> sound
3 -> companies/products

# %%
aspects_unique_filtered_df_tsne.to_excel('../results/reviews_Cell_Phones_and_Accessories/aspects_per_edu_filtered_min_10_freq_clustered_spacy_en.xlsx')

# %%
aspects_unique_filtered_df_tsne[aspects_unique_filtered_df_tsne.cluster == 4]
# Out:
#              x          y                       intent  \
# 19  -16.618031  -8.395959                        works
# 30    0.983883   8.936417                     software
# 45  -25.705854  13.111171                       design
# 55   -9.545662  -9.006220                      support
# 59  -17.710215  31.984634                    interface
# 61  -28.507902  10.697180                       signal
# 63    3.422139  15.756899                       memory
# 68   -5.470905 -11.306073                      outlook
# 77   -5.529461   4.885927                 applications
# 82   -0.239239  12.443504                      install
# 89  -27.592661   3.108701                    reception
# 96   -9.634354  -8.148787                 tech support
# 97  -28.854853  19.508131                         menu
# 101 -11.999481 -18.982904                      program
# 117 -30.601892  16.041061                      operate
# 120 -10.647747  -7.166709                     hardware
# 123 -14.751036   8.124493                        built
# 128 -25.149134   0.945872                 construction
# 129 -12.005169 -18.980343                     programs
# 136  15.148778  23.250425                  radio shack
# 137 -13.065238  -4.507011                        drive
# 143 -26.897472  18.340015                        setup
# 147  -9.306968  -9.904614             customer support
# 149  -0.261500  12.449614                 installation
# 154 -29.135260  16.589128                       system
# 161 -21.935984  11.176597                     graphics
# 167 -13.260045  29.636208                        specs
# 173   4.704273  30.856035                headset works
# 178   7.438897  25.733747             verizon wireless
# 190 -17.725651  32.109535               user interface
# ..         ...        ...                          ...
# 679  -9.609338 -15.036681                  call center
# 693  -9.800172 -13.962778               service center
# 711  11.298935  -2.554614                        excel
# 712 -10.577779 -15.434584                       office
# 721   6.995852   2.359441                     explorer
# 737   5.444708  30.830322           speakerphone works
# 777  -9.283878   8.975702                dialing works
# 779   4.199035  32.553535                    mic works
# 783 -18.255823 -23.697170                         free
# 789   6.197408  26.760031                         wifi
# 799 -14.790824  -8.908309                   item works
# 809   8.317228  -3.559988                     defender
# 812 -25.209902  21.389313                     settings
# 827   4.237097  32.410019             microphone works
# 831   2.680944   3.877486  the logitech mobile freedom
# 849  -7.810040 -30.305553                    organizer
# 852  -5.526169   4.890624                  application
# 855 -13.723158  24.303093                        usage
# 860 -23.154699  19.551929                         data
# 863 -21.536949   3.099540                   components
# 866  -5.028285 -27.615627                      standby
# 880 -38.213211  20.695015                        alarm
# 882  -3.571025  19.763094                          car
# 895  11.232981  -2.774201                   powerpoint
# 902 -17.364408  -9.294392                       worked
# 915 -38.213120  20.692816                  alarm clock
# 923 -26.939152 -10.534090                        handy
# 937   6.682444 -31.837769                new york city
# 940  -8.265819   8.121046               text messaging
# 945   4.457280  29.930855              bluetooth works
#
#                          tooltip  cluster
# 19                         works        4
# 30                      software        4
# 45                        design        4
# 55                       support        4
# 59                     interface        4
# 61                        signal        4
# 63                        memory        4
# 68                       outlook        4
# 77                  applications        4
# 82                       install        4
# 89                     reception        4
# 96                  tech support        4
# 97                          menu        4
# 101                      program        4
# 117                      operate        4
# 120                     hardware        4
# 123                        built        4
# 128                 construction        4
# 129                     programs        4
# 136                  radio shack        4
# 137                        drive        4
# 143                        setup        4
# 147             customer support        4
# 149                 installation        4
# 154                       system        4
# 161                     graphics        4
# 167                        specs        4
# 173                headset works        4
# 178             verizon wireless        4
# 190               user interface        4
# ..                           ...      ...
# 679                  call center        4
# 693               service center        4
# 711                        excel        4
# 712                       office        4
# 721                     explorer        4
# 737           speakerphone works        4
# 777                dialing works        4
# 779                    mic works        4
# 783                         free        4
# 789                         wifi        4
# 799                   item works        4
# 809                     defender        4
# 812                     settings        4
# 827             microphone works        4
# 831  the logitech mobile freedom        4
# 849                    organizer        4
# 852                  application        4
# 855                        usage        4
# 860                         data        4
# 863                   components        4
# 866                      standby        4
# 880                        alarm        4
# 882                          car        4
# 895                   powerpoint        4
# 902                       worked        4
# 915                  alarm clock        4
# 923                        handy        4
# 937                new york city        4
# 940               text messaging        4
# 945              bluetooth works        4
#
# [109 rows x 5 columns]

# %% [markdown]
# # Get aspects from SemEval - annotated

# %%
from aspects.analysis import statistics_dataset

# %%
aspects = statistics_dataset.get_aspects()
# Out:
# Corpus iterator: 49475it [00:00, 356789.73it/s]
# Corpus iterator: 53781it [00:00, 229197.01it/s]
# Corpus iterator: 12470it [00:00, 543995.29it/s]
# Corpus iterator: 13257it [00:00, 403704.88it/s]

# %%
# aspects
# Out:
# {'Restaurants_poria-train': ['staff',
#   'food',
#   'food',
#   'kitchen',
#   'menu',
#   'food',
#   'perks',
#   'orrechiete with sausage and chicken',
#   'waiters',
#   'dish',
#   'meats',
#   'bagels',
#   'food',
#   'mayonnaise',
#   'toast',
#   'ingredients',
#   'cheese',
#   'omelet',
#   'bacon',
#   'plate',
#   'check',
#   'drinks',
#   'design',
#   'atmosphere',
#   'cuisine',
#   'pizza',
#   'thin crusted pizza',
#   'interior decoration',
#   'chefs',
#   'seats',
#   'seltzer with lime',
#   'pickles and',
#   'selection of meats and seafoods',
#   'eat family style',
#   'dishes',
#   'vibe',
#   'owner',
#   'service',
#   'delivery',
#   'food',
#   'atmosphere',
#   'service',
#   'food',
#   'prices',
#   'interior decor',
#   'prices',
#   'wine',
#   'price',
#   'service',
#   'quantity',
#   'sushi',
#   'sushi bar',
#   'fried rice',
#   'courses',
#   'mussels',
#   'puff pastry goat cheese',
#   'salad with a delicious dressing',
#   'a hanger steak au poivre',
#   'indian food',
#   'place',
#   'service',
#   'with',
#   'broth with noodles',
#   'meal',
#   'money',
#   'food',
#   'wine list',
#   'thai',
#   'thai food',
#   'glass of wine',
#   'specials',
#   'dine',
#   'lunch',
#   'dinner',
#   'atmosphere',
#   'service',
#   'desert',
#   'bar',
#   'table',
#   'dinner',
#   'service',
#   'food',
#   'atmosphere',
#   'environment',
#   'lasagnette appetizer',
#   'beer selection',
#   'food',
#   'menu',
#   'service',
#   'setting',
#   'dinner',
#   'dining',
#   'dosa',
#   'wine list selection',
#   'wine-by-the-glass',
#   'menu',
#   'menu',
#   'entrees',
#   'menu',
#   'dishes',
#   'sake martini',
#   'bagels',
#   'spreads',
#   'service',
#   'table',
#   'food',
#   'meal',
#   'ingredients',
#   'chopsticks',
#   'garden terrace',
#   'pizza',
#   'cuisine',
#   'atmosphere',
#   'crowded',
#   'service',
#   'dish',
#   'atmosphere',
#   'service',
#   'food',
#   'grilled branzino',
#   'wait staff',
#   'food',
#   'packed',
#   'vibe',
#   'french food',
#   'place',
#   'pizza',
#   'pre-theater menu',
#   'delivery',
#   'order',
#   'server',
#   'meal',
#   'scents',
#   'lobster sandwich',
#   'check',
#   'spider roll',
#   'shell crab',
#   'price',
#   'deep fried skewers',
#   'reservations',
#   'hostess',
#   'rice dishes',
#   'congee ( rice porridge )',
#   'tuna tartar appetizer',
#   'food',
#   'cuisine',
#   'fish dishes',
#   'soups',
#   'wine',
#   'cheese',
#   'french fare',
#   'indian food',
#   'baby pizzas',
#   'waiting',
#   'lava cake dessert',
#   'baby pizzas',
#   'service',
#   'food',
#   'managers',
#   'food',
#   'food',
#   'table',
#   'selection of wines',
#   'italian decor',
#   'food',
#   'dining experience',
#   'wine selection',
#   'reservation',
#   'service',
#   'reservation',
#   'maitre',
#   'panang duck',
#   'food',
#   'raw vegatables',
#   'service',
#   'indian',
#   'prices',
#   'ambiance',
#   'bbq salmon',
#   'sea bass',
#   'crispy duck',
#   'ingredients',
#   'ingredients',
#   'pizza',
#   'crust',
#   'dal bukhara',
#   'kababs',
#   'eating',
#   'taste',
#   'meal',
#   'price',
#   'glass of leaping lizard',
#   'glass of prosecco',
#   'mussels',
#   'food',
#   'creme brulee',
#   'sugar',
#   'food',
#   'served',
#   'pizza',
#   'pizza',
#   'garlic knots',
#   'delivery',
#   'chinese food',
#   'service',
#   'food',
#   'chef',
#   'service',
#   'teapot',
#   'pizza',
#   'fresh mozzarella',
#   'cheese',
#   'place',
#   'food',
#   'service',
#   'a',
#   'getting a table',
#   'atmosphere',
#   'bistro-type vibe',
#   'waitress',
#   'tables',
#   'food',
#   'prices',
#   'food',
#   'fish',
#   'variety of fish',
#   'of',
#   'meal',
#   'pesto pizza',
#   'house salad',
#   'bottle of wine',
#   'beverage manager',
#   'bartender',
#   'ambiance',
#   'music',
#   'food',
#   'drinks',
#   'service',
#   'food',
#   'refleshment',
#   'ambiance',
#   'service',
#   'sommlier',
#   'captain',
#   'back waiters',
#   'foods',
#   'tastes',
#   'waitress',
#   'tandoori salmon',
#   'atmosphere',
#   'space',
#   'service',
#   'atmorphere',
#   'service',
#   'menu items',
#   'three course meal',
#   'pizza',
#   'environment',
#   'food',
#   'service',
#   'crawfish boiled',
#   'reservation',
#   'table',
#   'pad thai',
#   'noodles',
#   'delivered',
#   'values for your money',
#   'lunch',
#   'hostess',
#   'food',
#   'wait building',
#   'corridor',
#   'space',
#   'counters',
#   'counter',
#   'entrees',
#   'food',
#   'steaks',
#   'salads',
#   'sides',
#   'lunch',
#   'pickels and slaw',
#   'wine',
#   'prices',
#   'delivered',
#   'the wine by the glass',
#   'price',
#   'dish',
#   'change mojito',
#   'service',
#   'food',
#   'service',
#   'food',
#   'soup for the udon',
#   'soy sauce',
#   'water',
#   'anti-pasta',
#   'calamari',
#   'filling pasta mains',
#   'waitress',
#   'glasses of wine',
#   'food',
#   'counter',
#   'food',
#   'sushi',
#   'ceviche mix ( special )',
#   'crab dumplings',
#   'assorted sashimi',
#   'sushi',
#   'rolls',
#   'sake',
#   'banana tempura',
#   'plain pizza',
#   'garlic',
#   'eggplant',
#   'servers',
#   'servers',
#   'getting a table',
#   'service',
#   'takeout menu',
#   'menu',
#   'italian dishes',
#   'thai food',
#   'hostess',
#   'pizza',
#   'bottles of wine',
#   'beers',
#   'food',
#   'dish',
#   'pumkin tortelini',
#   'dinner special',
#   'crabmeat lasagna',
#   'chocolate bread pudding',
#   'dessert',
#   'pasta dishes',
#   'tiramisu',
#   'service',
#   'prices',
#   'lunch',
#   'service',
#   'staff',
#   'menu',
#   'meal',
#   'bagel',
#   'food',
#   'servers',
#   'food',
#   'plate of dumplings',
#   'filet mignon',
#   'bar',
#   'sangria',
#   'bar',
#   'bartender',
#   'sake menu',
#   'drinks',
#   'beef cubes',
#   'service',
#   'wine selection',
#   'ambiance',
#   'reservations',
#   'service',
#   'service',
#   'waiters',
#   'food',
#   'portions',
#   'dessert',
#   'traffic noise',
#   'food',
#   'food',
#   'ambience',
#   'service',
#   'dinner meeting',
#   'atmosphere',
#   'food',
#   'cantonese',
#   'cooking',
#   'food',
#   'atmosphere',
#   'prix fixe menu',
#   'quantity',
#   'quality',
#   'lunch',
#   'eggs benedict',
#   'brunch',
#   'hollondaise sauce',
#   'oatmeal',
#   'food',
#   'menu',
#   'chilean sea bass',
#   'server',
#   'specials',
#   'food',
#   'onion soup',
#   'wine',
#   'staff',
#   'dinner',
#   'dim sum',
#   'roll',
#   'roll',
#   'roll',
#   'rice',
#   'gin and tonic',
#   'tonic',
#   'dim sum',
#   'little dishes',
#   'service',
#   'thai',
#   'reservation',
#   'grilled chicken special with edamame puree',
#   'roast duck',
#   'pork',
#   'chicken on rice with ginger',
#   'menu',
#   'staff',
#   'reservation',
#   'dinner',
#   'sake',
#   'portion',
#   'dishes',
#   'food',
#   'service',
#   'roti rolls',
#   'ingredients',
#   'meal',
#   'tip',
#   'food',
#   'service',
#   'meat',
#   'hot dogs',
#   'delivery',
#   'noise level',
#   'personal pans',
#   'spicy fried clam rolls',
#   'spider rolls',
#   'menu',
#   'atmosphere',
#   'place',
#   'food',
#   'lunch',
#   'food quality',
#   'man',
#   'table',
#   'table',
#   'cheesecake',
#   'food',
#   'manager',
#   'employees for',
#   'containers for condiments',
#   'containers',
#   'indian food',
#   'service',
#   'decor',
#   'food',
#   'wine list',
#   'food',
#   'salmon dish',
#   'price',
#   'flavor',
#   'tuna melt',
#   'cheese',
#   'tuna sandwich',
#   'chicken tikka',
#   'naan',
#   'dals',
#   'waiters',
#   'bill',
#   'lawns',
#   'staff',
#   'sangria',
#   'thai food',
#   'food',
#   'service',
#   'ravioli',
#   'menu',
#   'service',
#   'bill',
#   'lunch',
#   'drinks',
#   'sushi',
#   'food',
#   'service',
#   'price tag',
#   'thai food',
#   'appetizers',
#   'service',
#   'mozzarella',
#   'pie',
#   'fish',
#   'main dining room',
#   'ceiling',
#   'menu selections',
#   'service',
#   'music',
#   'establishment',
#   'dim sum',
#   'food',
#   'wait staff',
#   'dim sum',
#   'service',
#   'seafood dishes',
#   'appetizers',
#   'lunch',
#   'dinner',
#   'grapes',
#   'bottle of wine',
#   'prices',
#   'thai food',
#   'dish',
#   'staples',
#   'burger',
#   'pastas',
#   'food',
#   'dim sum',
#   'food',
#   'waitress',
#   'place',
#   'seating',
#   'bar',
#   'dinner',
#   'music',
#   'food',
#   'service',
#   'prices',
#   'wait',
#   'lobster sandwich',
#   'price',
#   'owner',
#   'sides',
#   'seafood',
#   'menu',
#   'salmon',
#   'place',
#   'beverages',
#   'dessert',
#   'hostess',
#   'waitress',
#   'asian appetizers',
#   'drinks',
#   'wait',
#   'view',
#   'meal',
#   'dinner',
#   'ambiance',
#   'food',
#   'service',
#   'prices',
#   'atmosphere',
#   'value',
#   'sushi',
#   'service',
#   'served',
#   'service',
#   'service',
#   'attitude',
#   'food',
#   'striped bass',
#   'music',
#   'corriander',
#   'black white shakes',
#   'meal',
#   'dinner',
#   'seating',
#   'chu chu curry',
#   'pad thai chicken',
#   'prix fixe',
#   'food',
#   'pastrami',
#   'soups',
#   'bagels',
#   'sushi',
#   'bagel with lox spread',
#   'bagles',
#   'food',
#   'quality of food',
#   'lobby area',
#   'seated',
#   'pizza',
#   'proprietor',
#   'lunch meetings',
#   'decor',
#   "food's presentation",
#   'prices',
#   'waitstaff',
#   'swordfish',
#   'meal',
#   'setting',
#   'management',
#   'service',
#   'seating',
#   'delivery',
#   'sushi',
#   'desserts',
#   'italian food',
#   'service',
#   'food',
#   'salmon dish',
#   'rolls',
#   'food',
#   'decor',
#   'prices',
#   'owner',
#   'lunch',
#   'dinner',
#   'moules',
#   'lobster ravioli',
#   'eat',
#   'dosa',
#   'atmosphere',
#   'waiters',
#   'seafood',
#   'wine list',
#   'menu',
#   'wine',
#   'indian',
#   'wine list',
#   'wines',
#   'pastrami or corned beef',
#   'rye bread',
#   'glasses of champagne',
#   'bottle of wine',
#   'after dinner drinks',
#   'seasoning',
#   'food',
#   'food',
#   'waitress',
#   'food',
#   'ambience',
#   'service',
#   'wine list',
#   'staff',
#   'owners',
#   'menu',
#   'people',
#   'menu',
#   'waiter',
#   'specials',
#   'main dishes',
#   'location',
#   'ambience',
#   'food',
#   'stuff',
#   'eats',
#   'dinner',
#   'gourmet food',
#   'bruschetta',
#   'dishes',
#   'menu',
#   'service',
#   'waitress',
#   'and',
#   'and',
#   'the fried mini buns with the condensed milk and the assorted fruits on beancurd',
#   'food',
#   'prices',
#   'food',
#   'sushi',
#   'portions',
#   'servers',
#   'starter',
#   'bagels',
#   'food',
#   'pizza',
#   'take-out pizza',
#   'server',
#   'green curry with vegetables',
#   'place',
#   'door',
#   'priced',
#   'food',
#   'portioins',
#   'reservation',
#   'pad thai',
#   'lunch specials',
#   'place',
#   'pizzas',
#   'food',
#   'pot-stickers',
#   'tempura dish',
#   'stuff',
#   'entree range',
#   'food',
#   'range',
#   'atmosphere',
#   'french food',
#   'deliveries',
#   'food',
#   'staff',
#   'portions',
#   'staff',
#   'smoked salmon and roe appetizer and',
#   'lunch',
#   'food',
#   'garlic shrimp',
#   'okra ( bindi )',
#   'lamb',
#   'waiter',
#   'menu',
#   'burger',
#   'steak',
#   'escargot',
#   'plate',
#   'food',
#   'casual dinner',
#   'food',
#   'price',
#   'wine list',
#   'prices',
#   'chicken tikka marsala',
#   'styles of pizza',
#   'look',
#   'food',
#   'portions',
#   'coconut rice',
#   'appetizer',
#   'food',
#   'food',
#   'beers on tap',
#   'priced wine list',
#   'music',
#   'bottle minimun',
#   'food',
#   'spot',
#   'staff',
#   'meal',
#   'table',
#   'quality of food',
#   'price',
#   'pork',
#   'fish',
#   'chicken',
#   'lamb',
#   'vegetables',
#   'place',
#   'seating',
#   'appetizing',
#   'price',
#   'bun',
#   'food',
#   'priced',
#   'fusion of french and indian cooking',
#   'turnip cake',
#   'roast pork buns',
#   'egg custards',
#   'bagels',
#   'the',
#   'seating in the garden',
#   'the seats',
#   'water',
#   'service',
#   'place',
#   'food',
#   'place',
#   'food options',
#   'cost',
#   'pre-theatre 3 - course dinner',
#   'wine flight',
#   'lunch',
#   'dinner',
#   'calzones',
#   'drink',
#   'place',
#   'bar scene',
#   'staff',
#   'spreads',
#   'beverage selections',
#   'bagels',
#   'waiter',
#   'served',
#   'specials',
#   'meal',
#   'tiramisu',
#   'secret back room',
#   'bar',
#   'food',
#   'service',
#   'gulab jamun',
#   'prices',
#   'atmosphere',
#   'service',
#   'wine list',
#   'diner',
#   'table',
#   'wait staff',
#   'meal',
#   'room',
#   'dinner',
#   'desserts',
#   'in',
#   'in',
#   'desserts with frog jelly in',
#   'pig feet ginger simmered in black vinegar',
#   'food',
#   'priced',
#   'thai cuisine',
#   'host',
#   'crew',
#   'round tables',
#   'taiwanese',
#   'portion',
#   'french fries',
#   'dinner',
#   'food',
#   'specials',
#   'regular menu-fare',
#   'dishes',
#   'prices',
#   'fresh tomato sauce',
#   'fresh mozz cheese',
#   'basil',
#   'dough',
#   'flour',
#   'food',
#   'indian food',
#   'paneer roll',
#   'food',
#   'plates',
#   'fresh mozzerella slices',
#   'plain cheese slice',
#   'food',
#   'food',
#   'food',
#   'filet mignon with garlic mash',
#   'pre-theater menu',
#   'roasted tomato soup with chevre',
#   'steak frites',
#   'creme brulee',
#   'waitstaff',
#   'bread',
#   'and',
#   'pizza',
#   'and',
#   "peter's favourite pizza with prosciutto and baby arugula",
#   'margarite pizza with cold prosciutto and baby arugula on top',
#   'salad',
#   'prices',
#   'bruschettas',
#   'paninis',
#   'tramezzinis',
#   'waiters',
#   'diners',
#   'chef',
#   'cuisine',
#   'dishes',
#   'indian',
#   'owner',
#   'food',
#   'meal',
#   'pre-theater prix-fixe',
#   'dining',
#   'food',
#   'wine',
#   'menu',
#   'fried chicken',
#   'pork chop',
#   'noodle dishes',
#   'indian food',
#   'place',
#   'corner booth table',
#   'privacy',
#   'open faced cheese sandwich',
#   'manager',
#   'breads',
#   'naan',
#   'half-price saturday night option',
#   'squid',
#   'pizza',
#   'homemade pasta',
#   'value ofr money',
#   'soup',
#   'mushrooms',
#   'service',
#   'waiting',
#   'beginning appetizers',
#   'scallops',
#   'chocolate souffle with rasberry mint sorbet',
#   'taste',
#   'japanese tapas',
#   'fish',
#   'rice',
#   'seaweed',
#   'dishes',
#   'lamb sausages',
#   'sardines with biscuits',
#   'large whole shrimp',
#   'pistachio ice cream',
#   'food',
#   'price',
#   'ambiance',
#   'atmosphere',
#   'food',
#   'service',
#   'server',
#   'served',
#   'food',
#   'drinks',
#   'food',
#   'sushi',
#   'thai food',
#   'chef',
#   'table',
#   'service',
#   'sauce on the pizza',
#   'garlic',
#   'fresh tomatoes',
#   'outdoor seating',
#   'mesclun',
#   'salmon',
#   'ice cream',
#   'courses',
#   'wait',
#   'food',
#   'place',
#   'staff',
#   'bistro fare',
#   'jazz brunch',
#   'live jazz',
#   'chilaquiles',
#   'prices',
#   'bill',
#   'measures of liquers',
#   'of',
#   'table service',
#   'service',
#   'thai food',
#   'food',
#   'pork belly',
#   'fat',
#   'food',
#   'tables',
#   'place',
#   'dinner',
#   'pizza',
#   'bar',
#   'service',
#   'lamb chop',
#   'salads',
#   'lemon',
#   'extra virgnin olive oil',
#   'sushi',
#   'meal',
#   'cost',
#   'dishes',
#   'pastrami sandwich',
#   'pickles',
#   'beer',
#   'plain pizza',
#   'wild mushroom ( third generation-fornini ) pizza',
#   'truffle oil',
#   '(',
#   ')',
#   'omelletes',
#   'tip',
#   'lunch',
#   'dinner',
#   'counter',
#   'sushi fix',
#   'fish',
#   'service',
#   'waitress',
#   'table',
#   'reservation sigh',
#   'food',
#   'place',
#   'menu',
#   'food art',
#   'outdoor atmosphere',
#   'toppings',
#   'pizza',
#   'service',
#   'food',
#   'price',
#   'thai food',
#   'bagels',
#   'bills',
#   'scallion pancakes',
#   'fried dumplings',
#   'appetizers',
#   'salads',
#   'steak',
#   'pasta',
#   'table',
#   'served dishes',
#   'table',
#   'served',
#   'bill',
#   'service',
#   'food',
#   'dumpling',
#   'fondue appetizer',
#   'spice',
#   'octopus salad',
#   'msg cooking',
#   'foods',
#   'tom kha soup',
#   'bombay beer',
#   'decor',
#   'semi-private boths',
#   'dining hall',
#   'service',
#   'service',
#   ...],
#  'Laptops_poria-train': ['cord',
#   'battery life',
#   'tech guy',
#   'service center',
#   '" sales " team',
#   'quality',
#   'gui',
#   'applications',
#   'use',
#   'start up',
#   'features',
#   'ichat',
#   'photobooth',
#   'garage band',
#   'features',
#   'gui',
#   'screen',
#   'power light',
#   'hard drive light',
#   'battery',
#   'rubber enclosure',
#   'edge',
#   'multi-touch gestures',
#   'tracking area',
#   'external mouse',
#   'gaming',
#   'suite of software',
#   'speed',
#   'windows 7',
#   'usb devices',
#   'keyboard',
#   'software',
#   'system',
#   'microsoft office for the mac',
#   'syncing',
#   '30 " hd monitor',
#   'screen',
#   'boot up',
#   'service',
#   'battery',
#   'operating system',
#   'preloaded software',
#   'price',
#   'features',
#   'clock in bios setup',
#   'warranty service',
#   'brand',
#   'warranty',
#   'features',
#   'fan',
#   'customer service number',
#   'warranty',
#   'talking to a technician',
#   'hard disc',
#   'windows',
#   'drivers',
#   'drivers',
#   'bios update',
#   'system',
#   'hp technical support',
#   'browser',
#   'keyboard',
#   'virus scan',
#   '9 punds',
#   'program',
#   'warrenty',
#   'toshiba',
#   'toshiba warranty',
#   'quality',
#   'webcam',
#   'value',
#   'internet',
#   'managing personal files',
#   'motherboard',
#   'system',
#   'charger',
#   'hardware',
#   'force quit',
#   'works',
#   'windows 7',
#   'vmware program',
#   'navigate',
#   'operating system',
#   'find files',
#   'runs',
#   'warrenty',
#   'extended warranty',
#   'memory',
#   'performace',
#   'speed',
#   'opening my documents folder',
#   'operating systems',
#   'charger',
#   'speed',
#   'glass touchpad',
#   'hard drive',
#   'mother board',
#   'external speaker',
#   'sound',
#   'battery life',
#   'hardware',
#   'shipping',
#   'use',
#   'mac software',
#   'microsoft software',
#   'editing',
#   'delete key',
#   'use',
#   'service',
#   'phone assistance',
#   'genius bar',
#   'battery life',
#   'web browsing',
#   'word editing',
#   'gaming',
#   'movie playing',
#   'battery life',
#   'recovery discs',
#   'office max\'s " max assurance "',
#   '"',
#   '"',
#   'imac backup disc',
#   'usb',
#   'battery life',
#   'battery timer',
#   'temperatures',
#   'core processing unit temperatures',
#   'service',
#   'virus protection for mac',
#   'bluetooth',
#   'lg notebook service center',
#   'hinge',
#   'games',
#   'responds',
#   'motherboard',
#   'motherboard',
#   'hardware',
#   'motherboard',
#   'use',
#   'representive at microsoft',
#   'system',
#   'xp',
#   'windows 7',
#   'vista',
#   'keyboard',
#   "dell's customer disservice",
#   'cooling system',
#   'use',
#   'quad core i7',
#   'sales associate',
#   'system',
#   'windows applications',
#   'virus program',
#   'weighed',
#   'seven pounds',
#   'battery',
#   'bag',
#   'color',
#   'keys',
#   'designed',
#   'style',
#   'speed',
#   'keyboard',
#   'mousepad',
#   'battery',
#   'sales',
#   'service',
#   'dell',
#   'dell support',
#   'hard drive',
#   'motherboard',
#   'cost',
#   'speed',
#   'construction quality',
#   'longevity',
#   'keyboard',
#   'keyboard',
#   'keys',
#   'configuration of " extra key "',
#   'touch pad',
#   'use',
#   'security',
#   'pricetag',
#   'use',
#   'work',
#   'preloaded software',
#   'webcam',
#   'vga port',
#   'screen',
#   'battery life',
#   'keys',
#   'software',
#   'volume',
#   'mouse',
#   'touchpad',
#   'boots up',
#   'hard drive',
#   'look and feel standpoint',
#   'safari',
#   'safari',
#   'mozzilla firfox',
#   'bluetooth',
#   'fingerprint reader driver',
#   'software',
#   'battery',
#   'speed',
#   'display',
#   'delivery',
#   'battery life',
#   'performance',
#   'memory',
#   'applications',
#   'microsoft office',
#   'resolution',
#   'appearance',
#   'cooling system',
#   'graphics card',
#   'built-in webcam',
#   'built-in mic',
#   'cam',
#   'mic',
#   'windows vista',
#   'board',
#   'connector',
#   'power supply',
#   'warrenty',
#   'power supply',
#   'works',
#   'ethernet',
#   'drag and drop feature',
#   'webcam',
#   'sales tax',
#   'software packages',
#   'iwork',
#   'garageband',
#   'imovie',
#   'screen',
#   'colors',
#   'resolution',
#   'monitor',
#   'itunes',
#   'size',
#   'external monitor',
#   'base installation',
#   'software',
#   'manuf',
#   'camera',
#   'display',
#   'amd turin processor',
#   'intel',
#   'warranty',
#   'start menu',
#   'navigate',
#   'bluray read / write drive',
#   'service tech',
#   'tech store',
#   'surface',
#   'screen',
#   'keyboard',
#   'ilife',
#   'snow leopard x',
#   'price tag',
#   'mac os',
#   'output',
#   'sound output quality',
#   'techie',
#   'use',
#   'toshiba online help',
#   'service life',
#   'ports',
#   'processor',
#   'price',
#   'look',
#   'keyboard',
#   'keys',
#   'screen',
#   'quality',
#   'stock screen',
#   'gray color',
#   'volume buttons',
#   'processor',
#   'computing',
#   'protector',
#   'key pad',
#   'magnetic plug-in power charging power cord',
#   'xp',
#   'vista',
#   'use',
#   'graphics',
#   'mac os',
#   'use',
#   'support',
#   'geek squad',
#   'graphics quality',
#   'appleworks',
#   'browser',
#   'paint',
#   'keyboard',
#   'service department',
#   'warrenty',
#   'warrentys',
#   'hard disk',
#   'running',
#   'cd drive',
#   'screen size',
#   'web browsing',
#   'software',
#   'loads',
#   'trackpad',
#   'external mouse',
#   'trackpad',
#   'games',
#   'games',
#   'features',
#   'human interface',
#   'software',
#   'inbuilt applications',
#   'body',
#   'i5',
#   'antivirus software',
#   'firewall',
#   'price',
#   'apple team',
#   'vista',
#   'vista',
#   'vista',
#   'operating system',
#   'video chat',
#   'quality',
#   'mouse',
#   'fan',
#   'cooling pad',
#   'feature',
#   'software',
#   'installation time',
#   'power',
#   'storage',
#   'abilitiy',
#   'feature',
#   'spotlight search',
#   'search',
#   'wireless system',
#   'windows 7',
#   'quality',
#   'battery life',
#   'speed',
#   'os',
#   'os',
#   'itunes',
#   'program',
#   'gaming',
#   'battery',
#   'apple support',
#   'techs',
#   'adding the bluetooth',
#   'graphic power',
#   'adobe creative apps',
#   'programs',
#   'use',
#   'materials',
#   'software',
#   'tech support',
#   'power supply',
#   'power supply',
#   'size',
#   'warranty',
#   'windows xp sp2',
#   'windows 7 ultimate',
#   'bluetooth',
#   'fingerprint reader',
#   'software',
#   'techs at hp',
#   'video card',
#   'graphics',
#   'security',
#   'audio',
#   'keyboard',
#   'runs',
#   'set up',
#   'screen',
#   'word processing',
#   'internet',
#   'trackpad',
#   'battery life',
#   'spec',
#   'dvd burner',
#   'hd',
#   'graphics chip',
#   'components',
#   'usb ports',
#   'software',
#   'system',
#   'ran',
#   'price',
#   'operation',
#   'brand',
#   'components',
#   'ground loop isolator',
#   'quality',
#   'price range',
#   'warranty',
#   'leading edge',
#   'bloatware',
#   'maximum sound',
#   'windows 7',
#   'bootcamp',
#   'price',
#   'works',
#   'action pack games',
#   'price',
#   'performance',
#   'twin packing',
#   'functions',
#   'look',
#   'after sales support',
#   'display screen',
#   'acer arcade',
#   'customer support',
#   'screen',
#   'cd drive',
#   'runs',
#   'design',
#   'size',
#   'games',
#   'games',
#   'life',
#   'warranty',
#   'pad',
#   'value',
#   'price',
#   'linux based os',
#   'system performance',
#   'use',
#   'batteries',
#   'shipping carton',
#   'use',
#   'program',
#   'virus protection',
#   'screen',
#   'processor',
#   'osx 16',
#   'graphics',
#   'hardware',
#   'software',
#   'intel core processors',
#   'hdmi port',
#   'internet explorer',
#   'staff',
#   'price premium',
#   'features',
#   'product and help aftermarket',
#   'microsoft word',
#   'usb ports',
#   'sd memory card reader',
#   'sd memory car expansion',
#   'lacie 2big external drive',
#   'firewire 800 interface',
#   'time machine',
#   'sound',
#   'extra features',
#   'windows 7 home premium',
#   'boot',
#   'acer screen',
#   'usb port',
#   'battery life',
#   'fires up',
#   'keyboard',
#   'software',
#   'online tutorial videos',
#   'image',
#   'soud',
#   'windows',
#   'boot up',
#   'shut down',
#   'windows',
#   'use',
#   'mac os',
#   'cost',
#   'windows 7 starter',
#   'windows 7 home premium',
#   'windows 7 professional',
#   'specifications',
#   'power cords',
#   'multi-touch features',
#   'screen',
#   'clicking buttons',
#   'battery life',
#   'windows',
#   'wired lan',
#   'hard reboot',
#   'hardware',
#   'hard drive',
#   'battery life',
#   'apple care',
#   'features',
#   'font',
#   'programs',
#   'run',
#   'plastic pieces',
#   '2gb ram stick',
#   'windows',
#   'microsoft word for mac',
#   'warranty company',
#   'cusromer service center',
#   'size',
#   'weight',
#   'battery',
#   'aluminum body',
#   'playing',
#   'watching movies',
#   'build quality',
#   'performance',
#   'dock',
#   'program',
#   'program',
#   'working',
#   'costing',
#   'i7',
#   'price',
#   'monitor',
#   'extended warranty',
#   'boots up',
#   'runs',
#   'screen',
#   'driver',
#   'tech support',
#   'work',
#   'hard drive',
#   'twin packing',
#   'functions',
#   'warranty',
#   'performance',
#   'price',
#   'bios',
#   'design',
#   'tech issues',
#   'size',
#   'space',
#   'service',
#   'priced',
#   'memory',
#   'speed',
#   'internet speed',
#   'programs',
#   'school or office use',
#   'pages',
#   'numbers',
#   'keynote',
#   'music',
#   'garageband',
#   'photo management',
#   'photo booth',
#   'iphoto',
#   'video-editing or movie-making',
#   'imovie',
#   'screen',
#   'colors',
#   'value',
#   'price',
#   'value',
#   "burn cd's",
#   'web cam',
#   '17 inch screen',
#   'support',
#   'bluetooth',
#   'launch manager',
#   'drivers / applications dvd',
#   'glass screen',
#   'switchable graphic card',
#   'gaming',
#   'service',
#   'battery life',
#   'technical support',
#   'boot mgr',
#   'recovery cd',
#   'price',
#   'features',
#   'skype',
#   'mouse buttons',
#   'hdd',
#   'rails',
#   'hard drive',
#   'quality',
#   'staff',
#   'games',
#   'garageband',
#   'warranty',
#   'hard drive',
#   'price',
#   'home use',
#   'business use',
#   'virus protection',
#   'updates',
#   'ms office apps',
#   'games',
#   'feature',
#   'windows',
#   'battery life',
#   'battery life',
#   'price',
#   'nortons virus scan',
#   'frame',
#   'features',
#   'use',
#   'loaded',
#   'windows',
#   'windows 7',
#   'vista',
#   'vista',
#   'windows xp',
#   'vista',
#   'key broad',
#   'warranty',
#   'repair " depot "',
#   'school use',
#   'design',
#   'battery life',
#   'programs',
#   'wireless',
#   'battery life',
#   'programs',
#   'trackpad',
#   'navigating',
#   'programs',
#   'speakers',
#   'subwoofer',
#   'built in camera',
#   'price',
#   'warranty',
#   'left mouse key',
#   'costed',
#   'speed',
#   'hard drive space',
#   'picture',
#   'extended warranty',
#   'extended warranties',
#   'battery',
#   'screen',
#   'battery life',
#   'appearance',
#   'technical service for dell',
#   'graphics',
#   'warranty',
#   'battery',
#   'case',
#   'performance',
#   'price',
#   'look',
#   'applications',
#   'speed',
#   'tech support',
#   'use',
#   'gaming',
#   'photoshop',
#   'system clock',
#   'ram',
#   'driver updates',
#   'windows',
#   'work',
#   'works',
#   'hd',
#   'graphics card',
#   'hd',
#   'built in camera',
#   'in',
#   'dvd burner',
#   'dvd burner',
#   'works',
#   '15 inch',
#   'product support',
#   'use',
#   'screen',
#   'casing of the power cord',
#   'of the',
#   'internet signals',
#   'price',
#   'right speaker',
#   'price tag',
#   'software',
#   'updates',
#   'multiple page viewer',
#   'page',
#   'shipped',
#   'keyboard',
#   'use',
#   'warranty',
#   'quality',
#   'features',
#   'recovery disk',
#   'features',
#   'programs',
#   'office',
#   'office programs',
#   'wifi',
#   'typing',
#   'screen',
#   'temp',
#   'windows operating system',
#   'os',
#   'processor speed',
#   'thunderbolt port',
#   'lcd screen',
#   'images',
#   'windows vista',
#   'windows xp',
#   'vista',
#   'adobe flash player',
#   'internet explore',
#   'windows update',
#   'update',
#   'switch',
#   'switch',
#   '4gb stick of ram',
#   'hardrive',
#   'touch control buttons',
#   'keyboard',
#   'performance',
#   'runs',
#   'ilife software',
#   'iphoto',
#   'imovie',
#   'iweb',
#   'itunes',
#   'garageband',
#   'system board',
#   'size',
#   'software',
#   'hardware',
#   'memory',
#   'hard drive',
#   'graphics',
#   'programs',
#   'navigation',
#   'hinge',
#   'lcd',
#   'dell customer service',
#   'rma service',
#   'rma',
#   'design',
#   'keyboard',
#   'battery life',
#   'screen / video resolution',
#   'resolution',
#   'dreamweaver',
#   'final cut pro 7',
#   'photoshop',
#   'safari',
#   'firefox',
#   'msn messenger',
#   'applications',
#   'warrenty',
#   'tech support',
#   'apple applications',
#   'gigs',
#   'memory',
#   '17 - inch screen',
#   'dvd',
#   'cd burners',
#   'web browsing',
#   'uploading photos',
#   'watching movies',
#   'creating presentations',
#   'quality display',
#   'weight',
#   '12 cell battery',
#   'case',
#   'power adapter plug',
#   'features',
#   'speakers',
#   'screen',
#   'tab',
#   'extended warrenty',
#   'tft panel',
#   'navigation',
#   'windows operating systems',
#   'screen',
#   'screen size',
#   'bulk',
#   'picture',
#   'video',
#   'music software',
#   'software',
#   'combined touch pad and clicker',
#   'unibody construction',
#   'value',
#   'windows',
#   'screen hinges',
#   'battery',
#   'storage life',
#   'service',
#   'storage',
#   'ram',
#   'nvidia chipset',
#   'extended warranty',
#   'programs',
#   'charge time',
#   'size',
#   'consistancy',
#   'key bindings',
#   'keyboard',
#   'size',
#   '10 - key',
#   'fan',
#   'fan',
#   'screen',
#   'operating system',
#   'processor',
#   '500gb hard drive',
#   'feature',
#   'tech support',
#   'usb output',
#   'wireless mouse',
#   'windows',
#   'linux',
#   'size',
#   'screen',
#   'windows disc',
#   'quality',
#   'touchpad',
#   'video card',
#   'touch pad',
#   'external mouse',
#   'set up',
#   'video',
#   'value',
#   'hard drive',
#   'runs',
#   'loads',
#   'warranty',
#   'program',
#   'spinning beachball',
#   'disk throughput',
#   'access wireless internet access',
#   'value',
#   'ran',
#   'battery',
#   'company',
#   'screen resolutions',
#   'carry',
#   'keyboard',
#   'edges',
#   'programs',
#   'ilife',
#   'iphotos',
#   'processor',
#   'fan',
#   'motherboard',
#   'built',
#   'performance',
#   'screen resolution',
#   'snow leopard',
#   'cpu',
#   'spinning wheel',
#   'office mac applications',
#   'word',
#   'excel',
#   'pad',
#   'keyboard',
#   'screen',
#   'windows 7',
#   'programs',
#   'ilife',
#   'iwork',
#   '18.4 " screen',
#   'battery life',
#   'runs',
#   'regular layout keyboard',
#   'programs',
#   'windows',
#   'recovery discs',
#   'windows 7 starter',
#   'support',
#   '3 year warranty',
#   'online chat service',
#   'iphoto',
#   'works',
#   'battery',
#   'quality',
#   'vhs',
#   'use',
#   'navigate',
#   'battery life',
#   'battery',
#   'usb ports',
#   'battery',
#   'design',
#   'quality',
#   'mac version of microsoft office',
#   'starting-up time',
#   'operates',
#   'touch pad',
#   'touch pad',
#   'pictures',
#   'transporting',
#   'gaming',
#   'wifi card',
#   'network capability',
#   'printer',
#   'use',
#   'os x',
#   'repair service',
#   'customer service agents',
#   'photoshop',
#   'aftereffects programs',
#   'runs',
#   'warrenty',
#   'look',
#   'dependability',
#   'company',
#   'warranty',
#   'features',
#   'mouse button',
#   'performance',
#   'touchpad',
#   'buttons',
#   'programs',
#   'space',
#   'keyboard',
#   'battery',
#   'keyboard',
#   'battery life',
#   'hard drive',
#   'windows 7',
#   'processor',
#   'load webpages',
#   'applications',
#   'battery',
#   'boot',
#   'windows',
#   'runs',
#   'openoffice',
#   'firefox',
#   'price',
#   'quality',
#   'performance',
#   'battery life',
#   'use',
#   'product key',
#   'specs',
#   'bluetooth',
#   'one touch keys',
#   'feature',
#   'battery life',
#   'keyboard',
#   'speed',
#   'specs',
#   'price',
#   'delivery',
#   'stability',
#   'mac software',
#   'operating system',
#   'sata controller',
#   'video editing',
#   'performance',
#   'mobile video editing',
#   'imovie program',
#   'processor',
#   'ram',
#   'battery',
#   'price',
#   'designed',
#   'warranty',
#   'bluetooth mouse',
#   'features',
#   'keyboard',
#   'control buttons',
#   'screen',
#   'motherboard',
#   'motherboard',
#   'processor',
#   'performance',
#   'motherboard',
#   'patches',
#   'speed',
#   'system memory',
#   'radeon 5850',
#   'ddr 5',
#   'ddr 3',
#   'programs',
#   'programs',
#   'speed',
#   'size',
#   'os ( vista )',
#   'software',
#   'battery life',
#   'battery life',
#   'extended warranty',
#   'use',
#   'use',
#   'features',
#   'programs',
#   'pop up windows',
#   'pop ups',
#   'web programming software',
#   'memory',
#   'web access',
#   '3g network',
#   'screen',
#   'design based programs',
#   'adobe creative suite',
#   ...],
#  'Laptops_poria-test': ['boot time',
#   'tech support',
#   'set up',
#   'windows 8',
#   'touchscreen functions',
#   'click pads',
#   'internal speakers',
#   'price tag',
#   'installation disk ( dvd )',
#   'use',
#   'works',
#   'apple os',
#   'features',
#   'log on',
#   'wifi connection',
#   'battery life',
#   'delete key',
#   'interneting',
#   'priced',
#   'works',
#   'track pad',
#   'graphics',
#   'mountain lion',
#   'build',
#   'durability',
#   'battery life',
#   'works',
#   'windows 8',
#   'baterry',
#   'size',
#   'weight',
#   'performance',
#   'usb ports',
#   'speed',
#   'screen',
#   'price',
#   'hardware performance',
#   'works',
#   'set up',
#   'keyboard',
#   'windows 8',
#   'setup',
#   'configure',
#   'windows 8',
#   'usb ports',
#   'features',
#   'screen',
#   'keyboard',
#   'performance',
#   'quality',
#   'performance',
#   'os',
#   'portability',
#   'portable computing',
#   'ms office 2011 for mac',
#   'performance',
#   'look',
#   'performance',
#   'lit up keys',
#   'screen display',
#   'mountain lion os',
#   'microsoft windows',
#   'osx',
#   'microsoft office',
#   'graphics',
#   'colors',
#   'built-in apps',
#   'screen resolution',
#   'speed',
#   'multi touch gestures',
#   'operating system',
#   'windows',
#   'size',
#   'squaretrade 3 - year computer accidental protection warranty',
#   'applecare',
#   'transport',
#   'windows 8 set-up',
#   'size',
#   'retina display',
#   'design',
#   'aluminum casing',
#   'aluminum body',
#   'integrate bluetooth devices',
#   'usb devices',
#   'intel 4000 graphic chip',
#   'dvd drive firewire port',
#   'adapter',
#   'sdxc slot',
#   'durability',
#   'designed',
#   'use',
#   'value',
#   'specs',
#   'product quality',
#   'aesthetics',
#   'craftmanship',
#   'customer service',
#   'size',
#   'windows 8',
#   'windows 8',
#   'startup times',
#   'colors',
#   'price',
#   'shipping',
#   'mouse',
#   'battery',
#   'windows 7',
#   'price',
#   'delivery',
#   'service',
#   'customer service',
#   'windows 8',
#   'price',
#   'set up',
#   'win 8',
#   'features',
#   'price',
#   'osx',
#   'support for games',
#   'mobility',
#   'price',
#   'set up',
#   'usb 3',
#   'sound',
#   'track pad',
#   'settings',
#   'openoffice',
#   'form factor',
#   'battery life',
#   'ux',
#   'keyboard',
#   'screen',
#   'touchpad',
#   'mavericks',
#   'i5',
#   'service',
#   'shipping',
#   'performance',
#   'built-in applications',
#   'iphoto',
#   'hard drive',
#   'samsung 830 ssd',
#   'starts up',
#   'aluminum',
#   'built in virus control',
#   'retina display',
#   'components',
#   'hardware',
#   'battery',
#   'snow lion',
#   'shipping',
#   'features',
#   'quality',
#   'keyboard',
#   'sound quality',
#   'navigate',
#   'battery life',
#   'performance',
#   'quality',
#   'windows xp',
#   'windows vista',
#   'windows 7',
#   'ssd drive',
#   'memory',
#   'start up',
#   'itune',
#   'os',
#   'restore disks',
#   'charging cables',
#   'material',
#   'cables',
#   'graphic design',
#   'external mics',
#   'os',
#   'screen',
#   'works',
#   'system',
#   'customize setting',
#   'create your own bookmarks',
#   'wireless keyboard / mouse',
#   'hdmi cable',
#   'features',
#   'price',
#   'working',
#   'gaming',
#   'operating system',
#   'set up',
#   'hard drive',
#   'boots up',
#   'scanning',
#   'price point',
#   'works',
#   'working',
#   'surfing',
#   'works',
#   'software',
#   'word processing',
#   'web browsing',
#   'gaming',
#   'programming',
#   'function',
#   'performance',
#   'apple " help "',
#   'work',
#   'harddrive',
#   'on / off switch',
#   'instructions',
#   'gaming',
#   'integrated intel 4000 graphics',
#   'features',
#   'content creation',
#   'audio',
#   'video',
#   'photo editing',
#   'screen',
#   'brightness',
#   'applications',
#   'use',
#   'use',
#   'i5 processor',
#   'built in features',
#   'screen',
#   'keyboard',
#   'delivery',
#   'ssd',
#   '16gb ram',
#   'memory',
#   'works',
#   'design',
#   'keyboard',
#   'ports',
#   'service',
#   'web browsing',
#   'safari browser',
#   'lighted screen',
#   'use',
#   'start up',
#   'operation',
#   'usb 3 peripherals',
#   'thunderbolt',
#   'media editing',
#   'battery',
#   'user experience',
#   'shipment',
#   'price',
#   'performance',
#   'usability',
#   'presentation',
#   'time response',
#   'size',
#   'mac os',
#   'programs',
#   'appleworks',
#   'filemaker pro',
#   'quicken',
#   'photoshop',
#   'operating system',
#   'form factor',
#   'loading the internet',
#   'looking',
#   'xp',
#   'support',
#   'os',
#   'overall build',
#   'keyboard',
#   'construction',
#   'system',
#   'unibody construction',
#   'runs',
#   'disk drive',
#   'hdmi receptacle',
#   'sd card slot',
#   'works',
#   'design app',
#   'trackpad',
#   'looks',
#   'feels',
#   'finish',
#   'price',
#   'price',
#   'system',
#   'power down',
#   'configuration',
#   'speakers',
#   'looks',
#   'use',
#   'trackpad',
#   'web surfuring',
#   'interface',
#   'portability',
#   'works',
#   'carry',
#   'handle',
#   'hardware ( keyboard )',
#   'performance',
#   'battery lifetime',
#   'runs',
#   'footprint',
#   'exterior',
#   'performance',
#   'design',
#   'intel 4000 graphics chipset',
#   'osx mountain lion',
#   'mavericks',
#   'usb ports',
#   'wakes',
#   'lid',
#   'size',
#   'speed',
#   'customer service',
#   'performed',
#   'battery cycle count',
#   'hardware',
#   'os',
#   'finger swipes',
#   'mouse',
#   'storage',
#   'screen',
#   'photoshop',
#   'mac os',
#   'speaker quality',
#   'shipped',
#   'thunderbolt port',
#   'performance',
#   'streaming video',
#   'entertainment uses',
#   'design',
#   'features',
#   'mac office',
#   'apple tech support',
#   'spec',
#   'works',
#   'use',
#   'looks',
#   'office',
#   'retina display',
#   'performance',
#   'ssd',
#   'magsafe accessories',
#   'magsafe 2 connection',
#   'touchpad',
#   'mouse',
#   'runs',
#   'fans',
#   'mac os',
#   'mac ecosystem',
#   'price',
#   'use',
#   'appearance',
#   'functionality',
#   'graphic design',
#   'slot',
#   'os',
#   'use',
#   'ssd',
#   'built-in camera',
#   'voice recording',
#   'start up',
#   'functionality',
#   'function',
#   'graphics',
#   'build quality',
#   'unibody construction',
#   'flexibility for connectivity',
#   'portability',
#   'mac tutorials',
#   'technical support',
#   'adapter',
#   'technical support',
#   'iphoto',
#   'garage band',
#   'logic board',
#   'sound',
#   'volume',
#   'osx lion',
#   'application',
#   'physical form',
#   'body',
#   'unibody construction',
#   '3d rendering',
#   'os x mountain lion',
#   'screen',
#   'apps',
#   'boot',
#   'ports',
#   'and',
#   'quad-core 2.5 ghz cpu',
#   'radeon hd 6750m 512mb graphic card',
#   'integrated intel 4000 card',
#   'and',
#   'wireless apple keyboard and mouse',
#   'and',
#   'package',
#   'cover',
#   'gestures',
#   'extender cable',
#   'cable',
#   '2.9 ghz dual-core i7 chip',
#   'starts up',
#   'noise',
#   'heat',
#   'windows 8',
#   'internal cd drive',
#   'hard drive',
#   'network lights',
#   'priced',
#   'storage',
#   'ports',
#   'audio volume',
#   'size',
#   'windows 8',
#   'capabilities',
#   'settings',
#   'runs',
#   'boot-up',
#   'windows updates',
#   'logic board',
#   'internet',
#   'word processing',
#   'graphic design',
#   'gaming',
#   'setup',
#   'install',
#   'tutorial',
#   'features',
#   'right mouse click menu',
#   'runs',
#   'ram memory',
#   'profile',
#   'wifi capability',
#   'disk drive',
#   'usb ports',
#   'sd card reader',
#   'the nail slot on the card',
#   'slot',
#   'touch',
#   'anodized aluminum',
#   'aluminium',
#   'glass',
#   'aluminum',
#   '16gb of ram',
#   'seagate momentus xt hybrid drives',
#   'owc upgrade kit',
#   'hard drive',
#   'number pad on the keyboard',
#   'on',
#   'regular hard drive',
#   'cd slot',
#   'hdmi port',
#   'install mountain lion',
#   'customization',
#   'hd',
#   'micron ssd',
#   'two finger clicking',
#   'right click button',
#   'superdrive',
#   'power plug',
#   'power adaptor',
#   'battery',
#   'battery',
#   'practicality',
#   'os',
#   'monitors',
#   'hdmi cables',
#   'price',
#   'ac adaptor',
#   'fan',
#   'playing a game',
#   'usb 2 ports',
#   'startup disk',
#   '" tools " menu',
#   'word program',
#   'cd / dvd drive',
#   'power switch',
#   'windows 7',
#   'windows 8',
#   'install',
#   'configure for adsl cable or wifi',
#   'speakers',
#   'packing',
#   'windows',
#   'idvd',
#   'windows 7',
#   'mac system',
#   'windows',
#   'works',
#   'software',
#   'os',
#   'works',
#   'runs',
#   'price',
#   'os',
#   'touch pad',
#   'reliability',
#   'sound',
#   'headphones',
#   'track pad',
#   'os',
#   'application',
#   'price',
#   'battery',
#   'speed',
#   'price',
#   'shipping',
#   'retina display display',
#   'compact computing',
#   'the',
#   'performance and feature set of the hardware',
#   'ports',
#   'firewire 800',
#   'gigabit ethernet',
#   'magsafe port',
#   'microphone jack',
#   'ventilation system',
#   'watching videos',
#   'playing steam games',
#   'acer support',
#   'operating system files',
#   'keys',
#   'os',
#   'lion',
#   'mac os',
#   'ram',
#   'hdd',
#   'cd / dvd player',
#   'ram memory',
#   'os . x',
#   'windows',
#   'windows .',
#   'softwares',
#   'os',
#   'mac os x 10.8 " mountain lion "',
#   'performance',
#   'external 24 " lcd screen',
#   'built in screen size',
#   'dvd slot',
#   'install software',
#   'word processing program',
#   'third-generation cpu ( " ivy bridge " )',
#   'fourth-generation haswell cpu',
#   'cd rom',
#   'features',
#   'volume',
#   'volume',
#   'case',
#   'price',
#   'log into the system',
#   'ssd',
#   '21 " led screen',
#   'set up',
#   'case',
#   'external power supply',
#   'size',
#   'wireless mouse',
#   'pad',
#   'works',
#   'key board',
#   'cost of ownership',
#   'price tag',
#   'features',
#   'vga port',
#   'hdmi',
#   'ethernet',
#   'usb ports',
#   'rubber pads',
#   'price',
#   'price',
#   'heat output',
#   'operation',
#   'upgrade the ram',
#   'price',
#   'mac',
#   'built-in mic',
#   'mac os 10.9',
#   'external microphones',
#   'features',
#   'shortcuts',
#   'ios system',
#   'resolution',
#   'fonts',
#   'working',
#   'features',
#   'brightness',
#   'adjustments',
#   'cd / dvd player',
#   'backlit keys',
#   '" home / end " type keys',
#   'microsoft word',
#   'memory',
#   'speed',
#   'flexibility',
#   'speed',
#   'simplicity',
#   'design',
#   'battery life',
#   'display',
#   'downloading apps',
#   'screen',
#   'software',
#   'operating system',
#   'slim plastic case',
#   'recovery usb stick',
#   'bass',
#   'sound',
#   'built quality',
#   'performance',
#   'mac',
#   'bluetooth interface',
#   'mac os',
#   'range',
#   'start',
#   'start menu',
#   'ram',
#   'touch screen',
#   'games',
#   'photoshop',
#   '" wlan " card',
#   'lan device drivers',
#   'built',
#   'battery life',
#   'os',
#   'apple customer support',
#   'firewire 800',
#   'usb 3',
#   'usb 3',
#   'mac os',
#   'windows 7',
#   'itunes',
#   'security',
#   'mini form factor',
#   'graphics stuff',
#   'the card reader',
#   'remove the card',
#   'spinning hard disk',
#   'ssd drive',
#   'hdmi',
#   'firmware patch',
#   'specs',
#   'packing',
#   'mother boards',
#   'mother board',
#   'graphics card',
#   '4g of ram',
#   '8g of ram',
#   'performs',
#   'virtual home schooling',
#   'cost',
#   'operating system',
#   'size',
#   'weight',
#   'mobility',
#   'durability of the battery',
#   'the functions provided by the trackpad',
#   'by',
#   'hardware',
#   'software',
#   'updates',
#   'disc drive',
#   'screen',
#   'res'],
#  'Restaurants_poria-test': ['bread',
#   'delivery times',
#   'food',
#   'coffee',
#   'sushi',
#   'place',
#   'people',
#   'japanese food',
#   'spicy tuna roll',
#   'asian salad',
#   'rose roll',
#   'menu',
#   'drinks',
#   'lychee martini',
#   'food',
#   'nicoise salad',
#   'menu',
#   'drinks',
#   'dessert pizza',
#   'food',
#   'live entertainment',
#   'waiter',
#   'menu',
#   'sushi',
#   'portions',
#   'price',
#   'food',
#   'service',
#   'portions of the food',
#   "waitress's",
#   'staff memebers',
#   'parking',
#   'desserts',
#   'desserts',
#   'tart of the day',
#   'food',
#   'wine',
#   'lasagna',
#   'array of sushi',
#   'cuisine',
#   'owners',
#   'staff',
#   'indian food',
#   'ambiance',
#   'food',
#   'service',
#   'garden',
#   'food',
#   'appetizers',
#   'entrees',
#   'food',
#   'decor',
#   'lunch',
#   'dinners',
#   'steaks',
#   'staff',
#   'meatball parm',
#   'latin food',
#   'taglierini with truffles',
#   'staff',
#   'gnocchi',
#   'staff',
#   'food',
#   'portion size',
#   'portobello / gorgonzola / sausage appetizer',
#   'lobster risotto',
#   'entrees',
#   'lasagna',
#   'fettuccine alfredo',
#   'chicken parmigiana',
#   'food',
#   'teriyaki',
#   'meal',
#   'peanut butter sorbet',
#   'pizza with soy cheese',
#   'food',
#   'price',
#   'food',
#   'service',
#   'atmosphere',
#   'food',
#   'waitstaff',
#   'atmosphere',
#   'beer',
#   'food',
#   'kimono shrimp special',
#   'atmosphere',
#   'menu',
#   'priced',
#   'food',
#   'ingredients',
#   'food',
#   'appetizer',
#   'meal',
#   'spicy mussels',
#   'onion rings',
#   'food',
#   'portions',
#   'service',
#   'prices',
#   'service',
#   'food',
#   'waiter',
#   'manager',
#   'food',
#   'milkshakes',
#   'mushroom barley soup',
#   'food',
#   'staff',
#   'duck',
#   'drinks',
#   'food',
#   'curried casseroles',
#   'food',
#   'taste',
#   'space',
#   'cuisine',
#   'seafood',
#   'orange donut',
#   'atmosphere',
#   'meats',
#   'management',
#   'ambience',
#   'teas',
#   'sweets',
#   'mojitos',
#   'service',
#   'sandwiches',
#   'burgers',
#   'salads',
#   'lemon-dressed cobb',
#   'design',
#   'food',
#   'staff',
#   'taste',
#   'fajita',
#   'mole sauce',
#   'roasted chickens',
#   'atmosphere',
#   'food',
#   'selection',
#   'prices',
#   'drinks',
#   'steak',
#   'food',
#   'waiters',
#   'priced',
#   'selection of food',
#   'atmosphere',
#   'dessert',
#   'taste',
#   'food',
#   'hot dog',
#   'bar',
#   'food',
#   'waiters',
#   'atmosphere',
#   'food',
#   'wraps',
#   'burgers',
#   'salads',
#   'mango margareta',
#   'prices',
#   'service',
#   'waiter',
#   'staff',
#   'folding chair',
#   'service',
#   'fettucino alfredo',
#   'food',
#   'vegan options',
#   'indian food',
#   'smoked trout',
#   'lamb chops',
#   'veal chops',
#   'rabbit',
#   'potato gratin',
#   'chef',
#   'food',
#   'service',
#   'eggs benedict',
#   'mussels',
#   'hamburger',
#   'waiters',
#   'falafal',
#   'chicken',
#   'grand marnier shrimp',
#   'food',
#   'food',
#   'service',
#   'desserts',
#   'flan',
#   'sopaipillas',
#   'portions',
#   'wait staff',
#   'food',
#   'service',
#   'sushi',
#   'service',
#   'soup',
#   'crepes',
#   'creme brulee',
#   'apple',
#   'shrimp creole',
#   'chicken dinner',
#   'chili signed food items',
#   'decor',
#   'food',
#   'ribs',
#   'beef',
#   'coconut rice',
#   'avocado salad',
#   'honey bbq rib tips',
#   'chinese food',
#   'service',
#   'atmosphere',
#   'staff',
#   'waiters',
#   'pasta',
#   'wine list',
#   'cocktail menu',
#   'crab cakes',
#   'bbq rib',
#   'food',
#   'service',
#   'sauce',
#   'service',
#   'desserts',
#   'atmosphere',
#   'drinks',
#   'appetizers',
#   'pizza',
#   'service',
#   'food',
#   'beer list',
#   'chinese food',
#   'waiter',
#   'scallops',
#   'asparagus',
#   'soft shell crab',
#   'cheese plate',
#   'service',
#   'hotdogs',
#   'staff',
#   'saag gosht',
#   'garlic knots',
#   'indian food',
#   'pizza',
#   'music',
#   'service',
#   'owner',
#   'staff',
#   'sushi',
#   'menu',
#   'food',
#   'sushi',
#   'cooked food',
#   'dinner specials',
#   'food',
#   'drinks',
#   'dining atmosphere',
#   'price',
#   'food',
#   'food portion',
#   'chairs',
#   'tacos pastor',
#   'tostada de tinga',
#   'bartenders',
#   'managers',
#   'decor',
#   'soup and sandwich meal',
#   'hot and sour soup',
#   'drinks',
#   'atmosphere',
#   'service',
#   'food',
#   'chick peas with shrimp ( appetizer )',
#   'service',
#   'lamb',
#   'soft shell crab sandwich with fries',
#   'hong kong-style food',
#   'food',
#   'wine',
#   'staff',
#   'kitchen food',
#   'sushi',
#   'service',
#   'waitresses',
#   'atmosphere',
#   'italian food',
#   'food',
#   'rolls',
#   'sushi / sashimi',
#   'sashimi',
#   'price',
#   'hot dogs',
#   'breakfast sandwiches',
#   'tator tots',
#   'english muffins',
#   'pork product',
#   'taylor ham',
#   'manager',
#   'bartender',
#   'waiting',
#   'drinks',
#   'service',
#   'atmosphere',
#   'dish',
#   'green chillis',
#   'service',
#   'food',
#   'meals',
#   'lunch',
#   'take-out',
#   'dine-in',
#   'food',
#   'fresh juice concoctions',
#   'food',
#   'prices',
#   'place',
#   'soul food',
#   'place',
#   'roast chicken',
#   'salad',
#   'chicken with avocado',
#   'tuna',
#   'meals',
#   'chicken',
#   'sauce',
#   'malted milk ball gelato',
#   'meal',
#   'service',
#   'bar service',
#   'dessert',
#   'service',
#   'black vinegar',
#   'shredded ginger',
#   'lighting',
#   'food',
#   'disco pop duo',
#   'escargot',
#   'place',
#   'service',
#   'owner',
#   'waiters',
#   'food',
#   'waiter',
#   'salads',
#   'vegetarian platters',
#   'meal',
#   'food',
#   'service',
#   'pizza',
#   'pizza',
#   'service',
#   'chicken',
#   'food',
#   'host ( owner )',
#   'servers',
#   'food',
#   'atmosphere',
#   'hostess',
#   'food',
#   'service',
#   'vietnamese beef noodle soup',
#   'dining experience',
#   'indian food',
#   'waiters',
#   'interior',
#   'service',
#   'food',
#   'decor',
#   'menu',
#   'selection',
#   'sauce',
#   'crust',
#   'sushi',
#   'selection',
#   'rolls with crab',
#   'host',
#   'bartender',
#   'servers',
#   'food',
#   'potato spinach gnocchi',
#   'lamb',
#   'lunch',
#   'sandwiches',
#   'portuguese cheese cart',
#   'port',
#   'burger',
#   'blueberry pancakes',
#   'food',
#   'bill',
#   'toppings',
#   'crust',
#   'service',
#   'food',
#   'waitstaff',
#   'food',
#   'lobster ravioli',
#   'meal',
#   'service',
#   'wait',
#   'price',
#   'food',
#   'coffee',
#   'cosi sandwiches',
#   'drink',
#   'prices',
#   'food',
#   'waiting',
#   'place',
#   'ambience',
#   'brunch',
#   'food',
#   'crust',
#   'food',
#   'cake',
#   'dinner',
#   'service',
#   'delmonico steak',
#   'menu',
#   'chicken',
#   'rice',
#   'beans',
#   'service',
#   'value',
#   'food',
#   'value',
#   'garlic soup',
#   'falafel',
#   'tabouleh',
#   'humus',
#   'mediterranean delights',
#   "pizza's",
#   'staff',
#   'chef',
#   'priced',
#   'sushi',
#   'for',
#   'seafood paella for two',
#   'apetizers',
#   'sangria',
#   'service',
#   'server',
#   'staff',
#   'food',
#   'service',
#   'host',
#   'hostess',
#   'wait staff',
#   'meal',
#   'salmon dishes',
#   'foie gras',
#   'menu',
#   'mac cheese',
#   'brunch menu',
#   'jazz singer',
#   'service',
#   'food',
#   'breakfast food',
#   'soups',
#   'salads',
#   'sandwiches',
#   'food',
#   'banana pudding',
#   'crabcakes',
#   'and',
#   'mac and cheese',
#   'staff',
#   'prices',
#   'service',
#   'food',
#   'downstairs bar scene',
#   'food',
#   'price',
#   'drinks',
#   'casual lunches',
#   'tequila',
#   'beer selection',
#   'beers',
#   'delivary',
#   'food',
#   'owner',
#   'homemade pastas',
#   'gnocchi',
#   'vegetable risotto',
#   'flavor',
#   'price',
#   'service',
#   'dinner',
#   'prices',
#   'sandwiches',
#   'soup',
#   'pizza',
#   'homemade sorbets',
#   'homemade guacamole',
#   'entree',
#   'deserts',
#   'sushi',
#   'priced',
#   'deserts',
#   'grill',
#   'churrasco',
#   'ribs',
#   'traditional italian items',
#   'served',
#   'setting',
#   'iced blended mocha',
#   'hot white mocha',
#   'late lunch',
#   'parmesan cheese',
#   'waitress',
#   'food',
#   'wine',
#   'service',
#   'portions',
#   'ambiance',
#   'salad',
#   'salad dressing',
#   'quesedilla',
#   "pizza's",
#   'service',
#   'food',
#   'cost',
#   'food',
#   'staff',
#   'bar',
#   'chef',
#   'indian food',
#   'service',
#   'odessa stew',
#   'rabbit stew',
#   'kompot',
#   'lunch',
#   'waitress',
#   'quality of the meat',
#   'smoothies',
#   'fresh juices',
#   'black roasted codfish',
#   'dish',
#   'manager',
#   'menu',
#   'waiter',
#   'chicken',
#   'taste',
#   'reservation',
#   'brunch',
#   'sushi',
#   'sushi',
#   'food',
#   'served',
#   'the erbazzone emiliana',
#   'the mostarda on the cheese plate',
#   'the dishes',
#   'food',
#   'bar',
#   'vibe',
#   'candlelight',
#   'music',
#   'food',
#   'dining experience',
#   'food',
#   'service',
#   'place',
#   'food',
#   'chicken teriyaki',
#   'garlic shrimp',
#   'japanese food',
#   'food',
#   'staff members',
#   'drink',
#   'atmosphere',
#   'sashimi portion',
#   'artifical lobster meat',
#   'wheat crusted pizza',
#   'ingredients',
#   'dinner',
#   'food',
#   'service',
#   'cake',
#   'slices',
#   'staff',
#   'wait',
#   'wine list',
#   'priced',
#   'salads',
#   'bathroom',
#   'delivers',
#   'food',
#   'prices',
#   'service',
#   'repast',
#   'waiters',
#   'italian meal',
#   'pizza',
#   'steak',
#   ', organic grilled burgers',
#   'dish ,',
#   'jerusalem market-style falafel wraps and mediterranean salads--layered with beets , goat cheese and',
#   'dining experience',
#   'waiter',
#   'texture',
#   'hint of cocoa',
#   'the round corner table next to the large window',
#   'twist on pizza',
#   'flavor',
#   'ac',
#   'service',
#   'sales people',
#   'location',
#   'the display and quality of the food',
#   'food',
#   'food',
#   'italian cuisine',
#   'atmoshere',
#   'booth by the windows',
#   'place',
#   'food',
#   'service',
#   'coffee',
#   'wine list',
#   'vintages',
#   'priced food',
#   'scenery',
#   'new hamburger with special sauce',
#   'big mac',
#   'pasta',
#   'sauce',
#   'portions',
#   'prices',
#   'food',
#   'service',
#   'staff',
#   'owners',
#   'owner',
#   'place',
#   'meal',
#   'place',
#   'service',
#   'staff',
#   'food',
#   'fortune cookies',
#   'cookie',
#   'sushi lunch',
#   'mojito',
#   'back patio',
#   'service',
#   'meal',
#   'braised lamb shank with mashed potatoes',
#   'waitress',
#   'soy sauce',
#   'lunch',
#   'bar',
#   'bartender',
#   'fried pork dumplings',
#   'orange chicken / beef',
#   'fried rice',
#   'menu',
#   'french fries - - with the kalmata dip',
#   'wait',
#   'manager',
#   'bartender',
#   'drinks',
#   'boutique selection of wines',
#   'assortment of wraps',
#   'traditional mediterranean fare',
#   'fresh veggies',
#   'middle eastern spreads',
#   'cheese',
#   'falafel',
#   'soup',
#   'fish',
#   'rice',
#   'root vegetables',
#   'rice medley',
#   'spinach thing',
#   'lamb kebabs',
#   'cheese baclava',
#   'fooood',
#   'saketini',
#   'bar menu',
#   'look',
#   'martinis',
#   'chairs',
#   'table',
#   'happy hour',
#   'service',
#   'atmosphere',
#   'waiting',
#   'waiter',
#   'kitchen',
#   'quaility',
#   'atmosphere',
#   'space',
#   'treats',
#   'prices',
#   'menu',
#   'seats',
#   'value',
#   'attitude',
#   'food',
#   'glass of wine',
#   'wine',
#   'flavors',
#   'place',
#   'service',
#   'food',
#   'price',
#   'burrito',
#   'tacos',
#   'margarita',
#   'dessert',
#   'space',
#   'reservations',
#   'food',
#   'interior',
#   'owners',
#   'dining',
#   'service',
#   'food',
#   'value',
#   'wait',
#   'hot cakes',
#   'egg mcmuffin sandwich',
#   'breakfast',
#   'service',
#   'food',
#   'music',
#   'bartender',
#   'drinks',
#   'rice dishes',
#   'noodle dishes',
#   'ice drink',
#   'cuisine',
#   'billed',
#   'asian fusion',
#   'bill',
#   'dishes',
#   'king crab salad with passion fruit vinaigrette',
#   'fettuccine with grilled seafood in a rosemary-orange sauce',
#   'bistro menu',
#   'dishes',
#   '" roy\'s classics "',
#   'menu',
#   'recipes',
#   'macadamia-crusted mahi mahi',
#   'sweet honey-mustard beef short ribs',
#   'cold sesame noodles',
#   'meal',
#   'food served',
#   'argentine chorizo appetizer',
#   'fennel flavored italian sausage',
#   'dinner',
#   'delivery',
#   'value',
#   'sandwiches',
#   'soy mayonaise',
#   'table',
#   'hostess',
#   'dinner',
#   'food',
#   'staff',
#   'food',
#   'wine',
#   'music',
#   'tapas',
#   'selection of wines ( primarily spanish )',
#   'clientele',
#   'food',
#   'dumplings',
#   'cold sesame noodles',
#   'chicken',
#   'shrimp dishs',
#   'food',
#   'food',
#   'waiting',
#   'entrees',
#   'place',
#   'duck confitte',
#   'wine list',
#   'tapas',
#   'atmosphere',
#   'food',
#   'food price',
#   'food',
#   'service',
#   'prices',
#   'food',
#   'meal',
#   'food',
#   'service',
#   'dinner menu',
#   'entrees',
#   'seafood',
#   'steaks',
#   'non-meat alternatives',
#   'menu',
#   'food',
#   'appetizers',
#   'service',
#   'food',
#   'price',
#   'waitress',
#   'entree',
#   'prices',
#   'gratuity',
#   'bill',
#   'halibut cheek appetizer',
#   'portion of foie gras',
#   'meal',
#   'food',
#   'empenadas',
#   'plaintains',
#   'afternoon snack',
#   'appetizer',
#   'pasta specials',
#   'big mac',
#   'chicken mcnuggets',
#   'filet-o-fish sandwich',
#   "mcdonald's famous french fries",
#   'entree-sized salads',
#   'noise',
#   'pizza',
#   'pizza',
#   'tables',
#   'lunch',
#   'scene',
#   'blue bar area',
#   'upstrairs dining area',
#   'veggie burger',
#   'chickpeas',
#   'carrots',
#   'vegetables',
#   'spices',
#   'tables',
#   'service',
#   'menus',
#   'sweet corn-foie gras brulee',
#   'carinthia cheese ravioli with wild mushrooms',
#   'caviar-topped sturgeon',
#   'with',
#   'green spinach-vodka sauce',
#   'burgers',
#   'patties',
#   'lunch',
#   'delivery service',
#   'quality',
#   'prices',
#   'staff person',
#   'fork',
#   'specials',
#   'salmon',
#   'pastas',
#   'atmosphere',
#   'decor',
#   'wait staff',
#   'food',
#   'dishes',
#   'place',
#   'desserts',
#   'food',
#   'staff',
#   'service',
#   'atmosphere',
#   'branzini',
#   'fish',
#   'food',
#   'service',
#   'price',
#   'menu',
#   'ambiance',
#   'service',
#   'food',
#   'food',
#   'wine',
#   'host',
#   'pizzas',
#   'appetizers',
#   'main courses',
#   'calamari',
#   'pasta',
#   'sliced steak entree',
#   'caeser salad',
#   'fried calamari',
#   'atmosphere',
#   'food',
#   'food',
#   'service',
#   'portions',
#   'service',
#   'chicken milanese',
#   'tapas',
#   'prices',
#   'service',
#   'chocolate raspberry cake',
#   'flavor',
#   'waiter',
#   'food',
#   'wine',
#   'meal',
#   'service',
#   'hot dogs',
#   'service',
#   'food',
#   'wine',
#   'desserts',
#   'dining experience',
#   'food',
#   'service',
#   'escargot',
#   'menu',
#   'deco',
#   'ambiance',
#   'french food',
#   'indian food',
#   'curry',
#   'poori',
#   'naan',
#   'paratha',
#   'homemade breads',
#   'sushi',
#   'korean dishes',
#   'prix fixe menu',
#   'waiter',
#   'place',
#   'service',
#   'food',
#   'burgers',
#   'grilled cheeses',
#   'french fries',
#   'yellowfin tuna',
#   "calf's liver",
#   'sushi',
#   'bill',
#   'sauce cart',
#   'table',
#   'choices of sauces',
#   'steak',
#   'sushi',
#   'entrees',
#   'duck',
#   'variety',
#   'utensils',
#   'pie',
#   'thin crust',
#   'slices',
#   'green beans',
#   'egg',
#   'anchovy dressing',
#   'nicoise olives',
#   'red onion',
#   'meal',
#   'side orders',
#   "amazin ' greens salads",
#   'buffalo chicken kickers',
#   'cinna stix',
#   'fries',
#   'meaty chili',
#   'stuffed baked potatoes',
#   'menu',
#   'chocolate frosty',
#   'waiter',
#   'menu',
#   'cake',
#   'cake',
#   'employees',
#   'cherry marscapone',
#   'roti canai appetizer',
#   'fried pancake served with pungent curry dipping sauce',
#   'mango chicken',
#   'outside',
#   'atmosphere',
#   'ground chickpea soup',
#   'starter',
#   'sushi',
#   'service',
#   'quality of food',
#   'bartenders',
#   'clientele',
#   'staff',
#   'meal',
#   'desserts',
#   'tables',
#   'rooftop bar',
#   'decoration',
#   'ambience',
#   'food',
#   'catfish',
#   'service',
#   'food',
#   'brisket',
#   'ribs',
#   'wings',
#   'cajun shrimp',
#   'atmosphere',
#   'counter',
#   'bottle of wine',
#   'menu',
#   'japanese dishes',
#   ...]}

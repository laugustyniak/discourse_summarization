# %%
import pandas as pd

# %%
import sys

# %%
sys.path.append('/home/jovyan/data/sentic/senticnet-4.0/')

# %%
from senticnet4 import senticnet

# %%
sentic_df = pd.DataFrame.from_dict(senticnet, orient='index')

# %%
sentic_df.head()
# Out:
#                            0      1      2      3          4            5   \
# fawn                        0      0  -0.86  -0.97      #fear     #disgust
# unsupportable           -0.88      0  0.907  -0.84   #sadness       #anger
# systemic_manifestation  -0.85      0  0.676  -0.82   #sadness     #disgust
# manual_typewriter       0.025  0.176  -0.06  0.114  #interest  #admiration
# stabilize_afghanistan   -0.94      0      0  -0.98   #sadness     #disgust
#
#                               6      7             8             9   \
# fawn                    negative  -0.61         crawl           dun
# unsupportable           negative  -0.88   intolerable  unacceptable
# systemic_manifestation  negative  -0.78  erythroderma      erythema
# manual_typewriter       positive  0.083     stamp_pad           pen
# stabilize_afghanistan   negative  -0.64        combat        uprise
#
#                                          10             11               12
# fawn                                  toady          creep           grovel
# unsupportable                        bitter     impossible     insufferable
# systemic_manifestation  erythema_multiforme       windburn           hickey
# manual_typewriter         mechanical_pencil  ballpoint_pen  graphite_pencil
# stabilize_afghanistan             big_fight     opposition         violence

# %%
sentic_df.columns = ['pleasantness', 'attention', 'sensivity', 'aptitude', 'modtag1', 'modtag2', 'polarity_value', 
                    'polarity_intensity', 'semantics1', 'semantics2', 'semantics3', 'semantics4', 'semantics5']

# %%
sentic_df
# Out:
#                           pleasantness attention sensivity aptitude  \
# fawn                                 0         0     -0.86    -0.97
# unsupportable                    -0.88         0     0.907    -0.84
# systemic_manifestation           -0.85         0     0.676    -0.82
# manual_typewriter                0.025     0.176     -0.06    0.114
# stabilize_afghanistan            -0.94         0         0    -0.98
# extra_tyre                       0.686     0.526         0    0.812
# use_match                        0.215     0.194     -0.20    0.279
# impermanence                     -0.87         0     0.744    -0.54
# step_aside                           0     0.953         0    0.998
# fistula_formation                -0.56         0     0.806    -0.76
# nematode_worm                    -0.74         0      0.94    -0.87
# abductor_muscle                  0.934     -0.62         0     0.79
# regularize                       -0.91         0     0.637    -0.59
# scold                                0         0     -0.87        0
# pooled_fund_study                    0     0.966         0    0.803
# gab                              -0.51         0     0.545    -0.91
# originality                          0     0.885         0    0.937
# change_behavior                  0.881      0.92         0        0
# opener                           0.034     -0.02     0.054    -0.09
# alphabetic                       0.049     0.113     0.107    0.162
# professional_athlete                 0         0         0     0.97
# small_fishing_boat               0.073     -0.02         0        0
# chocolate_chip_cooky             0.274     -0.01     0.012    0.132
# slothful                             0         0     -0.85    -0.88
# spray_tan                        -0.96         0     0.636    -0.64
# jemmy                            -0.96         0     0.624    -0.99
# feel_anger                       -0.29     -0.03     -0.23    -0.22
# pigment                              0         0         0    0.098
# capoeira                         -0.06     -0.00     -0.09        0
# pen_nib                          0.025     0.176     -0.06    0.114
# ...                                ...       ...       ...      ...
# boor                                 0         0     -0.72    -0.78
# assorted                         -0.83         0     0.752    -0.52
# boot                             0.306     0.228         0    0.087
# book                             0.755     0.743         0        0
# bad_meal                         -0.92         0     0.784    -0.91
# boon                             0.808     -0.83         0    0.548
# greater_credence                 0.751     -0.98         0    0.989
# go_to_theater                    0.995     0.722         0    0.773
# flexion                          -0.76         0     0.969    -0.55
# lance                            0.932     -0.52         0    0.534
# junk                                 0     -0.01     0.026    -0.06
# receive_applause                 0.875     -0.99         0        0
# general_custer                   0.029         0         0     0.05
# make_new_friend                  0.746         0         0    0.907
# june                                 0         0     -0.11        0
# strip_naked                      -0.05         0     -0.05    -0.04
# witchetty_grub                   0.866     -0.91         0    0.893
# build_foundation                 0.487     0.675     -0.26    0.266
# resister                         -0.97         0      0.62    -0.72
# give_a_lot_of_flowers            0.024     0.091     0.023    0.067
# catatonic_state                  -0.81         0     -0.73        0
# codings                              0         0         0    0.074
# space                             0.86     -0.79         0    0.905
# mutual_resemblance               -0.88         0     0.813    -0.57
# love_god                         0.743     0.855         0        0
# tax_payer_dollar                 0.046     -0.66         0    0.365
# criminal_defense_attorney            0     0.146     -0.05    0.077
# avoid_detention                      0     -0.04         0    0.244
# transit_card                      0.04     0.144     -0.07    0.122
# jawbone                          0.651     -0.92         0    0.657
#
#                                modtag1      modtag2 polarity_value  \
# fawn                             #fear     #disgust       negative
# unsupportable                 #sadness       #anger       negative
# systemic_manifestation        #sadness     #disgust       negative
# manual_typewriter            #interest  #admiration       positive
# stabilize_afghanistan         #sadness     #disgust       negative
# extra_tyre                        #joy  #admiration       positive
# use_match                         #joy  #admiration       positive
# impermanence                  #sadness       #anger       negative
# step_aside                   #interest  #admiration       positive
# fistula_formation               #anger     #disgust       negative
# nematode_worm                   #anger     #disgust       negative
# abductor_muscle                   #joy  #admiration       positive
# regularize                    #sadness       #anger       negative
# scold                            #fear        #fear       negative
# pooled_fund_study            #interest  #admiration       positive
# gab                             #anger     #disgust       negative
# originality                  #interest  #admiration       positive
# change_behavior                   #joy    #interest       positive
# opener                          #anger     #disgust       negative
# alphabetic                   #interest  #admiration       positive
# professional_athlete       #admiration  #admiration       positive
# small_fishing_boat                #joy    #surprise       positive
# chocolate_chip_cooky              #joy  #admiration       positive
# slothful                         #fear     #disgust       negative
# spray_tan                     #sadness     #disgust       negative
# jemmy                         #sadness     #disgust       negative
# feel_anger                    #sadness        #fear       negative
# pigment                    #admiration  #admiration       positive
# capoeira                      #sadness        #fear       negative
# pen_nib                      #interest  #admiration       positive
# ...                                ...          ...            ...
# boor                             #fear     #disgust       negative
# assorted                      #sadness       #anger       negative
# boot                              #joy    #interest       positive
# book                              #joy    #interest       positive
# bad_meal                      #sadness     #disgust       negative
# boon                              #joy    #surprise       positive
# greater_credence             #surprise  #admiration       positive
# go_to_theater                     #joy  #admiration       positive
# flexion                       #sadness       #anger       negative
# lance                             #joy  #admiration       positive
# junk                            #anger     #disgust       negative
# receive_applause                  #joy    #surprise       positive
# general_custer                    #joy  #admiration       positive
# make_new_friend                   #joy  #admiration       positive
# june                             #fear        #fear       negative
# strip_naked                   #sadness        #fear       negative
# witchetty_grub               #surprise  #admiration       positive
# build_foundation                  #joy    #interest       positive
# resister                      #sadness     #disgust       negative
# give_a_lot_of_flowers        #interest  #admiration       positive
# catatonic_state               #sadness        #fear       negative
# codings                    #admiration  #admiration       positive
# space                             #joy  #admiration       positive
# mutual_resemblance            #sadness       #anger       negative
# love_god                          #joy    #interest       positive
# tax_payer_dollar             #surprise  #admiration       positive
# criminal_defense_attorney    #interest  #admiration       positive
# avoid_detention              #surprise  #admiration       positive
# transit_card                 #interest  #admiration       positive
# jawbone                      #surprise  #admiration       positive
#
#                           polarity_intensity         semantics1  \
# fawn                                   -0.61              crawl
# unsupportable                          -0.88        intolerable
# systemic_manifestation                 -0.78       erythroderma
# manual_typewriter                      0.083          stamp_pad
# stabilize_afghanistan                  -0.64             combat
# extra_tyre                             0.675               boot
# use_match                              0.161          diligence
# impermanence                           -0.72      temporariness
# step_aside                              0.65               trot
# fistula_formation                      -0.70      rhinostenosis
# nematode_worm                          -0.85   fungal_infection
# abductor_muscle                        0.781   voluntary_muscle
# regularize                             -0.71              gauge
# scold                                  -0.29          reprimand
# pooled_fund_study                       0.59       feasibleness
# gab                                    -0.65             gossip
# originality                            0.607            novelty
# change_behavior                          0.6             felony
# opener                                 -0.02            compass
# alphabetic                             0.072        list_number
# professional_athlete                   0.323  increase_strength
# small_fishing_boat                     0.032             angler
# chocolate_chip_cooky                   0.136         dance_type
# slothful                               -0.57             otiose
# spray_tan                              -0.75               burn
# jemmy                                  -0.86           vitiated
# feel_anger                             -0.24      arrest_police
# pigment                                0.033             cobalt
# capoeira                               -0.05             madman
# pen_nib                                0.083          stamp_pad
# ...                                      ...                ...
# boor                                   -0.50               tyke
# assorted                               -0.70      inhomogeneous
# boot                                   0.207               shoe
# book                                   0.499           bookmark
# bad_meal                               -0.87      eat_fast_food
# boon                                    0.73     successfulness
# greater_credence                       0.909               okay
# go_to_theater                           0.83   go_movie_theater
# flexion                                -0.76            variant
# lance                                  0.662    surgical_knifet
# junk                                   -0.02          old_paper
# receive_applause                       0.622         exaggerate
# general_custer                         0.026        flower_type
# make_new_friend                        0.551           foreplay
# june                                   -0.03               year
# strip_naked                            -0.05      empty_bladder
# witchetty_grub                         0.892              mooch
# build_foundation                       0.387          put_basis
# resister                               -0.77         obstructor
# give_a_lot_of_flowers                  0.053   a_lot_of_flowers
# catatonic_state                        -0.51        change_mind
# codings                                0.025      write_message
# space                                  0.853              round
# mutual_resemblance                     -0.75           affinity
# love_god                               0.533           religion
# tax_payer_dollar                       0.357       address_book
# criminal_defense_attorney              0.057             lawyer
# avoid_detention                        0.095             behave
# transit_card                           0.077            transit
# jawbone                                0.746           schmooze
#
#                                  semantics2            semantics3  \
# fawn                                    dun                 toady
# unsupportable                  unacceptable                bitter
# systemic_manifestation             erythema   erythema_multiforme
# manual_typewriter                       pen     mechanical_pencil
# stabilize_afghanistan                uprise             big_fight
# extra_tyre                    put_groceries             car_trunk
# use_match                     gather_kindle  combustible_material
# impermanence                     transience            transiency
# step_aside                         step_out               meander
# fistula_formation            enterostenosis       laryngostenosis
# nematode_worm                       mycosis                kerion
# abductor_muscle                     deltoid                muscle
# regularize                           govern              regulate
# scold                             jail_time         feel_stressed
# pooled_fund_study            practicability                 phase
# gab                                chitchat             chit_chat
# originality                  innovativeness             freshness
# change_behavior                   vengeance      restrict_freedom
# opener                     swiss_army_knife              bake_pan
# alphabetic                          ordinal                 count
# professional_athlete               keep_fit            fit_person
# small_fishing_boat             informal_rod        archaic_fisher
# chocolate_chip_cooky                  swirl        throw_football
# slothful                           indolent              faineant
# spray_tan                               tan     hyperpigmentation
# jemmy                              impaired                dickey
# feel_anger                     feel_remorse              end_life
# pigment                         many_shades                  cyan
# capoeira                            trouble                 agony
# pen_nib                                 pen     mechanical_pencil
# ...                                     ...                   ...
# boor                              barbarian               peasant
# assorted                         nonuniform         heterogeneous
# boot                               moccasin           cowboy_boot
# book                        store_knowledge         find_bookmark
# bad_meal                          eat_snack    eat_unhealthy_food
# boon                              luckiness            prosperity
# greater_credence                   approval          commendation
# go_to_theater                     go_cinema         drive_theater
# flexion                            flection             deviation
# lance                               catling        surgical_knife
# junk                              old_stuff             egg_shell
# receive_applause                   wave_arm              show_off
# general_custer                   rise_plant           symbol_love
# make_new_friend               enjoy_company        new_friendship
# june                                   week               century
# strip_naked                             pee              go_potty
# witchetty_grub                        cadge              freeload
# build_foundation                solid_basis            study_hard
# resister                         obstructer           technophobe
# give_a_lot_of_flowers                  love             show_love
# catatonic_state                   think_sex            invigorate
# codings                             grammar     computer_language
# space                                 pause         time_interval
# mutual_resemblance              resemblance             alikeness
# love_god                         great_love              get_help
# tax_payer_dollar                   get_rich                 ladle
# criminal_defense_attorney        negotiator               arbiter
# avoid_detention                good_citizen         make_up_story
# transit_card                       bus_pass           travel_card
# jawbone                            schmoose               shmooze
#
#                                           semantics4             semantics5
# fawn                                           creep                 grovel
# unsupportable                             impossible           insufferable
# systemic_manifestation                      windburn                 hickey
# manual_typewriter                      ballpoint_pen        graphite_pencil
# stabilize_afghanistan                     opposition               violence
# extra_tyre                                     store          storage_place
# use_match                     rub_two_stick_together                lighter
# impermanence                          transitoriness              mortality
# step_aside                                  progress            enter_place
# fistula_formation                    aortic_stenosis        mitral_stenosis
# nematode_worm                            tinea_pedis           athlete_foot
# abductor_muscle                             abductor        skeletal_muscle
# regularize                               standardize                  order
# scold                                   go_to_prison             feel_anger
# pooled_fund_study               small_business_phase            feasibility
# gab                                             chat             small_talk
# originality                                  ability                  power
# change_behavior                              revenge           commit_crime
# opener                                    coffee_mug            wine_opener
# alphabetic                                 numerical            enumeration
# professional_athlete                        exercise       strengthen_heart
# small_fishing_boat                     rare_piscator           fishing_line
# chocolate_chip_cooky                     jump_around             dance_move
# slothful                                        lazy               work-shy
# spray_tan                                    sunburn     physical_condition
# jemmy                                       lessened             diminished
# feel_anger                              seek_revenge              call_help
# pigment                                 green_yellow                   tint
# capoeira                               cause_problem           river_stream
# pen_nib                                ballpoint_pen        graphite_pencil
# ...                                              ...                    ...
# boor                                           churl                   goth
# assorted                                      sundry                  mixed
# boot                                    casual_shoes                slipper
# book                                    use_bookmark        bookmark_relate
# bad_meal                            eat_expired_food            eat_quickly
# boon                                    circumstance               blessing
# greater_credence                                okey                   okeh
# go_to_theater                             pay_ticket            watch_movie
# flexion                                  discrepancy              variation
# lance                                        scalpel                  knife
# junk                                      food_scrap            old_clothes
# receive_applause                               laugh               applause
# general_custer                             sign_love                   rose
# make_new_friend                           friendship          companionship
# june                                           month                 reckon
# strip_naked                                   go_pee              go_toilet
# witchetty_grub                                sponge                    bum
# build_foundation                         intelligent    gather_intelligence
# resister                              obstructionist               naysayer
# give_a_lot_of_flowers                           rose                 flower
# catatonic_state            alter_state_consciousness  loss_of_consciousness
# codings                                      english       program_language
# space                             lunitidal_interval                  break
# mutual_resemblance                          likeness             similitude
# love_god                            religious_belief                   hope
# tax_payer_dollar                    swiss_army_knife                  whisk
# criminal_defense_attorney                 judge_jury           decide_guilt
# avoid_detention                          follow_rule                  think
# transit_card                          transit_ticket         transport_card
# jawbone                                      shmoose               chew_fat
#
# [50000 rows x 13 columns]

# %%
sentic_df.ix['good']
# Out:
# pleasantness                   0.526
# attention                      -0.56
# sensivity                          0
# aptitude                       0.903
# modtag1                    #surprise
# modtag2                  #admiration
# polarity_value              positive
# polarity_intensity             0.664
# semantics1              advantageous
# semantics2                  positive
# semantics3                beneficial
# semantics4                      plus
# semantics5            discriminatory
# Name: good, dtype: object

# %%
sentic_df.ix['screen']
# Out:
# pleasantness                       0.039
# attention                           0.08
# sensivity                              0
# aptitude                           -0.03
# modtag1                             #joy
# modtag2                        #interest
# polarity_value                  positive
# polarity_intensity                 0.027
# semantics1                       display
# semantics2                         pixel
# semantics3            visual_information
# semantics4                         image
# semantics5              computer_monitor
# Name: screen, dtype: object

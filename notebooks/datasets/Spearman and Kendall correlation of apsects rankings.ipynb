# %%
from pathlib import Path
import sys
sys.path.append("../..") # go to parent dir

import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
from aspects.analysis.aspect_ranking_correlation import get_spearman_and_kendalltau_correlations

# %%
correlations = get_spearman_and_kendalltau_correlations(100)
# Out:
# Dataset to analyze: MicroMP3
# ['player', 'sound', 'look', 'size', 'storage', 'features', 'touchpad', 'battery life', 'software', 'sound quality', 'design', 'interface', 'headphones', 'zen micro', 'battery', 'accessories', 'fm reception', 'price', 'earbuds', 'working', 'touch pad', 'fm tuner', 'bass', 'construction', 'navigation', 'functioning', 'audio quality', 'headphone jack', 'firmware', 'feel', 'case', 'transfer speed', 'bag', 'stand', 'support', 'quality', 'creative', 'installation', 'extra features', 'file transfer', 'durability', 'microphone', 'looks', 'ease of use', 'zen', 'organization', 'format', 'belt clip', 'scroll bar', 'back', 'controls', 'functionality', 'battery usage', 'instruction', 'fm receiver', 'cost', 'touch-pad', 'built', 'portability', 'user interface', 'touchpad controls', 'comfort', 'screen review', 'compatibility', 'small', 'feature', 'radio', 'charging', 'color', 'outlook sync', 'space', 'formats', 'constructed', 'tiny', 'adapter', 'plaeyr', 'trnasfer', 'file transfer/rip software', 'music source support', 'read', 'navigate', 'sync to windows media player', 'menu', 'usage with subscription service', 'dj', 'radio feature', 'touch sensitivity', 'power', 'feels', 'configuration', 'recharge cord', 'subscription drm-encoded', 'touch controls', 'audio', 'usb', 'touch screen', 'audio formats', 'media player compatibility', 'itunes', 'manual']
# [1, 112, 313, 292, 363, 547, 22, 55, 34, 32, 97, 43, 547, 29, 30, 547, 547, 206, 281, 547, 255, 547, 547, 547, 547, 547, 547, 547, 10, 547, 263, 547, 157, 375, 189, 40, 36, 19, 547, 547, 264, 158, 547, 547, 416, 345, 66, 547, 547, 547, 547, 547, 547, 294, 547, 547, 547, 547, 547, 136, 547, 547, 547, 479, 547, 23, 196, 547, 547, 547, 197, 547, 547, 504, 547, 547, 547, 547, 547, 547, 547, 547, 79, 547, 547, 547, 547, 387, 547, 547, 193, 547, 547, 133, 154, 547, 547, 547, 547, 166]
# MicroMP3, Spearman correlation of ranking: SpearmanrResult(correlation=0.35960382198111956, pvalue=0.00023827369685663395)
# MicroMP3, KendalTau correlation of ranking: KendalltauResult(correlation=0.26610092928749113, pvalue=0.0003530480772368626)
# Dataset to analyze: Canon S100
# ['camera', 'size', 'pictures', 'small', 'software', 'battery', 'use', 'ease of use', 's100', 'zoom', 'buttons', 'light', 'price', 'memory', 'compact', 'flash', 'picture', 'product', 'hot', 'fits', 'auto mode', 'features', 'picture quality', 'housing', 'work', 'focus', 'snapshots', 'macro mode', 'looks', 'lcd', 'body', 'cameras', 'exposure', 'mode', 'photos', 'wait', 'drivers', 'controls', 'macro', 'smal', 'start-up', 'on-camera controls', 'metal case', 'lens', 'usability', 'zoom range', 'capacity', 'cap', 'screen', 'picture detail', 'purchase', 'covering', 'pics', 'prints', 'room', 'resolution', 'panorama setting', 'performance', 'processing', 'tft screen', 'functionality', 'auto-focus', 'bundled software', 'delay', 'manual mode', 'durable', 'auto color balance', 'panorama modes', 'batteries', 'resolution setting', 'canon s100', 'zooms', 'smaller', 'movie mode', 'pictures of people', 'rugged', 'read', 'color balance', 'panorama mode', 'case', 'fun', 'color and light', 'autofocus', 'image quality', 'smallest', 'download', 'tiny', 'casing', 'design', 'performs', 'sharp', 'best-built', 'automatic modes', 'elph s100', 'dynamic range', 'color rendition', 'viewfinder', 'weighs', 'detail', 'tft']
# [1, 57, 196, 196, 33, 14, 115, 196, 34, 196, 196, 76, 113, 161, 27, 133, 3, 196, 196, 196, 9, 196, 68, 89, 26, 53, 196, 196, 196, 148, 22, 196, 11, 5, 196, 196, 196, 196, 196, 196, 196, 196, 196, 67, 196, 196, 196, 72, 194, 196, 196, 196, 196, 196, 92, 99, 196, 196, 196, 196, 196, 196, 196, 196, 196, 196, 196, 196, 196, 196, 196, 196, 196, 196, 196, 196, 196, 196, 196, 45, 196, 196, 196, 196, 196, 196, 196, 196, 31, 196, 196, 196, 196, 138, 196, 196, 196, 196, 196, 193]
# Canon S100, Spearman correlation of ranking: SpearmanrResult(correlation=0.4297144682380328, pvalue=8.134570564500218e-06)
# Canon S100, KendalTau correlation of ranking: KendalltauResult(correlation=0.3260546535181914, pvalue=2.1337570045701803e-05)
# Dataset to analyze: norton
# ['product', 'support', 'norton', 'installation', 'install', 'antivirus', 'symantec', 'firewall', 'uninstall', 'internet security', 'performance', 'liveupdate', 'program', 'update', 'speed', 'upgrade', 'products', 'tech', 'memory usage', 'home version', 'components', 'anti-spam', 'corporate edition', 'charge', 'help', 'remove', 'intrusion', 'version 2004', 'work', 'installed', 'installing', 'cost', 'updates', 'blocking', 'slow', 'alerts', 'nis 2004', 'size', 'sygate', 'capacity', 'spam killer', 'priority id', 'home network', 'fragments', 'wizard', 'antivirus software', 'booting', 'activation process', 'semantic', 'spam', 'removal program', 'refund', 'symantect products', 'features', 'nis2004', 'nis 04', 'antispam', 'functionality', '2004 version', 'symantec/norton site', 'popup blocker', 'program scan', 'boot', 'scan', 'processor', 'suite', 'nis ', 'symantec softwares ', 'system works', 'security suite', 'norton products', 'nstalling', 'corporate', 'nis 2003', 'systemworks', 'norton internet security', '2004 edition', 'function', 'visual backtracking', 'manual shutdown', 'nis', 'product ', 'installs', 'parental control', 'antispam function', 'scanning', 'tech line', 'mcafee anti-virus 8', 'functions', 'symantec customer service', 'unstalling', 'instruction', 'professional version', 'working', 'uninstallation', 'reinstall', 'norton program', 'computer associates ez', 'operation interfaces', 'service']
# [1, 27, 3, 4, 287, 246, 12, 113, 70, 20, 305, 83, 13, 233, 305, 100, 305, 206, 305, 52, 305, 305, 305, 305, 305, 305, 232, 305, 42, 305, 305, 195, 305, 305, 305, 305, 305, 305, 248, 305, 305, 305, 305, 305, 141, 305, 305, 305, 305, 262, 305, 305, 305, 305, 305, 305, 127, 181, 305, 305, 305, 305, 305, 305, 209, 104, 305, 305, 182, 139, 305, 305, 111, 305, 154, 123, 305, 251, 305, 305, 34, 305, 305, 305, 138, 305, 305, 305, 305, 305, 305, 193, 305, 305, 305, 305, 305, 305, 305, 305]
# norton, Spearman correlation of ranking: SpearmanrResult(correlation=0.37044414413471166, pvalue=0.0001483792293743941)
# norton, KendalTau correlation of ranking: KendalltauResult(correlation=0.28123043423381056, pvalue=0.0002057258348806991)
# Dataset to analyze: Diaper Champ
# ['diaper champ', 'odor', 'champ', 'diaper pail', 'product', 'use', 'refills', 'works', 'diapers', 'smell', 'pail', 'diaper', 'open', 'odors', 'garbage bags', 'trash bags', 'work', 'holds', 'bags', 'size', 'item', 'diaper genie', 'clean', 'change', 'empty', 'dispose', 'unit', 'wipes', 'fit', 'diaper wipes', 'opening', 'space', 'price', 'stable', 'oderous', 'plunger', 'pluger', 'investment', 'smelling', 'bag', 'diaper dekor', 'cost effective', 'gift', 'convenient', 'store bags', 'semelled', 'safer', 'operate', 'other pail', 'ease of use', 'bargins', 'deal', 'operated', 'top loader', 'container', 'replacement', 'pull', 'emptying', 'trash bag', 'function', 'filp', 'install', 'hole', 'costly', 'effective', 'pail.', 'capacity', 'stinky', 'fill', 'noise', 'unload', 'seal', 'height', 'smells', 'purchases', 'assemble', 'worked']
# [11, 38, 5, 6, 76, 142, 160, 160, 160, 13, 24, 1, 160, 160, 160, 160, 160, 160, 160, 160, 57, 74, 160, 160, 160, 87, 56, 160, 160, 160, 160, 160, 160, 160, 120, 48, 160, 160, 160, 4, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 49, 160, 160, 160, 40, 160, 160, 16, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160]
# Diaper Champ, Spearman correlation of ranking: SpearmanrResult(correlation=0.4270390102757404, pvalue=0.00010742259023443047)
# Diaper Champ, KendalTau correlation of ranking: KendalltauResult(correlation=0.33212889975297255, pvalue=0.00018845594963368242)
# Dataset to analyze: Hitachi router
# ['router', 'price', 'power', 'adjustment', 'control', 'speed', 'use', 'heavy', 'money', 'collet', 'plunge', 'plunging', 'machine', 'start', 'safety', 'guide', 'weight', 'stable', 'wrench', 'runs', 'cheap', 'powerful', 'm12v', 'depth', 'spring', 'controls', 'starts', 'sawdust', 'chuck', 'stability', 'bog', 'cuts', 'collets', 'tool', 'hitachi', 'shafts', 'quiet', 'fence', 'springs', 'vibration', 'shaft', 'visibility', 'workload', 'heft', 'equipment', 'fit', 'spindle', 'solidity', 'slop', 'worth', 'performed', 'hitachi m12v', 'adjust', 'performance', 'operation', 'adustment knob', 'precise', 'track record', 'big', 'latch', 'instructions', 'adjustments', 'noise', 'affordable', 'operate', 'switch', 'features', 'performer', 'used', 'lock', 'simple', 'accessible', 'costs', 'smooth', 'pretty', 'works', 'motor', 'result', 'system', 'nimble', 'product', 'balance', 'depths', 'bigger', 'heavier', 'looked', 'm12', 'last', 'quite', 'router razier', 'grip', 'finish', 'lighter', 'setup', 'duration', 'speeds']
# [1, 47, 3, 184, 184, 30, 16, 91, 32, 118, 184, 184, 93, 66, 184, 174, 8, 184, 15, 184, 184, 184, 159, 184, 182, 184, 184, 184, 184, 153, 184, 184, 184, 5, 63, 184, 184, 184, 184, 184, 184, 184, 184, 184, 154, 87, 184, 184, 79, 184, 184, 184, 184, 128, 38, 184, 184, 184, 184, 184, 184, 184, 184, 184, 184, 184, 184, 184, 184, 107, 184, 184, 184, 184, 184, 184, 18, 184, 184, 184, 184, 184, 184, 184, 184, 184, 184, 184, 184, 184, 12, 94, 184, 9, 184, 184]
# Hitachi router, Spearman correlation of ranking: SpearmanrResult(correlation=0.33866655171754756, pvalue=0.0007379122715434908)
# Hitachi router, KendalTau correlation of ranking: KendalltauResult(correlation=0.26783880651293723, pvalue=0.0006450268683634414)
# Dataset to analyze: ipod
# ['ipod', 'battery', 'itunes', 'design', 'use', 'sound', 'apple', 'capacity', 'features', 'interface', 'click wheel', 'scratches', 'games', 'hard drive', 'controls', 'usb', 'sound quality', 'equalizer', 'service', 'accessories', 'versatile', 'screen', 'product', 'scratch', 'bass', 'firewire', 'flip side', 'voice recorder', 'headphones', 'memory stick slots', 'compact', 'helpline', 'battery life', 'treble', 'arm band', 'photo quality', 'store', 'weight', 'durable', 'i-pod', 'outside finish', 'freezes', 'hold', 'reliability', 'volume', 'sturdy', 'breaks', 'support service', 'earphones', 'customer service', 'quality', 'alternative', 'device', 'pay', 'affordable', 'sensitive', 'charger', 'connection options', 'batteries', 'using', 'replaceable battery', 'display', 'looks', 'amazon', 'reformatted', 'price', 'voice recording', 'backlighting', 'song quality', 'play wma', 'storage space', 'amplifier', 'battery ', 'steel backing', 'technical service', 'i-tunes', 'photos', 'quality of audio', 'ear buds', 'sounds', 'case', 'solid feel', 'finding', 'earbuds', 'adapter', 'player', 'proprietary', 'purchase', 'wheel', 'photo viewing', 'package', 'fm tuner', 'overall', 'radio tuner']
# [2, 6, 358, 180, 257, 73, 3, 272, 224, 384, 107, 471, 471, 471, 471, 366, 152, 157, 23, 471, 471, 403, 40, 350, 471, 471, 471, 471, 471, 471, 471, 471, 32, 471, 471, 471, 420, 247, 471, 471, 471, 471, 471, 471, 371, 471, 471, 471, 471, 404, 286, 66, 46, 471, 471, 471, 471, 471, 471, 471, 471, 471, 471, 419, 471, 144, 183, 105, 471, 471, 310, 471, 471, 471, 471, 471, 471, 471, 471, 471, 34, 471, 471, 471, 71, 5, 471, 72, 17, 471, 9, 471, 471, 471]
# ipod, Spearman correlation of ranking: SpearmanrResult(correlation=0.22761864710891397, pvalue=0.02735841619445775)
# ipod, KendalTau correlation of ranking: KendalltauResult(correlation=0.17830753788536846, pvalue=0.021208318592565643)
# Dataset to analyze: Nokia 6600
# ['phone', 'bluetooth', 'camera', '6600', 'battery life', 'screen', 'features', 'size', 'interface', 'nokia', 'video', 't-mobile', 'slow', 'games', 'battery', 'speaker phone', 'menu', 'reception', 'rebate', 'os', 'ringtones', 'ringtone', 'calls', 'applications', 'memory', 'keypad', 'look', 'phones', 'display', 'mmc card', 'shape', 'use', 'joystick', 'service', 'keys', 'picture', 'feature', 'speed', 'buttons', 'voice-dialing system', 'camera quality', 't-mobile service', 'handsfree', 'memory card', 'movies', 'internet', 'photos', 'construction', 'big', 'isync compaibility', 'menus', 'signal', 'pictures', 'video recorder', 'video recording', 'gprs', 'build', 'weight', 'n6600', 'quality', 'volume', 'web browser', 'bulky', 'joy stick', 'audio quality', 'phone card calling', 'small', 'game', 'pda', 'coverage', 'modem', 'user-interfaces', 'programs', 'wide', 'application', 'back cover', 'rundown time', 'lcd', 'large', 'rebates', 'sturdy', 'upgrade', 'hear', 'upgradibility', 'colors', 'screens', 'processor', 'multimedia functions', '3650', 'feels', 'video recorders', 'looking', 'mmc slot', 'sim-card', 'visibility', 't610', 'versatility', 'hand set', 'carrier', 'verizon']
# [1, 17, 11, 66, 367, 72, 367, 53, 52, 3, 112, 367, 367, 367, 227, 367, 172, 366, 367, 86, 367, 251, 367, 367, 114, 90, 367, 367, 29, 367, 31, 21, 358, 32, 367, 267, 2, 119, 367, 367, 51, 367, 367, 38, 367, 292, 367, 367, 367, 367, 367, 367, 367, 188, 367, 57, 367, 367, 367, 54, 367, 367, 367, 367, 367, 367, 367, 152, 59, 268, 157, 367, 367, 367, 143, 367, 367, 367, 367, 367, 367, 367, 367, 367, 367, 367, 367, 367, 151, 367, 367, 367, 367, 367, 367, 367, 367, 367, 166, 367]
# Nokia 6600, Spearman correlation of ranking: SpearmanrResult(correlation=0.4378257152483469, pvalue=5.229711785938154e-06)
# Nokia 6600, KendalTau correlation of ranking: KendalltauResult(correlation=0.335700937385921, pvalue=8.478883080552352e-06)
# Dataset to analyze: Linksys Router
# ['router', 'setup', 'works', 'cd', 'installation', 'connection', 'speed', 'security', 'product', 'instructions', 'linksys', 'set up', 'documentation', 'wizard', 'support', 'signal', 'install', 'configuration', 'working', 'range', 'quality', 'wrt54g', 'software', 'firmware update', 'features', 'firmware', 'reliable', 'use', 'connectivity', 'tech support', 'connect', 'design', 'access', 'performance', 'upnp', 'wep encryption', 'costlier', 'user guide', 'stream', 'setting', 'multipurpose', 'desktops', 'enterprise piece', 'logging', 'slow', '1-800', 'setting up', 'backward', 'transmission speed', 'tivo', 'customer service', 'well-priced', 'work', 'reliability', 'model', 'products', 'desktop card', 'hardware version', 'speeds', 'broadband', 'user manual', 'anteanna', 'priced', 'antenna', 'dhcp', 'web site', 'signals', 'cheapest', 'feature', 'technical support', 'wpa encryption', 'look', 'instruction', 'running', 'instant setup', 'manual', 'pipeline', 'junk', 'voip', 'signal quality', 'coverage', 'broadcom hardware', 'signal strength', 'disconnecting', 'configuration options', 'configuration menu', 'setup software', 'copy large files', 'compatibility', 'backward compatible', 'equipment', 'cheap', 'customer support', 'satellite']
# [1, 5, 345, 22, 144, 62, 25, 38, 4, 345, 2, 345, 59, 72, 55, 345, 246, 11, 345, 111, 345, 345, 58, 343, 345, 275, 345, 265, 345, 345, 345, 345, 345, 16, 215, 345, 345, 345, 345, 7, 345, 345, 123, 345, 345, 345, 345, 345, 345, 345, 169, 345, 315, 345, 345, 345, 345, 345, 345, 345, 345, 345, 345, 345, 210, 297, 345, 345, 84, 345, 345, 345, 71, 345, 345, 165, 345, 345, 345, 345, 90, 345, 345, 345, 345, 345, 345, 345, 345, 345, 345, 345, 26, 232]
# Linksys Router, Spearman correlation of ranking: SpearmanrResult(correlation=0.41443433263948803, pvalue=3.286197467562902e-05)
# Linksys Router, KendalTau correlation of ranking: KendalltauResult(correlation=0.3189631625548717, pvalue=4.520859569226273e-05)
# Dataset to analyze: Canon PowerShot SD500
# ['camera', 'lcd', 'pictures', 'image', 'sd500', 'flash', 'size', 'picture', 'pics', 'quality', 'powerup', 'zoom', 'video', 'canon', 'buttons', 'battery', 'user interface', 'photo', 'compact', 'fits', 'software', 'looking', 'prints', 'feels', 'start up', 'made', 'user definable', 'small', 'image-processing system', 'build', 'controls', 'pricey', 'low-light conditions', 'audio', 'autofocus', 'responce', 'design', 'movie mode', 'settings', 'automatic shutter', 'battery charger', 'features', 'fast', 'power button', 'macros-results', 'designed', 'starts up', 'advanced controls', 'instruction', 'powers up', 'white balance', 'merge pictures', 'digic ii chip', 'switch', 'edges', 'manual', 'manual controls', 'color', 'sound', 'automatic settings', 'weight', 'preset', 'sony', 'focus', '640x480 mode', 'clips', 'video-quality', 'documentatio', 'multiple picture', 'view finder', 'focuses', 'colors', 'looks', 'camera shake', 'manual control', 'multiple pictures']
# [1, 64, 177, 27, 4, 68, 55, 5, 177, 98, 82, 136, 50, 28, 177, 146, 177, 84, 148, 177, 177, 152, 177, 177, 177, 177, 177, 177, 177, 177, 177, 177, 177, 177, 105, 177, 177, 177, 177, 177, 177, 177, 177, 177, 177, 177, 177, 177, 177, 177, 177, 177, 177, 177, 177, 137, 177, 165, 37, 177, 177, 177, 177, 177, 177, 177, 177, 177, 177, 94, 177, 177, 177, 177, 177, 177]
# Canon PowerShot SD500, Spearman correlation of ranking: SpearmanrResult(correlation=0.5180473342655434, pvalue=1.6436049993951682e-06)
# Canon PowerShot SD500, KendalTau correlation of ranking: KendalltauResult(correlation=0.41827816381571176, pvalue=2.534535252836704e-06)

# %%
df = pd.DataFrame(correlations).T

# %%
df
# Out:
#                        Kendall Tau Correlation  Kendall Tau p-value  \
# Canon PowerShot SD500                 0.418278             0.000003
# Canon S100                            0.326055             0.000021
# Diaper Champ                          0.332129             0.000188
# Hitachi router                        0.267839             0.000645
# Linksys Router                        0.318963             0.000045
# MicroMP3                              0.266101             0.000353
# Nokia 6600                            0.335701             0.000008
# ipod                                  0.178308             0.021208
# norton                                0.281230             0.000206
#
#                        Spearman Correlation  Spearman p-value
# Canon PowerShot SD500              0.518047          0.000002
# Canon S100                         0.429714          0.000008
# Diaper Champ                       0.427039          0.000107
# Hitachi router                     0.338667          0.000738
# Linksys Router                     0.414434          0.000033
# MicroMP3                           0.359604          0.000238
# Nokia 6600                         0.437826          0.000005
# ipod                               0.227619          0.027358
# norton                             0.370444          0.000148

# %%
# top 10
df.plot(kind='bar', y=['Spearman Correlation', 'Kendall Tau Correlation'])
plt.title('Spearman and Kendall Tau Correlations for Bing Liu datasets \n'
          'manually extracted aspects vs RST + pagerank-based rankings')
# Out:
# Text(0.5,1,'Spearman and Kendall Tau Correlations for Bing Liu datasets \nmanually extracted aspects vs RST + pagerank-based rankings')

# %%
df.plot(kind='bar', y=['Spearman p-value', 'Kendall Tau p-value'])
plt.title('Spearman and Kendall Tau Correlations [p-value] for Bing Liu datasets \n'
          'manually extracted aspects vs RST + pagerank-based rankings')
# Out:
# Text(0.5,1,'Spearman and Kendall Tau Correlations [p-value] for Bing Liu datasets \nmanually extracted aspects vs RST + pagerank-based rankings')

# %%
from aspects.analysis.statistics_rst_graphs import get_aspect_ranking_based_on_rst_and_pagerank, ASPECTS_GRAPH_PATHS

# %%
all_aspects = []
all_texts_labels = []
for aspect_graph_path in ASPECTS_GRAPH_PATHS:
    dataset_name = Path(aspect_graph_path).parent.name
    print(dataset_name)
    aspects = get_aspect_ranking_based_on_rst_and_pagerank(aspect_graph_path, 50)
    all_aspects += aspects
    all_texts_labels += [dataset_name for _ in aspects]
# Out:
# ipod
# Diaper Champ
# norton
# Linksys Router
# MicroMP3
# Canon S100
# Canon PowerShot SD500
# Nokia 6600
# Hitachi router

# %%
from embedisualization.embedisualization import Embedisualisation
emb = Embedisualisation(texts=all_aspects, text_labels=all_texts_labels, num_clusters=5)
emb.create_d3_visualisation()
# Out:
# 100%|██████████| 450/450 [00:00<00:00, 12563.82it/s]
# Note: if you're in the IPython notebook, mpld3.show() is not the best command
#       to use. Consider using mpld3.display(), or mpld3.enable_notebook().
#       See more information at http://mpld3.github.io/quickstart.html .
#
# You must interrupt the kernel to end this command
#
# Serving to http://127.0.0.1:8889/    [Ctrl-C to exit]
# 127.0.0.1 - - [16/May/2018 14:29:39] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [16/May/2018 14:29:40] "GET /d3.js HTTP/1.1" 200 -
# 127.0.0.1 - - [16/May/2018 14:29:41] "GET /mpld3.js HTTP/1.1" 200 -
# 127.0.0.1 - - [16/May/2018 14:29:41] code 404, message Not Found
# 127.0.0.1 - - [16/May/2018 14:29:41] "GET /favicon.ico HTTP/1.1" 404 -

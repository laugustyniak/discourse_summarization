# %%
from pathlib import Path
import sys
sys.path.append("../..") # go to parent dir

import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
from aspects.analysis.aspect_ranking_correlation import get_spearman_and_kendalltau_correlations

# %%
correlations = get_spearman_and_kendalltau_correlations(100)
# Out:
# Dataset to analyze: MicroMP3
# ['player', 'sound', 'look', 'size', 'storage', 'touchpad', 'features', 'software', 'battery life', 'sound quality', 'design', 'interface', 'headphones', 'zen micro', 'battery', 'fm reception', 'accessories', 'price', 'working', 'earbuds', 'fm tuner', 'navigation', 'functioning', 'firmware', 'case', 'touch pad', 'construction', 'headphone jack', 'audio quality', 'bass', 'feel', 'zen', 'quality', 'stand', 'bag', 'ease of use', 'microphone', 'extra features', 'file transfer', 'durability', 'organization', 'transfer speed', 'belt clip', 'format', 'installation', 'looks', 'support', 'creative', 'screen review', 'portability', 'compatibility', 'color', 'battery usage', 'fm receiver', 'touchpad controls', 'user interface', 'controls', 'feature', 'small', 'comfort', 'back', 'touch-pad', 'functionality', 'charging', 'built', 'scroll bar', 'cost', 'radio', 'instruction', 'extra battery', 'manual', 'power', 'tiny', 'read', 'wma files', 'space', 'converter', 'navigate', 'variety of colours', 'backlight', 'file transfer speed', 'off', 'subscription wma', 'charged', 'batterylife', 'file transfers', 'sync to windows media player', 'wav format', 'volume ', 'ease of usage', 'constructed', 'menu', 'creative zen', 'trnasfer', 'speed', 'access', 'storage ', 'warranty', 'zen touch', 'audio']
# [1, 112, 313, 292, 363, 22, 547, 34, 55, 32, 97, 43, 547, 29, 30, 547, 547, 206, 547, 281, 547, 547, 547, 10, 263, 255, 547, 547, 547, 547, 547, 416, 40, 375, 157, 547, 158, 547, 547, 264, 345, 547, 547, 66, 19, 547, 189, 36, 547, 547, 479, 547, 547, 547, 547, 136, 547, 23, 547, 547, 547, 547, 547, 547, 547, 547, 547, 196, 294, 547, 166, 387, 504, 547, 547, 197, 547, 547, 547, 547, 547, 547, 547, 547, 547, 547, 547, 547, 547, 547, 547, 79, 547, 547, 547, 547, 547, 374, 547, 133]
# MicroMP3, Spearman correlation of ranking: SpearmanrResult(correlation=0.4143837942356985, pvalue=1.818616324749153e-05)
# MicroMP3, KendalTau correlation of ranking: KendalltauResult(correlation=0.30843161230798866, pvalue=3.60818168137072e-05)
# Dataset to analyze: Canon S100
# ['camera', 'size', 'pictures', 'small', 'software', 'battery', 'use', 'ease of use', 's100', 'zoom', 'flash', 'price', 'picture', 'buttons', 'memory', 'compact', 'light', 'mode', 'body', 'features', 'lcd', 'exposure', 'fits', 'work', 'snapshots', 'housing', 'auto mode', 'cameras', 'looks', 'macro mode', 'hot', 'focus', 'product', 'picture quality', 'panorama mode', 'start-up', 'auto color balance', 'casing', 'capacity', 'memory expansion', 'automatic modes', 'smallest', 'lens', 'tft screen', 'macro', 'wait', 'sharp', 'color balance', 'autofocus', 'room', 'canon s100', 'jewel', 'bundled software', 'pictures of people', 'dynamic range', 'manual mode', 'processing', 'prints', 'case', 'screen', 'movie mode', 'images', 'drivers', 'color and light', 'pics', 'download', 'manual modes', 'design', 'usability', 'panorama setting', 'tft', 'color rendering', 'expandability', 'on-camera controls', 'smaller', 'performance', 'smal', 'purchase', 'performs', 'read', 'rugged', 'metal case', 'image quality', 'best-built', 'picture detail', 'weighs', 'detail', 'cap', 'durable', 'delay', 'fun', 'elph s100', 'functionality', 'zoom range', 'optical zoom', 'resolution setting', 'covering', 'photos', 'auto-focus', 'panorama modes']
# [1, 57, 196, 196, 33, 14, 115, 196, 34, 196, 133, 113, 3, 196, 161, 27, 76, 5, 22, 196, 148, 11, 196, 26, 196, 89, 9, 196, 196, 196, 196, 53, 196, 68, 196, 196, 196, 196, 196, 43, 196, 196, 67, 196, 196, 196, 196, 196, 196, 92, 196, 196, 196, 196, 196, 196, 196, 196, 45, 194, 196, 196, 196, 196, 196, 196, 196, 31, 196, 196, 193, 196, 196, 196, 196, 196, 196, 196, 196, 196, 196, 196, 196, 196, 196, 196, 196, 72, 196, 196, 196, 138, 196, 196, 196, 196, 196, 196, 196, 196]
# Canon S100, Spearman correlation of ranking: SpearmanrResult(correlation=0.48472520459782437, pvalue=3.2146054986355364e-07)
# Canon S100, KendalTau correlation of ranking: KendalltauResult(correlation=0.37009320412324587, pvalue=1.403577671596677e-06)
# Dataset to analyze: norton
# ['product', 'support', 'norton', 'installation', 'install', 'antivirus', 'symantec', 'performance', 'firewall', 'uninstall', 'internet security', 'liveupdate', 'program', 'tech', 'corporate edition', 'upgrade', 'memory usage', 'speed', 'products', 'anti-spam', 'home version', 'components', 'update', 'alerts', 'version 2004', 'nis 2004', 'slow', 'intrusion', 'charge', 'blocking', 'help', 'work', 'remove', 'installed', 'installing', 'cost', 'updates', 'priority id', 'booting', 'spam killer', 'symantec customer service', 'systemworks', 'scandisk', 'size', '2004 edition', 'popups', 'features', 'antivirus software', 'network', 'norton internet/av 2004', 'activation process', 'functions', 'home network', 'parental control', 'refund', 'processor', 'spam', 'nis ', 'popup blocker', '2004', 'faster', 'norton internet security', 'nstalling', 'menu', 'manual shutdown', 'antispam function', 'nis', 'email spam', 'capacity', 'norton program', 'zone alarm', 'tech line', 'mcafee anti-virus 8', 'uninstallation', 'options', 'working', 'parental controls', 'symantec softwares ', 'removal program', 'operation interfaces', 'fragments', 'download', 'suite', 'service', 'installs', 'norton products', 'norton antispam', 'nis 2003', 'function', 'product ', 'professional version', 'symantec/norton site', 'computer associates ez', 'semantic', 'set-up', 'boot', 'software', 'instruction', 'scanning', 'scan']
# [1, 27, 3, 4, 287, 246, 12, 305, 113, 70, 20, 83, 13, 206, 305, 100, 305, 305, 305, 305, 52, 305, 233, 305, 305, 305, 305, 232, 305, 305, 305, 42, 305, 305, 305, 195, 305, 305, 305, 305, 305, 154, 130, 305, 305, 305, 305, 305, 305, 305, 305, 305, 305, 305, 305, 209, 262, 305, 305, 305, 305, 123, 305, 305, 305, 138, 34, 305, 305, 305, 305, 305, 305, 305, 305, 305, 305, 305, 305, 305, 305, 305, 104, 305, 305, 305, 305, 305, 251, 305, 305, 305, 305, 305, 305, 305, 168, 193, 305, 305]
# norton, Spearman correlation of ranking: SpearmanrResult(correlation=0.4190543336184527, pvalue=1.4291904893489144e-05)
# norton, KendalTau correlation of ranking: KendalltauResult(correlation=0.3232316695050469, pvalue=2.513167215863168e-05)
# Dataset to analyze: Diaper Champ
# ['diaper champ', 'odor', 'champ', 'diaper pail', 'use', 'product', 'refills', 'works', 'diapers', 'smell', 'pail', 'diaper', 'odors', 'garbage bags', 'open', 'clean', 'change', 'holds', 'size', 'bags', 'work', 'item', 'diaper genie', 'trash bags', 'fit', 'wipes', 'opening', 'unit', 'empty', 'space', 'diaper wipes', 'dispose', 'price', 'smelling', 'replacement', 'cost effective', 'hole', 'operated', 'filp', 'unload', 'operate', 'stable', 'container', 'assemble', 'deal', 'height', 'semelled', 'plunger', 'pail.', 'safer', 'seal', 'top loader', 'investment', 'oderous', 'bargins', 'emptying', 'smells', 'convenient', 'ease of use', 'function', 'pull', 'purchases', 'gift', 'fill', 'noise', 'trash bag', 'diaper dekor', 'bag', 'store bags', 'install', 'worked', 'capacity', 'effective', 'stinky', 'costly', 'pluger', 'other pail']
# [11, 38, 5, 6, 142, 76, 160, 160, 160, 13, 24, 1, 160, 160, 160, 160, 160, 160, 160, 160, 160, 57, 74, 160, 160, 160, 160, 56, 160, 160, 160, 87, 160, 160, 40, 160, 160, 160, 160, 160, 160, 160, 160, 160, 49, 160, 160, 48, 160, 160, 160, 160, 160, 120, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 160, 16, 160, 4, 160, 160, 160, 160, 160, 160, 160, 160, 160]
# Diaper Champ, Spearman correlation of ranking: SpearmanrResult(correlation=0.3626487881446781, pvalue=0.0011899649340815482)
# Diaper Champ, KendalTau correlation of ranking: KendalltauResult(correlation=0.28445985329856777, pvalue=0.0013834475873851124)
# Dataset to analyze: Hitachi router
# ['router', 'price', 'power', 'adjustment', 'control', 'speed', 'use', 'heavy', 'plunge', 'money', 'collet', 'plunging', 'start', 'machine', 'guide', 'stable', 'wrench', 'safety', 'runs', 'weight', 'vibration', 'springs', 'quiet', 'stability', 'cheap', 'hitachi', 'shafts', 'controls', 'bog', 'cuts', 'collets', 'starts', 'chuck', 'fence', 'depth', 'spring', 'powerful', 'sawdust', 'tool', 'm12v', 'affordable', 'smooth', 'product', 'quite', 'last', 'solidity', 'setup', 'simple', 'adjustments', 'hitachi m12v', 'spindle', 'noise', 'operation', 'latch', 'operate', 'fit', 'result', 'router razier', 'big', 'balance', 'grip', 'performer', 'pretty', 'features', 'lock', 'duration', 'finish', 'adustment knob', 'motor', 'm12', 'accessible', 'works', 'nimble', 'costs', 'slop', 'heft', 'bigger', 'equipment', 'performed', 'heavier', 'worth', 'shaft', 'instructions', 'used', 'lighter', 'track record', 'workload', 'looked', 'depths', 'precise', 'performance', 'switch', 'speeds', 'adjust', 'visibility', 'system']
# [1, 47, 3, 184, 184, 30, 16, 91, 184, 32, 118, 184, 66, 93, 174, 184, 15, 184, 184, 8, 184, 184, 184, 153, 184, 63, 184, 184, 184, 184, 184, 184, 184, 184, 184, 182, 184, 184, 5, 159, 184, 184, 184, 184, 184, 184, 9, 184, 184, 184, 184, 184, 38, 184, 184, 87, 184, 184, 184, 184, 12, 184, 184, 184, 107, 184, 94, 184, 18, 184, 184, 184, 184, 184, 79, 184, 184, 154, 184, 184, 184, 184, 184, 184, 184, 184, 184, 184, 184, 184, 128, 184, 184, 184, 184, 184]
# Hitachi router, Spearman correlation of ranking: SpearmanrResult(correlation=0.35702285155746744, pvalue=0.0003560185980982117)
# Hitachi router, KendalTau correlation of ranking: KendalltauResult(correlation=0.27899875678430963, pvalue=0.00037927135949488344)
# Dataset to analyze: ipod
# ['ipod', 'battery', 'itunes', 'design', 'use', 'sound', 'apple', 'capacity', 'interface', 'features', 'click wheel', 'hard drive', 'controls', 'usb', 'games', 'sound quality', 'scratches', 'bass', 'service', 'firewire', 'equalizer', 'product', 'versatile', 'screen', 'accessories', 'scratch', 'alternative', 'looks', 'radio tuner', 'treble', 'durable', 'purchase', 'voice recording', 'i-pod', 'play wma', 'fm tuner', 'price', 'charger', 'earphones', 'display', 'reformatted', 'technical service', 'support service', 'connection options', 'quality of audio', 'case', 'compact', 'replaceable battery', 'proprietary', 'i-tunes', 'outside finish', 'photos', 'ear buds', 'photo viewing', 'device', 'sensitive', 'battery life', 'wheel', 'solid feel', 'hold', 'store', 'customer service', 'song quality', 'headphones', 'flip side', 'voice recorder', 'volume', 'sounds', 'arm band', 'using', 'helpline', 'breaks', 'batteries', 'earbuds', 'sturdy', 'photo quality', 'package', 'steel backing', 'amplifier', 'amazon', 'adapter', 'player', 'quality', 'freezes', 'finding', 'overall', 'pay', 'storage space', 'affordable', 'backlighting', 'battery ', 'weight', 'memory stick slots', 'reliability']
# [2, 6, 358, 180, 257, 73, 3, 272, 384, 224, 107, 471, 471, 366, 471, 152, 471, 471, 23, 471, 157, 40, 471, 403, 471, 350, 66, 471, 471, 471, 471, 72, 183, 471, 471, 471, 144, 471, 471, 471, 471, 471, 471, 471, 471, 34, 471, 471, 471, 471, 471, 471, 471, 471, 46, 471, 32, 17, 471, 471, 420, 404, 471, 471, 471, 471, 371, 471, 471, 471, 471, 471, 471, 471, 471, 471, 9, 471, 471, 419, 71, 5, 286, 471, 471, 471, 471, 310, 471, 105, 471, 247, 471, 471]
# ipod, Spearman correlation of ranking: SpearmanrResult(correlation=0.27925143711309636, pvalue=0.006417185835504123)
# ipod, KendalTau correlation of ranking: KendalltauResult(correlation=0.20529772880521488, pvalue=0.007976863834093337)
# Dataset to analyze: Nokia 6600
# ['phone', 'bluetooth', 'camera', 'battery life', '6600', 'screen', 'features', 'interface', 'size', 't-mobile', 'video', 'nokia', 'games', 'slow', 'speaker phone', 'battery', 'rebate', 'reception', 'menu', 'os', 'memory', 'calls', 'keypad', 'look', 'ringtones', 'ringtone', 'applications', 'mmc card', 'speed', 'buttons', 'keys', 'shape', 'picture', 'service', 'voice-dialing system', 'phones', 'use', 'display', 'feature', 'joystick', 'weight', 'n6600', 'construction', 'memory card', 'pda', 'big', 'quality', 'photos', 'menus', 'joy stick', 'volume', 'build', 'phone card calling', 'isync compaibility', 'movies', 'handsfree', 'camera quality', 'video recorder', 'gprs', 'internet', 't-mobile service', 'signal', 'bulky', 'small', 'pictures', 'audio quality', 'web browser', 'video recording', 'game', 'carrier', 'music', 'ear volume', 't610', 'time', 'mhz', 'upgradibility', 'priced', 'call logs', 'mmc', 'application', 'processor', 'customer care', 'dependability', 'color', 'multimedia', 'lcd', 'sound', 'versatility', 'load time', 'transfer', 'att', 'back cover', 'operation', 'color tft display', 'freespeak', 'feels', 'quest wireless', 'sony ericsson t610', 'wide', 'screens']
# [1, 17, 11, 367, 66, 72, 367, 52, 53, 367, 112, 3, 367, 367, 367, 227, 367, 366, 172, 86, 114, 367, 90, 367, 367, 251, 367, 367, 119, 367, 367, 31, 267, 32, 367, 367, 21, 29, 2, 358, 367, 367, 367, 38, 59, 367, 54, 367, 367, 367, 367, 367, 367, 367, 367, 367, 51, 188, 57, 292, 367, 367, 367, 367, 367, 367, 367, 367, 152, 166, 367, 367, 367, 367, 367, 367, 367, 367, 113, 143, 367, 281, 367, 28, 137, 367, 84, 367, 367, 367, 320, 367, 22, 367, 367, 367, 367, 367, 367, 367]
# Nokia 6600, Spearman correlation of ranking: SpearmanrResult(correlation=0.31632104059005756, pvalue=0.0013450615891752895)
# Nokia 6600, KendalTau correlation of ranking: KendalltauResult(correlation=0.23800431297936292, pvalue=0.0014330557370371363)
# Dataset to analyze: Linksys Router
# ['router', 'setup', 'works', 'installation', 'cd', 'speed', 'connection', 'product', 'security', 'wizard', 'documentation', 'set up', 'instructions', 'linksys', 'support', 'install', 'signal', 'quality', 'wrt54g', 'working', 'configuration', 'range', 'connectivity', 'design', 'software', 'use', 'connect', 'firmware update', 'access', 'performance', 'reliable', 'firmware', 'features', 'tech support', 'customer support', 'wpa encryption', 'pipeline', 'running', 'work', 'signal quality', 'junk', 'speeds', 'coverage', 'multipurpose', 'desktops', 'desktop card', 'antenna', 'setting up', 'upnp', 'manual', 'copy large files', 'model', 'setting', 'user manual', 'dhcp', 'transmission speed', 'backward compatible', 'configuration options', 'slow', 'priced', 'logging', 'stream', 'tivo', 'well-priced', 'feature', 'customer service', 'backward', 'instruction', 'instant setup', 'setup software', 'broadband', '1-800', 'products', 'cheapest', 'technical support', 'voip', 'compatibility', 'web site', 'user guide', 'hardware version', 'costlier', 'cheap', 'broadcom hardware', 'configuration menu', 'disconnecting', 'wep encryption', 'signals', 'equipment', 'look', 'enterprise piece', 'signal strength', 'satellite', 'anteanna', 'reliability']
# [1, 5, 345, 144, 22, 25, 62, 4, 38, 72, 59, 345, 345, 2, 55, 246, 345, 345, 345, 345, 11, 111, 345, 345, 58, 265, 345, 343, 345, 16, 345, 275, 345, 345, 26, 345, 345, 345, 315, 345, 345, 345, 90, 345, 345, 345, 345, 345, 215, 165, 345, 345, 7, 345, 210, 345, 345, 345, 345, 345, 345, 345, 345, 345, 84, 169, 345, 71, 345, 345, 345, 345, 345, 345, 345, 345, 345, 297, 345, 345, 345, 345, 345, 345, 345, 345, 345, 345, 345, 123, 345, 232, 345, 345]
# Linksys Router, Spearman correlation of ranking: SpearmanrResult(correlation=0.45972270091189316, pvalue=3.143072108131764e-06)
# Linksys Router, KendalTau correlation of ranking: KendalltauResult(correlation=0.3537700551760995, pvalue=6.06122004407541e-06)
# Dataset to analyze: Canon PowerShot SD500
# ['camera', 'lcd', 'pictures', 'image', 'sd500', 'flash', 'size', 'picture', 'pics', 'quality', 'fits', 'zoom', 'battery', 'software', 'buttons', 'user interface', 'photo', 'powerup', 'canon', 'compact', 'video', 'design', 'autofocus', 'multiple picture', 'manual control', 'small', 'macros-results', 'feels', 'fast', 'settings', 'sound', 'movie mode', 'powers up', 'start up', 'image-processing system', 'white balance', 'digic ii chip', 'camera shake', 'designed', 'pricey', 'multiple pictures', 'build', 'focus', 'manual', 'sony', 'video-quality', 'user definable', 'weight', 'merge pictures', 'automatic settings', 'low-light conditions', '640x480 mode', 'advanced controls', 'clips', 'features', 'view finder', 'made', 'power button', 'instruction', 'documentatio', 'automatic shutter', 'color', 'colors', 'preset', 'responce', 'controls', 'audio', 'prints', 'edges', 'looks', 'looking', 'manual controls', 'focuses', 'starts up', 'switch', 'battery charger']
# [1, 64, 177, 27, 4, 68, 55, 5, 177, 98, 177, 136, 146, 177, 177, 177, 84, 82, 28, 148, 50, 177, 105, 177, 177, 177, 177, 177, 177, 177, 37, 177, 177, 177, 177, 177, 177, 177, 177, 177, 177, 177, 177, 137, 177, 177, 177, 177, 177, 177, 177, 177, 177, 177, 177, 94, 177, 177, 177, 177, 177, 165, 177, 177, 177, 177, 177, 177, 177, 177, 152, 177, 177, 177, 177, 177]
# Canon PowerShot SD500, Spearman correlation of ranking: SpearmanrResult(correlation=0.5265473072694986, pvalue=1.0306524959987728e-06)
# Canon PowerShot SD500, KendalTau correlation of ranking: KendalltauResult(correlation=0.4132081254664304, pvalue=3.3468617285860788e-06)

# %%
df = pd.DataFrame(correlations).T

# %%
df
# Out:
#                        Kendall Tau Correlation  Kendall Tau p-value  \
# Canon PowerShot SD500                 0.413208             0.000003
# Canon S100                            0.370093             0.000001
# Diaper Champ                          0.284460             0.001383
# Hitachi router                        0.278999             0.000379
# Linksys Router                        0.353770             0.000006
# MicroMP3                              0.308432             0.000036
# Nokia 6600                            0.238004             0.001433
# ipod                                  0.205298             0.007977
# norton                                0.323232             0.000025
#
#                        Spearman Correlation  Spearman p-value
# Canon PowerShot SD500              0.526547      1.030652e-06
# Canon S100                         0.484725      3.214605e-07
# Diaper Champ                       0.362649      1.189965e-03
# Hitachi router                     0.357023      3.560186e-04
# Linksys Router                     0.459723      3.143072e-06
# MicroMP3                           0.414384      1.818616e-05
# Nokia 6600                         0.316321      1.345062e-03
# ipod                               0.279251      6.417186e-03
# norton                             0.419054      1.429190e-05

# %%
# top 10
df.plot(kind='bar', y=['Spearman Correlation', 'Kendall Tau Correlation'])
plt.title('Spearman and Kendall Tau Correlations for Bing Liu datasets \n'
          'manually extracted aspects vs RST + pagerank-based rankings')
# Out:
# Text(0.5,1,'Spearman and Kendall Tau Correlations for Bing Liu datasets \nmanually extracted aspects vs RST + pagerank-based rankings')

# %%
df.plot(kind='bar', y=['Spearman p-value', 'Kendall Tau p-value'])
plt.title('Spearman and Kendall Tau Correlations [p-value] for Bing Liu datasets \n'
          'manually extracted aspects vs RST + pagerank-based rankings')
# Out:
# Text(0.5,1,'Spearman and Kendall Tau Correlations [p-value] for Bing Liu datasets \nmanually extracted aspects vs RST + pagerank-based rankings')

# %%
from aspects.analysis.statistics_rst_graphs import get_aspect_ranking_based_on_rst_and_pagerank, ASPECTS_GRAPH_PATHS

# %%
all_aspects = []
all_texts_labels = []
for aspect_graph_path in ASPECTS_GRAPH_PATHS:
    dataset_name = Path(aspect_graph_path).parent.name
    print(dataset_name)
    aspects = get_aspect_ranking_based_on_rst_and_pagerank(aspect_graph_path, 50)
    all_aspects += aspects
    all_texts_labels += [dataset_name for _ in aspects]
# Out:
# ipod
# Diaper Champ
# norton
# Linksys Router
# MicroMP3
# Canon S100
# Canon PowerShot SD500
# Nokia 6600
# Hitachi router

# %%
from embedisualization.embedisualization import Embedisualisation
emb = Embedisualisation(texts=all_aspects, text_labels=all_texts_labels, num_clusters=5)
emb.create_d3_visualisation()
# Out:
# 100%|██████████| 450/450 [00:00<00:00, 9943.61it/s]
# Note: if you're in the IPython notebook, mpld3.show() is not the best command
#       to use. Consider using mpld3.display(), or mpld3.enable_notebook().
#       See more information at http://mpld3.github.io/quickstart.html .
#
# You must interrupt the kernel to end this command
#
# Serving to http://127.0.0.1:8889/    [Ctrl-C to exit]
# 127.0.0.1 - - [11/May/2018 02:42:37] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [11/May/2018 02:42:38] "GET /d3.js HTTP/1.1" 200 -
# 127.0.0.1 - - [11/May/2018 02:42:39] "GET /mpld3.js HTTP/1.1" 200 -
